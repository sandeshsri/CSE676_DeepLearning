# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Dropout
from keras.optimizers import Adam, SGD
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 100
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout.h5"
# path_best = "../weights/VGGNet16_SGD_Dropout.h5"
path_train = "gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar100.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def create_VGG16Model():
    model = Sequential()
    
    model.add(Conv2D(input_shape=(32,32,3), filters=64, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

    model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
    model.add(Dropout(0.5))

    model.add(Flatten())

    model.add(Dense(4096))
    model.add(Activation('relu'))

    model.add(Dense(4096))
    model.add(Activation('relu'))

    model.add(Dense(NUMBER_OF_CLASSES))
    model.add(Activation('softmax'))
    return model

# %%
model = create_VGG16Model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_8 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_10 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_11 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_12 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# activation_13 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_14 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               409700
# _________________________________________________________________
# activation_15 (Activation)   (None, 100)               0
# =================================================================
# Total params: 34,006,948
# Trainable params: 34,006,948
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint, early],verbose=2)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0183s vs `on_train_batch_end` time: 0.0295s). Check your callbacks.
#
# Epoch 00001: val_accuracy improved from -inf to 0.01070, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 38s - loss: 4.6058 - accuracy: 0.0089 - val_loss: 4.6050 - val_accuracy: 0.0107
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.01070 to 0.01450, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 35s - loss: 4.6022 - accuracy: 0.0105 - val_loss: 4.5749 - val_accuracy: 0.0145
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.01450 to 0.03230, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 35s - loss: 4.4961 - accuracy: 0.0226 - val_loss: 4.3931 - val_accuracy: 0.0323
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.03230 to 0.04210, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 35s - loss: 4.2954 - accuracy: 0.0357 - val_loss: 4.2005 - val_accuracy: 0.0421
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.04210 to 0.06710, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 35s - loss: 4.0815 - accuracy: 0.0538 - val_loss: 3.9448 - val_accuracy: 0.0671
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.06710 to 0.09390, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 3.9008 - accuracy: 0.0757 - val_loss: 3.7939 - val_accuracy: 0.0939
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.09390 to 0.10790, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 3.7736 - accuracy: 0.0942 - val_loss: 3.6732 - val_accuracy: 0.1079
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.10790 to 0.12170, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 3.6326 - accuracy: 0.1132 - val_loss: 3.5725 - val_accuracy: 0.1217
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.12170 to 0.15220, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 3.4647 - accuracy: 0.1416 - val_loss: 3.5066 - val_accuracy: 0.1522
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.15220 to 0.20710, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 3.2717 - accuracy: 0.1773 - val_loss: 3.1206 - val_accuracy: 0.2071
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.20710 to 0.22880, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 3.0767 - accuracy: 0.2131 - val_loss: 3.0330 - val_accuracy: 0.2288
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.22880 to 0.29130, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 2.8984 - accuracy: 0.2506 - val_loss: 2.7138 - val_accuracy: 0.2913
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.29130 to 0.30980, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 2.7366 - accuracy: 0.2844 - val_loss: 2.6441 - val_accuracy: 0.3098
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.30980 to 0.34650, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 2.5928 - accuracy: 0.3159 - val_loss: 2.4601 - val_accuracy: 0.3465
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.34650 to 0.37220, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 2.4528 - accuracy: 0.3464 - val_loss: 2.3346 - val_accuracy: 0.3722
# Epoch 16/200
#
# Epoch 00016: val_accuracy improved from 0.37220 to 0.41150, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 2.3259 - accuracy: 0.3769 - val_loss: 2.1967 - val_accuracy: 0.4115
# Epoch 17/200
#
# Epoch 00017: val_accuracy did not improve from 0.41150
# 500/500 - 32s - loss: 2.2079 - accuracy: 0.4010 - val_loss: 2.3281 - val_accuracy: 0.3885
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.41150 to 0.43310, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 2.0994 - accuracy: 0.4299 - val_loss: 2.1820 - val_accuracy: 0.4331
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.43310 to 0.44160, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 2.0161 - accuracy: 0.4514 - val_loss: 2.1405 - val_accuracy: 0.4416
# Epoch 20/200
#
# Epoch 00020: val_accuracy improved from 0.44160 to 0.45770, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.9357 - accuracy: 0.4710 - val_loss: 2.0418 - val_accuracy: 0.4577
# Epoch 21/200
#
# Epoch 00021: val_accuracy improved from 0.45770 to 0.48000, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.8490 - accuracy: 0.4926 - val_loss: 1.9873 - val_accuracy: 0.4800
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.48000 to 0.48990, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.7854 - accuracy: 0.5088 - val_loss: 1.9668 - val_accuracy: 0.4899
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.48990 to 0.50550, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.7194 - accuracy: 0.5272 - val_loss: 1.8906 - val_accuracy: 0.5055
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.50550
# 500/500 - 32s - loss: 1.6609 - accuracy: 0.5421 - val_loss: 2.0304 - val_accuracy: 0.4920
# Epoch 25/200
#
# Epoch 00025: val_accuracy did not improve from 0.50550
# 500/500 - 31s - loss: 1.6082 - accuracy: 0.5571 - val_loss: 1.9376 - val_accuracy: 0.4997
# Epoch 26/200
#
# Epoch 00026: val_accuracy improved from 0.50550 to 0.52410, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 1.5476 - accuracy: 0.5713 - val_loss: 1.8459 - val_accuracy: 0.5241
# Epoch 27/200
#
# Epoch 00027: val_accuracy improved from 0.52410 to 0.52980, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.4948 - accuracy: 0.5845 - val_loss: 1.8752 - val_accuracy: 0.5298
# Epoch 28/200
#
# Epoch 00028: val_accuracy improved from 0.52980 to 0.53020, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.4402 - accuracy: 0.5992 - val_loss: 1.8345 - val_accuracy: 0.5302
# Epoch 29/200
#
# Epoch 00029: val_accuracy improved from 0.53020 to 0.54230, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 1.3957 - accuracy: 0.6128 - val_loss: 1.8231 - val_accuracy: 0.5423
# Epoch 30/200
#
# Epoch 00030: val_accuracy did not improve from 0.54230
# 500/500 - 32s - loss: 1.3488 - accuracy: 0.6260 - val_loss: 1.8664 - val_accuracy: 0.5324
# Epoch 31/200
#
# Epoch 00031: val_accuracy improved from 0.54230 to 0.55830, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 1.3188 - accuracy: 0.6297 - val_loss: 1.7986 - val_accuracy: 0.5583
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.55830 to 0.55870, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 1.2709 - accuracy: 0.6421 - val_loss: 1.7752 - val_accuracy: 0.5587
# Epoch 33/200
#
# Epoch 00033: val_accuracy did not improve from 0.55870
# 500/500 - 31s - loss: 1.2380 - accuracy: 0.6530 - val_loss: 1.8223 - val_accuracy: 0.5518
# Epoch 34/200
#
# Epoch 00034: val_accuracy improved from 0.55870 to 0.56880, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 1.1917 - accuracy: 0.6666 - val_loss: 1.7405 - val_accuracy: 0.5688
# Epoch 35/200
#
# Epoch 00035: val_accuracy improved from 0.56880 to 0.56970, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.1680 - accuracy: 0.6711 - val_loss: 1.7365 - val_accuracy: 0.5697
# Epoch 36/200
#
# Epoch 00036: val_accuracy improved from 0.56970 to 0.57560, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.1311 - accuracy: 0.6800 - val_loss: 1.7612 - val_accuracy: 0.5756
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.57560
# 500/500 - 32s - loss: 1.1027 - accuracy: 0.6871 - val_loss: 1.7898 - val_accuracy: 0.5703
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.57560
# 500/500 - 31s - loss: 1.0742 - accuracy: 0.6958 - val_loss: 1.9022 - val_accuracy: 0.5492
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.57560 to 0.57710, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 1.0433 - accuracy: 0.7039 - val_loss: 1.7548 - val_accuracy: 0.5771
# Epoch 40/200
#
# Epoch 00040: val_accuracy did not improve from 0.57710
# 500/500 - 31s - loss: 1.0101 - accuracy: 0.7122 - val_loss: 1.8943 - val_accuracy: 0.5654
# Epoch 41/200
#
# Epoch 00041: val_accuracy improved from 0.57710 to 0.58230, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.9922 - accuracy: 0.7175 - val_loss: 1.7723 - val_accuracy: 0.5823
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.58230
# 500/500 - 32s - loss: 0.9632 - accuracy: 0.7283 - val_loss: 1.8288 - val_accuracy: 0.5744
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.58230
# 500/500 - 31s - loss: 0.9348 - accuracy: 0.7338 - val_loss: 1.8093 - val_accuracy: 0.5751
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.58230
# 500/500 - 31s - loss: 0.9058 - accuracy: 0.7417 - val_loss: 1.8106 - val_accuracy: 0.5752
# Epoch 45/200
#
# Epoch 00045: val_accuracy improved from 0.58230 to 0.59300, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.8893 - accuracy: 0.7459 - val_loss: 1.7290 - val_accuracy: 0.5930
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.59300
# 500/500 - 32s - loss: 0.8602 - accuracy: 0.7534 - val_loss: 1.8287 - val_accuracy: 0.5850
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.59300
# 500/500 - 31s - loss: 0.8526 - accuracy: 0.7565 - val_loss: 1.8002 - val_accuracy: 0.5871
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.59300
# 500/500 - 31s - loss: 0.8268 - accuracy: 0.7624 - val_loss: 1.8257 - val_accuracy: 0.5921
# Epoch 49/200
#
# Epoch 00049: val_accuracy improved from 0.59300 to 0.59540, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.8164 - accuracy: 0.7649 - val_loss: 1.8540 - val_accuracy: 0.5954
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.59540
# 500/500 - 31s - loss: 0.7866 - accuracy: 0.7752 - val_loss: 1.7645 - val_accuracy: 0.5953
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.59540
# 500/500 - 31s - loss: 0.7663 - accuracy: 0.7781 - val_loss: 1.8431 - val_accuracy: 0.5880
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.59540
# 500/500 - 31s - loss: 0.7515 - accuracy: 0.7812 - val_loss: 1.8741 - val_accuracy: 0.5936
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.59540
# 500/500 - 31s - loss: 0.7335 - accuracy: 0.7905 - val_loss: 1.9010 - val_accuracy: 0.5901
# Epoch 54/200
#
# Epoch 00054: val_accuracy improved from 0.59540 to 0.60200, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 32s - loss: 0.7178 - accuracy: 0.7924 - val_loss: 1.8286 - val_accuracy: 0.6020
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.60200
# 500/500 - 31s - loss: 0.6928 - accuracy: 0.7990 - val_loss: 1.9349 - val_accuracy: 0.5873
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.60200
# 500/500 - 31s - loss: 0.6799 - accuracy: 0.8041 - val_loss: 1.8517 - val_accuracy: 0.5996
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.60200
# 500/500 - 31s - loss: 0.6662 - accuracy: 0.8078 - val_loss: 1.8902 - val_accuracy: 0.6012
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.60200
# 500/500 - 31s - loss: 0.6545 - accuracy: 0.8097 - val_loss: 1.9102 - val_accuracy: 0.5872
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.60200
# 500/500 - 31s - loss: 0.6446 - accuracy: 0.8140 - val_loss: 1.8843 - val_accuracy: 0.5992
# Epoch 60/200
#
# Epoch 00060: val_accuracy improved from 0.60200 to 0.60710, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.6243 - accuracy: 0.8197 - val_loss: 1.8964 - val_accuracy: 0.6071
# Epoch 61/200
#
# Epoch 00061: val_accuracy improved from 0.60710 to 0.60810, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 0.6166 - accuracy: 0.8214 - val_loss: 1.9109 - val_accuracy: 0.6081
# Epoch 62/200
#
# Epoch 00062: val_accuracy improved from 0.60810 to 0.60920, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 34s - loss: 0.6055 - accuracy: 0.8252 - val_loss: 1.8360 - val_accuracy: 0.6092
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.60920
# 500/500 - 31s - loss: 0.5921 - accuracy: 0.8298 - val_loss: 1.8854 - val_accuracy: 0.6024
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.60920
# 500/500 - 31s - loss: 0.5793 - accuracy: 0.8322 - val_loss: 1.9916 - val_accuracy: 0.5971
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.60920
# 500/500 - 31s - loss: 0.5610 - accuracy: 0.8383 - val_loss: 1.9371 - val_accuracy: 0.5963
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.60920
# 500/500 - 31s - loss: 0.5505 - accuracy: 0.8427 - val_loss: 1.9216 - val_accuracy: 0.6054
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.60920
# 500/500 - 31s - loss: 0.5355 - accuracy: 0.8463 - val_loss: 2.0070 - val_accuracy: 0.6024
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.60920
# 500/500 - 31s - loss: 0.5341 - accuracy: 0.8471 - val_loss: 1.9388 - val_accuracy: 0.6077
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.60920
# 500/500 - 31s - loss: 0.5181 - accuracy: 0.8521 - val_loss: 1.9205 - val_accuracy: 0.6090
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.60920
# 500/500 - 31s - loss: 0.5229 - accuracy: 0.8499 - val_loss: 1.8612 - val_accuracy: 0.6006
# Epoch 71/200
#
# Epoch 00071: val_accuracy improved from 0.60920 to 0.60980, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 32s - loss: 0.5091 - accuracy: 0.8535 - val_loss: 1.8131 - val_accuracy: 0.6098
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.60980
# 500/500 - 31s - loss: 0.5005 - accuracy: 0.8572 - val_loss: 1.9170 - val_accuracy: 0.6086
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.60980
# 500/500 - 31s - loss: 0.4862 - accuracy: 0.8585 - val_loss: 1.9989 - val_accuracy: 0.5959
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.60980
# 500/500 - 31s - loss: 0.4845 - accuracy: 0.8612 - val_loss: 1.9974 - val_accuracy: 0.5978
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.60980
# 500/500 - 31s - loss: 0.4812 - accuracy: 0.8625 - val_loss: 1.9030 - val_accuracy: 0.6023
# Epoch 76/200
#
# Epoch 00076: val_accuracy improved from 0.60980 to 0.61100, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 32s - loss: 0.4687 - accuracy: 0.8659 - val_loss: 1.8431 - val_accuracy: 0.6110
# Epoch 77/200
#
# Epoch 00077: val_accuracy improved from 0.61100 to 0.61380, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.4667 - accuracy: 0.8670 - val_loss: 1.9180 - val_accuracy: 0.6138
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.61380
# 500/500 - 32s - loss: 0.4534 - accuracy: 0.8716 - val_loss: 1.9785 - val_accuracy: 0.6024
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.61380
# 500/500 - 31s - loss: 0.4422 - accuracy: 0.8747 - val_loss: 1.9207 - val_accuracy: 0.6061
# Epoch 80/200
#
# Epoch 00080: val_accuracy improved from 0.61380 to 0.61520, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 32s - loss: 0.4249 - accuracy: 0.8785 - val_loss: 1.9347 - val_accuracy: 0.6152
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.61520
# 500/500 - 32s - loss: 0.4274 - accuracy: 0.8782 - val_loss: 1.9805 - val_accuracy: 0.5981
# Epoch 82/200
#
# Epoch 00082: val_accuracy improved from 0.61520 to 0.61670, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.4151 - accuracy: 0.8830 - val_loss: 1.9739 - val_accuracy: 0.6167
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.61670
# 500/500 - 32s - loss: 0.4143 - accuracy: 0.8849 - val_loss: 1.9452 - val_accuracy: 0.6089
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.61670
# 500/500 - 32s - loss: 0.4078 - accuracy: 0.8850 - val_loss: 2.0861 - val_accuracy: 0.6086
# Epoch 85/200
#
# Epoch 00085: val_accuracy improved from 0.61670 to 0.61860, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.4078 - accuracy: 0.8861 - val_loss: 1.8392 - val_accuracy: 0.6186
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.61860
# 500/500 - 32s - loss: 0.4138 - accuracy: 0.8829 - val_loss: 1.8865 - val_accuracy: 0.6116
# Epoch 87/200
#
# Epoch 00087: val_accuracy improved from 0.61860 to 0.62400, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.3930 - accuracy: 0.8899 - val_loss: 1.8755 - val_accuracy: 0.6240
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.62400
# 500/500 - 31s - loss: 0.3985 - accuracy: 0.8888 - val_loss: 1.9521 - val_accuracy: 0.6034
# Epoch 89/200
#
# Epoch 00089: val_accuracy improved from 0.62400 to 0.62430, saving model to gdrive/My Drive/Colab Notebooks/VGGNet16_SGD_Dropout_2.h5
# 500/500 - 33s - loss: 0.3856 - accuracy: 0.8927 - val_loss: 1.9585 - val_accuracy: 0.6243
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3837 - accuracy: 0.8936 - val_loss: 2.0375 - val_accuracy: 0.5970
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3849 - accuracy: 0.8930 - val_loss: 2.0166 - val_accuracy: 0.6031
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3716 - accuracy: 0.8964 - val_loss: 2.1715 - val_accuracy: 0.5951
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3663 - accuracy: 0.8975 - val_loss: 1.9911 - val_accuracy: 0.6094
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3739 - accuracy: 0.8975 - val_loss: 1.9764 - val_accuracy: 0.6128
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3683 - accuracy: 0.8992 - val_loss: 2.0663 - val_accuracy: 0.6071
# Epoch 96/200
#
# Epoch 00096: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3673 - accuracy: 0.8980 - val_loss: 1.9735 - val_accuracy: 0.6100
# Epoch 97/200
#
# Epoch 00097: val_accuracy did not improve from 0.62430
# 500/500 - 32s - loss: 0.3615 - accuracy: 0.8995 - val_loss: 2.0814 - val_accuracy: 0.6036
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.62430
# 500/500 - 32s - loss: 0.3547 - accuracy: 0.9030 - val_loss: 1.9969 - val_accuracy: 0.6086
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.62430
# 500/500 - 32s - loss: 0.3511 - accuracy: 0.9023 - val_loss: 1.9668 - val_accuracy: 0.6230
# Epoch 100/200
#
# Epoch 00100: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3451 - accuracy: 0.9054 - val_loss: 1.9832 - val_accuracy: 0.6122
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3381 - accuracy: 0.9083 - val_loss: 2.0117 - val_accuracy: 0.6172
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3539 - accuracy: 0.9028 - val_loss: 2.1651 - val_accuracy: 0.5943
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.62430
# 500/500 - 32s - loss: 0.3499 - accuracy: 0.9049 - val_loss: 2.0707 - val_accuracy: 0.6152
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.62430
# 500/500 - 32s - loss: 0.3438 - accuracy: 0.9061 - val_loss: 2.2273 - val_accuracy: 0.6019
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.62430
# 500/500 - 32s - loss: 0.3314 - accuracy: 0.9103 - val_loss: 2.0733 - val_accuracy: 0.6165
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.62430
# 500/500 - 32s - loss: 0.3464 - accuracy: 0.9065 - val_loss: 2.0232 - val_accuracy: 0.6161
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.62430
# 500/500 - 32s - loss: 0.3505 - accuracy: 0.9075 - val_loss: 1.8911 - val_accuracy: 0.6157
# Epoch 108/200
#
# Epoch 00108: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3270 - accuracy: 0.9128 - val_loss: 1.9489 - val_accuracy: 0.6210
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.62430
# 500/500 - 31s - loss: 0.3262 - accuracy: 0.9118 - val_loss: 2.1374 - val_accuracy: 0.6045
# Epoch 00109: early stopping

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best) 
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.6444911844824157
# Recall:  0.6323
# Accuracy:  0.6323
