# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, \
                    add, AveragePooling2D, BatchNormalization
from keras.optimizers import SGD
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 100
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch.h5"
# path_best = "../weights/Resnet18_SGD_Batch.h5"
path_train = "gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar100.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 11s 0us/step

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def resnetBuilder(l, filters):
    x = l

    l = Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(l)
    l = BatchNormalization()(l)
    l = Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(l)
    l = BatchNormalization()(l)
    
    x = Conv2D(filters=filters, kernel_size=(1,1), padding='same', activation='relu')(x)
    x = add([x,l])
    x = Activation('relu')(x)

    return x

# %%
def createResnetModel():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    l = MaxPool2D(pool_size=(3,3))(l)

    l = resnetBuilder(l, 64)
    l = resnetBuilder(l, 64)
    l = resnetBuilder(l, 128)
    l = resnetBuilder(l, 128)
    l = resnetBuilder(l, 256)
    l = resnetBuilder(l, 256)
    l = resnetBuilder(l, 512)
    l = resnetBuilder(l, 512)

    l = AveragePooling2D(pool_size=(8,8))(l)
    l = Flatten()(l)
    output = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs=input, outputs=output)
    return model

# %%
model = createResnetModel()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 10, 10, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 10, 10, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 10, 10, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 10, 10, 64)   36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 10, 10, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 10, 10, 64)   0           conv2d_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10, 10, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 10, 10, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 10, 10, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 10, 10, 64)   36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 10, 10, 64)   4160        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10, 10, 64)   0           conv2d_6[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 10, 10, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 10, 10, 128)  73856       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 10, 10, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 10, 128)  147584      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 10, 10, 128)  8320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 10, 10, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 10, 10, 128)  0           conv2d_9[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 10, 10, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 10, 10, 128)  147584      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 10, 10, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 10, 10, 128)  147584      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 10, 10, 128)  16512       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 10, 10, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 10, 10, 128)  0           conv2d_12[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 10, 10, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 10, 10, 256)  295168      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 10, 10, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 10, 10, 256)  590080      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 10, 10, 256)  33024       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 10, 10, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 10, 10, 256)  0           conv2d_15[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 10, 10, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 10, 10, 256)  590080      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 10, 10, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 10, 10, 256)  590080      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 10, 10, 256)  65792       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 10, 10, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 10, 10, 256)  0           conv2d_18[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 10, 10, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 10, 10, 512)  1180160     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 10, 10, 512)  2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 10, 10, 512)  2359808     batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 10, 10, 512)  131584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 10, 10, 512)  2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 10, 10, 512)  0           conv2d_21[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 10, 10, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 10, 10, 512)  2359808     activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 10, 10, 512)  2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 10, 10, 512)  2359808     batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 10, 10, 512)  262656      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 10, 10, 512)  2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 10, 10, 512)  0           conv2d_24[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10, 10, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 512)    0           activation_8[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          51300       flatten[0][0]
# ==================================================================================================
# Total params: 11,591,652
# Trainable params: 11,583,972
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint, early],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.12310, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 39s - loss: 3.9881 - accuracy: 0.0853 - val_loss: 3.8932 - val_accuracy: 0.1231
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.12310 to 0.18340, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 3.4017 - accuracy: 0.1779 - val_loss: 3.4020 - val_accuracy: 0.1834
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.18340 to 0.24940, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 3.0735 - accuracy: 0.2420 - val_loss: 3.0811 - val_accuracy: 0.2494
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.24940 to 0.29580, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 2.7990 - accuracy: 0.2969 - val_loss: 2.8463 - val_accuracy: 0.2958
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.29580 to 0.35540, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 2.5529 - accuracy: 0.3466 - val_loss: 2.6194 - val_accuracy: 0.3554
# Epoch 6/200
#
# Epoch 00006: val_accuracy did not improve from 0.35540
# 500/500 - 37s - loss: 2.3344 - accuracy: 0.3942 - val_loss: 2.6472 - val_accuracy: 0.3501
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.35540 to 0.40160, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 2.1619 - accuracy: 0.4324 - val_loss: 2.3659 - val_accuracy: 0.4016
# Epoch 8/200
#
# Epoch 00008: val_accuracy did not improve from 0.40160
# 500/500 - 37s - loss: 2.0128 - accuracy: 0.4645 - val_loss: 2.3974 - val_accuracy: 0.3983
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.40160 to 0.43120, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 1.8846 - accuracy: 0.4944 - val_loss: 2.2221 - val_accuracy: 0.4312
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.43120 to 0.44470, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 1.7720 - accuracy: 0.5176 - val_loss: 2.2465 - val_accuracy: 0.4447
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.44470 to 0.49490, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 1.6823 - accuracy: 0.5407 - val_loss: 1.9591 - val_accuracy: 0.4949
# Epoch 12/200
#
# Epoch 00012: val_accuracy did not improve from 0.49490
# 500/500 - 37s - loss: 1.5850 - accuracy: 0.5652 - val_loss: 2.0590 - val_accuracy: 0.4759
# Epoch 13/200
#
# Epoch 00013: val_accuracy did not improve from 0.49490
# 500/500 - 36s - loss: 1.5060 - accuracy: 0.5826 - val_loss: 2.3595 - val_accuracy: 0.4445
# Epoch 14/200
#
# Epoch 00014: val_accuracy did not improve from 0.49490
# 500/500 - 37s - loss: 1.4209 - accuracy: 0.6026 - val_loss: 2.3916 - val_accuracy: 0.4480
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.49490 to 0.52000, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 1.3445 - accuracy: 0.6224 - val_loss: 1.8750 - val_accuracy: 0.5200
# Epoch 16/200
#
# Epoch 00016: val_accuracy did not improve from 0.52000
# 500/500 - 37s - loss: 1.2708 - accuracy: 0.6395 - val_loss: 2.2104 - val_accuracy: 0.4701
# Epoch 17/200
#
# Epoch 00017: val_accuracy did not improve from 0.52000
# 500/500 - 37s - loss: 1.2071 - accuracy: 0.6558 - val_loss: 2.1909 - val_accuracy: 0.4800
# Epoch 18/200
#
# Epoch 00018: val_accuracy did not improve from 0.52000
# 500/500 - 37s - loss: 1.1235 - accuracy: 0.6752 - val_loss: 2.0691 - val_accuracy: 0.5031
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.52000 to 0.53420, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 1.0508 - accuracy: 0.6958 - val_loss: 1.9480 - val_accuracy: 0.5342
# Epoch 20/200
#
# Epoch 00020: val_accuracy did not improve from 0.53420
# 500/500 - 37s - loss: 0.9852 - accuracy: 0.7126 - val_loss: 2.0479 - val_accuracy: 0.5260
# Epoch 21/200
#
# Epoch 00021: val_accuracy did not improve from 0.53420
# 500/500 - 37s - loss: 0.9253 - accuracy: 0.7265 - val_loss: 2.1361 - val_accuracy: 0.5110
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.53420 to 0.55300, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.8669 - accuracy: 0.7412 - val_loss: 1.9431 - val_accuracy: 0.5530
# Epoch 23/200
#
# Epoch 00023: val_accuracy did not improve from 0.55300
# 500/500 - 36s - loss: 0.8107 - accuracy: 0.7574 - val_loss: 1.9716 - val_accuracy: 0.5510
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.55300
# 500/500 - 37s - loss: 0.7576 - accuracy: 0.7725 - val_loss: 2.0649 - val_accuracy: 0.5390
# Epoch 25/200
#
# Epoch 00025: val_accuracy improved from 0.55300 to 0.55400, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.7256 - accuracy: 0.7778 - val_loss: 2.0570 - val_accuracy: 0.5540
# Epoch 26/200
#
# Epoch 00026: val_accuracy did not improve from 0.55400
# 500/500 - 37s - loss: 0.6707 - accuracy: 0.7958 - val_loss: 2.2245 - val_accuracy: 0.5290
# Epoch 27/200
#
# Epoch 00027: val_accuracy improved from 0.55400 to 0.55450, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.6308 - accuracy: 0.8059 - val_loss: 2.0849 - val_accuracy: 0.5545
# Epoch 28/200
#
# Epoch 00028: val_accuracy did not improve from 0.55450
# 500/500 - 37s - loss: 0.5894 - accuracy: 0.8196 - val_loss: 2.2296 - val_accuracy: 0.5535
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.55450
# 500/500 - 37s - loss: 0.5548 - accuracy: 0.8274 - val_loss: 2.2085 - val_accuracy: 0.5438
# Epoch 30/200
#
# Epoch 00030: val_accuracy did not improve from 0.55450
# 500/500 - 37s - loss: 0.5229 - accuracy: 0.8363 - val_loss: 2.3192 - val_accuracy: 0.5393
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.55450
# 500/500 - 37s - loss: 0.4938 - accuracy: 0.8467 - val_loss: 2.3628 - val_accuracy: 0.5380
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.55450 to 0.55570, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.4604 - accuracy: 0.8534 - val_loss: 2.3375 - val_accuracy: 0.5557
# Epoch 33/200
#
# Epoch 00033: val_accuracy improved from 0.55570 to 0.56330, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.4312 - accuracy: 0.8647 - val_loss: 2.2714 - val_accuracy: 0.5633
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.56330
# 500/500 - 36s - loss: 0.4044 - accuracy: 0.8713 - val_loss: 2.5640 - val_accuracy: 0.5394
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.56330
# 500/500 - 37s - loss: 0.3915 - accuracy: 0.8770 - val_loss: 2.4621 - val_accuracy: 0.5467
# Epoch 36/200
#
# Epoch 00036: val_accuracy did not improve from 0.56330
# 500/500 - 37s - loss: 0.3651 - accuracy: 0.8841 - val_loss: 2.6173 - val_accuracy: 0.5572
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.56330
# 500/500 - 37s - loss: 0.3408 - accuracy: 0.8904 - val_loss: 2.5130 - val_accuracy: 0.5510
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.56330
# 500/500 - 37s - loss: 0.3186 - accuracy: 0.8984 - val_loss: 2.5581 - val_accuracy: 0.5540
# Epoch 39/200
#
# Epoch 00039: val_accuracy did not improve from 0.56330
# 500/500 - 37s - loss: 0.2962 - accuracy: 0.9061 - val_loss: 2.6490 - val_accuracy: 0.5529
# Epoch 40/200
#
# Epoch 00040: val_accuracy did not improve from 0.56330
# 500/500 - 37s - loss: 0.2859 - accuracy: 0.9088 - val_loss: 2.4524 - val_accuracy: 0.5547
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.56330
# 500/500 - 37s - loss: 0.2765 - accuracy: 0.9101 - val_loss: 2.6565 - val_accuracy: 0.5615
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.56330
# 500/500 - 37s - loss: 0.2663 - accuracy: 0.9147 - val_loss: 2.4573 - val_accuracy: 0.5624
# Epoch 43/200
#
# Epoch 00043: val_accuracy improved from 0.56330 to 0.56820, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.2533 - accuracy: 0.9180 - val_loss: 2.6171 - val_accuracy: 0.5682
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.56820
# 500/500 - 37s - loss: 0.2319 - accuracy: 0.9248 - val_loss: 2.5541 - val_accuracy: 0.5622
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.56820
# 500/500 - 37s - loss: 0.2250 - accuracy: 0.9270 - val_loss: 2.9654 - val_accuracy: 0.5416
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.56820
# 500/500 - 37s - loss: 0.2214 - accuracy: 0.9285 - val_loss: 2.6907 - val_accuracy: 0.5610
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.56820
# 500/500 - 37s - loss: 0.2054 - accuracy: 0.9340 - val_loss: 2.6913 - val_accuracy: 0.5663
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.56820
# 500/500 - 37s - loss: 0.1897 - accuracy: 0.9385 - val_loss: 2.6490 - val_accuracy: 0.5650
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.56820
# 500/500 - 37s - loss: 0.1843 - accuracy: 0.9386 - val_loss: 2.8337 - val_accuracy: 0.5614
# Epoch 50/200
#
# Epoch 00050: val_accuracy improved from 0.56820 to 0.57000, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.1748 - accuracy: 0.9426 - val_loss: 2.7094 - val_accuracy: 0.5700
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.57000
# 500/500 - 37s - loss: 0.1682 - accuracy: 0.9464 - val_loss: 2.6161 - val_accuracy: 0.5674
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.57000
# 500/500 - 37s - loss: 0.1652 - accuracy: 0.9457 - val_loss: 2.8787 - val_accuracy: 0.5564
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.57000
# 500/500 - 37s - loss: 0.1616 - accuracy: 0.9480 - val_loss: 3.0140 - val_accuracy: 0.5537
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.57000
# 500/500 - 36s - loss: 0.1528 - accuracy: 0.9508 - val_loss: 2.7777 - val_accuracy: 0.5654
# Epoch 55/200
#
# Epoch 00055: val_accuracy improved from 0.57000 to 0.57400, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.1426 - accuracy: 0.9541 - val_loss: 2.8121 - val_accuracy: 0.5740
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.57400
# 500/500 - 37s - loss: 0.1392 - accuracy: 0.9546 - val_loss: 2.8562 - val_accuracy: 0.5671
# Epoch 57/200
#
# Epoch 00057: val_accuracy improved from 0.57400 to 0.57720, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 39s - loss: 0.1425 - accuracy: 0.9533 - val_loss: 2.7993 - val_accuracy: 0.5772
# Epoch 58/200
#
# Epoch 00058: val_accuracy improved from 0.57720 to 0.58360, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.1299 - accuracy: 0.9582 - val_loss: 2.7736 - val_accuracy: 0.5836
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.1295 - accuracy: 0.9581 - val_loss: 3.0069 - val_accuracy: 0.5668
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.1261 - accuracy: 0.9587 - val_loss: 3.0947 - val_accuracy: 0.5668
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.58360
# 500/500 - 36s - loss: 0.1180 - accuracy: 0.9621 - val_loss: 2.8884 - val_accuracy: 0.5816
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.1186 - accuracy: 0.9617 - val_loss: 2.9598 - val_accuracy: 0.5805
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.1094 - accuracy: 0.9652 - val_loss: 3.2733 - val_accuracy: 0.5454
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.1110 - accuracy: 0.9643 - val_loss: 2.8846 - val_accuracy: 0.5702
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.58360
# 500/500 - 36s - loss: 0.1064 - accuracy: 0.9656 - val_loss: 2.7957 - val_accuracy: 0.5828
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.58360
# 500/500 - 36s - loss: 0.0987 - accuracy: 0.9683 - val_loss: 2.9021 - val_accuracy: 0.5646
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.0935 - accuracy: 0.9706 - val_loss: 3.0497 - val_accuracy: 0.5652
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.0941 - accuracy: 0.9699 - val_loss: 3.1525 - val_accuracy: 0.5571
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.0911 - accuracy: 0.9704 - val_loss: 2.9475 - val_accuracy: 0.5808
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.0873 - accuracy: 0.9716 - val_loss: 2.9812 - val_accuracy: 0.5742
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.58360
# 500/500 - 37s - loss: 0.0877 - accuracy: 0.9708 - val_loss: 3.0316 - val_accuracy: 0.5771
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.58360
# 500/500 - 36s - loss: 0.0797 - accuracy: 0.9745 - val_loss: 3.2136 - val_accuracy: 0.5557
# Epoch 73/200
#
# Epoch 00073: val_accuracy improved from 0.58360 to 0.58880, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_SGD_Batch_2.h5
# 500/500 - 38s - loss: 0.0862 - accuracy: 0.9720 - val_loss: 3.0028 - val_accuracy: 0.5888
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0746 - accuracy: 0.9763 - val_loss: 3.1158 - val_accuracy: 0.5778
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.58880
# 500/500 - 36s - loss: 0.0728 - accuracy: 0.9765 - val_loss: 3.2449 - val_accuracy: 0.5735
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.58880
# 500/500 - 36s - loss: 0.0743 - accuracy: 0.9763 - val_loss: 3.1086 - val_accuracy: 0.5678
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.58880
# 500/500 - 36s - loss: 0.0783 - accuracy: 0.9742 - val_loss: 3.1383 - val_accuracy: 0.5768
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0709 - accuracy: 0.9775 - val_loss: 3.2265 - val_accuracy: 0.5734
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0682 - accuracy: 0.9778 - val_loss: 2.9934 - val_accuracy: 0.5814
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0710 - accuracy: 0.9765 - val_loss: 3.0779 - val_accuracy: 0.5778
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0642 - accuracy: 0.9788 - val_loss: 3.2621 - val_accuracy: 0.5688
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0673 - accuracy: 0.9784 - val_loss: 3.1419 - val_accuracy: 0.5735
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0626 - accuracy: 0.9801 - val_loss: 3.4135 - val_accuracy: 0.5704
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0647 - accuracy: 0.9796 - val_loss: 3.1970 - val_accuracy: 0.5872
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0565 - accuracy: 0.9819 - val_loss: 3.0853 - val_accuracy: 0.5815
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.58880
# 500/500 - 36s - loss: 0.0576 - accuracy: 0.9812 - val_loss: 3.1572 - val_accuracy: 0.5884
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.58880
# 500/500 - 36s - loss: 0.0556 - accuracy: 0.9820 - val_loss: 3.0532 - val_accuracy: 0.5888
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0557 - accuracy: 0.9821 - val_loss: 3.1411 - val_accuracy: 0.5888
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0577 - accuracy: 0.9817 - val_loss: 3.3766 - val_accuracy: 0.5782
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0544 - accuracy: 0.9826 - val_loss: 3.2498 - val_accuracy: 0.5770
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0593 - accuracy: 0.9812 - val_loss: 3.2391 - val_accuracy: 0.5830
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0532 - accuracy: 0.9823 - val_loss: 3.2056 - val_accuracy: 0.5772
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.58880
# 500/500 - 37s - loss: 0.0546 - accuracy: 0.9818 - val_loss: 3.2216 - val_accuracy: 0.5855
# Epoch 00093: early stopping

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best) 
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.6058462152223448
# Recall:  0.598
# Accuracy:  0.598
