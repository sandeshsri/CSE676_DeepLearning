# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adam, SGD
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 100
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch.h5"
# path_best = "../weights/InceptionV2_ADAM_Batch.h5"
path_train = "gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar100.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu')(l_3)
    l_3 = BatchNormalization()(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu')(l_5)
    l_5 = BatchNormalization()(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    l_p = BatchNormalization()(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu')(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = BatchNormalization()(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 64)   9472        input_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 64)   4160        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 192)  110784      conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 7, 7, 192)    0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 192)    768         max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 96)     18528       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 16)     3088        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 7, 7, 192)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 128)    110720      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 32)     12832       conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 32)     6176        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 64)     12352       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, 7, 32)     128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 7, 7, 32)     128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 256)    0           conv2d_45[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_24[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 128)    32896       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 32)     8224        concatenate_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 7, 7, 256)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 128)    32896       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 7, 7, 192)    768         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 7, 7, 96)     384         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 7, 7, 64)     256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 480)    0           conv2d_51[0][0]
#                                                                  batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 4, 4, 480)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 4, 4, 480)    0           max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 208)    832         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 48)     192         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 64)     256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 4, 4, 512)    0           conv2d_57[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_30[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 512)    2048        concatenate_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          51300       global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 1,110,596
# Trainable params: 1,107,460
# Non-trainable params: 3,136
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint, early],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.10990, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 27s - loss: 3.7257 - accuracy: 0.1456 - val_loss: 3.8961 - val_accuracy: 0.1099
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.10990 to 0.26950, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 3.1428 - accuracy: 0.2434 - val_loss: 3.0125 - val_accuracy: 0.2695
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.26950 to 0.27340, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 2.8477 - accuracy: 0.2978 - val_loss: 2.9897 - val_accuracy: 0.2734
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.27340 to 0.33480, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 2.6350 - accuracy: 0.3380 - val_loss: 2.6798 - val_accuracy: 0.3348
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.33480 to 0.35240, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 2.4804 - accuracy: 0.3678 - val_loss: 2.5743 - val_accuracy: 0.3524
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.35240 to 0.36850, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 2.3502 - accuracy: 0.3962 - val_loss: 2.4884 - val_accuracy: 0.3685
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.36850 to 0.37590, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 2.2359 - accuracy: 0.4216 - val_loss: 2.4638 - val_accuracy: 0.3759
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.37590 to 0.41350, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 2.1422 - accuracy: 0.4397 - val_loss: 2.3035 - val_accuracy: 0.4135
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.41350 to 0.42500, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 2.0499 - accuracy: 0.4601 - val_loss: 2.2043 - val_accuracy: 0.4250
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.42500 to 0.43430, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.9793 - accuracy: 0.4754 - val_loss: 2.2127 - val_accuracy: 0.4343
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.43430 to 0.43930, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.9125 - accuracy: 0.4914 - val_loss: 2.1686 - val_accuracy: 0.4393
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.43930 to 0.45160, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.8446 - accuracy: 0.5073 - val_loss: 2.1322 - val_accuracy: 0.4516
# Epoch 13/200
#
# Epoch 00013: val_accuracy did not improve from 0.45160
# 500/500 - 26s - loss: 1.7849 - accuracy: 0.5212 - val_loss: 2.1707 - val_accuracy: 0.4445
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.45160 to 0.45370, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.7381 - accuracy: 0.5316 - val_loss: 2.1430 - val_accuracy: 0.4537
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.45370 to 0.48720, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.6855 - accuracy: 0.5431 - val_loss: 1.9763 - val_accuracy: 0.4872
# Epoch 16/200
#
# Epoch 00016: val_accuracy did not improve from 0.48720
# 500/500 - 26s - loss: 1.6396 - accuracy: 0.5532 - val_loss: 2.1786 - val_accuracy: 0.4521
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.48720 to 0.48940, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.5952 - accuracy: 0.5634 - val_loss: 1.9554 - val_accuracy: 0.4894
# Epoch 18/200
#
# Epoch 00018: val_accuracy did not improve from 0.48940
# 500/500 - 26s - loss: 1.5565 - accuracy: 0.5731 - val_loss: 2.1085 - val_accuracy: 0.4661
# Epoch 19/200
#
# Epoch 00019: val_accuracy did not improve from 0.48940
# 500/500 - 25s - loss: 1.5071 - accuracy: 0.5857 - val_loss: 2.1232 - val_accuracy: 0.4623
# Epoch 20/200
#
# Epoch 00020: val_accuracy improved from 0.48940 to 0.49700, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.4797 - accuracy: 0.5906 - val_loss: 1.9348 - val_accuracy: 0.4970
# Epoch 21/200
#
# Epoch 00021: val_accuracy did not improve from 0.49700
# 500/500 - 25s - loss: 1.4398 - accuracy: 0.6005 - val_loss: 2.0205 - val_accuracy: 0.4833
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.49700 to 0.51240, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.4005 - accuracy: 0.6094 - val_loss: 1.9054 - val_accuracy: 0.5124
# Epoch 23/200
#
# Epoch 00023: val_accuracy did not improve from 0.51240
# 500/500 - 26s - loss: 1.3761 - accuracy: 0.6169 - val_loss: 1.8822 - val_accuracy: 0.5105
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.51240
# 500/500 - 26s - loss: 1.3328 - accuracy: 0.6304 - val_loss: 1.9977 - val_accuracy: 0.4946
# Epoch 25/200
#
# Epoch 00025: val_accuracy did not improve from 0.51240
# 500/500 - 26s - loss: 1.3016 - accuracy: 0.6369 - val_loss: 1.9776 - val_accuracy: 0.4947
# Epoch 26/200
#
# Epoch 00026: val_accuracy did not improve from 0.51240
# 500/500 - 26s - loss: 1.2698 - accuracy: 0.6445 - val_loss: 1.9257 - val_accuracy: 0.5043
# Epoch 27/200
#
# Epoch 00027: val_accuracy did not improve from 0.51240
# 500/500 - 26s - loss: 1.2478 - accuracy: 0.6498 - val_loss: 2.0190 - val_accuracy: 0.4933
# Epoch 28/200
#
# Epoch 00028: val_accuracy did not improve from 0.51240
# 500/500 - 26s - loss: 1.2156 - accuracy: 0.6555 - val_loss: 1.9004 - val_accuracy: 0.5108
# Epoch 29/200
#
# Epoch 00029: val_accuracy improved from 0.51240 to 0.51430, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.1943 - accuracy: 0.6630 - val_loss: 1.9328 - val_accuracy: 0.5143
# Epoch 30/200
#
# Epoch 00030: val_accuracy improved from 0.51430 to 0.51720, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.1637 - accuracy: 0.6712 - val_loss: 1.8723 - val_accuracy: 0.5172
# Epoch 31/200
#
# Epoch 00031: val_accuracy improved from 0.51720 to 0.52070, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.1408 - accuracy: 0.6759 - val_loss: 1.8861 - val_accuracy: 0.5207
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.52070 to 0.52620, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.1205 - accuracy: 0.6817 - val_loss: 1.8286 - val_accuracy: 0.5262
# Epoch 33/200
#
# Epoch 00033: val_accuracy did not improve from 0.52620
# 500/500 - 26s - loss: 1.0883 - accuracy: 0.6904 - val_loss: 1.8731 - val_accuracy: 0.5242
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.52620
# 500/500 - 26s - loss: 1.0694 - accuracy: 0.6943 - val_loss: 1.9011 - val_accuracy: 0.5165
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.52620
# 500/500 - 26s - loss: 1.0387 - accuracy: 0.7034 - val_loss: 1.9320 - val_accuracy: 0.5183
# Epoch 36/200
#
# Epoch 00036: val_accuracy did not improve from 0.52620
# 500/500 - 26s - loss: 1.0247 - accuracy: 0.7043 - val_loss: 1.9129 - val_accuracy: 0.5159
# Epoch 37/200
#
# Epoch 00037: val_accuracy improved from 0.52620 to 0.52770, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 1.0009 - accuracy: 0.7116 - val_loss: 1.8883 - val_accuracy: 0.5277
# Epoch 38/200
#
# Epoch 00038: val_accuracy improved from 0.52770 to 0.53270, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 0.9722 - accuracy: 0.7207 - val_loss: 1.8242 - val_accuracy: 0.5327
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.53270 to 0.53290, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 0.9584 - accuracy: 0.7218 - val_loss: 1.8764 - val_accuracy: 0.5329
# Epoch 40/200
#
# Epoch 00040: val_accuracy did not improve from 0.53290
# 500/500 - 25s - loss: 0.9304 - accuracy: 0.7311 - val_loss: 1.9074 - val_accuracy: 0.5264
# Epoch 41/200
#
# Epoch 00041: val_accuracy improved from 0.53290 to 0.53440, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 0.9147 - accuracy: 0.7358 - val_loss: 1.8642 - val_accuracy: 0.5344
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.53440
# 500/500 - 26s - loss: 0.8967 - accuracy: 0.7406 - val_loss: 1.9280 - val_accuracy: 0.5239
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.53440
# 500/500 - 26s - loss: 0.8781 - accuracy: 0.7436 - val_loss: 1.9280 - val_accuracy: 0.5245
# Epoch 44/200
#
# Epoch 00044: val_accuracy improved from 0.53440 to 0.53500, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 0.8560 - accuracy: 0.7501 - val_loss: 1.9204 - val_accuracy: 0.5350
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.53500
# 500/500 - 26s - loss: 0.8434 - accuracy: 0.7541 - val_loss: 1.8783 - val_accuracy: 0.5342
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.53500
# 500/500 - 25s - loss: 0.8256 - accuracy: 0.7589 - val_loss: 1.8876 - val_accuracy: 0.5345
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.53500
# 500/500 - 25s - loss: 0.8082 - accuracy: 0.7622 - val_loss: 1.9709 - val_accuracy: 0.5278
# Epoch 48/200
#
# Epoch 00048: val_accuracy improved from 0.53500 to 0.53760, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 0.7915 - accuracy: 0.7679 - val_loss: 1.8595 - val_accuracy: 0.5376
# Epoch 49/200
#
# Epoch 00049: val_accuracy improved from 0.53760 to 0.54280, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 0.7755 - accuracy: 0.7720 - val_loss: 1.8741 - val_accuracy: 0.5428
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.7591 - accuracy: 0.7781 - val_loss: 1.9948 - val_accuracy: 0.5157
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.7419 - accuracy: 0.7805 - val_loss: 1.9741 - val_accuracy: 0.5269
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.7324 - accuracy: 0.7812 - val_loss: 1.9296 - val_accuracy: 0.5376
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.7079 - accuracy: 0.7914 - val_loss: 1.9692 - val_accuracy: 0.5218
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.7008 - accuracy: 0.7907 - val_loss: 1.9589 - val_accuracy: 0.5334
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.6811 - accuracy: 0.7971 - val_loss: 1.9441 - val_accuracy: 0.5402
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.54280
# 500/500 - 26s - loss: 0.6718 - accuracy: 0.8007 - val_loss: 1.8960 - val_accuracy: 0.5411
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.6600 - accuracy: 0.8045 - val_loss: 1.9884 - val_accuracy: 0.5321
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.6387 - accuracy: 0.8090 - val_loss: 1.9952 - val_accuracy: 0.5333
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.6385 - accuracy: 0.8105 - val_loss: 1.9489 - val_accuracy: 0.5422
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.54280
# 500/500 - 25s - loss: 0.6192 - accuracy: 0.8163 - val_loss: 2.0269 - val_accuracy: 0.5272
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.54280
# 500/500 - 26s - loss: 0.6009 - accuracy: 0.8212 - val_loss: 2.0413 - val_accuracy: 0.5287
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.54280
# 500/500 - 26s - loss: 0.5979 - accuracy: 0.8207 - val_loss: 1.9951 - val_accuracy: 0.5328
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.54280
# 500/500 - 26s - loss: 0.5809 - accuracy: 0.8261 - val_loss: 2.0410 - val_accuracy: 0.5298
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.54280
# 500/500 - 26s - loss: 0.5638 - accuracy: 0.8320 - val_loss: 2.0918 - val_accuracy: 0.5302
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.54280
# 500/500 - 26s - loss: 0.5660 - accuracy: 0.8308 - val_loss: 2.0109 - val_accuracy: 0.5326
# Epoch 66/200
#
# Epoch 00066: val_accuracy improved from 0.54280 to 0.54620, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 0.5502 - accuracy: 0.8343 - val_loss: 1.9502 - val_accuracy: 0.5462
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.54620
# 500/500 - 26s - loss: 0.5404 - accuracy: 0.8386 - val_loss: 1.9996 - val_accuracy: 0.5425
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.54620
# 500/500 - 26s - loss: 0.5384 - accuracy: 0.8378 - val_loss: 2.0050 - val_accuracy: 0.5423
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.54620
# 500/500 - 26s - loss: 0.5187 - accuracy: 0.8435 - val_loss: 2.0456 - val_accuracy: 0.5432
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.54620
# 500/500 - 25s - loss: 0.5150 - accuracy: 0.8458 - val_loss: 2.0292 - val_accuracy: 0.5433
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.54620
# 500/500 - 25s - loss: 0.5025 - accuracy: 0.8486 - val_loss: 2.1169 - val_accuracy: 0.5278
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.54620
# 500/500 - 25s - loss: 0.4904 - accuracy: 0.8530 - val_loss: 2.0636 - val_accuracy: 0.5351
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.54620
# 500/500 - 26s - loss: 0.4857 - accuracy: 0.8539 - val_loss: 2.0140 - val_accuracy: 0.5437
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.54620
# 500/500 - 26s - loss: 0.4722 - accuracy: 0.8574 - val_loss: 2.0499 - val_accuracy: 0.5405
# Epoch 75/200
#
# Epoch 00075: val_accuracy improved from 0.54620 to 0.55080, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_ADAM_Batch_2.h5
# 500/500 - 26s - loss: 0.4702 - accuracy: 0.8570 - val_loss: 2.0158 - val_accuracy: 0.5508
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.4541 - accuracy: 0.8642 - val_loss: 2.0728 - val_accuracy: 0.5388
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.4470 - accuracy: 0.8661 - val_loss: 2.0824 - val_accuracy: 0.5414
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.4371 - accuracy: 0.8667 - val_loss: 2.0946 - val_accuracy: 0.5427
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.4284 - accuracy: 0.8698 - val_loss: 2.1482 - val_accuracy: 0.5408
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.4269 - accuracy: 0.8705 - val_loss: 2.1994 - val_accuracy: 0.5255
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.4181 - accuracy: 0.8732 - val_loss: 2.1132 - val_accuracy: 0.5400
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.4073 - accuracy: 0.8767 - val_loss: 2.1550 - val_accuracy: 0.5390
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.3996 - accuracy: 0.8788 - val_loss: 2.2273 - val_accuracy: 0.5326
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.3940 - accuracy: 0.8823 - val_loss: 2.0526 - val_accuracy: 0.5506
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.3878 - accuracy: 0.8816 - val_loss: 2.0720 - val_accuracy: 0.5480
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.3880 - accuracy: 0.8823 - val_loss: 2.0880 - val_accuracy: 0.5469
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.3772 - accuracy: 0.8855 - val_loss: 2.2003 - val_accuracy: 0.5382
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.55080
# 500/500 - 25s - loss: 0.3747 - accuracy: 0.8855 - val_loss: 2.1425 - val_accuracy: 0.5466
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.55080
# 500/500 - 25s - loss: 0.3693 - accuracy: 0.8875 - val_loss: 2.1264 - val_accuracy: 0.5451
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.55080
# 500/500 - 25s - loss: 0.3563 - accuracy: 0.8918 - val_loss: 2.2245 - val_accuracy: 0.5393
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.55080
# 500/500 - 25s - loss: 0.3517 - accuracy: 0.8937 - val_loss: 2.1646 - val_accuracy: 0.5423
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.55080
# 500/500 - 25s - loss: 0.3498 - accuracy: 0.8939 - val_loss: 2.1535 - val_accuracy: 0.5456
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.55080
# 500/500 - 25s - loss: 0.3404 - accuracy: 0.8960 - val_loss: 2.1772 - val_accuracy: 0.5504
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.55080
# 500/500 - 25s - loss: 0.3356 - accuracy: 0.8979 - val_loss: 2.3282 - val_accuracy: 0.5284
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.55080
# 500/500 - 26s - loss: 0.3323 - accuracy: 0.8992 - val_loss: 2.2089 - val_accuracy: 0.5403
# Epoch 00095: early stopping

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.5772988803145424
# Recall:  0.5647
# Accuracy:  0.5647
