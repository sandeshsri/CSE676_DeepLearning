# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adam, SGD
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 100
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch.h5"
# path_best = "../weights/InceptionV2_SGD_Batch.h5"
path_train = "gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar100.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu')(l_3)
    l_3 = BatchNormalization()(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu')(l_5)
    l_5 = BatchNormalization()(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    l_p = BatchNormalization()(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu')(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = BatchNormalization()(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 64)   9472        input_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 64)   4160        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 192)  110784      conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 7, 7, 192)    0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 192)    768         max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 96)     18528       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 16)     3088        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 7, 7, 192)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 128)    110720      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 32)     12832       conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 32)     6176        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 64)     12352       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, 7, 32)     128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 7, 7, 32)     128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 256)    0           conv2d_45[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_24[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 128)    32896       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 32)     8224        concatenate_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 7, 7, 256)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 128)    32896       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 7, 7, 192)    768         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 7, 7, 96)     384         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 7, 7, 64)     256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 480)    0           conv2d_51[0][0]
#                                                                  batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 4, 4, 480)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 4, 4, 480)    0           max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 208)    832         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 48)     192         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 64)     256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 4, 4, 512)    0           conv2d_57[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_30[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 512)    2048        concatenate_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          51300       global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 1,110,596
# Trainable params: 1,107,460
# Non-trainable params: 3,136
# __________________________________________________________________________________________________

# %%
sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint, early],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.20360, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 3.5911 - accuracy: 0.1551 - val_loss: 3.3097 - val_accuracy: 0.2036
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.20360 to 0.27970, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 2.9097 - accuracy: 0.2713 - val_loss: 2.9337 - val_accuracy: 0.2797
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.27970 to 0.32120, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 2.5254 - accuracy: 0.3454 - val_loss: 2.7681 - val_accuracy: 0.3212
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.32120 to 0.38160, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 2.2612 - accuracy: 0.4034 - val_loss: 2.4365 - val_accuracy: 0.3816
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.38160 to 0.42650, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 25s - loss: 2.0804 - accuracy: 0.4430 - val_loss: 2.2097 - val_accuracy: 0.4265
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.42650 to 0.44940, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.9126 - accuracy: 0.4825 - val_loss: 2.2087 - val_accuracy: 0.4494
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.44940 to 0.45930, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.7969 - accuracy: 0.5112 - val_loss: 2.1259 - val_accuracy: 0.4593
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.45930 to 0.48720, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.6965 - accuracy: 0.5329 - val_loss: 1.9466 - val_accuracy: 0.4872
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.48720 to 0.50180, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.6088 - accuracy: 0.5516 - val_loss: 1.8858 - val_accuracy: 0.5018
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.50180 to 0.51250, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.5291 - accuracy: 0.5726 - val_loss: 1.8754 - val_accuracy: 0.5125
# Epoch 11/200
#
# Epoch 00011: val_accuracy did not improve from 0.51250
# 500/500 - 23s - loss: 1.4696 - accuracy: 0.5859 - val_loss: 1.9168 - val_accuracy: 0.5112
# Epoch 12/200
#
# Epoch 00012: val_accuracy did not improve from 0.51250
# 500/500 - 23s - loss: 1.4046 - accuracy: 0.6034 - val_loss: 2.0130 - val_accuracy: 0.4928
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.51250 to 0.52460, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.3601 - accuracy: 0.6121 - val_loss: 1.8251 - val_accuracy: 0.5246
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.52460 to 0.54080, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.3023 - accuracy: 0.6257 - val_loss: 1.7686 - val_accuracy: 0.5408
# Epoch 15/200
#
# Epoch 00015: val_accuracy did not improve from 0.54080
# 500/500 - 23s - loss: 1.2525 - accuracy: 0.6391 - val_loss: 1.8423 - val_accuracy: 0.5309
# Epoch 16/200
#
# Epoch 00016: val_accuracy did not improve from 0.54080
# 500/500 - 23s - loss: 1.2149 - accuracy: 0.6482 - val_loss: 1.8374 - val_accuracy: 0.5271
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.54080 to 0.54430, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.1697 - accuracy: 0.6588 - val_loss: 1.7912 - val_accuracy: 0.5443
# Epoch 18/200
#
# Epoch 00018: val_accuracy did not improve from 0.54430
# 500/500 - 24s - loss: 1.1308 - accuracy: 0.6717 - val_loss: 1.9383 - val_accuracy: 0.5256
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.54430 to 0.54690, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.0967 - accuracy: 0.6759 - val_loss: 1.8827 - val_accuracy: 0.5469
# Epoch 20/200
#
# Epoch 00020: val_accuracy improved from 0.54690 to 0.56270, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 1.0774 - accuracy: 0.6823 - val_loss: 1.7713 - val_accuracy: 0.5627
# Epoch 21/200
#
# Epoch 00021: val_accuracy did not improve from 0.56270
# 500/500 - 24s - loss: 1.0330 - accuracy: 0.6927 - val_loss: 1.7204 - val_accuracy: 0.5622
# Epoch 22/200
#
# Epoch 00022: val_accuracy did not improve from 0.56270
# 500/500 - 23s - loss: 0.9921 - accuracy: 0.7046 - val_loss: 1.8732 - val_accuracy: 0.5484
# Epoch 23/200
#
# Epoch 00023: val_accuracy did not improve from 0.56270
# 500/500 - 24s - loss: 0.9650 - accuracy: 0.7123 - val_loss: 1.9464 - val_accuracy: 0.5435
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.56270
# 500/500 - 23s - loss: 0.9399 - accuracy: 0.7182 - val_loss: 2.2056 - val_accuracy: 0.5211
# Epoch 25/200
#
# Epoch 00025: val_accuracy did not improve from 0.56270
# 500/500 - 23s - loss: 0.9212 - accuracy: 0.7226 - val_loss: 1.8670 - val_accuracy: 0.5558
# Epoch 26/200
#
# Epoch 00026: val_accuracy improved from 0.56270 to 0.56550, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 0.8873 - accuracy: 0.7335 - val_loss: 1.9020 - val_accuracy: 0.5655
# Epoch 27/200
#
# Epoch 00027: val_accuracy did not improve from 0.56550
# 500/500 - 23s - loss: 0.8520 - accuracy: 0.7432 - val_loss: 1.9119 - val_accuracy: 0.5602
# Epoch 28/200
#
# Epoch 00028: val_accuracy did not improve from 0.56550
# 500/500 - 23s - loss: 0.8290 - accuracy: 0.7460 - val_loss: 1.9966 - val_accuracy: 0.5433
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.56550
# 500/500 - 23s - loss: 0.8119 - accuracy: 0.7495 - val_loss: 1.9653 - val_accuracy: 0.5553
# Epoch 30/200
#
# Epoch 00030: val_accuracy did not improve from 0.56550
# 500/500 - 23s - loss: 0.7871 - accuracy: 0.7592 - val_loss: 1.9679 - val_accuracy: 0.5511
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.56550
# 500/500 - 24s - loss: 0.7668 - accuracy: 0.7658 - val_loss: 1.9928 - val_accuracy: 0.5613
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.56550 to 0.56680, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 0.7476 - accuracy: 0.7665 - val_loss: 1.9707 - val_accuracy: 0.5668
# Epoch 33/200
#
# Epoch 00033: val_accuracy did not improve from 0.56680
# 500/500 - 23s - loss: 0.7272 - accuracy: 0.7731 - val_loss: 2.0734 - val_accuracy: 0.5553
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.56680
# 500/500 - 23s - loss: 0.7042 - accuracy: 0.7820 - val_loss: 2.0769 - val_accuracy: 0.5642
# Epoch 35/200
#
# Epoch 00035: val_accuracy improved from 0.56680 to 0.56700, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 25s - loss: 0.6796 - accuracy: 0.7898 - val_loss: 2.0768 - val_accuracy: 0.5670
# Epoch 36/200
#
# Epoch 00036: val_accuracy did not improve from 0.56700
# 500/500 - 23s - loss: 0.6633 - accuracy: 0.7922 - val_loss: 2.0492 - val_accuracy: 0.5630
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.56700
# 500/500 - 23s - loss: 0.6526 - accuracy: 0.7942 - val_loss: 2.3092 - val_accuracy: 0.5580
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.56700
# 500/500 - 24s - loss: 0.6381 - accuracy: 0.7994 - val_loss: 2.1483 - val_accuracy: 0.5618
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.56700 to 0.56740, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 0.6173 - accuracy: 0.8069 - val_loss: 2.1528 - val_accuracy: 0.5674
# Epoch 40/200
#
# Epoch 00040: val_accuracy did not improve from 0.56740
# 500/500 - 23s - loss: 0.6030 - accuracy: 0.8072 - val_loss: 2.2647 - val_accuracy: 0.5531
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.56740
# 500/500 - 23s - loss: 0.5905 - accuracy: 0.8125 - val_loss: 2.1733 - val_accuracy: 0.5612
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.56740
# 500/500 - 23s - loss: 0.5791 - accuracy: 0.8171 - val_loss: 2.1802 - val_accuracy: 0.5654
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.56740
# 500/500 - 23s - loss: 0.5563 - accuracy: 0.8252 - val_loss: 2.1794 - val_accuracy: 0.5672
# Epoch 44/200
#
# Epoch 00044: val_accuracy improved from 0.56740 to 0.57490, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 25s - loss: 0.5466 - accuracy: 0.8250 - val_loss: 2.2074 - val_accuracy: 0.5749
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.57490
# 500/500 - 24s - loss: 0.5325 - accuracy: 0.8297 - val_loss: 2.4546 - val_accuracy: 0.5466
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.57490
# 500/500 - 24s - loss: 0.5199 - accuracy: 0.8328 - val_loss: 2.6311 - val_accuracy: 0.5314
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.57490
# 500/500 - 24s - loss: 0.5166 - accuracy: 0.8347 - val_loss: 2.2620 - val_accuracy: 0.5689
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.57490
# 500/500 - 23s - loss: 0.4936 - accuracy: 0.8430 - val_loss: 2.3579 - val_accuracy: 0.5622
# Epoch 49/200
#
# Epoch 00049: val_accuracy improved from 0.57490 to 0.58080, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 0.4825 - accuracy: 0.8454 - val_loss: 2.2543 - val_accuracy: 0.5808
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.58080
# 500/500 - 24s - loss: 0.4867 - accuracy: 0.8451 - val_loss: 2.2989 - val_accuracy: 0.5680
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.58080
# 500/500 - 23s - loss: 0.4680 - accuracy: 0.8480 - val_loss: 2.2128 - val_accuracy: 0.5757
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.58080
# 500/500 - 23s - loss: 0.4592 - accuracy: 0.8504 - val_loss: 2.2781 - val_accuracy: 0.5716
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.58080
# 500/500 - 23s - loss: 0.4532 - accuracy: 0.8529 - val_loss: 2.4101 - val_accuracy: 0.5711
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.58080
# 500/500 - 23s - loss: 0.4380 - accuracy: 0.8571 - val_loss: 2.3905 - val_accuracy: 0.5721
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.58080
# 500/500 - 23s - loss: 0.4260 - accuracy: 0.8615 - val_loss: 2.4464 - val_accuracy: 0.5599
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.58080
# 500/500 - 23s - loss: 0.4262 - accuracy: 0.8627 - val_loss: 2.3335 - val_accuracy: 0.5785
# Epoch 57/200
#
# Epoch 00057: val_accuracy improved from 0.58080 to 0.58730, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 0.4011 - accuracy: 0.8710 - val_loss: 2.2756 - val_accuracy: 0.5873
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.58730
# 500/500 - 23s - loss: 0.4003 - accuracy: 0.8714 - val_loss: 2.3831 - val_accuracy: 0.5863
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.58730
# 500/500 - 23s - loss: 0.3939 - accuracy: 0.8721 - val_loss: 2.4828 - val_accuracy: 0.5632
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.58730
# 500/500 - 23s - loss: 0.3953 - accuracy: 0.8712 - val_loss: 2.4254 - val_accuracy: 0.5702
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.58730
# 500/500 - 23s - loss: 0.3883 - accuracy: 0.8738 - val_loss: 2.3928 - val_accuracy: 0.5734
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.58730
# 500/500 - 23s - loss: 0.3746 - accuracy: 0.8788 - val_loss: 2.5719 - val_accuracy: 0.5667
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.58730
# 500/500 - 24s - loss: 0.3609 - accuracy: 0.8834 - val_loss: 2.4529 - val_accuracy: 0.5821
# Epoch 64/200
#
# Epoch 00064: val_accuracy improved from 0.58730 to 0.58820, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 0.3577 - accuracy: 0.8828 - val_loss: 2.4110 - val_accuracy: 0.5882
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.58820
# 500/500 - 23s - loss: 0.3507 - accuracy: 0.8859 - val_loss: 2.6524 - val_accuracy: 0.5689
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.58820
# 500/500 - 23s - loss: 0.3415 - accuracy: 0.8881 - val_loss: 2.4637 - val_accuracy: 0.5823
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.58820
# 500/500 - 23s - loss: 0.3469 - accuracy: 0.8862 - val_loss: 2.5140 - val_accuracy: 0.5769
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.58820
# 500/500 - 23s - loss: 0.3339 - accuracy: 0.8887 - val_loss: 2.6203 - val_accuracy: 0.5698
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.58820
# 500/500 - 23s - loss: 0.3349 - accuracy: 0.8900 - val_loss: 2.5897 - val_accuracy: 0.5742
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.58820
# 500/500 - 24s - loss: 0.3194 - accuracy: 0.8956 - val_loss: 2.6976 - val_accuracy: 0.5719
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.58820
# 500/500 - 24s - loss: 0.3288 - accuracy: 0.8929 - val_loss: 2.4840 - val_accuracy: 0.5817
# Epoch 72/200
#
# Epoch 00072: val_accuracy improved from 0.58820 to 0.59520, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 0.3113 - accuracy: 0.8982 - val_loss: 2.4713 - val_accuracy: 0.5952
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.59520
# 500/500 - 24s - loss: 0.3193 - accuracy: 0.8953 - val_loss: 2.6651 - val_accuracy: 0.5618
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.59520
# 500/500 - 23s - loss: 0.3075 - accuracy: 0.8981 - val_loss: 2.4994 - val_accuracy: 0.5859
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.59520
# 500/500 - 23s - loss: 0.2960 - accuracy: 0.9026 - val_loss: 2.4860 - val_accuracy: 0.5940
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.59520
# 500/500 - 23s - loss: 0.2887 - accuracy: 0.9041 - val_loss: 2.6784 - val_accuracy: 0.5833
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.59520
# 500/500 - 23s - loss: 0.2970 - accuracy: 0.9018 - val_loss: 2.5798 - val_accuracy: 0.5873
# Epoch 78/200
#
# Epoch 00078: val_accuracy improved from 0.59520 to 0.60110, saving model to gdrive/My Drive/Colab Notebooks/InceptionV2_SGD_Batch_2.h5
# 500/500 - 24s - loss: 0.2887 - accuracy: 0.9051 - val_loss: 2.4645 - val_accuracy: 0.6011
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2810 - accuracy: 0.9076 - val_loss: 2.6562 - val_accuracy: 0.5787
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2602 - accuracy: 0.9134 - val_loss: 2.4707 - val_accuracy: 0.5944
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2693 - accuracy: 0.9120 - val_loss: 2.6921 - val_accuracy: 0.5886
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2630 - accuracy: 0.9129 - val_loss: 2.5659 - val_accuracy: 0.5933
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2692 - accuracy: 0.9115 - val_loss: 2.6345 - val_accuracy: 0.5767
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.60110
# 500/500 - 24s - loss: 0.2602 - accuracy: 0.9154 - val_loss: 2.5621 - val_accuracy: 0.5903
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2546 - accuracy: 0.9157 - val_loss: 2.6314 - val_accuracy: 0.5856
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2511 - accuracy: 0.9170 - val_loss: 2.7697 - val_accuracy: 0.5850
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2375 - accuracy: 0.9216 - val_loss: 2.7811 - val_accuracy: 0.5828
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2428 - accuracy: 0.9185 - val_loss: 2.6793 - val_accuracy: 0.5927
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2411 - accuracy: 0.9198 - val_loss: 2.8392 - val_accuracy: 0.5772
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2387 - accuracy: 0.9219 - val_loss: 2.7803 - val_accuracy: 0.5835
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2339 - accuracy: 0.9237 - val_loss: 2.9148 - val_accuracy: 0.5707
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2361 - accuracy: 0.9232 - val_loss: 2.7852 - val_accuracy: 0.5816
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2296 - accuracy: 0.9249 - val_loss: 3.0800 - val_accuracy: 0.5632
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2354 - accuracy: 0.9233 - val_loss: 2.7891 - val_accuracy: 0.5854
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2197 - accuracy: 0.9265 - val_loss: 2.5852 - val_accuracy: 0.5983
# Epoch 96/200
#
# Epoch 00096: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2247 - accuracy: 0.9262 - val_loss: 2.8520 - val_accuracy: 0.5829
# Epoch 97/200
#
# Epoch 00097: val_accuracy did not improve from 0.60110
# 500/500 - 24s - loss: 0.2195 - accuracy: 0.9282 - val_loss: 2.8511 - val_accuracy: 0.5815
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.60110
# 500/500 - 23s - loss: 0.2195 - accuracy: 0.9285 - val_loss: 2.8871 - val_accuracy: 0.5832
# Epoch 00098: early stopping

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.6107212801385873
# Recall:  0.6011
# Accuracy:  0.6011
