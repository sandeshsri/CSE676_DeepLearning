# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, \
                    add, AveragePooling2D, Dropout
from keras.optimizers import Adam
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 100
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout.h5"
# path_best = "../weights/Resnet18_ADAM_Dropout.h5"
path_train = "gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar100.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def resnetBuilder(l, filters):
    x = l

    l = Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(l)
    l = Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(l)
    l = Dropout(0.5)(l)

    x = Conv2D(filters=filters, kernel_size=(1,1), padding='same', activation='relu')(x)
    x = add([x,l])
    x = Activation('relu')(x)

    return x

# %%
def createResnetModel():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    l = MaxPool2D(pool_size=(3,3))(l)

    l = resnetBuilder(l, 64)
    l = resnetBuilder(l, 64)
    l = resnetBuilder(l, 128)
    l = resnetBuilder(l, 128)
    l = resnetBuilder(l, 256)
    l = resnetBuilder(l, 256)
    l = resnetBuilder(l, 512)
    l = resnetBuilder(l, 512)

    l = AveragePooling2D(pool_size=(8,8))(l)
    l = Flatten()(l)
    output = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs=input, outputs=output)
    return model

# %%
model = createResnetModel()
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 64)   9472        input_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 10, 10, 64)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 10, 10, 64)   36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 10, 10, 64)   36928       conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 10, 10, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 10, 10, 64)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 10, 10, 64)   0           conv2d_28[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 10, 10, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 10, 10, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 10, 10, 64)   36928       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 10, 10, 64)   4160        activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 10, 10, 64)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 10, 10, 64)   0           conv2d_31[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 10, 10, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 10, 10, 128)  73856       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 10, 10, 128)  147584      conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 10, 10, 128)  8320        activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 10, 10, 128)  0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 10, 10, 128)  0           conv2d_34[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 10, 10, 128)  0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 10, 10, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 10, 10, 128)  147584      conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 10, 10, 128)  16512       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 10, 10, 128)  0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 128)  0           conv2d_37[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 10, 10, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 10, 10, 256)  295168      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 10, 10, 256)  590080      conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 10, 10, 256)  33024       activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 10, 10, 256)  0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 10, 10, 256)  0           conv2d_40[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 10, 10, 256)  0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 10, 10, 256)  590080      activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 10, 10, 256)  590080      conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 10, 10, 256)  65792       activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 10, 10, 256)  0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 10, 10, 256)  0           conv2d_43[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 10, 10, 256)  0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 10, 10, 512)  1180160     activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 10, 10, 512)  2359808     conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 10, 10, 512)  131584      activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 10, 10, 512)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 512)  0           conv2d_46[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 10, 10, 512)  0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 10, 10, 512)  2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 10, 10, 512)  2359808     conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 10, 10, 512)  262656      activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 10, 10, 512)  0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 512)  0           conv2d_49[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 10, 10, 512)  0           add_15[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          51300       flatten_1[0][0]
# ==================================================================================================
# Total params: 11,576,292
# Trainable params: 11,576,292
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=50, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint, early],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.05800, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 4.3020 - accuracy: 0.0323 - val_loss: 4.0134 - val_accuracy: 0.0580
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.05800 to 0.11740, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 3.8648 - accuracy: 0.0863 - val_loss: 3.7169 - val_accuracy: 0.1174
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.11740 to 0.14840, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 3.6264 - accuracy: 0.1296 - val_loss: 3.5601 - val_accuracy: 0.1484
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.14840 to 0.20030, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 3.4000 - accuracy: 0.1751 - val_loss: 3.2849 - val_accuracy: 0.2003
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.20030 to 0.23850, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 3.1899 - accuracy: 0.2168 - val_loss: 3.1568 - val_accuracy: 0.2385
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.23850 to 0.26510, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 3.0096 - accuracy: 0.2489 - val_loss: 2.9849 - val_accuracy: 0.2651
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.26510 to 0.29740, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.8591 - accuracy: 0.2796 - val_loss: 2.8357 - val_accuracy: 0.2974
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.29740 to 0.32140, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.7338 - accuracy: 0.3056 - val_loss: 2.7016 - val_accuracy: 0.3214
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.32140 to 0.33670, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.6091 - accuracy: 0.3315 - val_loss: 2.6332 - val_accuracy: 0.3367
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.33670 to 0.36240, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.5109 - accuracy: 0.3519 - val_loss: 2.5031 - val_accuracy: 0.3624
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.36240 to 0.38020, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.3969 - accuracy: 0.3767 - val_loss: 2.4467 - val_accuracy: 0.3802
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.38020 to 0.38360, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.3137 - accuracy: 0.3935 - val_loss: 2.4328 - val_accuracy: 0.3836
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.38360 to 0.39810, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.2260 - accuracy: 0.4151 - val_loss: 2.3593 - val_accuracy: 0.3981
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.39810 to 0.41710, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.1462 - accuracy: 0.4302 - val_loss: 2.2939 - val_accuracy: 0.4171
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.41710 to 0.43090, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.0925 - accuracy: 0.4437 - val_loss: 2.2071 - val_accuracy: 0.4309
# Epoch 16/200
#
# Epoch 00016: val_accuracy improved from 0.43090 to 0.43210, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 2.0198 - accuracy: 0.4604 - val_loss: 2.2282 - val_accuracy: 0.4321
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.43210 to 0.44750, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 1.9593 - accuracy: 0.4723 - val_loss: 2.1499 - val_accuracy: 0.4475
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.44750 to 0.46490, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 1.9062 - accuracy: 0.4853 - val_loss: 2.0615 - val_accuracy: 0.4649
# Epoch 19/200
#
# Epoch 00019: val_accuracy did not improve from 0.46490
# 500/500 - 63s - loss: 1.8447 - accuracy: 0.4995 - val_loss: 2.1467 - val_accuracy: 0.4486
# Epoch 20/200
#
# Epoch 00020: val_accuracy improved from 0.46490 to 0.48230, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 1.8001 - accuracy: 0.5087 - val_loss: 1.9875 - val_accuracy: 0.4823
# Epoch 21/200
#
# Epoch 00021: val_accuracy did not improve from 0.48230
# 500/500 - 63s - loss: 1.7404 - accuracy: 0.5215 - val_loss: 2.1785 - val_accuracy: 0.4521
# Epoch 22/200
#
# Epoch 00022: val_accuracy did not improve from 0.48230
# 500/500 - 63s - loss: 1.6949 - accuracy: 0.5360 - val_loss: 2.0240 - val_accuracy: 0.4823
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.48230 to 0.48350, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 1.6445 - accuracy: 0.5450 - val_loss: 2.0642 - val_accuracy: 0.4835
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.48350
# 500/500 - 63s - loss: 1.6036 - accuracy: 0.5562 - val_loss: 2.0878 - val_accuracy: 0.4709
# Epoch 25/200
#
# Epoch 00025: val_accuracy improved from 0.48350 to 0.50010, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 1.5644 - accuracy: 0.5649 - val_loss: 1.9629 - val_accuracy: 0.5001
# Epoch 26/200
#
# Epoch 00026: val_accuracy did not improve from 0.50010
# 500/500 - 63s - loss: 1.5074 - accuracy: 0.5775 - val_loss: 1.9965 - val_accuracy: 0.4995
# Epoch 27/200
#
# Epoch 00027: val_accuracy did not improve from 0.50010
# 500/500 - 63s - loss: 1.4726 - accuracy: 0.5867 - val_loss: 2.0236 - val_accuracy: 0.4973
# Epoch 28/200
#
# Epoch 00028: val_accuracy improved from 0.50010 to 0.51140, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 1.4279 - accuracy: 0.5971 - val_loss: 1.9595 - val_accuracy: 0.5114
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.51140
# 500/500 - 63s - loss: 1.3874 - accuracy: 0.6073 - val_loss: 1.9468 - val_accuracy: 0.5069
# Epoch 30/200
#
# Epoch 00030: val_accuracy did not improve from 0.51140
# 500/500 - 63s - loss: 1.3520 - accuracy: 0.6137 - val_loss: 2.0488 - val_accuracy: 0.4945
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.51140
# 500/500 - 63s - loss: 1.3057 - accuracy: 0.6264 - val_loss: 2.0452 - val_accuracy: 0.4984
# Epoch 32/200
#
# Epoch 00032: val_accuracy did not improve from 0.51140
# 500/500 - 63s - loss: 1.2833 - accuracy: 0.6305 - val_loss: 2.0438 - val_accuracy: 0.5067
# Epoch 33/200
#
# Epoch 00033: val_accuracy improved from 0.51140 to 0.52150, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 1.2233 - accuracy: 0.6467 - val_loss: 1.9518 - val_accuracy: 0.5215
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.52150
# 500/500 - 63s - loss: 1.2026 - accuracy: 0.6532 - val_loss: 1.9743 - val_accuracy: 0.5148
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.52150
# 500/500 - 63s - loss: 1.1634 - accuracy: 0.6609 - val_loss: 2.0241 - val_accuracy: 0.5104
# Epoch 36/200
#
# Epoch 00036: val_accuracy did not improve from 0.52150
# 500/500 - 63s - loss: 1.1279 - accuracy: 0.6705 - val_loss: 1.9830 - val_accuracy: 0.5171
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.52150
# 500/500 - 63s - loss: 1.0965 - accuracy: 0.6806 - val_loss: 2.0653 - val_accuracy: 0.5065
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.52150
# 500/500 - 63s - loss: 1.0673 - accuracy: 0.6871 - val_loss: 2.0340 - val_accuracy: 0.5131
# Epoch 39/200
#
# Epoch 00039: val_accuracy did not improve from 0.52150
# 500/500 - 63s - loss: 1.0321 - accuracy: 0.6956 - val_loss: 2.0835 - val_accuracy: 0.5176
# Epoch 40/200
#
# Epoch 00040: val_accuracy did not improve from 0.52150
# 500/500 - 64s - loss: 0.9901 - accuracy: 0.7041 - val_loss: 2.1128 - val_accuracy: 0.5196
# Epoch 41/200
#
# Epoch 00041: val_accuracy improved from 0.52150 to 0.52270, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 0.9689 - accuracy: 0.7122 - val_loss: 2.1101 - val_accuracy: 0.5227
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.52270
# 500/500 - 63s - loss: 0.9390 - accuracy: 0.7176 - val_loss: 2.1935 - val_accuracy: 0.5086
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.52270
# 500/500 - 63s - loss: 0.9034 - accuracy: 0.7275 - val_loss: 2.1658 - val_accuracy: 0.5149
# Epoch 44/200
#
# Epoch 00044: val_accuracy improved from 0.52270 to 0.52540, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 0.8770 - accuracy: 0.7343 - val_loss: 2.1174 - val_accuracy: 0.5254
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.52540
# 500/500 - 63s - loss: 0.8490 - accuracy: 0.7405 - val_loss: 2.1346 - val_accuracy: 0.5251
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.52540
# 500/500 - 63s - loss: 0.8207 - accuracy: 0.7515 - val_loss: 2.1972 - val_accuracy: 0.5158
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.52540
# 500/500 - 63s - loss: 0.8049 - accuracy: 0.7565 - val_loss: 2.3856 - val_accuracy: 0.5123
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.52540
# 500/500 - 63s - loss: 0.7720 - accuracy: 0.7623 - val_loss: 2.2591 - val_accuracy: 0.5115
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.52540
# 500/500 - 63s - loss: 0.7679 - accuracy: 0.7633 - val_loss: 2.2522 - val_accuracy: 0.5210
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.52540
# 500/500 - 63s - loss: 0.7286 - accuracy: 0.7742 - val_loss: 2.2511 - val_accuracy: 0.5201
# Epoch 51/200
#
# Epoch 00051: val_accuracy improved from 0.52540 to 0.52780, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 0.7131 - accuracy: 0.7774 - val_loss: 2.3852 - val_accuracy: 0.5278
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.52780
# 500/500 - 63s - loss: 0.6751 - accuracy: 0.7890 - val_loss: 2.5743 - val_accuracy: 0.5084
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.52780
# 500/500 - 63s - loss: 0.6651 - accuracy: 0.7905 - val_loss: 2.4453 - val_accuracy: 0.5113
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.52780
# 500/500 - 63s - loss: 0.6407 - accuracy: 0.7995 - val_loss: 2.4760 - val_accuracy: 0.5198
# Epoch 55/200
#
# Epoch 00055: val_accuracy improved from 0.52780 to 0.53990, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Dropout_2.h5
# 500/500 - 65s - loss: 0.6313 - accuracy: 0.8024 - val_loss: 2.3143 - val_accuracy: 0.5399
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.6074 - accuracy: 0.8095 - val_loss: 2.4834 - val_accuracy: 0.5139
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.5889 - accuracy: 0.8136 - val_loss: 2.5643 - val_accuracy: 0.5140
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.5849 - accuracy: 0.8157 - val_loss: 2.4231 - val_accuracy: 0.5242
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.5508 - accuracy: 0.8243 - val_loss: 2.5895 - val_accuracy: 0.5203
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.5363 - accuracy: 0.8292 - val_loss: 2.6429 - val_accuracy: 0.5196
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.5247 - accuracy: 0.8324 - val_loss: 2.5335 - val_accuracy: 0.5252
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.5062 - accuracy: 0.8370 - val_loss: 2.5961 - val_accuracy: 0.5186
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.5039 - accuracy: 0.8392 - val_loss: 2.6559 - val_accuracy: 0.5065
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.4896 - accuracy: 0.8446 - val_loss: 2.7463 - val_accuracy: 0.5130
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.4652 - accuracy: 0.8506 - val_loss: 2.6873 - val_accuracy: 0.5139
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.4648 - accuracy: 0.8514 - val_loss: 2.6178 - val_accuracy: 0.5390
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.4435 - accuracy: 0.8564 - val_loss: 2.6481 - val_accuracy: 0.5241
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.4457 - accuracy: 0.8582 - val_loss: 2.5774 - val_accuracy: 0.5315
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.4317 - accuracy: 0.8608 - val_loss: 2.8444 - val_accuracy: 0.5072
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.4132 - accuracy: 0.8673 - val_loss: 2.7930 - val_accuracy: 0.5179
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.4100 - accuracy: 0.8677 - val_loss: 2.8174 - val_accuracy: 0.5090
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.53990
# 500/500 - 64s - loss: 0.4046 - accuracy: 0.8691 - val_loss: 2.8101 - val_accuracy: 0.5146
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3888 - accuracy: 0.8736 - val_loss: 2.7896 - val_accuracy: 0.5192
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3838 - accuracy: 0.8757 - val_loss: 2.8182 - val_accuracy: 0.5172
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3767 - accuracy: 0.8784 - val_loss: 2.8962 - val_accuracy: 0.5195
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3640 - accuracy: 0.8815 - val_loss: 2.7988 - val_accuracy: 0.5222
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3524 - accuracy: 0.8852 - val_loss: 2.9420 - val_accuracy: 0.5172
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3553 - accuracy: 0.8852 - val_loss: 2.8983 - val_accuracy: 0.5217
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3383 - accuracy: 0.8886 - val_loss: 2.9433 - val_accuracy: 0.5241
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3277 - accuracy: 0.8928 - val_loss: 3.0918 - val_accuracy: 0.5125
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3268 - accuracy: 0.8939 - val_loss: 3.0358 - val_accuracy: 0.5225
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3302 - accuracy: 0.8928 - val_loss: 2.9139 - val_accuracy: 0.5309
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3095 - accuracy: 0.9000 - val_loss: 3.0228 - val_accuracy: 0.5263
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.3162 - accuracy: 0.8962 - val_loss: 2.9885 - val_accuracy: 0.5276
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2994 - accuracy: 0.9021 - val_loss: 3.1140 - val_accuracy: 0.5275
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2937 - accuracy: 0.9039 - val_loss: 3.2282 - val_accuracy: 0.5179
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2937 - accuracy: 0.9039 - val_loss: 3.1463 - val_accuracy: 0.5218
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2885 - accuracy: 0.9062 - val_loss: 3.2348 - val_accuracy: 0.5199
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2772 - accuracy: 0.9097 - val_loss: 3.0490 - val_accuracy: 0.5211
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2863 - accuracy: 0.9069 - val_loss: 3.2413 - val_accuracy: 0.5165
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2740 - accuracy: 0.9108 - val_loss: 3.1186 - val_accuracy: 0.5274
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2628 - accuracy: 0.9140 - val_loss: 3.2223 - val_accuracy: 0.5169
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2680 - accuracy: 0.9130 - val_loss: 3.1352 - val_accuracy: 0.5244
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2602 - accuracy: 0.9132 - val_loss: 3.2016 - val_accuracy: 0.5241
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2609 - accuracy: 0.9154 - val_loss: 3.1761 - val_accuracy: 0.5137
# Epoch 96/200
#
# Epoch 00096: val_accuracy did not improve from 0.53990
# 500/500 - 64s - loss: 0.2475 - accuracy: 0.9194 - val_loss: 3.1328 - val_accuracy: 0.5322
# Epoch 97/200
#
# Epoch 00097: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2428 - accuracy: 0.9194 - val_loss: 3.1977 - val_accuracy: 0.5194
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2423 - accuracy: 0.9204 - val_loss: 3.0936 - val_accuracy: 0.5337
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2411 - accuracy: 0.9218 - val_loss: 3.3828 - val_accuracy: 0.5187
# Epoch 100/200
#
# Epoch 00100: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2373 - accuracy: 0.9226 - val_loss: 3.2126 - val_accuracy: 0.5280
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2296 - accuracy: 0.9265 - val_loss: 3.2500 - val_accuracy: 0.5189
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2370 - accuracy: 0.9235 - val_loss: 3.2115 - val_accuracy: 0.5270
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2253 - accuracy: 0.9268 - val_loss: 3.3319 - val_accuracy: 0.5196
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2166 - accuracy: 0.9298 - val_loss: 3.1764 - val_accuracy: 0.5312
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.53990
# 500/500 - 63s - loss: 0.2228 - accuracy: 0.9279 - val_loss: 3.3244 - val_accuracy: 0.5272
# Epoch 00105: early stopping

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.5592437272620149
# Recall:  0.5513
# Accuracy:  0.5513
