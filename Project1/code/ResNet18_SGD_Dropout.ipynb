# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, \
                    add, AveragePooling2D, Dropout
from keras.optimizers import SGD
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 100
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout.h5"
# path_best = "../weights/ResNet18_SGD_Dropout.h5"
path_train = "gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar100.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 11s 0us/step

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def resnetBuilder(l, filters):
    x = l

    l = Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(l)
    l = Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(l)
    l = Dropout(0.5)(l)

    x = Conv2D(filters=filters, kernel_size=(1,1), padding='same', activation='relu')(x)
    x = add([x,l])
    x = Activation('relu')(x)

    return x

# %%
def createResnetModel():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    l = MaxPool2D(pool_size=(3,3))(l)

    l = resnetBuilder(l, 64)
    l = resnetBuilder(l, 64)
    l = resnetBuilder(l, 128)
    l = resnetBuilder(l, 128)
    l = resnetBuilder(l, 256)
    l = resnetBuilder(l, 256)
    l = resnetBuilder(l, 512)
    l = resnetBuilder(l, 512)

    l = AveragePooling2D(pool_size=(8,8))(l)
    l = Flatten()(l)
    output = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs=input, outputs=output)
    return model

# %%
model = createResnetModel()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 10, 10, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 10, 10, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 10, 10, 64)   36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 10, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 10, 10, 64)   0           conv2d_3[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10, 10, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 10, 10, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 10, 10, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 10, 10, 64)   4160        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10, 10, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10, 10, 64)   0           conv2d_6[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 10, 10, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 10, 10, 128)  73856       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 10, 128)  147584      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 10, 10, 128)  8320        activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 10, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 10, 10, 128)  0           conv2d_9[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 10, 10, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 10, 10, 128)  147584      activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 10, 10, 128)  147584      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 10, 10, 128)  16512       activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 10, 10, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 10, 10, 128)  0           conv2d_12[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 10, 10, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 10, 10, 256)  295168      activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 10, 10, 256)  590080      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 10, 10, 256)  33024       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 10, 256)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 10, 10, 256)  0           conv2d_15[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 10, 10, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 10, 10, 256)  590080      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 10, 10, 256)  590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 10, 10, 256)  65792       activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 10, 10, 256)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 10, 10, 256)  0           conv2d_18[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 10, 10, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 10, 10, 512)  1180160     activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 10, 10, 512)  2359808     conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 10, 10, 512)  131584      activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 10, 10, 512)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 10, 10, 512)  0           conv2d_21[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 10, 10, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 10, 10, 512)  2359808     activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 10, 10, 512)  2359808     conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 10, 10, 512)  262656      activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 10, 10, 512)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 10, 10, 512)  0           conv2d_24[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10, 10, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 512)    0           activation_8[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          51300       flatten[0][0]
# ==================================================================================================
# Total params: 11,576,292
# Trainable params: 11,576,292
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint, early],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.03570, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 141s - loss: 4.4436 - accuracy: 0.0230 - val_loss: 4.2739 - val_accuracy: 0.0357
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.03570 to 0.09390, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 4.0343 - accuracy: 0.0621 - val_loss: 3.8276 - val_accuracy: 0.0939
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.09390 to 0.13380, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 3.7605 - accuracy: 0.1063 - val_loss: 3.6183 - val_accuracy: 0.1338
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.13380 to 0.18630, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 3.4992 - accuracy: 0.1527 - val_loss: 3.3198 - val_accuracy: 0.1863
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.18630 to 0.23590, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 3.2612 - accuracy: 0.1987 - val_loss: 3.0978 - val_accuracy: 0.2359
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.23590 to 0.25740, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 3.0553 - accuracy: 0.2405 - val_loss: 2.9892 - val_accuracy: 0.2574
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.25740 to 0.31820, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 2.8699 - accuracy: 0.2754 - val_loss: 2.6745 - val_accuracy: 0.3182
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.31820 to 0.35730, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 2.6978 - accuracy: 0.3117 - val_loss: 2.5280 - val_accuracy: 0.3573
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.35730 to 0.39160, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 2.5383 - accuracy: 0.3475 - val_loss: 2.3753 - val_accuracy: 0.3916
# Epoch 10/200
#
# Epoch 00010: val_accuracy did not improve from 0.39160
# 500/500 - 139s - loss: 2.3903 - accuracy: 0.3761 - val_loss: 2.4083 - val_accuracy: 0.3900
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.39160 to 0.43460, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 2.2661 - accuracy: 0.4021 - val_loss: 2.1966 - val_accuracy: 0.4346
# Epoch 12/200
#
# Epoch 00012: val_accuracy did not improve from 0.43460
# 500/500 - 139s - loss: 2.1475 - accuracy: 0.4281 - val_loss: 2.2304 - val_accuracy: 0.4313
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.43460 to 0.46740, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 2.0420 - accuracy: 0.4565 - val_loss: 2.0276 - val_accuracy: 0.4674
# Epoch 14/200
#
# Epoch 00014: val_accuracy did not improve from 0.46740
# 500/500 - 139s - loss: 1.9519 - accuracy: 0.4740 - val_loss: 2.1613 - val_accuracy: 0.4559
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.46740 to 0.48550, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.8664 - accuracy: 0.4949 - val_loss: 1.9774 - val_accuracy: 0.4855
# Epoch 16/200
#
# Epoch 00016: val_accuracy improved from 0.48550 to 0.49500, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.7921 - accuracy: 0.5089 - val_loss: 1.9307 - val_accuracy: 0.4950
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.49500 to 0.49730, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.7202 - accuracy: 0.5286 - val_loss: 1.8994 - val_accuracy: 0.4973
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.49730 to 0.51610, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.6518 - accuracy: 0.5432 - val_loss: 1.8252 - val_accuracy: 0.5161
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.51610 to 0.53030, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.5807 - accuracy: 0.5587 - val_loss: 1.7666 - val_accuracy: 0.5303
# Epoch 20/200
#
# Epoch 00020: val_accuracy did not improve from 0.53030
# 500/500 - 139s - loss: 1.5233 - accuracy: 0.5754 - val_loss: 2.0050 - val_accuracy: 0.4981
# Epoch 21/200
#
# Epoch 00021: val_accuracy improved from 0.53030 to 0.53260, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.4626 - accuracy: 0.5895 - val_loss: 1.8499 - val_accuracy: 0.5326
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.53260 to 0.54400, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.4103 - accuracy: 0.5989 - val_loss: 1.7941 - val_accuracy: 0.5440
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.54400 to 0.54720, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.3606 - accuracy: 0.6155 - val_loss: 1.7374 - val_accuracy: 0.5472
# Epoch 24/200
#
# Epoch 00024: val_accuracy improved from 0.54720 to 0.55030, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.2981 - accuracy: 0.6299 - val_loss: 1.7840 - val_accuracy: 0.5503
# Epoch 25/200
#
# Epoch 00025: val_accuracy improved from 0.55030 to 0.55240, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.2560 - accuracy: 0.6384 - val_loss: 1.7933 - val_accuracy: 0.5524
# Epoch 26/200
#
# Epoch 00026: val_accuracy improved from 0.55240 to 0.55830, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.2153 - accuracy: 0.6512 - val_loss: 1.7434 - val_accuracy: 0.5583
# Epoch 27/200
#
# Epoch 00027: val_accuracy improved from 0.55830 to 0.56630, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.1596 - accuracy: 0.6654 - val_loss: 1.7569 - val_accuracy: 0.5663
# Epoch 28/200
#
# Epoch 00028: val_accuracy improved from 0.56630 to 0.57180, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 1.1156 - accuracy: 0.6743 - val_loss: 1.6899 - val_accuracy: 0.5718
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.57180
# 500/500 - 139s - loss: 1.0799 - accuracy: 0.6838 - val_loss: 1.7255 - val_accuracy: 0.5692
# Epoch 30/200
#
# Epoch 00030: val_accuracy did not improve from 0.57180
# 500/500 - 139s - loss: 1.0373 - accuracy: 0.6949 - val_loss: 1.7120 - val_accuracy: 0.5622
# Epoch 31/200
#
# Epoch 00031: val_accuracy improved from 0.57180 to 0.57940, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 0.9946 - accuracy: 0.7054 - val_loss: 1.7221 - val_accuracy: 0.5794
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.57940 to 0.58490, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 140s - loss: 0.9700 - accuracy: 0.7137 - val_loss: 1.7563 - val_accuracy: 0.5849
# Epoch 33/200
#
# Epoch 00033: val_accuracy did not improve from 0.58490
# 500/500 - 139s - loss: 0.9278 - accuracy: 0.7248 - val_loss: 1.8293 - val_accuracy: 0.5697
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.58490
# 500/500 - 139s - loss: 0.8936 - accuracy: 0.7312 - val_loss: 1.8491 - val_accuracy: 0.5691
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.58490
# 500/500 - 139s - loss: 0.8609 - accuracy: 0.7408 - val_loss: 1.8703 - val_accuracy: 0.5716
# Epoch 36/200
#
# Epoch 00036: val_accuracy improved from 0.58490 to 0.59500, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 139s - loss: 0.8308 - accuracy: 0.7475 - val_loss: 1.8687 - val_accuracy: 0.5950
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.8032 - accuracy: 0.7555 - val_loss: 1.8819 - val_accuracy: 0.5641
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.7761 - accuracy: 0.7641 - val_loss: 1.7751 - val_accuracy: 0.5854
# Epoch 39/200
#
# Epoch 00039: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.7497 - accuracy: 0.7703 - val_loss: 1.9538 - val_accuracy: 0.5877
# Epoch 40/200
#
# Epoch 00040: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.7245 - accuracy: 0.7783 - val_loss: 2.0315 - val_accuracy: 0.5579
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.59500
# 500/500 - 138s - loss: 0.6987 - accuracy: 0.7859 - val_loss: 1.9483 - val_accuracy: 0.5935
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.59500
# 500/500 - 138s - loss: 0.6744 - accuracy: 0.7911 - val_loss: 1.9524 - val_accuracy: 0.5867
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.59500
# 500/500 - 138s - loss: 0.6589 - accuracy: 0.7956 - val_loss: 1.9251 - val_accuracy: 0.5880
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.59500
# 500/500 - 138s - loss: 0.6324 - accuracy: 0.8024 - val_loss: 1.9795 - val_accuracy: 0.5736
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.6086 - accuracy: 0.8108 - val_loss: 2.0039 - val_accuracy: 0.5836
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.5912 - accuracy: 0.8145 - val_loss: 2.0203 - val_accuracy: 0.5799
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.5791 - accuracy: 0.8178 - val_loss: 2.0029 - val_accuracy: 0.5796
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.5547 - accuracy: 0.8260 - val_loss: 2.0764 - val_accuracy: 0.5896
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.5208 - accuracy: 0.8358 - val_loss: 2.1855 - val_accuracy: 0.5811
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.59500
# 500/500 - 138s - loss: 0.5207 - accuracy: 0.8356 - val_loss: 2.1426 - val_accuracy: 0.5789
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.5068 - accuracy: 0.8375 - val_loss: 2.1052 - val_accuracy: 0.5871
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.4929 - accuracy: 0.8426 - val_loss: 2.1471 - val_accuracy: 0.5891
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.59500
# 500/500 - 137s - loss: 0.4776 - accuracy: 0.8463 - val_loss: 2.1972 - val_accuracy: 0.5773
# Epoch 54/200
#
# Epoch 00054: val_accuracy improved from 0.59500 to 0.59590, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 138s - loss: 0.4706 - accuracy: 0.8519 - val_loss: 2.2629 - val_accuracy: 0.5959
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.59590
# 500/500 - 137s - loss: 0.4501 - accuracy: 0.8574 - val_loss: 2.2622 - val_accuracy: 0.5791
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.59590
# 500/500 - 137s - loss: 0.4413 - accuracy: 0.8592 - val_loss: 2.2251 - val_accuracy: 0.5774
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.59590
# 500/500 - 137s - loss: 0.4251 - accuracy: 0.8635 - val_loss: 2.1788 - val_accuracy: 0.5800
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.59590
# 500/500 - 137s - loss: 0.4179 - accuracy: 0.8664 - val_loss: 2.4031 - val_accuracy: 0.5790
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.59590
# 500/500 - 137s - loss: 0.4116 - accuracy: 0.8683 - val_loss: 2.4408 - val_accuracy: 0.5692
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.59590
# 500/500 - 137s - loss: 0.3968 - accuracy: 0.8740 - val_loss: 2.3024 - val_accuracy: 0.5911
# Epoch 61/200
#
# Epoch 00061: val_accuracy improved from 0.59590 to 0.59600, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 139s - loss: 0.3880 - accuracy: 0.8770 - val_loss: 2.3101 - val_accuracy: 0.5960
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.59600
# 500/500 - 137s - loss: 0.3795 - accuracy: 0.8792 - val_loss: 2.3117 - val_accuracy: 0.5845
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.59600
# 500/500 - 137s - loss: 0.3684 - accuracy: 0.8812 - val_loss: 2.4462 - val_accuracy: 0.5769
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.59600
# 500/500 - 138s - loss: 0.3581 - accuracy: 0.8854 - val_loss: 2.5025 - val_accuracy: 0.5665
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.59600
# 500/500 - 137s - loss: 0.3514 - accuracy: 0.8863 - val_loss: 2.2857 - val_accuracy: 0.5953
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.59600
# 500/500 - 137s - loss: 0.3475 - accuracy: 0.8884 - val_loss: 2.4062 - val_accuracy: 0.5768
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.59600
# 500/500 - 138s - loss: 0.3325 - accuracy: 0.8924 - val_loss: 2.7206 - val_accuracy: 0.5731
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.59600
# 500/500 - 138s - loss: 0.3370 - accuracy: 0.8923 - val_loss: 2.4129 - val_accuracy: 0.5931
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.59600
# 500/500 - 138s - loss: 0.3172 - accuracy: 0.8984 - val_loss: 2.4617 - val_accuracy: 0.5833
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.59600
# 500/500 - 138s - loss: 0.3182 - accuracy: 0.8973 - val_loss: 2.4238 - val_accuracy: 0.5912
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.59600
# 500/500 - 138s - loss: 0.3052 - accuracy: 0.9040 - val_loss: 2.6725 - val_accuracy: 0.5675
# Epoch 72/200
#
# Epoch 00072: val_accuracy improved from 0.59600 to 0.59630, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 139s - loss: 0.3060 - accuracy: 0.9021 - val_loss: 2.4375 - val_accuracy: 0.5963
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.59630
# 500/500 - 138s - loss: 0.2965 - accuracy: 0.9040 - val_loss: 2.4982 - val_accuracy: 0.5786
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.59630
# 500/500 - 138s - loss: 0.2908 - accuracy: 0.9055 - val_loss: 2.5099 - val_accuracy: 0.5906
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.59630
# 500/500 - 138s - loss: 0.2825 - accuracy: 0.9090 - val_loss: 2.5805 - val_accuracy: 0.5802
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.59630
# 500/500 - 138s - loss: 0.2742 - accuracy: 0.9116 - val_loss: 2.6477 - val_accuracy: 0.5904
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.59630
# 500/500 - 138s - loss: 0.2792 - accuracy: 0.9113 - val_loss: 2.8067 - val_accuracy: 0.5811
# Epoch 78/200
#
# Epoch 00078: val_accuracy improved from 0.59630 to 0.59650, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 139s - loss: 0.2710 - accuracy: 0.9126 - val_loss: 2.4820 - val_accuracy: 0.5965
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.59650
# 500/500 - 138s - loss: 0.2613 - accuracy: 0.9164 - val_loss: 2.6637 - val_accuracy: 0.5782
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.59650
# 500/500 - 137s - loss: 0.2565 - accuracy: 0.9167 - val_loss: 2.4496 - val_accuracy: 0.5963
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.59650
# 500/500 - 137s - loss: 0.2545 - accuracy: 0.9185 - val_loss: 2.6577 - val_accuracy: 0.5842
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.59650
# 500/500 - 138s - loss: 0.2398 - accuracy: 0.9222 - val_loss: 2.7575 - val_accuracy: 0.5917
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.59650
# 500/500 - 138s - loss: 0.2445 - accuracy: 0.9207 - val_loss: 2.9713 - val_accuracy: 0.5658
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.59650
# 500/500 - 138s - loss: 0.2486 - accuracy: 0.9202 - val_loss: 2.8190 - val_accuracy: 0.5870
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.59650
# 500/500 - 137s - loss: 0.2342 - accuracy: 0.9246 - val_loss: 2.7843 - val_accuracy: 0.5858
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.59650
# 500/500 - 137s - loss: 0.2352 - accuracy: 0.9229 - val_loss: 2.7178 - val_accuracy: 0.5950
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.59650
# 500/500 - 137s - loss: 0.2284 - accuracy: 0.9261 - val_loss: 2.7589 - val_accuracy: 0.5909
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.59650
# 500/500 - 137s - loss: 0.2214 - accuracy: 0.9297 - val_loss: 2.8160 - val_accuracy: 0.5865
# Epoch 89/200
#
# Epoch 00089: val_accuracy improved from 0.59650 to 0.59900, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 138s - loss: 0.2242 - accuracy: 0.9281 - val_loss: 2.5805 - val_accuracy: 0.5990
# Epoch 90/200
#
# Epoch 00090: val_accuracy improved from 0.59900 to 0.60140, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 139s - loss: 0.2171 - accuracy: 0.9314 - val_loss: 2.6140 - val_accuracy: 0.6014
# Epoch 91/200
#
# Epoch 00091: val_accuracy improved from 0.60140 to 0.60780, saving model to gdrive/My Drive/Colab Notebooks/ResNet18_SGD_Dropout_2.h5
# 500/500 - 139s - loss: 0.2105 - accuracy: 0.9333 - val_loss: 2.6037 - val_accuracy: 0.6078
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.60780
# 500/500 - 137s - loss: 0.2134 - accuracy: 0.9326 - val_loss: 2.6266 - val_accuracy: 0.5980
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.60780
# 500/500 - 137s - loss: 0.2075 - accuracy: 0.9344 - val_loss: 2.7934 - val_accuracy: 0.5908
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.60780
# 500/500 - 137s - loss: 0.2109 - accuracy: 0.9313 - val_loss: 2.7583 - val_accuracy: 0.5878
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.60780
# 500/500 - 137s - loss: 0.2054 - accuracy: 0.9347 - val_loss: 2.7324 - val_accuracy: 0.5998
# Epoch 96/200
#
# Epoch 00096: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1953 - accuracy: 0.9374 - val_loss: 2.9878 - val_accuracy: 0.5996
# Epoch 97/200
#
# Epoch 00097: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.2007 - accuracy: 0.9357 - val_loss: 2.8668 - val_accuracy: 0.5974
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1930 - accuracy: 0.9389 - val_loss: 2.8977 - val_accuracy: 0.5837
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1952 - accuracy: 0.9366 - val_loss: 2.7327 - val_accuracy: 0.5955
# Epoch 100/200
#
# Epoch 00100: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1862 - accuracy: 0.9408 - val_loss: 2.6102 - val_accuracy: 0.6030
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1861 - accuracy: 0.9394 - val_loss: 2.7120 - val_accuracy: 0.5989
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1817 - accuracy: 0.9413 - val_loss: 2.9277 - val_accuracy: 0.5963
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1814 - accuracy: 0.9424 - val_loss: 2.9600 - val_accuracy: 0.5945
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.60780
# 500/500 - 137s - loss: 0.1822 - accuracy: 0.9408 - val_loss: 2.7855 - val_accuracy: 0.5984
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1867 - accuracy: 0.9396 - val_loss: 2.7669 - val_accuracy: 0.5919
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1777 - accuracy: 0.9426 - val_loss: 2.8634 - val_accuracy: 0.5862
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.60780
# 500/500 - 137s - loss: 0.1746 - accuracy: 0.9433 - val_loss: 2.9113 - val_accuracy: 0.6061
# Epoch 108/200
#
# Epoch 00108: val_accuracy did not improve from 0.60780
# 500/500 - 137s - loss: 0.1759 - accuracy: 0.9429 - val_loss: 3.0468 - val_accuracy: 0.5982
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1772 - accuracy: 0.9427 - val_loss: 2.9843 - val_accuracy: 0.5836
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1666 - accuracy: 0.9457 - val_loss: 3.0444 - val_accuracy: 0.5899
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.60780
# 500/500 - 138s - loss: 0.1683 - accuracy: 0.9456 - val_loss: 2.8414 - val_accuracy: 0.5864
# Epoch 00111: early stopping

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best) 
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.6191829839763499
# Recall:  0.6078
# Accuracy:  0.6078
