# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input,  \
                    add, AveragePooling2D, BatchNormalization
from keras.optimizers import Adam
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 100
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch.h5"
# path_best = "../weights/Resnet18_ADAM_Batch.h5"
path_train = "gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar100.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 11s 0us/step

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def resnetBuilder(l, filters):
    x = l

    l = Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(l)
    l = BatchNormalization()(l)
    l = Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(l)
    l = BatchNormalization()(l)
    
    x = Conv2D(filters=filters, kernel_size=(1,1), padding='same', activation='relu')(x)
    x = add([x,l])
    x = Activation('relu')(x)

    return x

# %%
def createResnetModel():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    l = MaxPool2D(pool_size=(3,3))(l)

    l = resnetBuilder(l, 64)
    l = resnetBuilder(l, 64)
    l = resnetBuilder(l, 128)
    l = resnetBuilder(l, 128)
    l = resnetBuilder(l, 256)
    l = resnetBuilder(l, 256)
    l = resnetBuilder(l, 512)
    l = resnetBuilder(l, 512)

    l = AveragePooling2D(pool_size=(8,8))(l)
    l = Flatten()(l)
    output = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs=input, outputs=output)
    return model

# %%
model = createResnetModel()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 10, 10, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 10, 10, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 10, 10, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 10, 10, 64)   36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 10, 10, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 10, 10, 64)   0           conv2d_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10, 10, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 10, 10, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 10, 10, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 10, 10, 64)   36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 10, 10, 64)   4160        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10, 10, 64)   0           conv2d_6[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 10, 10, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 10, 10, 128)  73856       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 10, 10, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 10, 128)  147584      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 10, 10, 128)  8320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 10, 10, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 10, 10, 128)  0           conv2d_9[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 10, 10, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 10, 10, 128)  147584      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 10, 10, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 10, 10, 128)  147584      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 10, 10, 128)  16512       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 10, 10, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 10, 10, 128)  0           conv2d_12[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 10, 10, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 10, 10, 256)  295168      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 10, 10, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 10, 10, 256)  590080      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 10, 10, 256)  33024       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 10, 10, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 10, 10, 256)  0           conv2d_15[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 10, 10, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 10, 10, 256)  590080      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 10, 10, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 10, 10, 256)  590080      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 10, 10, 256)  65792       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 10, 10, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 10, 10, 256)  0           conv2d_18[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 10, 10, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 10, 10, 512)  1180160     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 10, 10, 512)  2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 10, 10, 512)  2359808     batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 10, 10, 512)  131584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 10, 10, 512)  2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 10, 10, 512)  0           conv2d_21[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 10, 10, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 10, 10, 512)  2359808     activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 10, 10, 512)  2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 10, 10, 512)  2359808     batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 10, 10, 512)  262656      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 10, 10, 512)  2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 10, 10, 512)  0           conv2d_24[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10, 10, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 512)    0           activation_8[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          51300       flatten[0][0]
# ==================================================================================================
# Total params: 11,591,652
# Trainable params: 11,583,972
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint, early],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.12530, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 151s - loss: 3.8638 - accuracy: 0.1120 - val_loss: 3.8875 - val_accuracy: 0.1253
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.12530 to 0.22520, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 149s - loss: 3.2655 - accuracy: 0.2065 - val_loss: 3.2698 - val_accuracy: 0.2252
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.22520 to 0.24500, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 149s - loss: 2.9667 - accuracy: 0.2620 - val_loss: 3.2245 - val_accuracy: 0.2450
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.24500 to 0.32480, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 149s - loss: 2.7168 - accuracy: 0.3118 - val_loss: 2.6790 - val_accuracy: 0.3248
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.32480 to 0.34130, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 2.4984 - accuracy: 0.3593 - val_loss: 2.6113 - val_accuracy: 0.3413
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.34130 to 0.35880, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 2.3177 - accuracy: 0.3948 - val_loss: 2.5582 - val_accuracy: 0.3588
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.35880 to 0.37670, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 149s - loss: 2.1527 - accuracy: 0.4340 - val_loss: 2.4726 - val_accuracy: 0.3767
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.37670 to 0.40030, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 2.0038 - accuracy: 0.4658 - val_loss: 2.3411 - val_accuracy: 0.4003
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.40030 to 0.43470, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 149s - loss: 1.8726 - accuracy: 0.4957 - val_loss: 2.2134 - val_accuracy: 0.4347
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.43470 to 0.44660, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 1.7608 - accuracy: 0.5224 - val_loss: 2.1519 - val_accuracy: 0.4466
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.44660 to 0.45980, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 1.6380 - accuracy: 0.5493 - val_loss: 2.0908 - val_accuracy: 0.4598
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.45980 to 0.46470, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 1.5422 - accuracy: 0.5745 - val_loss: 2.1104 - val_accuracy: 0.4647
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.46470 to 0.48400, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 1.4374 - accuracy: 0.5997 - val_loss: 2.0332 - val_accuracy: 0.4840
# Epoch 14/200
#
# Epoch 00014: val_accuracy did not improve from 0.48400
# 500/500 - 146s - loss: 1.3325 - accuracy: 0.6282 - val_loss: 2.0674 - val_accuracy: 0.4765
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.48400 to 0.49970, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 1.2472 - accuracy: 0.6458 - val_loss: 2.0035 - val_accuracy: 0.4997
# Epoch 16/200
#
# Epoch 00016: val_accuracy did not improve from 0.49970
# 500/500 - 146s - loss: 1.1601 - accuracy: 0.6692 - val_loss: 2.0824 - val_accuracy: 0.4830
# Epoch 17/200
#
# Epoch 00017: val_accuracy did not improve from 0.49970
# 500/500 - 146s - loss: 1.0704 - accuracy: 0.6942 - val_loss: 2.0836 - val_accuracy: 0.4846
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.49970 to 0.50190, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.9899 - accuracy: 0.7162 - val_loss: 2.0334 - val_accuracy: 0.5019
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.50190 to 0.51730, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.9126 - accuracy: 0.7358 - val_loss: 1.9589 - val_accuracy: 0.5173
# Epoch 20/200
#
# Epoch 00020: val_accuracy did not improve from 0.51730
# 500/500 - 146s - loss: 0.8413 - accuracy: 0.7563 - val_loss: 2.0790 - val_accuracy: 0.4959
# Epoch 21/200
#
# Epoch 00021: val_accuracy did not improve from 0.51730
# 500/500 - 146s - loss: 0.7857 - accuracy: 0.7713 - val_loss: 2.0448 - val_accuracy: 0.5092
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.51730 to 0.52140, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.7115 - accuracy: 0.7922 - val_loss: 2.0006 - val_accuracy: 0.5214
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.52140 to 0.52740, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.6546 - accuracy: 0.8076 - val_loss: 2.0087 - val_accuracy: 0.5274
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.52740
# 500/500 - 146s - loss: 0.5976 - accuracy: 0.8272 - val_loss: 2.0650 - val_accuracy: 0.5203
# Epoch 25/200
#
# Epoch 00025: val_accuracy improved from 0.52740 to 0.53180, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.5519 - accuracy: 0.8394 - val_loss: 2.0416 - val_accuracy: 0.5318
# Epoch 26/200
#
# Epoch 00026: val_accuracy did not improve from 0.53180
# 500/500 - 146s - loss: 0.5128 - accuracy: 0.8503 - val_loss: 2.1591 - val_accuracy: 0.5090
# Epoch 27/200
#
# Epoch 00027: val_accuracy did not improve from 0.53180
# 500/500 - 146s - loss: 0.4624 - accuracy: 0.8651 - val_loss: 2.1097 - val_accuracy: 0.5219
# Epoch 28/200
#
# Epoch 00028: val_accuracy did not improve from 0.53180
# 500/500 - 146s - loss: 0.4266 - accuracy: 0.8752 - val_loss: 2.1145 - val_accuracy: 0.5234
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.53180
# 500/500 - 146s - loss: 0.3945 - accuracy: 0.8856 - val_loss: 2.1917 - val_accuracy: 0.5133
# Epoch 30/200
#
# Epoch 00030: val_accuracy improved from 0.53180 to 0.53240, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.3647 - accuracy: 0.8950 - val_loss: 2.1509 - val_accuracy: 0.5324
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.53240
# 500/500 - 146s - loss: 0.3478 - accuracy: 0.8992 - val_loss: 2.3049 - val_accuracy: 0.5103
# Epoch 32/200
#
# Epoch 00032: val_accuracy did not improve from 0.53240
# 500/500 - 146s - loss: 0.3145 - accuracy: 0.9081 - val_loss: 2.1842 - val_accuracy: 0.5301
# Epoch 33/200
#
# Epoch 00033: val_accuracy did not improve from 0.53240
# 500/500 - 146s - loss: 0.2989 - accuracy: 0.9129 - val_loss: 2.3070 - val_accuracy: 0.5218
# Epoch 34/200
#
# Epoch 00034: val_accuracy improved from 0.53240 to 0.53500, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.2811 - accuracy: 0.9177 - val_loss: 2.1388 - val_accuracy: 0.5350
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.53500
# 500/500 - 146s - loss: 0.2559 - accuracy: 0.9259 - val_loss: 2.2681 - val_accuracy: 0.5213
# Epoch 36/200
#
# Epoch 00036: val_accuracy improved from 0.53500 to 0.54120, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.2392 - accuracy: 0.9316 - val_loss: 2.2364 - val_accuracy: 0.5412
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.54120
# 500/500 - 146s - loss: 0.2361 - accuracy: 0.9323 - val_loss: 2.2760 - val_accuracy: 0.5276
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.54120
# 500/500 - 146s - loss: 0.2260 - accuracy: 0.9344 - val_loss: 2.3360 - val_accuracy: 0.5298
# Epoch 39/200
#
# Epoch 00039: val_accuracy did not improve from 0.54120
# 500/500 - 146s - loss: 0.2103 - accuracy: 0.9398 - val_loss: 2.3659 - val_accuracy: 0.5265
# Epoch 40/200
#
# Epoch 00040: val_accuracy improved from 0.54120 to 0.54760, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.2034 - accuracy: 0.9421 - val_loss: 2.2549 - val_accuracy: 0.5476
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1955 - accuracy: 0.9437 - val_loss: 2.3482 - val_accuracy: 0.5271
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1901 - accuracy: 0.9441 - val_loss: 2.4077 - val_accuracy: 0.5354
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1828 - accuracy: 0.9464 - val_loss: 2.3519 - val_accuracy: 0.5408
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1719 - accuracy: 0.9497 - val_loss: 2.3804 - val_accuracy: 0.5340
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1626 - accuracy: 0.9526 - val_loss: 2.3927 - val_accuracy: 0.5371
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1587 - accuracy: 0.9537 - val_loss: 2.3627 - val_accuracy: 0.5403
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1503 - accuracy: 0.9565 - val_loss: 2.4895 - val_accuracy: 0.5326
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1474 - accuracy: 0.9572 - val_loss: 2.5019 - val_accuracy: 0.5225
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1425 - accuracy: 0.9595 - val_loss: 2.5297 - val_accuracy: 0.5324
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1404 - accuracy: 0.9588 - val_loss: 2.4382 - val_accuracy: 0.5388
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1370 - accuracy: 0.9593 - val_loss: 2.3822 - val_accuracy: 0.5458
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1343 - accuracy: 0.9619 - val_loss: 2.3849 - val_accuracy: 0.5442
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1312 - accuracy: 0.9624 - val_loss: 2.5746 - val_accuracy: 0.5297
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1277 - accuracy: 0.9628 - val_loss: 2.4817 - val_accuracy: 0.5410
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1234 - accuracy: 0.9647 - val_loss: 2.4479 - val_accuracy: 0.5437
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1189 - accuracy: 0.9656 - val_loss: 2.5533 - val_accuracy: 0.5348
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.54760
# 500/500 - 146s - loss: 0.1194 - accuracy: 0.9647 - val_loss: 2.6293 - val_accuracy: 0.5311
# Epoch 58/200
#
# Epoch 00058: val_accuracy improved from 0.54760 to 0.55000, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.1081 - accuracy: 0.9694 - val_loss: 2.4468 - val_accuracy: 0.5500
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.1122 - accuracy: 0.9673 - val_loss: 2.6717 - val_accuracy: 0.5323
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.1129 - accuracy: 0.9656 - val_loss: 2.4920 - val_accuracy: 0.5465
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.1086 - accuracy: 0.9687 - val_loss: 2.5190 - val_accuracy: 0.5418
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.1014 - accuracy: 0.9703 - val_loss: 2.5826 - val_accuracy: 0.5389
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.1032 - accuracy: 0.9698 - val_loss: 2.6173 - val_accuracy: 0.5377
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0958 - accuracy: 0.9717 - val_loss: 2.6583 - val_accuracy: 0.5427
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0964 - accuracy: 0.9720 - val_loss: 2.6676 - val_accuracy: 0.5376
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0965 - accuracy: 0.9716 - val_loss: 2.6963 - val_accuracy: 0.5290
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0903 - accuracy: 0.9732 - val_loss: 2.7660 - val_accuracy: 0.5213
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0875 - accuracy: 0.9748 - val_loss: 2.6874 - val_accuracy: 0.5328
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0901 - accuracy: 0.9735 - val_loss: 2.7474 - val_accuracy: 0.5231
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0897 - accuracy: 0.9733 - val_loss: 2.8146 - val_accuracy: 0.5112
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0882 - accuracy: 0.9739 - val_loss: 2.6024 - val_accuracy: 0.5491
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.55000
# 500/500 - 146s - loss: 0.0856 - accuracy: 0.9747 - val_loss: 2.5890 - val_accuracy: 0.5426
# Epoch 73/200
#
# Epoch 00073: val_accuracy improved from 0.55000 to 0.55900, saving model to gdrive/My Drive/Colab Notebooks/Resnet18_ADAM_Batch_2.h5
# 500/500 - 148s - loss: 0.0827 - accuracy: 0.9754 - val_loss: 2.5326 - val_accuracy: 0.5590
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0785 - accuracy: 0.9770 - val_loss: 2.6164 - val_accuracy: 0.5500
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0780 - accuracy: 0.9777 - val_loss: 2.6957 - val_accuracy: 0.5396
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0764 - accuracy: 0.9774 - val_loss: 2.6453 - val_accuracy: 0.5460
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0786 - accuracy: 0.9773 - val_loss: 2.7058 - val_accuracy: 0.5449
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.55900
# 500/500 - 145s - loss: 0.0754 - accuracy: 0.9785 - val_loss: 2.8224 - val_accuracy: 0.5398
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0795 - accuracy: 0.9759 - val_loss: 2.7520 - val_accuracy: 0.5403
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0797 - accuracy: 0.9763 - val_loss: 2.7216 - val_accuracy: 0.5508
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0734 - accuracy: 0.9779 - val_loss: 2.5985 - val_accuracy: 0.5508
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0688 - accuracy: 0.9794 - val_loss: 2.7079 - val_accuracy: 0.5542
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.55900
# 500/500 - 145s - loss: 0.0673 - accuracy: 0.9801 - val_loss: 2.7769 - val_accuracy: 0.5489
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0700 - accuracy: 0.9793 - val_loss: 2.7763 - val_accuracy: 0.5432
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.55900
# 500/500 - 145s - loss: 0.0751 - accuracy: 0.9774 - val_loss: 2.9331 - val_accuracy: 0.5361
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.55900
# 500/500 - 145s - loss: 0.0642 - accuracy: 0.9811 - val_loss: 2.6448 - val_accuracy: 0.5504
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0660 - accuracy: 0.9801 - val_loss: 2.7061 - val_accuracy: 0.5515
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0690 - accuracy: 0.9791 - val_loss: 2.7884 - val_accuracy: 0.5330
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0650 - accuracy: 0.9802 - val_loss: 2.7057 - val_accuracy: 0.5461
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0597 - accuracy: 0.9824 - val_loss: 2.9147 - val_accuracy: 0.5278
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0702 - accuracy: 0.9790 - val_loss: 2.8090 - val_accuracy: 0.5389
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0615 - accuracy: 0.9824 - val_loss: 2.7152 - val_accuracy: 0.5489
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.55900
# 500/500 - 146s - loss: 0.0613 - accuracy: 0.9818 - val_loss: 2.7690 - val_accuracy: 0.5391
# Epoch 00093: early stopping

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.578685921999758
# Recall:  0.5569
# Accuracy:  0.5569
