# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adamax
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 10
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/Dropout_3.h5"
path_train = "gdrive/My Drive/Colab Notebooks/Dropout_3.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar10.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     zca_epsilon=1e-06,
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     vertical_flip=False)

# datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu')(l_3)
    l_3 = Dropout(0.1)(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu')(l_5)
    l_5 = Dropout(0.1)(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    l_p = Dropout(0.1)(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu')(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 192)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 96)     18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 16)     3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 192)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 128)    110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 32)     12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 64)     12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 7, 7, 128)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 7, 7, 32)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 7, 7, 32)     0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 256)    0           conv2d_3[0][0]
#                                                                  dropout[0][0]
#                                                                  dropout_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 7, 7, 192)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 7, 7, 96)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 7, 7, 64)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 480)    0           conv2d_9[0][0]
#                                                                  dropout_3[0][0]
#                                                                  dropout_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 4, 4, 208)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 4, 4, 48)     0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 4, 4, 64)     0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4, 4, 512)    0           conv2d_15[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,058,154
# Trainable params: 1,058,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adamax(learning_rate=0.0001, decay=1e-06), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# model.load_weights(path_best)
history = model.fit(x_train_norm, y_train_norm,
                        batch_size=batch_size,
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.37900, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 12s - loss: 1.9282 - accuracy: 0.2895 - val_loss: 1.7061 - val_accuracy: 0.3790
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.37900 to 0.43070, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.6352 - accuracy: 0.3994 - val_loss: 1.5608 - val_accuracy: 0.4307
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.43070 to 0.46100, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.5150 - accuracy: 0.4458 - val_loss: 1.4758 - val_accuracy: 0.4610
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.46100 to 0.49670, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.4358 - accuracy: 0.4775 - val_loss: 1.3894 - val_accuracy: 0.4967
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.49670 to 0.51780, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.3793 - accuracy: 0.5010 - val_loss: 1.3390 - val_accuracy: 0.5178
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.51780 to 0.52500, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.3316 - accuracy: 0.5192 - val_loss: 1.3248 - val_accuracy: 0.5250
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.52500 to 0.54740, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.2901 - accuracy: 0.5350 - val_loss: 1.2697 - val_accuracy: 0.5474
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.54740 to 0.55760, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.2518 - accuracy: 0.5530 - val_loss: 1.2353 - val_accuracy: 0.5576
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.55760 to 0.56250, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.2140 - accuracy: 0.5664 - val_loss: 1.2223 - val_accuracy: 0.5625
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.56250 to 0.59340, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.1851 - accuracy: 0.5771 - val_loss: 1.1732 - val_accuracy: 0.5934
# Epoch 11/200
#
# Epoch 00011: val_accuracy did not improve from 0.59340
# 500/500 - 11s - loss: 1.1549 - accuracy: 0.5882 - val_loss: 1.1677 - val_accuracy: 0.5930
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.59340 to 0.60280, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.1295 - accuracy: 0.5985 - val_loss: 1.1343 - val_accuracy: 0.6028
# Epoch 13/200
#
# Epoch 00013: val_accuracy did not improve from 0.60280
# 500/500 - 11s - loss: 1.1027 - accuracy: 0.6107 - val_loss: 1.1438 - val_accuracy: 0.5969
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.60280 to 0.61700, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.0806 - accuracy: 0.6192 - val_loss: 1.0880 - val_accuracy: 0.6170
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.61700 to 0.62740, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.0560 - accuracy: 0.6276 - val_loss: 1.0692 - val_accuracy: 0.6274
# Epoch 16/200
#
# Epoch 00016: val_accuracy did not improve from 0.62740
# 500/500 - 11s - loss: 1.0329 - accuracy: 0.6348 - val_loss: 1.0675 - val_accuracy: 0.6260
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.62740 to 0.64620, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 1.0153 - accuracy: 0.6418 - val_loss: 1.0190 - val_accuracy: 0.6462
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.64620 to 0.65140, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.9944 - accuracy: 0.6515 - val_loss: 1.0123 - val_accuracy: 0.6514
# Epoch 19/200
#
# Epoch 00019: val_accuracy did not improve from 0.65140
# 500/500 - 11s - loss: 0.9749 - accuracy: 0.6569 - val_loss: 1.0047 - val_accuracy: 0.6459
# Epoch 20/200
#
# Epoch 00020: val_accuracy improved from 0.65140 to 0.65890, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.9581 - accuracy: 0.6623 - val_loss: 0.9831 - val_accuracy: 0.6589
# Epoch 21/200
#
# Epoch 00021: val_accuracy improved from 0.65890 to 0.66730, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.9405 - accuracy: 0.6706 - val_loss: 0.9663 - val_accuracy: 0.6673
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.66730 to 0.67580, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.9249 - accuracy: 0.6725 - val_loss: 0.9392 - val_accuracy: 0.6758
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.67580 to 0.67590, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.9067 - accuracy: 0.6816 - val_loss: 0.9317 - val_accuracy: 0.6759
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.67590
# 500/500 - 11s - loss: 0.8962 - accuracy: 0.6851 - val_loss: 0.9417 - val_accuracy: 0.6717
# Epoch 25/200
#
# Epoch 00025: val_accuracy did not improve from 0.67590
# 500/500 - 11s - loss: 0.8840 - accuracy: 0.6891 - val_loss: 0.9238 - val_accuracy: 0.6751
# Epoch 26/200
#
# Epoch 00026: val_accuracy improved from 0.67590 to 0.68330, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.8651 - accuracy: 0.6967 - val_loss: 0.9209 - val_accuracy: 0.6833
# Epoch 27/200
#
# Epoch 00027: val_accuracy improved from 0.68330 to 0.69040, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.8546 - accuracy: 0.6999 - val_loss: 0.8942 - val_accuracy: 0.6904
# Epoch 28/200
#
# Epoch 00028: val_accuracy improved from 0.69040 to 0.69310, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.8461 - accuracy: 0.7036 - val_loss: 0.8804 - val_accuracy: 0.6931
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.69310
# 500/500 - 11s - loss: 0.8316 - accuracy: 0.7082 - val_loss: 0.8826 - val_accuracy: 0.6923
# Epoch 30/200
#
# Epoch 00030: val_accuracy improved from 0.69310 to 0.69330, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.8169 - accuracy: 0.7122 - val_loss: 0.8807 - val_accuracy: 0.6933
# Epoch 31/200
#
# Epoch 00031: val_accuracy improved from 0.69330 to 0.70050, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.8014 - accuracy: 0.7202 - val_loss: 0.8609 - val_accuracy: 0.7005
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.70050 to 0.70920, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.7901 - accuracy: 0.7237 - val_loss: 0.8390 - val_accuracy: 0.7092
# Epoch 33/200
#
# Epoch 00033: val_accuracy improved from 0.70920 to 0.71040, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.7833 - accuracy: 0.7247 - val_loss: 0.8332 - val_accuracy: 0.7104
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.71040
# 500/500 - 11s - loss: 0.7662 - accuracy: 0.7329 - val_loss: 0.8309 - val_accuracy: 0.7069
# Epoch 35/200
#
# Epoch 00035: val_accuracy improved from 0.71040 to 0.71300, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.7552 - accuracy: 0.7347 - val_loss: 0.8195 - val_accuracy: 0.7130
# Epoch 36/200
#
# Epoch 00036: val_accuracy improved from 0.71300 to 0.72130, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.7464 - accuracy: 0.7392 - val_loss: 0.8119 - val_accuracy: 0.7213
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.72130
# 500/500 - 11s - loss: 0.7383 - accuracy: 0.7420 - val_loss: 0.8253 - val_accuracy: 0.7171
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.72130
# 500/500 - 11s - loss: 0.7275 - accuracy: 0.7455 - val_loss: 0.8183 - val_accuracy: 0.7133
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.72130 to 0.72630, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.7142 - accuracy: 0.7502 - val_loss: 0.7935 - val_accuracy: 0.7263
# Epoch 40/200
#
# Epoch 00040: val_accuracy improved from 0.72630 to 0.73190, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.7071 - accuracy: 0.7519 - val_loss: 0.7854 - val_accuracy: 0.7319
# Epoch 41/200
#
# Epoch 00041: val_accuracy improved from 0.73190 to 0.73530, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.6921 - accuracy: 0.7608 - val_loss: 0.7681 - val_accuracy: 0.7353
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.73530
# 500/500 - 11s - loss: 0.6866 - accuracy: 0.7612 - val_loss: 0.7739 - val_accuracy: 0.7322
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.73530
# 500/500 - 11s - loss: 0.6784 - accuracy: 0.7637 - val_loss: 0.7713 - val_accuracy: 0.7325
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.73530
# 500/500 - 11s - loss: 0.6668 - accuracy: 0.7669 - val_loss: 0.7780 - val_accuracy: 0.7298
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.73530
# 500/500 - 11s - loss: 0.6575 - accuracy: 0.7690 - val_loss: 0.7938 - val_accuracy: 0.7286
# Epoch 46/200
#
# Epoch 00046: val_accuracy improved from 0.73530 to 0.74030, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.6517 - accuracy: 0.7714 - val_loss: 0.7449 - val_accuracy: 0.7403
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.74030
# 500/500 - 11s - loss: 0.6420 - accuracy: 0.7766 - val_loss: 0.7711 - val_accuracy: 0.7299
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.74030
# 500/500 - 11s - loss: 0.6330 - accuracy: 0.7784 - val_loss: 0.7547 - val_accuracy: 0.7388
# Epoch 49/200
#
# Epoch 00049: val_accuracy improved from 0.74030 to 0.74170, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.6247 - accuracy: 0.7816 - val_loss: 0.7466 - val_accuracy: 0.7417
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.74170
# 500/500 - 11s - loss: 0.6178 - accuracy: 0.7850 - val_loss: 0.7666 - val_accuracy: 0.7351
# Epoch 51/200
#
# Epoch 00051: val_accuracy improved from 0.74170 to 0.75110, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.6108 - accuracy: 0.7854 - val_loss: 0.7274 - val_accuracy: 0.7511
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.75110
# 500/500 - 11s - loss: 0.6016 - accuracy: 0.7885 - val_loss: 0.7851 - val_accuracy: 0.7305
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.75110
# 500/500 - 11s - loss: 0.5934 - accuracy: 0.7918 - val_loss: 0.7561 - val_accuracy: 0.7409
# Epoch 54/200
#
# Epoch 00054: val_accuracy improved from 0.75110 to 0.75210, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.5839 - accuracy: 0.7957 - val_loss: 0.7296 - val_accuracy: 0.7521
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.75210
# 500/500 - 11s - loss: 0.5786 - accuracy: 0.7992 - val_loss: 0.7474 - val_accuracy: 0.7414
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.75210
# 500/500 - 11s - loss: 0.5713 - accuracy: 0.8005 - val_loss: 0.7189 - val_accuracy: 0.7472
# Epoch 57/200
#
# Epoch 00057: val_accuracy improved from 0.75210 to 0.75330, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.5616 - accuracy: 0.8037 - val_loss: 0.7151 - val_accuracy: 0.7533
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.75330
# 500/500 - 11s - loss: 0.5546 - accuracy: 0.8061 - val_loss: 0.7147 - val_accuracy: 0.7496
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.75330
# 500/500 - 11s - loss: 0.5457 - accuracy: 0.8116 - val_loss: 0.7203 - val_accuracy: 0.7484
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.75330
# 500/500 - 11s - loss: 0.5422 - accuracy: 0.8099 - val_loss: 0.7283 - val_accuracy: 0.7520
# Epoch 61/200
#
# Epoch 00061: val_accuracy improved from 0.75330 to 0.76080, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.5326 - accuracy: 0.8145 - val_loss: 0.6970 - val_accuracy: 0.7608
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.76080
# 500/500 - 11s - loss: 0.5242 - accuracy: 0.8181 - val_loss: 0.7061 - val_accuracy: 0.7563
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.76080
# 500/500 - 11s - loss: 0.5202 - accuracy: 0.8178 - val_loss: 0.7189 - val_accuracy: 0.7514
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.76080
# 500/500 - 11s - loss: 0.5114 - accuracy: 0.8215 - val_loss: 0.7241 - val_accuracy: 0.7477
# Epoch 65/200
#
# Epoch 00065: val_accuracy improved from 0.76080 to 0.76480, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.5055 - accuracy: 0.8235 - val_loss: 0.6811 - val_accuracy: 0.7648
# Epoch 66/200
#
# Epoch 00066: val_accuracy improved from 0.76480 to 0.76490, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.4997 - accuracy: 0.8256 - val_loss: 0.6915 - val_accuracy: 0.7649
# Epoch 67/200
#
# Epoch 00067: val_accuracy improved from 0.76490 to 0.76590, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.4914 - accuracy: 0.8283 - val_loss: 0.6762 - val_accuracy: 0.7659
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.76590
# 500/500 - 11s - loss: 0.4850 - accuracy: 0.8305 - val_loss: 0.7100 - val_accuracy: 0.7554
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.76590
# 500/500 - 11s - loss: 0.4773 - accuracy: 0.8333 - val_loss: 0.7074 - val_accuracy: 0.7595
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.76590
# 500/500 - 11s - loss: 0.4716 - accuracy: 0.8357 - val_loss: 0.6945 - val_accuracy: 0.7621
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.76590
# 500/500 - 11s - loss: 0.4647 - accuracy: 0.8374 - val_loss: 0.6818 - val_accuracy: 0.7648
# Epoch 72/200
#
# Epoch 00072: val_accuracy improved from 0.76590 to 0.77300, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.4633 - accuracy: 0.8388 - val_loss: 0.6661 - val_accuracy: 0.7730
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.77300
# 500/500 - 11s - loss: 0.4521 - accuracy: 0.8427 - val_loss: 0.6925 - val_accuracy: 0.7652
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.77300
# 500/500 - 11s - loss: 0.4476 - accuracy: 0.8437 - val_loss: 0.6847 - val_accuracy: 0.7676
# Epoch 75/200
#
# Epoch 00075: val_accuracy improved from 0.77300 to 0.77570, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.4392 - accuracy: 0.8481 - val_loss: 0.6708 - val_accuracy: 0.7757
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.4382 - accuracy: 0.8461 - val_loss: 0.7013 - val_accuracy: 0.7620
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.4291 - accuracy: 0.8505 - val_loss: 0.6812 - val_accuracy: 0.7685
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.4185 - accuracy: 0.8534 - val_loss: 0.6897 - val_accuracy: 0.7672
# Epoch 79/200
#
# Epoch 00079: val_accuracy improved from 0.77570 to 0.77750, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.4134 - accuracy: 0.8558 - val_loss: 0.6588 - val_accuracy: 0.7775
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.77750
# 500/500 - 11s - loss: 0.4111 - accuracy: 0.8583 - val_loss: 0.6651 - val_accuracy: 0.7768
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.77750
# 500/500 - 11s - loss: 0.4030 - accuracy: 0.8601 - val_loss: 0.6698 - val_accuracy: 0.7717
# Epoch 82/200
#
# Epoch 00082: val_accuracy improved from 0.77750 to 0.77940, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.3973 - accuracy: 0.8620 - val_loss: 0.6571 - val_accuracy: 0.7794
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.77940
# 500/500 - 11s - loss: 0.3917 - accuracy: 0.8632 - val_loss: 0.6719 - val_accuracy: 0.7764
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.77940
# 500/500 - 11s - loss: 0.3882 - accuracy: 0.8652 - val_loss: 0.6826 - val_accuracy: 0.7721
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.77940
# 500/500 - 11s - loss: 0.3799 - accuracy: 0.8675 - val_loss: 0.6690 - val_accuracy: 0.7782
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.77940
# 500/500 - 11s - loss: 0.3742 - accuracy: 0.8704 - val_loss: 0.6940 - val_accuracy: 0.7747
# Epoch 87/200
#
# Epoch 00087: val_accuracy improved from 0.77940 to 0.77970, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.3736 - accuracy: 0.8699 - val_loss: 0.6822 - val_accuracy: 0.7797
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.77970
# 500/500 - 11s - loss: 0.3654 - accuracy: 0.8722 - val_loss: 0.6620 - val_accuracy: 0.7784
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.77970
# 500/500 - 11s - loss: 0.3583 - accuracy: 0.8752 - val_loss: 0.6918 - val_accuracy: 0.7666
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.77970
# 500/500 - 11s - loss: 0.3501 - accuracy: 0.8781 - val_loss: 0.6992 - val_accuracy: 0.7701
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.77970
# 500/500 - 11s - loss: 0.3468 - accuracy: 0.8783 - val_loss: 0.6915 - val_accuracy: 0.7785
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.77970
# 500/500 - 11s - loss: 0.3393 - accuracy: 0.8824 - val_loss: 0.6901 - val_accuracy: 0.7734
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.77970
# 500/500 - 11s - loss: 0.3343 - accuracy: 0.8847 - val_loss: 0.6751 - val_accuracy: 0.7780
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.77970
# 500/500 - 11s - loss: 0.3322 - accuracy: 0.8849 - val_loss: 0.6678 - val_accuracy: 0.7773
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.77970
# 500/500 - 11s - loss: 0.3280 - accuracy: 0.8857 - val_loss: 0.7262 - val_accuracy: 0.7625
# Epoch 96/200
#
# Epoch 00096: val_accuracy improved from 0.77970 to 0.78090, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.3193 - accuracy: 0.8888 - val_loss: 0.6802 - val_accuracy: 0.7809
# Epoch 97/200
#
# Epoch 00097: val_accuracy did not improve from 0.78090
# 500/500 - 11s - loss: 0.3170 - accuracy: 0.8908 - val_loss: 0.6974 - val_accuracy: 0.7734
# Epoch 98/200
#
# Epoch 00098: val_accuracy improved from 0.78090 to 0.78720, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.3134 - accuracy: 0.8909 - val_loss: 0.6672 - val_accuracy: 0.7872
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.78720
# 500/500 - 11s - loss: 0.3071 - accuracy: 0.8944 - val_loss: 0.6649 - val_accuracy: 0.7871
# Epoch 100/200
#
# Epoch 00100: val_accuracy did not improve from 0.78720
# 500/500 - 11s - loss: 0.3040 - accuracy: 0.8942 - val_loss: 0.6734 - val_accuracy: 0.7834
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.78720
# 500/500 - 11s - loss: 0.2984 - accuracy: 0.8949 - val_loss: 0.6821 - val_accuracy: 0.7803
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.78720
# 500/500 - 11s - loss: 0.2949 - accuracy: 0.8978 - val_loss: 0.7081 - val_accuracy: 0.7761
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.78720
# 500/500 - 11s - loss: 0.2869 - accuracy: 0.9009 - val_loss: 0.6875 - val_accuracy: 0.7848
# Epoch 104/200
#
# Epoch 00104: val_accuracy improved from 0.78720 to 0.78740, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.2845 - accuracy: 0.9013 - val_loss: 0.6781 - val_accuracy: 0.7874
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.78740
# 500/500 - 11s - loss: 0.2763 - accuracy: 0.9046 - val_loss: 0.6822 - val_accuracy: 0.7858
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.78740
# 500/500 - 11s - loss: 0.2718 - accuracy: 0.9057 - val_loss: 0.6789 - val_accuracy: 0.7848
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.78740
# 500/500 - 11s - loss: 0.2673 - accuracy: 0.9081 - val_loss: 0.7317 - val_accuracy: 0.7733
# Epoch 108/200
#
# Epoch 00108: val_accuracy did not improve from 0.78740
# 500/500 - 11s - loss: 0.2642 - accuracy: 0.9089 - val_loss: 0.7007 - val_accuracy: 0.7814
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.78740
# 500/500 - 11s - loss: 0.2589 - accuracy: 0.9111 - val_loss: 0.6907 - val_accuracy: 0.7829
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.78740
# 500/500 - 11s - loss: 0.2541 - accuracy: 0.9126 - val_loss: 0.6929 - val_accuracy: 0.7838
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.78740
# 500/500 - 11s - loss: 0.2490 - accuracy: 0.9144 - val_loss: 0.7039 - val_accuracy: 0.7838
# Epoch 112/200
#
# Epoch 00112: val_accuracy improved from 0.78740 to 0.78770, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.2432 - accuracy: 0.9170 - val_loss: 0.6812 - val_accuracy: 0.7877
# Epoch 113/200
#
# Epoch 00113: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2410 - accuracy: 0.9169 - val_loss: 0.7046 - val_accuracy: 0.7877
# Epoch 114/200
#
# Epoch 00114: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2358 - accuracy: 0.9179 - val_loss: 0.7290 - val_accuracy: 0.7799
# Epoch 115/200
#
# Epoch 00115: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2332 - accuracy: 0.9185 - val_loss: 0.7656 - val_accuracy: 0.7686
# Epoch 116/200
#
# Epoch 00116: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2271 - accuracy: 0.9208 - val_loss: 0.7183 - val_accuracy: 0.7818
# Epoch 117/200
#
# Epoch 00117: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2286 - accuracy: 0.9218 - val_loss: 0.7100 - val_accuracy: 0.7831
# Epoch 118/200
#
# Epoch 00118: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2226 - accuracy: 0.9232 - val_loss: 0.7416 - val_accuracy: 0.7777
# Epoch 119/200
#
# Epoch 00119: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2148 - accuracy: 0.9257 - val_loss: 0.7499 - val_accuracy: 0.7824
# Epoch 120/200
#
# Epoch 00120: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2159 - accuracy: 0.9257 - val_loss: 0.7364 - val_accuracy: 0.7788
# Epoch 121/200
#
# Epoch 00121: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2055 - accuracy: 0.9295 - val_loss: 0.7264 - val_accuracy: 0.7867
# Epoch 122/200
#
# Epoch 00122: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2030 - accuracy: 0.9293 - val_loss: 0.7586 - val_accuracy: 0.7808
# Epoch 123/200
#
# Epoch 00123: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.2012 - accuracy: 0.9307 - val_loss: 0.7664 - val_accuracy: 0.7782
# Epoch 124/200
#
# Epoch 00124: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.1997 - accuracy: 0.9320 - val_loss: 0.7419 - val_accuracy: 0.7826
# Epoch 125/200
#
# Epoch 00125: val_accuracy did not improve from 0.78770
# 500/500 - 11s - loss: 0.1919 - accuracy: 0.9339 - val_loss: 0.7574 - val_accuracy: 0.7799
# Epoch 126/200
#
# Epoch 00126: val_accuracy improved from 0.78770 to 0.79260, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.1877 - accuracy: 0.9351 - val_loss: 0.7229 - val_accuracy: 0.7926
# Epoch 127/200
#
# Epoch 00127: val_accuracy did not improve from 0.79260
# 500/500 - 11s - loss: 0.1869 - accuracy: 0.9365 - val_loss: 0.7245 - val_accuracy: 0.7917
# Epoch 128/200
#
# Epoch 00128: val_accuracy did not improve from 0.79260
# 500/500 - 11s - loss: 0.1800 - accuracy: 0.9387 - val_loss: 0.7443 - val_accuracy: 0.7868
# Epoch 129/200
#
# Epoch 00129: val_accuracy did not improve from 0.79260
# 500/500 - 11s - loss: 0.1801 - accuracy: 0.9376 - val_loss: 0.8062 - val_accuracy: 0.7740
# Epoch 130/200
#
# Epoch 00130: val_accuracy did not improve from 0.79260
# 500/500 - 11s - loss: 0.1761 - accuracy: 0.9391 - val_loss: 0.7196 - val_accuracy: 0.7920
# Epoch 131/200
#
# Epoch 00131: val_accuracy did not improve from 0.79260
# 500/500 - 11s - loss: 0.1726 - accuracy: 0.9402 - val_loss: 0.7733 - val_accuracy: 0.7832
# Epoch 132/200
#
# Epoch 00132: val_accuracy improved from 0.79260 to 0.79610, saving model to gdrive/My Drive/Colab Notebooks/Dropout_3.h5
# 500/500 - 11s - loss: 0.1704 - accuracy: 0.9422 - val_loss: 0.7157 - val_accuracy: 0.7961
# Epoch 133/200
#
# Epoch 00133: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1647 - accuracy: 0.9441 - val_loss: 0.7592 - val_accuracy: 0.7868
# Epoch 134/200
#
# Epoch 00134: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1646 - accuracy: 0.9434 - val_loss: 0.7354 - val_accuracy: 0.7911
# Epoch 135/200
#
# Epoch 00135: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1580 - accuracy: 0.9475 - val_loss: 0.7468 - val_accuracy: 0.7919
# Epoch 136/200
#
# Epoch 00136: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1537 - accuracy: 0.9483 - val_loss: 0.7451 - val_accuracy: 0.7914
# Epoch 137/200
#
# Epoch 00137: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1542 - accuracy: 0.9479 - val_loss: 0.7766 - val_accuracy: 0.7837
# Epoch 138/200
#
# Epoch 00138: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1489 - accuracy: 0.9504 - val_loss: 0.7740 - val_accuracy: 0.7867
# Epoch 139/200
#
# Epoch 00139: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1450 - accuracy: 0.9515 - val_loss: 0.7544 - val_accuracy: 0.7914
# Epoch 140/200
#
# Epoch 00140: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1400 - accuracy: 0.9537 - val_loss: 0.7774 - val_accuracy: 0.7917
# Epoch 141/200
#
# Epoch 00141: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1367 - accuracy: 0.9549 - val_loss: 0.7860 - val_accuracy: 0.7891
# Epoch 142/200
#
# Epoch 00142: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1361 - accuracy: 0.9541 - val_loss: 0.7849 - val_accuracy: 0.7920
# Epoch 143/200
#
# Epoch 00143: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1359 - accuracy: 0.9548 - val_loss: 0.8078 - val_accuracy: 0.7877
# Epoch 144/200
#
# Epoch 00144: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1309 - accuracy: 0.9562 - val_loss: 0.7956 - val_accuracy: 0.7894
# Epoch 145/200
#
# Epoch 00145: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1266 - accuracy: 0.9581 - val_loss: 0.7918 - val_accuracy: 0.7901
# Epoch 146/200
#
# Epoch 00146: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1298 - accuracy: 0.9562 - val_loss: 0.8354 - val_accuracy: 0.7828
# Epoch 147/200
#
# Epoch 00147: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1245 - accuracy: 0.9590 - val_loss: 0.8066 - val_accuracy: 0.7874
# Epoch 148/200
#
# Epoch 00148: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1244 - accuracy: 0.9579 - val_loss: 0.8253 - val_accuracy: 0.7866
# Epoch 149/200
#
# Epoch 00149: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1161 - accuracy: 0.9611 - val_loss: 0.8489 - val_accuracy: 0.7834
# Epoch 150/200
#
# Epoch 00150: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1176 - accuracy: 0.9606 - val_loss: 0.8067 - val_accuracy: 0.7899
# Epoch 151/200
#
# Epoch 00151: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1123 - accuracy: 0.9623 - val_loss: 0.8297 - val_accuracy: 0.7897
# Epoch 152/200
#
# Epoch 00152: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1134 - accuracy: 0.9616 - val_loss: 0.8349 - val_accuracy: 0.7877
# Epoch 153/200
#
# Epoch 00153: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1092 - accuracy: 0.9635 - val_loss: 0.8775 - val_accuracy: 0.7808
# Epoch 154/200
#
# Epoch 00154: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1051 - accuracy: 0.9658 - val_loss: 0.8404 - val_accuracy: 0.7847
# Epoch 155/200
#
# Epoch 00155: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1036 - accuracy: 0.9656 - val_loss: 0.8092 - val_accuracy: 0.7940
# Epoch 156/200
#
# Epoch 00156: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1027 - accuracy: 0.9661 - val_loss: 0.8880 - val_accuracy: 0.7848
# Epoch 157/200
#
# Epoch 00157: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.1003 - accuracy: 0.9665 - val_loss: 0.8420 - val_accuracy: 0.7929
# Epoch 158/200
#
# Epoch 00158: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0987 - accuracy: 0.9676 - val_loss: 0.8612 - val_accuracy: 0.7876
# Epoch 159/200
#
# Epoch 00159: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0929 - accuracy: 0.9703 - val_loss: 0.9378 - val_accuracy: 0.7775
# Epoch 160/200
#
# Epoch 00160: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0960 - accuracy: 0.9681 - val_loss: 0.8762 - val_accuracy: 0.7843
# Epoch 161/200
#
# Epoch 00161: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0901 - accuracy: 0.9705 - val_loss: 0.8434 - val_accuracy: 0.7923
# Epoch 162/200
#
# Epoch 00162: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0911 - accuracy: 0.9690 - val_loss: 0.8952 - val_accuracy: 0.7885
# Epoch 163/200
#
# Epoch 00163: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0864 - accuracy: 0.9721 - val_loss: 0.8808 - val_accuracy: 0.7904
# Epoch 164/200
#
# Epoch 00164: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0865 - accuracy: 0.9704 - val_loss: 0.9300 - val_accuracy: 0.7876
# Epoch 165/200
#
# Epoch 00165: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0843 - accuracy: 0.9716 - val_loss: 0.9674 - val_accuracy: 0.7763
# Epoch 166/200
#
# Epoch 00166: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0835 - accuracy: 0.9725 - val_loss: 0.8926 - val_accuracy: 0.7909
# Epoch 167/200
#
# Epoch 00167: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0787 - accuracy: 0.9749 - val_loss: 0.9153 - val_accuracy: 0.7849
# Epoch 168/200
#
# Epoch 00168: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0800 - accuracy: 0.9730 - val_loss: 0.9163 - val_accuracy: 0.7890
# Epoch 169/200
#
# Epoch 00169: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0775 - accuracy: 0.9747 - val_loss: 0.9271 - val_accuracy: 0.7891
# Epoch 170/200
#
# Epoch 00170: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0773 - accuracy: 0.9754 - val_loss: 0.9091 - val_accuracy: 0.7891
# Epoch 171/200
#
# Epoch 00171: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0765 - accuracy: 0.9745 - val_loss: 0.9104 - val_accuracy: 0.7909
# Epoch 172/200
#
# Epoch 00172: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0704 - accuracy: 0.9777 - val_loss: 0.9786 - val_accuracy: 0.7783
# Epoch 173/200
#
# Epoch 00173: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0761 - accuracy: 0.9753 - val_loss: 0.9791 - val_accuracy: 0.7805
# Epoch 174/200
#
# Epoch 00174: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0699 - accuracy: 0.9769 - val_loss: 0.9063 - val_accuracy: 0.7918
# Epoch 175/200
#
# Epoch 00175: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0654 - accuracy: 0.9796 - val_loss: 0.9638 - val_accuracy: 0.7885
# Epoch 176/200
#
# Epoch 00176: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0690 - accuracy: 0.9780 - val_loss: 0.9465 - val_accuracy: 0.7903
# Epoch 177/200
#
# Epoch 00177: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0658 - accuracy: 0.9790 - val_loss: 0.9627 - val_accuracy: 0.7884
# Epoch 178/200
#
# Epoch 00178: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0649 - accuracy: 0.9797 - val_loss: 0.9285 - val_accuracy: 0.7907
# Epoch 179/200
#
# Epoch 00179: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0665 - accuracy: 0.9786 - val_loss: 0.9407 - val_accuracy: 0.7908
# Epoch 180/200
#
# Epoch 00180: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0596 - accuracy: 0.9812 - val_loss: 0.9403 - val_accuracy: 0.7900
# Epoch 181/200
#
# Epoch 00181: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0591 - accuracy: 0.9813 - val_loss: 0.9706 - val_accuracy: 0.7884
# Epoch 182/200
#
# Epoch 00182: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0567 - accuracy: 0.9822 - val_loss: 0.9971 - val_accuracy: 0.7838
# Epoch 183/200
#
# Epoch 00183: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0588 - accuracy: 0.9807 - val_loss: 1.0702 - val_accuracy: 0.7770
# Epoch 184/200
#
# Epoch 00184: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0584 - accuracy: 0.9809 - val_loss: 1.0515 - val_accuracy: 0.7849
# Epoch 185/200
#
# Epoch 00185: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0558 - accuracy: 0.9827 - val_loss: 1.0211 - val_accuracy: 0.7871
# Epoch 186/200
#
# Epoch 00186: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0576 - accuracy: 0.9815 - val_loss: 0.9790 - val_accuracy: 0.7899
# Epoch 187/200
#
# Epoch 00187: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0535 - accuracy: 0.9837 - val_loss: 0.9757 - val_accuracy: 0.7908
# Epoch 188/200
#
# Epoch 00188: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0516 - accuracy: 0.9841 - val_loss: 0.9754 - val_accuracy: 0.7895
# Epoch 189/200
#
# Epoch 00189: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0534 - accuracy: 0.9832 - val_loss: 0.9707 - val_accuracy: 0.7929
# Epoch 190/200
#
# Epoch 00190: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0495 - accuracy: 0.9847 - val_loss: 1.0328 - val_accuracy: 0.7824
# Epoch 191/200
#
# Epoch 00191: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0510 - accuracy: 0.9839 - val_loss: 0.9895 - val_accuracy: 0.7881
# Epoch 192/200
#
# Epoch 00192: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0504 - accuracy: 0.9842 - val_loss: 0.9941 - val_accuracy: 0.7927
# Epoch 193/200
#
# Epoch 00193: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0506 - accuracy: 0.9841 - val_loss: 0.9993 - val_accuracy: 0.7927
# Epoch 194/200
#
# Epoch 00194: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0489 - accuracy: 0.9850 - val_loss: 1.0393 - val_accuracy: 0.7877
# Epoch 195/200
#
# Epoch 00195: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0462 - accuracy: 0.9857 - val_loss: 1.0542 - val_accuracy: 0.7847
# Epoch 196/200
#
# Epoch 00196: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0450 - accuracy: 0.9863 - val_loss: 1.0858 - val_accuracy: 0.7824
# Epoch 197/200
#
# Epoch 00197: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0417 - accuracy: 0.9868 - val_loss: 1.0575 - val_accuracy: 0.7877
# Epoch 198/200
#
# Epoch 00198: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0463 - accuracy: 0.9858 - val_loss: 1.0724 - val_accuracy: 0.7861
# Epoch 199/200
#
# Epoch 00199: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0476 - accuracy: 0.9852 - val_loss: 1.0229 - val_accuracy: 0.7921
# Epoch 200/200
#
# Epoch 00200: val_accuracy did not improve from 0.79610
# 500/500 - 11s - loss: 0.0389 - accuracy: 0.9886 - val_loss: 1.0556 - val_accuracy: 0.7895

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.7975183116822876
# Recall:  0.7961
# Accuracy:  0.7961
