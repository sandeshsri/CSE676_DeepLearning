# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adamax
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 10
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/Combined_2.h5"
path_train = "gdrive/My Drive/Colab Notebooks/Combined_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar10.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(l2=0.001), bias_regularizer=l2(1e-4), activity_regularizer=l2(1e-5))(l_3)
    l_3 = Dropout(0.1)(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=l2(l2=0.001), bias_regularizer=l2(1e-4), activity_regularizer=l2(1e-5))(l_5)
    l_5 = Dropout(0.2)(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    l_p = Dropout(0.1)(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu', kernel_regularizer=l2(l2=0.001), bias_regularizer=l2(1e-4), activity_regularizer=l2(1e-5))(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    # l = BatchNormalization()(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    # l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 192)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 96)     18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 16)     3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 192)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 128)    110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 32)     12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 64)     12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 7, 7, 128)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 7, 7, 32)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 7, 7, 32)     0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 256)    0           conv2d_3[0][0]
#                                                                  dropout[0][0]
#                                                                  dropout_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 7, 7, 192)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 7, 7, 96)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 7, 7, 64)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 480)    0           conv2d_9[0][0]
#                                                                  dropout_3[0][0]
#                                                                  dropout_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 4, 4, 208)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 4, 4, 48)     0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 4, 4, 64)     0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4, 4, 512)    0           conv2d_15[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,058,154
# Trainable params: 1,058,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adamax(learning_rate=0.0001, decay=1e-06), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# model.load_weights(path_best)
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.37590, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 2.3783 - accuracy: 0.2812 - val_loss: 2.1142 - val_accuracy: 0.3759
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.37590 to 0.42080, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 2.0385 - accuracy: 0.3893 - val_loss: 1.9369 - val_accuracy: 0.4208
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.42080 to 0.46380, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.8980 - accuracy: 0.4384 - val_loss: 1.8160 - val_accuracy: 0.4638
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.46380 to 0.48710, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.8105 - accuracy: 0.4683 - val_loss: 1.7679 - val_accuracy: 0.4871
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.48710 to 0.50880, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.7433 - accuracy: 0.4920 - val_loss: 1.7058 - val_accuracy: 0.5088
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.50880 to 0.51440, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.6876 - accuracy: 0.5085 - val_loss: 1.6747 - val_accuracy: 0.5144
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.51440 to 0.52460, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.6364 - accuracy: 0.5289 - val_loss: 1.6429 - val_accuracy: 0.5246
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.52460 to 0.55290, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.5961 - accuracy: 0.5407 - val_loss: 1.5720 - val_accuracy: 0.5529
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.55290 to 0.56780, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.5610 - accuracy: 0.5524 - val_loss: 1.5569 - val_accuracy: 0.5678
# Epoch 10/200
#
# Epoch 00010: val_accuracy did not improve from 0.56780
# 500/500 - 27s - loss: 1.5285 - accuracy: 0.5630 - val_loss: 1.5249 - val_accuracy: 0.5613
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.56780 to 0.58010, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.5010 - accuracy: 0.5717 - val_loss: 1.4765 - val_accuracy: 0.5801
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.58010 to 0.58570, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 1.4648 - accuracy: 0.5818 - val_loss: 1.4584 - val_accuracy: 0.5857
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.58570 to 0.58800, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 1.4393 - accuracy: 0.5920 - val_loss: 1.4690 - val_accuracy: 0.5880
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.58800 to 0.60470, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 1.4151 - accuracy: 0.5989 - val_loss: 1.4066 - val_accuracy: 0.6047
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.60470 to 0.62420, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 1.3891 - accuracy: 0.6083 - val_loss: 1.3551 - val_accuracy: 0.6242
# Epoch 16/200
#
# Epoch 00016: val_accuracy improved from 0.62420 to 0.63490, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 1.3664 - accuracy: 0.6144 - val_loss: 1.3239 - val_accuracy: 0.6349
# Epoch 17/200
#
# Epoch 00017: val_accuracy did not improve from 0.63490
# 500/500 - 27s - loss: 1.3405 - accuracy: 0.6224 - val_loss: 1.3207 - val_accuracy: 0.6342
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.63490 to 0.63500, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 1.3197 - accuracy: 0.6289 - val_loss: 1.3147 - val_accuracy: 0.6350
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.63500 to 0.64050, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 1.3022 - accuracy: 0.6343 - val_loss: 1.3040 - val_accuracy: 0.6405
# Epoch 20/200
#
# Epoch 00020: val_accuracy did not improve from 0.64050
# 500/500 - 27s - loss: 1.2794 - accuracy: 0.6404 - val_loss: 1.2955 - val_accuracy: 0.6381
# Epoch 21/200
#
# Epoch 00021: val_accuracy improved from 0.64050 to 0.65310, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 1.2609 - accuracy: 0.6458 - val_loss: 1.2510 - val_accuracy: 0.6531
# Epoch 22/200
#
# Epoch 00022: val_accuracy did not improve from 0.65310
# 500/500 - 27s - loss: 1.2463 - accuracy: 0.6509 - val_loss: 1.2999 - val_accuracy: 0.6364
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.65310 to 0.66970, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.2289 - accuracy: 0.6592 - val_loss: 1.2011 - val_accuracy: 0.6697
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.66970
# 500/500 - 27s - loss: 1.2104 - accuracy: 0.6629 - val_loss: 1.2082 - val_accuracy: 0.6665
# Epoch 25/200
#
# Epoch 00025: val_accuracy improved from 0.66970 to 0.67620, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 1.1962 - accuracy: 0.6684 - val_loss: 1.1776 - val_accuracy: 0.6762
# Epoch 26/200
#
# Epoch 00026: val_accuracy did not improve from 0.67620
# 500/500 - 27s - loss: 1.1803 - accuracy: 0.6735 - val_loss: 1.1852 - val_accuracy: 0.6754
# Epoch 27/200
#
# Epoch 00027: val_accuracy did not improve from 0.67620
# 500/500 - 27s - loss: 1.1664 - accuracy: 0.6776 - val_loss: 1.1753 - val_accuracy: 0.6746
# Epoch 28/200
#
# Epoch 00028: val_accuracy improved from 0.67620 to 0.67990, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 1.1558 - accuracy: 0.6771 - val_loss: 1.1701 - val_accuracy: 0.6799
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.67990
# 500/500 - 27s - loss: 1.1444 - accuracy: 0.6830 - val_loss: 1.1810 - val_accuracy: 0.6750
# Epoch 30/200
#
# Epoch 00030: val_accuracy improved from 0.67990 to 0.68780, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 1.1260 - accuracy: 0.6888 - val_loss: 1.1399 - val_accuracy: 0.6878
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.68780
# 500/500 - 27s - loss: 1.1157 - accuracy: 0.6925 - val_loss: 1.2206 - val_accuracy: 0.6603
# Epoch 32/200
#
# Epoch 00032: val_accuracy did not improve from 0.68780
# 500/500 - 28s - loss: 1.1063 - accuracy: 0.6933 - val_loss: 1.1312 - val_accuracy: 0.6846
# Epoch 33/200
#
# Epoch 00033: val_accuracy improved from 0.68780 to 0.70170, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 1.0923 - accuracy: 0.7000 - val_loss: 1.0972 - val_accuracy: 0.7017
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.70170
# 500/500 - 28s - loss: 1.0791 - accuracy: 0.7041 - val_loss: 1.1277 - val_accuracy: 0.6877
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.70170
# 500/500 - 28s - loss: 1.0713 - accuracy: 0.7059 - val_loss: 1.0864 - val_accuracy: 0.7010
# Epoch 36/200
#
# Epoch 00036: val_accuracy did not improve from 0.70170
# 500/500 - 28s - loss: 1.0578 - accuracy: 0.7087 - val_loss: 1.0943 - val_accuracy: 0.6968
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.70170
# 500/500 - 28s - loss: 1.0495 - accuracy: 0.7135 - val_loss: 1.0902 - val_accuracy: 0.7007
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.70170
# 500/500 - 28s - loss: 1.0396 - accuracy: 0.7154 - val_loss: 1.1145 - val_accuracy: 0.6934
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.70170 to 0.72360, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 1.0281 - accuracy: 0.7163 - val_loss: 1.0170 - val_accuracy: 0.7236
# Epoch 40/200
#
# Epoch 00040: val_accuracy did not improve from 0.72360
# 500/500 - 27s - loss: 1.0222 - accuracy: 0.7205 - val_loss: 1.0338 - val_accuracy: 0.7205
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.72360
# 500/500 - 27s - loss: 1.0104 - accuracy: 0.7234 - val_loss: 1.0135 - val_accuracy: 0.7203
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.72360
# 500/500 - 27s - loss: 1.0004 - accuracy: 0.7258 - val_loss: 1.0478 - val_accuracy: 0.7121
# Epoch 43/200
#
# Epoch 00043: val_accuracy improved from 0.72360 to 0.72620, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 0.9969 - accuracy: 0.7267 - val_loss: 1.0093 - val_accuracy: 0.7262
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.72620
# 500/500 - 27s - loss: 0.9832 - accuracy: 0.7302 - val_loss: 1.0523 - val_accuracy: 0.7158
# Epoch 45/200
#
# Epoch 00045: val_accuracy improved from 0.72620 to 0.73090, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 0.9767 - accuracy: 0.7334 - val_loss: 1.0022 - val_accuracy: 0.7309
# Epoch 46/200
#
# Epoch 00046: val_accuracy improved from 0.73090 to 0.73190, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 0.9633 - accuracy: 0.7370 - val_loss: 1.0020 - val_accuracy: 0.7319
# Epoch 47/200
#
# Epoch 00047: val_accuracy improved from 0.73190 to 0.74400, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 0.9579 - accuracy: 0.7401 - val_loss: 0.9652 - val_accuracy: 0.7440
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.74400
# 500/500 - 27s - loss: 0.9527 - accuracy: 0.7402 - val_loss: 0.9911 - val_accuracy: 0.7361
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.74400
# 500/500 - 27s - loss: 0.9421 - accuracy: 0.7425 - val_loss: 0.9906 - val_accuracy: 0.7303
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.74400
# 500/500 - 27s - loss: 0.9384 - accuracy: 0.7438 - val_loss: 0.9764 - val_accuracy: 0.7320
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.74400
# 500/500 - 27s - loss: 0.9262 - accuracy: 0.7481 - val_loss: 0.9588 - val_accuracy: 0.7403
# Epoch 52/200
#
# Epoch 00052: val_accuracy improved from 0.74400 to 0.75240, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 0.9198 - accuracy: 0.7518 - val_loss: 0.9316 - val_accuracy: 0.7524
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.75240
# 500/500 - 28s - loss: 0.9128 - accuracy: 0.7519 - val_loss: 1.0134 - val_accuracy: 0.7174
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.75240
# 500/500 - 28s - loss: 0.9055 - accuracy: 0.7532 - val_loss: 0.9827 - val_accuracy: 0.7332
# Epoch 55/200
#
# Epoch 00055: val_accuracy improved from 0.75240 to 0.75370, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 0.8977 - accuracy: 0.7566 - val_loss: 0.9272 - val_accuracy: 0.7537
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.75370
# 500/500 - 27s - loss: 0.8926 - accuracy: 0.7602 - val_loss: 0.9248 - val_accuracy: 0.7504
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.75370
# 500/500 - 28s - loss: 0.8879 - accuracy: 0.7592 - val_loss: 0.9302 - val_accuracy: 0.7472
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.75370
# 500/500 - 27s - loss: 0.8783 - accuracy: 0.7641 - val_loss: 0.9220 - val_accuracy: 0.7528
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.75370
# 500/500 - 27s - loss: 0.8717 - accuracy: 0.7659 - val_loss: 0.9419 - val_accuracy: 0.7461
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.75370
# 500/500 - 27s - loss: 0.8717 - accuracy: 0.7637 - val_loss: 0.9515 - val_accuracy: 0.7433
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.75370
# 500/500 - 27s - loss: 0.8612 - accuracy: 0.7678 - val_loss: 0.9044 - val_accuracy: 0.7531
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.75370
# 500/500 - 27s - loss: 0.8554 - accuracy: 0.7692 - val_loss: 0.9297 - val_accuracy: 0.7485
# Epoch 63/200
#
# Epoch 00063: val_accuracy improved from 0.75370 to 0.75780, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 28s - loss: 0.8510 - accuracy: 0.7703 - val_loss: 0.8921 - val_accuracy: 0.7578
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.75780
# 500/500 - 27s - loss: 0.8494 - accuracy: 0.7719 - val_loss: 0.9395 - val_accuracy: 0.7444
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.75780
# 500/500 - 27s - loss: 0.8397 - accuracy: 0.7724 - val_loss: 0.9124 - val_accuracy: 0.7561
# Epoch 66/200
#
# Epoch 00066: val_accuracy improved from 0.75780 to 0.77030, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.8377 - accuracy: 0.7754 - val_loss: 0.8611 - val_accuracy: 0.7703
# Epoch 67/200
#
# Epoch 00067: val_accuracy improved from 0.77030 to 0.77940, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.8296 - accuracy: 0.7761 - val_loss: 0.8380 - val_accuracy: 0.7794
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.77940
# 500/500 - 26s - loss: 0.8234 - accuracy: 0.7801 - val_loss: 0.8950 - val_accuracy: 0.7601
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.77940
# 500/500 - 26s - loss: 0.8202 - accuracy: 0.7796 - val_loss: 0.8859 - val_accuracy: 0.7611
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.77940
# 500/500 - 27s - loss: 0.8146 - accuracy: 0.7808 - val_loss: 0.8969 - val_accuracy: 0.7602
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.77940
# 500/500 - 26s - loss: 0.8059 - accuracy: 0.7846 - val_loss: 0.8458 - val_accuracy: 0.7744
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.77940
# 500/500 - 26s - loss: 0.8025 - accuracy: 0.7836 - val_loss: 0.8305 - val_accuracy: 0.7781
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.77940
# 500/500 - 27s - loss: 0.7982 - accuracy: 0.7889 - val_loss: 0.9202 - val_accuracy: 0.7513
# Epoch 74/200
#
# Epoch 00074: val_accuracy improved from 0.77940 to 0.78280, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.7897 - accuracy: 0.7911 - val_loss: 0.8211 - val_accuracy: 0.7828
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.78280
# 500/500 - 26s - loss: 0.7887 - accuracy: 0.7883 - val_loss: 0.8326 - val_accuracy: 0.7821
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.78280
# 500/500 - 27s - loss: 0.7819 - accuracy: 0.7926 - val_loss: 0.8411 - val_accuracy: 0.7727
# Epoch 77/200
#
# Epoch 00077: val_accuracy improved from 0.78280 to 0.78600, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.7806 - accuracy: 0.7916 - val_loss: 0.8118 - val_accuracy: 0.7860
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.78600
# 500/500 - 27s - loss: 0.7776 - accuracy: 0.7919 - val_loss: 0.8671 - val_accuracy: 0.7617
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.78600
# 500/500 - 27s - loss: 0.7743 - accuracy: 0.7920 - val_loss: 0.8545 - val_accuracy: 0.7701
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.78600
# 500/500 - 26s - loss: 0.7703 - accuracy: 0.7944 - val_loss: 0.8571 - val_accuracy: 0.7665
# Epoch 81/200
#
# Epoch 00081: val_accuracy improved from 0.78600 to 0.79260, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.7577 - accuracy: 0.7989 - val_loss: 0.7782 - val_accuracy: 0.7926
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.79260
# 500/500 - 26s - loss: 0.7634 - accuracy: 0.7954 - val_loss: 0.8130 - val_accuracy: 0.7855
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.79260
# 500/500 - 26s - loss: 0.7571 - accuracy: 0.7988 - val_loss: 0.8071 - val_accuracy: 0.7858
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.79260
# 500/500 - 26s - loss: 0.7476 - accuracy: 0.8023 - val_loss: 0.8060 - val_accuracy: 0.7824
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.79260
# 500/500 - 26s - loss: 0.7444 - accuracy: 0.8025 - val_loss: 0.8154 - val_accuracy: 0.7838
# Epoch 86/200
#
# Epoch 00086: val_accuracy improved from 0.79260 to 0.79440, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.7429 - accuracy: 0.8036 - val_loss: 0.7745 - val_accuracy: 0.7944
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.79440
# 500/500 - 26s - loss: 0.7387 - accuracy: 0.8045 - val_loss: 0.8183 - val_accuracy: 0.7787
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.79440
# 500/500 - 26s - loss: 0.7372 - accuracy: 0.8042 - val_loss: 0.7843 - val_accuracy: 0.7928
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.79440
# 500/500 - 26s - loss: 0.7345 - accuracy: 0.8048 - val_loss: 0.8533 - val_accuracy: 0.7708
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.79440
# 500/500 - 26s - loss: 0.7279 - accuracy: 0.8066 - val_loss: 0.7912 - val_accuracy: 0.7875
# Epoch 91/200
#
# Epoch 00091: val_accuracy improved from 0.79440 to 0.79650, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.7176 - accuracy: 0.8081 - val_loss: 0.7640 - val_accuracy: 0.7965
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.79650
# 500/500 - 26s - loss: 0.7180 - accuracy: 0.8091 - val_loss: 0.7890 - val_accuracy: 0.7876
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.79650
# 500/500 - 26s - loss: 0.7130 - accuracy: 0.8108 - val_loss: 0.7962 - val_accuracy: 0.7878
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.79650
# 500/500 - 26s - loss: 0.7098 - accuracy: 0.8124 - val_loss: 0.7635 - val_accuracy: 0.7942
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.79650
# 500/500 - 26s - loss: 0.7091 - accuracy: 0.8120 - val_loss: 0.7922 - val_accuracy: 0.7837
# Epoch 96/200
#
# Epoch 00096: val_accuracy improved from 0.79650 to 0.79680, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.7080 - accuracy: 0.8144 - val_loss: 0.7625 - val_accuracy: 0.7968
# Epoch 97/200
#
# Epoch 00097: val_accuracy improved from 0.79680 to 0.80170, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.6981 - accuracy: 0.8147 - val_loss: 0.7423 - val_accuracy: 0.8017
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.80170
# 500/500 - 26s - loss: 0.6982 - accuracy: 0.8156 - val_loss: 0.8031 - val_accuracy: 0.7832
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.80170
# 500/500 - 26s - loss: 0.6919 - accuracy: 0.8184 - val_loss: 0.7841 - val_accuracy: 0.7886
# Epoch 100/200
#
# Epoch 00100: val_accuracy improved from 0.80170 to 0.80270, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.6920 - accuracy: 0.8172 - val_loss: 0.7484 - val_accuracy: 0.8027
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.80270
# 500/500 - 26s - loss: 0.6834 - accuracy: 0.8189 - val_loss: 0.8004 - val_accuracy: 0.7842
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.80270
# 500/500 - 26s - loss: 0.6811 - accuracy: 0.8205 - val_loss: 0.7674 - val_accuracy: 0.7891
# Epoch 103/200
#
# Epoch 00103: val_accuracy improved from 0.80270 to 0.80700, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.6798 - accuracy: 0.8220 - val_loss: 0.7284 - val_accuracy: 0.8070
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.80700
# 500/500 - 26s - loss: 0.6794 - accuracy: 0.8220 - val_loss: 0.7600 - val_accuracy: 0.8001
# Epoch 105/200
#
# Epoch 00105: val_accuracy improved from 0.80700 to 0.81160, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.6800 - accuracy: 0.8214 - val_loss: 0.7133 - val_accuracy: 0.8116
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.81160
# 500/500 - 26s - loss: 0.6709 - accuracy: 0.8230 - val_loss: 0.7236 - val_accuracy: 0.8094
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.81160
# 500/500 - 26s - loss: 0.6709 - accuracy: 0.8234 - val_loss: 0.7671 - val_accuracy: 0.7940
# Epoch 108/200
#
# Epoch 00108: val_accuracy improved from 0.81160 to 0.81350, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.6671 - accuracy: 0.8245 - val_loss: 0.7170 - val_accuracy: 0.8135
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6627 - accuracy: 0.8260 - val_loss: 0.7437 - val_accuracy: 0.8023
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6579 - accuracy: 0.8280 - val_loss: 0.7322 - val_accuracy: 0.8060
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6571 - accuracy: 0.8271 - val_loss: 0.7495 - val_accuracy: 0.8014
# Epoch 112/200
#
# Epoch 00112: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6540 - accuracy: 0.8280 - val_loss: 0.7194 - val_accuracy: 0.8064
# Epoch 113/200
#
# Epoch 00113: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6531 - accuracy: 0.8287 - val_loss: 0.7055 - val_accuracy: 0.8122
# Epoch 114/200
#
# Epoch 00114: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6509 - accuracy: 0.8294 - val_loss: 0.7290 - val_accuracy: 0.8055
# Epoch 115/200
#
# Epoch 00115: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6428 - accuracy: 0.8321 - val_loss: 0.7091 - val_accuracy: 0.8119
# Epoch 116/200
#
# Epoch 00116: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6444 - accuracy: 0.8327 - val_loss: 0.6987 - val_accuracy: 0.8134
# Epoch 117/200
#
# Epoch 00117: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6413 - accuracy: 0.8314 - val_loss: 0.7132 - val_accuracy: 0.8116
# Epoch 118/200
#
# Epoch 00118: val_accuracy did not improve from 0.81350
# 500/500 - 26s - loss: 0.6385 - accuracy: 0.8325 - val_loss: 0.7244 - val_accuracy: 0.8049
# Epoch 119/200
#
# Epoch 00119: val_accuracy improved from 0.81350 to 0.81600, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.6345 - accuracy: 0.8356 - val_loss: 0.6949 - val_accuracy: 0.8160
# Epoch 120/200
#
# Epoch 00120: val_accuracy did not improve from 0.81600
# 500/500 - 26s - loss: 0.6266 - accuracy: 0.8383 - val_loss: 0.7254 - val_accuracy: 0.8061
# Epoch 121/200
#
# Epoch 00121: val_accuracy did not improve from 0.81600
# 500/500 - 26s - loss: 0.6284 - accuracy: 0.8368 - val_loss: 0.7033 - val_accuracy: 0.8146
# Epoch 122/200
#
# Epoch 00122: val_accuracy improved from 0.81600 to 0.81930, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.6267 - accuracy: 0.8376 - val_loss: 0.6889 - val_accuracy: 0.8193
# Epoch 123/200
#
# Epoch 00123: val_accuracy did not improve from 0.81930
# 500/500 - 26s - loss: 0.6223 - accuracy: 0.8392 - val_loss: 0.6872 - val_accuracy: 0.8183
# Epoch 124/200
#
# Epoch 00124: val_accuracy did not improve from 0.81930
# 500/500 - 26s - loss: 0.6150 - accuracy: 0.8407 - val_loss: 0.7050 - val_accuracy: 0.8141
# Epoch 125/200
#
# Epoch 00125: val_accuracy did not improve from 0.81930
# 500/500 - 26s - loss: 0.6168 - accuracy: 0.8389 - val_loss: 0.7225 - val_accuracy: 0.8047
# Epoch 126/200
#
# Epoch 00126: val_accuracy did not improve from 0.81930
# 500/500 - 26s - loss: 0.6098 - accuracy: 0.8415 - val_loss: 0.6840 - val_accuracy: 0.8192
# Epoch 127/200
#
# Epoch 00127: val_accuracy did not improve from 0.81930
# 500/500 - 26s - loss: 0.6123 - accuracy: 0.8404 - val_loss: 0.6855 - val_accuracy: 0.8185
# Epoch 128/200
#
# Epoch 00128: val_accuracy improved from 0.81930 to 0.82430, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.6117 - accuracy: 0.8419 - val_loss: 0.6731 - val_accuracy: 0.8243
# Epoch 129/200
#
# Epoch 00129: val_accuracy did not improve from 0.82430
# 500/500 - 26s - loss: 0.6060 - accuracy: 0.8424 - val_loss: 0.7549 - val_accuracy: 0.7983
# Epoch 130/200
#
# Epoch 00130: val_accuracy did not improve from 0.82430
# 500/500 - 26s - loss: 0.6087 - accuracy: 0.8414 - val_loss: 0.6698 - val_accuracy: 0.8216
# Epoch 131/200
#
# Epoch 00131: val_accuracy did not improve from 0.82430
# 500/500 - 26s - loss: 0.5995 - accuracy: 0.8441 - val_loss: 0.7670 - val_accuracy: 0.7927
# Epoch 132/200
#
# Epoch 00132: val_accuracy did not improve from 0.82430
# 500/500 - 26s - loss: 0.6005 - accuracy: 0.8440 - val_loss: 0.7222 - val_accuracy: 0.8077
# Epoch 133/200
#
# Epoch 00133: val_accuracy did not improve from 0.82430
# 500/500 - 26s - loss: 0.5987 - accuracy: 0.8455 - val_loss: 0.6876 - val_accuracy: 0.8170
# Epoch 134/200
#
# Epoch 00134: val_accuracy did not improve from 0.82430
# 500/500 - 26s - loss: 0.5983 - accuracy: 0.8445 - val_loss: 0.7155 - val_accuracy: 0.8100
# Epoch 135/200
#
# Epoch 00135: val_accuracy did not improve from 0.82430
# 500/500 - 26s - loss: 0.5885 - accuracy: 0.8489 - val_loss: 0.6843 - val_accuracy: 0.8193
# Epoch 136/200
#
# Epoch 00136: val_accuracy did not improve from 0.82430
# 500/500 - 26s - loss: 0.5833 - accuracy: 0.8509 - val_loss: 0.7208 - val_accuracy: 0.8093
# Epoch 137/200
#
# Epoch 00137: val_accuracy improved from 0.82430 to 0.82970, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.5870 - accuracy: 0.8484 - val_loss: 0.6499 - val_accuracy: 0.8297
# Epoch 138/200
#
# Epoch 00138: val_accuracy did not improve from 0.82970
# 500/500 - 26s - loss: 0.5838 - accuracy: 0.8488 - val_loss: 0.6695 - val_accuracy: 0.8203
# Epoch 139/200
#
# Epoch 00139: val_accuracy did not improve from 0.82970
# 500/500 - 26s - loss: 0.5809 - accuracy: 0.8510 - val_loss: 0.6482 - val_accuracy: 0.8294
# Epoch 140/200
#
# Epoch 00140: val_accuracy did not improve from 0.82970
# 500/500 - 26s - loss: 0.5798 - accuracy: 0.8516 - val_loss: 0.7183 - val_accuracy: 0.8086
# Epoch 141/200
#
# Epoch 00141: val_accuracy did not improve from 0.82970
# 500/500 - 26s - loss: 0.5777 - accuracy: 0.8508 - val_loss: 0.6535 - val_accuracy: 0.8267
# Epoch 142/200
#
# Epoch 00142: val_accuracy did not improve from 0.82970
# 500/500 - 26s - loss: 0.5794 - accuracy: 0.8511 - val_loss: 0.6504 - val_accuracy: 0.8292
# Epoch 143/200
#
# Epoch 00143: val_accuracy did not improve from 0.82970
# 500/500 - 26s - loss: 0.5775 - accuracy: 0.8506 - val_loss: 0.6724 - val_accuracy: 0.8247
# Epoch 144/200
#
# Epoch 00144: val_accuracy did not improve from 0.82970
# 500/500 - 26s - loss: 0.5721 - accuracy: 0.8527 - val_loss: 0.6470 - val_accuracy: 0.8283
# Epoch 145/200
#
# Epoch 00145: val_accuracy improved from 0.82970 to 0.83220, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 27s - loss: 0.5654 - accuracy: 0.8554 - val_loss: 0.6394 - val_accuracy: 0.8322
# Epoch 146/200
#
# Epoch 00146: val_accuracy did not improve from 0.83220
# 500/500 - 26s - loss: 0.5661 - accuracy: 0.8555 - val_loss: 0.6951 - val_accuracy: 0.8165
# Epoch 147/200
#
# Epoch 00147: val_accuracy did not improve from 0.83220
# 500/500 - 26s - loss: 0.5670 - accuracy: 0.8558 - val_loss: 0.6803 - val_accuracy: 0.8212
# Epoch 148/200
#
# Epoch 00148: val_accuracy did not improve from 0.83220
# 500/500 - 26s - loss: 0.5638 - accuracy: 0.8560 - val_loss: 0.6516 - val_accuracy: 0.8273
# Epoch 149/200
#
# Epoch 00149: val_accuracy did not improve from 0.83220
# 500/500 - 26s - loss: 0.5610 - accuracy: 0.8568 - val_loss: 0.6730 - val_accuracy: 0.8230
# Epoch 150/200
#
# Epoch 00150: val_accuracy did not improve from 0.83220
# 500/500 - 26s - loss: 0.5585 - accuracy: 0.8562 - val_loss: 0.6972 - val_accuracy: 0.8133
# Epoch 151/200
#
# Epoch 00151: val_accuracy did not improve from 0.83220
# 500/500 - 26s - loss: 0.5570 - accuracy: 0.8578 - val_loss: 0.6680 - val_accuracy: 0.8247
# Epoch 152/200
#
# Epoch 00152: val_accuracy did not improve from 0.83220
# 500/500 - 26s - loss: 0.5520 - accuracy: 0.8585 - val_loss: 0.6824 - val_accuracy: 0.8194
# Epoch 153/200
#
# Epoch 00153: val_accuracy did not improve from 0.83220
# 500/500 - 26s - loss: 0.5527 - accuracy: 0.8611 - val_loss: 0.6392 - val_accuracy: 0.8314
# Epoch 154/200
#
# Epoch 00154: val_accuracy improved from 0.83220 to 0.83620, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.5485 - accuracy: 0.8609 - val_loss: 0.6314 - val_accuracy: 0.8362
# Epoch 155/200
#
# Epoch 00155: val_accuracy improved from 0.83620 to 0.83680, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.5458 - accuracy: 0.8613 - val_loss: 0.6270 - val_accuracy: 0.8368
# Epoch 156/200
#
# Epoch 00156: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5441 - accuracy: 0.8606 - val_loss: 0.6430 - val_accuracy: 0.8290
# Epoch 157/200
#
# Epoch 00157: val_accuracy did not improve from 0.83680
# 500/500 - 25s - loss: 0.5392 - accuracy: 0.8628 - val_loss: 0.6876 - val_accuracy: 0.8206
# Epoch 158/200
#
# Epoch 00158: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5406 - accuracy: 0.8620 - val_loss: 0.6290 - val_accuracy: 0.8345
# Epoch 159/200
#
# Epoch 00159: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5436 - accuracy: 0.8617 - val_loss: 0.6642 - val_accuracy: 0.8226
# Epoch 160/200
#
# Epoch 00160: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5385 - accuracy: 0.8631 - val_loss: 0.6621 - val_accuracy: 0.8271
# Epoch 161/200
#
# Epoch 00161: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5343 - accuracy: 0.8648 - val_loss: 0.6504 - val_accuracy: 0.8294
# Epoch 162/200
#
# Epoch 00162: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5372 - accuracy: 0.8630 - val_loss: 0.6473 - val_accuracy: 0.8282
# Epoch 163/200
#
# Epoch 00163: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5355 - accuracy: 0.8647 - val_loss: 0.6244 - val_accuracy: 0.8364
# Epoch 164/200
#
# Epoch 00164: val_accuracy did not improve from 0.83680
# 500/500 - 25s - loss: 0.5298 - accuracy: 0.8665 - val_loss: 0.6879 - val_accuracy: 0.8201
# Epoch 165/200
#
# Epoch 00165: val_accuracy did not improve from 0.83680
# 500/500 - 25s - loss: 0.5288 - accuracy: 0.8653 - val_loss: 0.6438 - val_accuracy: 0.8300
# Epoch 166/200
#
# Epoch 00166: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5264 - accuracy: 0.8668 - val_loss: 0.6288 - val_accuracy: 0.8353
# Epoch 167/200
#
# Epoch 00167: val_accuracy did not improve from 0.83680
# 500/500 - 25s - loss: 0.5265 - accuracy: 0.8668 - val_loss: 0.6736 - val_accuracy: 0.8215
# Epoch 168/200
#
# Epoch 00168: val_accuracy did not improve from 0.83680
# 500/500 - 26s - loss: 0.5228 - accuracy: 0.8673 - val_loss: 0.6417 - val_accuracy: 0.8314
# Epoch 169/200
#
# Epoch 00169: val_accuracy improved from 0.83680 to 0.83760, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.5207 - accuracy: 0.8693 - val_loss: 0.6225 - val_accuracy: 0.8376
# Epoch 170/200
#
# Epoch 00170: val_accuracy did not improve from 0.83760
# 500/500 - 26s - loss: 0.5154 - accuracy: 0.8701 - val_loss: 0.6731 - val_accuracy: 0.8183
# Epoch 171/200
#
# Epoch 00171: val_accuracy did not improve from 0.83760
# 500/500 - 25s - loss: 0.5178 - accuracy: 0.8693 - val_loss: 0.6512 - val_accuracy: 0.8281
# Epoch 172/200
#
# Epoch 00172: val_accuracy did not improve from 0.83760
# 500/500 - 26s - loss: 0.5139 - accuracy: 0.8709 - val_loss: 0.6754 - val_accuracy: 0.8215
# Epoch 173/200
#
# Epoch 00173: val_accuracy did not improve from 0.83760
# 500/500 - 26s - loss: 0.5136 - accuracy: 0.8706 - val_loss: 0.6797 - val_accuracy: 0.8195
# Epoch 174/200
#
# Epoch 00174: val_accuracy did not improve from 0.83760
# 500/500 - 25s - loss: 0.5115 - accuracy: 0.8725 - val_loss: 0.6651 - val_accuracy: 0.8223
# Epoch 175/200
#
# Epoch 00175: val_accuracy did not improve from 0.83760
# 500/500 - 26s - loss: 0.5075 - accuracy: 0.8736 - val_loss: 0.6347 - val_accuracy: 0.8323
# Epoch 176/200
#
# Epoch 00176: val_accuracy did not improve from 0.83760
# 500/500 - 25s - loss: 0.5059 - accuracy: 0.8738 - val_loss: 0.6609 - val_accuracy: 0.8249
# Epoch 177/200
#
# Epoch 00177: val_accuracy did not improve from 0.83760
# 500/500 - 25s - loss: 0.5057 - accuracy: 0.8738 - val_loss: 0.6428 - val_accuracy: 0.8333
# Epoch 178/200
#
# Epoch 00178: val_accuracy did not improve from 0.83760
# 500/500 - 25s - loss: 0.5041 - accuracy: 0.8739 - val_loss: 0.6615 - val_accuracy: 0.8268
# Epoch 179/200
#
# Epoch 00179: val_accuracy did not improve from 0.83760
# 500/500 - 25s - loss: 0.5022 - accuracy: 0.8750 - val_loss: 0.6377 - val_accuracy: 0.8314
# Epoch 180/200
#
# Epoch 00180: val_accuracy improved from 0.83760 to 0.83780, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.5024 - accuracy: 0.8738 - val_loss: 0.6157 - val_accuracy: 0.8378
# Epoch 181/200
#
# Epoch 00181: val_accuracy did not improve from 0.83780
# 500/500 - 25s - loss: 0.4995 - accuracy: 0.8756 - val_loss: 0.6989 - val_accuracy: 0.8136
# Epoch 182/200
#
# Epoch 00182: val_accuracy improved from 0.83780 to 0.83910, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.5003 - accuracy: 0.8755 - val_loss: 0.6196 - val_accuracy: 0.8391
# Epoch 183/200
#
# Epoch 00183: val_accuracy did not improve from 0.83910
# 500/500 - 26s - loss: 0.4951 - accuracy: 0.8771 - val_loss: 0.6837 - val_accuracy: 0.8173
# Epoch 184/200
#
# Epoch 00184: val_accuracy did not improve from 0.83910
# 500/500 - 26s - loss: 0.5003 - accuracy: 0.8749 - val_loss: 0.6217 - val_accuracy: 0.8371
# Epoch 185/200
#
# Epoch 00185: val_accuracy improved from 0.83910 to 0.84040, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.4899 - accuracy: 0.8764 - val_loss: 0.6188 - val_accuracy: 0.8404
# Epoch 186/200
#
# Epoch 00186: val_accuracy improved from 0.84040 to 0.84420, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.4928 - accuracy: 0.8759 - val_loss: 0.6006 - val_accuracy: 0.8442
# Epoch 187/200
#
# Epoch 00187: val_accuracy did not improve from 0.84420
# 500/500 - 26s - loss: 0.4864 - accuracy: 0.8793 - val_loss: 0.6109 - val_accuracy: 0.8388
# Epoch 188/200
#
# Epoch 00188: val_accuracy did not improve from 0.84420
# 500/500 - 26s - loss: 0.4854 - accuracy: 0.8798 - val_loss: 0.6323 - val_accuracy: 0.8341
# Epoch 189/200
#
# Epoch 00189: val_accuracy did not improve from 0.84420
# 500/500 - 26s - loss: 0.4885 - accuracy: 0.8793 - val_loss: 0.6430 - val_accuracy: 0.8283
# Epoch 190/200
#
# Epoch 00190: val_accuracy did not improve from 0.84420
# 500/500 - 26s - loss: 0.4856 - accuracy: 0.8807 - val_loss: 0.6572 - val_accuracy: 0.8237
# Epoch 191/200
#
# Epoch 00191: val_accuracy did not improve from 0.84420
# 500/500 - 26s - loss: 0.4840 - accuracy: 0.8799 - val_loss: 0.6207 - val_accuracy: 0.8388
# Epoch 192/200
#
# Epoch 00192: val_accuracy did not improve from 0.84420
# 500/500 - 26s - loss: 0.4805 - accuracy: 0.8808 - val_loss: 0.6703 - val_accuracy: 0.8234
# Epoch 193/200
#
# Epoch 00193: val_accuracy improved from 0.84420 to 0.84470, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.4804 - accuracy: 0.8822 - val_loss: 0.5964 - val_accuracy: 0.8447
# Epoch 194/200
#
# Epoch 00194: val_accuracy did not improve from 0.84470
# 500/500 - 26s - loss: 0.4787 - accuracy: 0.8817 - val_loss: 0.6979 - val_accuracy: 0.8179
# Epoch 195/200
#
# Epoch 00195: val_accuracy did not improve from 0.84470
# 500/500 - 25s - loss: 0.4787 - accuracy: 0.8810 - val_loss: 0.6214 - val_accuracy: 0.8364
# Epoch 196/200
#
# Epoch 00196: val_accuracy improved from 0.84470 to 0.84810, saving model to gdrive/My Drive/Colab Notebooks/Combined_2.h5
# 500/500 - 26s - loss: 0.4724 - accuracy: 0.8836 - val_loss: 0.5851 - val_accuracy: 0.8481
# Epoch 197/200
#
# Epoch 00197: val_accuracy did not improve from 0.84810
# 500/500 - 26s - loss: 0.4724 - accuracy: 0.8831 - val_loss: 0.6110 - val_accuracy: 0.8392
# Epoch 198/200
#
# Epoch 00198: val_accuracy did not improve from 0.84810
# 500/500 - 25s - loss: 0.4714 - accuracy: 0.8838 - val_loss: 0.5927 - val_accuracy: 0.8433
# Epoch 199/200
#
# Epoch 00199: val_accuracy did not improve from 0.84810
# 500/500 - 25s - loss: 0.4719 - accuracy: 0.8830 - val_loss: 0.6150 - val_accuracy: 0.8421
# Epoch 200/200
#
# Epoch 00200: val_accuracy did not improve from 0.84810
# 500/500 - 25s - loss: 0.4687 - accuracy: 0.8854 - val_loss: 0.5904 - val_accuracy: 0.8436

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.8485449745661212
# Recall:  0.8481
# Accuracy:  0.8481
