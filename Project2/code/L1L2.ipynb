# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adamax
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l1_l2
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 10
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/L1L2_1.h5"
path_train = "gdrive/My Drive/Colab Notebooks/L1L2_1.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar10.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     zca_epsilon=1e-06,
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     vertical_flip=False)

# datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l1_l2(l1=0.0001, l2=0.001))(l_3)
    # l_3 = BatchNormalization()(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=l1_l2(l1=0.0001, l2=0.001))(l_5)
    # l_5 = BatchNormalization()(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    # l_p = BatchNormalization()(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu', kernel_regularizer=l1_l2(l1=0.0001, l2=0.001))(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    # l = BatchNormalization()(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    # l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 192)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 96)     18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 16)     3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 192)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 64)     12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 128)    110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 32)     12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 256)    0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 480)    0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4, 4, 512)    0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,058,154
# Trainable params: 1,058,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adamax(learning_rate=0.0001, decay=1e-06), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# model.load_weights(path_best)
history = model.fit(x_train_norm, y_train_norm,
                        batch_size=batch_size,
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint],verbose=2)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_train_batch_end` time: 0.0142s). Check your callbacks.
#
# Epoch 00001: val_accuracy improved from -inf to 0.36400, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 3.5394 - accuracy: 0.2885 - val_loss: 3.0157 - val_accuracy: 0.3640
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.36400 to 0.42300, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.8668 - accuracy: 0.3951 - val_loss: 2.7639 - val_accuracy: 0.4230
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.42300 to 0.46030, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.6763 - accuracy: 0.4408 - val_loss: 2.5929 - val_accuracy: 0.4603
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.46030 to 0.47170, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.5529 - accuracy: 0.4729 - val_loss: 2.5458 - val_accuracy: 0.4717
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.47170 to 0.50470, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.4627 - accuracy: 0.4959 - val_loss: 2.4148 - val_accuracy: 0.5047
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.50470 to 0.51630, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.3848 - accuracy: 0.5158 - val_loss: 2.3511 - val_accuracy: 0.5163
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.51630 to 0.52880, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.3176 - accuracy: 0.5295 - val_loss: 2.2976 - val_accuracy: 0.5288
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.52880 to 0.53910, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.2619 - accuracy: 0.5410 - val_loss: 2.2617 - val_accuracy: 0.5391
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.53910 to 0.54450, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.2139 - accuracy: 0.5521 - val_loss: 2.2178 - val_accuracy: 0.5445
# Epoch 10/200
#
# Epoch 00010: val_accuracy did not improve from 0.54450
# 500/500 - 11s - loss: 2.1666 - accuracy: 0.5635 - val_loss: 2.1844 - val_accuracy: 0.5429
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.54450 to 0.56520, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.1200 - accuracy: 0.5721 - val_loss: 2.1292 - val_accuracy: 0.5652
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.56520 to 0.58510, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 2.0781 - accuracy: 0.5820 - val_loss: 2.0594 - val_accuracy: 0.5851
# Epoch 13/200
#
# Epoch 00013: val_accuracy did not improve from 0.58510
# 500/500 - 11s - loss: 2.0381 - accuracy: 0.5900 - val_loss: 2.0315 - val_accuracy: 0.5842
# Epoch 14/200
#
# Epoch 00014: val_accuracy did not improve from 0.58510
# 500/500 - 11s - loss: 2.0013 - accuracy: 0.5979 - val_loss: 2.0255 - val_accuracy: 0.5822
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.58510 to 0.59720, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.9704 - accuracy: 0.6030 - val_loss: 1.9758 - val_accuracy: 0.5972
# Epoch 16/200
#
# Epoch 00016: val_accuracy did not improve from 0.59720
# 500/500 - 11s - loss: 1.9404 - accuracy: 0.6066 - val_loss: 1.9583 - val_accuracy: 0.5951
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.59720 to 0.60260, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.9046 - accuracy: 0.6156 - val_loss: 1.9219 - val_accuracy: 0.6026
# Epoch 18/200
#
# Epoch 00018: val_accuracy did not improve from 0.60260
# 500/500 - 11s - loss: 1.8744 - accuracy: 0.6194 - val_loss: 1.9160 - val_accuracy: 0.5981
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.60260 to 0.62250, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.8486 - accuracy: 0.6264 - val_loss: 1.8553 - val_accuracy: 0.6225
# Epoch 20/200
#
# Epoch 00020: val_accuracy improved from 0.62250 to 0.62400, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.8230 - accuracy: 0.6272 - val_loss: 1.8281 - val_accuracy: 0.6240
# Epoch 21/200
#
# Epoch 00021: val_accuracy did not improve from 0.62400
# 500/500 - 11s - loss: 1.7926 - accuracy: 0.6351 - val_loss: 1.8379 - val_accuracy: 0.6172
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.62400 to 0.62500, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.7712 - accuracy: 0.6375 - val_loss: 1.8108 - val_accuracy: 0.6250
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.62500 to 0.64030, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.7468 - accuracy: 0.6414 - val_loss: 1.7512 - val_accuracy: 0.6403
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.64030
# 500/500 - 11s - loss: 1.7260 - accuracy: 0.6443 - val_loss: 1.7457 - val_accuracy: 0.6371
# Epoch 25/200
#
# Epoch 00025: val_accuracy improved from 0.64030 to 0.64600, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.7009 - accuracy: 0.6510 - val_loss: 1.7172 - val_accuracy: 0.6460
# Epoch 26/200
#
# Epoch 00026: val_accuracy did not improve from 0.64600
# 500/500 - 11s - loss: 1.6812 - accuracy: 0.6522 - val_loss: 1.7129 - val_accuracy: 0.6430
# Epoch 27/200
#
# Epoch 00027: val_accuracy did not improve from 0.64600
# 500/500 - 11s - loss: 1.6605 - accuracy: 0.6574 - val_loss: 1.6886 - val_accuracy: 0.6448
# Epoch 28/200
#
# Epoch 00028: val_accuracy did not improve from 0.64600
# 500/500 - 11s - loss: 1.6411 - accuracy: 0.6617 - val_loss: 1.6938 - val_accuracy: 0.6361
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.64600
# 500/500 - 11s - loss: 1.6175 - accuracy: 0.6645 - val_loss: 1.6688 - val_accuracy: 0.6414
# Epoch 30/200
#
# Epoch 00030: val_accuracy improved from 0.64600 to 0.66100, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.6020 - accuracy: 0.6677 - val_loss: 1.6239 - val_accuracy: 0.6610
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.66100
# 500/500 - 11s - loss: 1.5842 - accuracy: 0.6714 - val_loss: 1.6099 - val_accuracy: 0.6597
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.66100 to 0.67050, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.5624 - accuracy: 0.6767 - val_loss: 1.5831 - val_accuracy: 0.6705
# Epoch 33/200
#
# Epoch 00033: val_accuracy did not improve from 0.67050
# 500/500 - 11s - loss: 1.5481 - accuracy: 0.6785 - val_loss: 1.5746 - val_accuracy: 0.6678
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.67050
# 500/500 - 11s - loss: 1.5301 - accuracy: 0.6806 - val_loss: 1.5863 - val_accuracy: 0.6606
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.67050
# 500/500 - 11s - loss: 1.5128 - accuracy: 0.6864 - val_loss: 1.5590 - val_accuracy: 0.6681
# Epoch 36/200
#
# Epoch 00036: val_accuracy did not improve from 0.67050
# 500/500 - 11s - loss: 1.5011 - accuracy: 0.6857 - val_loss: 1.5525 - val_accuracy: 0.6631
# Epoch 37/200
#
# Epoch 00037: val_accuracy improved from 0.67050 to 0.67460, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.4806 - accuracy: 0.6912 - val_loss: 1.5371 - val_accuracy: 0.6746
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.67460
# 500/500 - 11s - loss: 1.4695 - accuracy: 0.6925 - val_loss: 1.5250 - val_accuracy: 0.6712
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.67460 to 0.67970, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.4571 - accuracy: 0.6945 - val_loss: 1.5045 - val_accuracy: 0.6797
# Epoch 40/200
#
# Epoch 00040: val_accuracy improved from 0.67970 to 0.68160, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.4396 - accuracy: 0.6986 - val_loss: 1.4826 - val_accuracy: 0.6816
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.68160
# 500/500 - 11s - loss: 1.4263 - accuracy: 0.7011 - val_loss: 1.4834 - val_accuracy: 0.6814
# Epoch 42/200
#
# Epoch 00042: val_accuracy improved from 0.68160 to 0.68290, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.4109 - accuracy: 0.7046 - val_loss: 1.4794 - val_accuracy: 0.6829
# Epoch 43/200
#
# Epoch 00043: val_accuracy improved from 0.68290 to 0.69730, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.4005 - accuracy: 0.7079 - val_loss: 1.4341 - val_accuracy: 0.6973
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.69730
# 500/500 - 11s - loss: 1.3877 - accuracy: 0.7098 - val_loss: 1.4311 - val_accuracy: 0.6925
# Epoch 45/200
#
# Epoch 00045: val_accuracy improved from 0.69730 to 0.70040, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.3736 - accuracy: 0.7112 - val_loss: 1.4173 - val_accuracy: 0.7004
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.70040
# 500/500 - 11s - loss: 1.3591 - accuracy: 0.7142 - val_loss: 1.4570 - val_accuracy: 0.6800
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.70040
# 500/500 - 11s - loss: 1.3513 - accuracy: 0.7172 - val_loss: 1.4176 - val_accuracy: 0.6901
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.70040
# 500/500 - 11s - loss: 1.3378 - accuracy: 0.7199 - val_loss: 1.4019 - val_accuracy: 0.6981
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.70040
# 500/500 - 11s - loss: 1.3270 - accuracy: 0.7204 - val_loss: 1.3950 - val_accuracy: 0.6998
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.70040
# 500/500 - 11s - loss: 1.3176 - accuracy: 0.7220 - val_loss: 1.3989 - val_accuracy: 0.6951
# Epoch 51/200
#
# Epoch 00051: val_accuracy improved from 0.70040 to 0.70120, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.3078 - accuracy: 0.7246 - val_loss: 1.3739 - val_accuracy: 0.7012
# Epoch 52/200
#
# Epoch 00052: val_accuracy improved from 0.70120 to 0.70190, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.2943 - accuracy: 0.7266 - val_loss: 1.3774 - val_accuracy: 0.7019
# Epoch 53/200
#
# Epoch 00053: val_accuracy improved from 0.70190 to 0.71390, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.2876 - accuracy: 0.7279 - val_loss: 1.3388 - val_accuracy: 0.7139
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.71390
# 500/500 - 11s - loss: 1.2759 - accuracy: 0.7311 - val_loss: 1.3428 - val_accuracy: 0.7054
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.71390
# 500/500 - 11s - loss: 1.2650 - accuracy: 0.7331 - val_loss: 1.3502 - val_accuracy: 0.7023
# Epoch 56/200
#
# Epoch 00056: val_accuracy improved from 0.71390 to 0.72070, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.2517 - accuracy: 0.7362 - val_loss: 1.3155 - val_accuracy: 0.7207
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.72070
# 500/500 - 11s - loss: 1.2478 - accuracy: 0.7348 - val_loss: 1.3552 - val_accuracy: 0.7007
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.72070
# 500/500 - 11s - loss: 1.2374 - accuracy: 0.7376 - val_loss: 1.2950 - val_accuracy: 0.7207
# Epoch 59/200
#
# Epoch 00059: val_accuracy improved from 0.72070 to 0.72280, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.2259 - accuracy: 0.7408 - val_loss: 1.2934 - val_accuracy: 0.7228
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.72280
# 500/500 - 11s - loss: 1.2217 - accuracy: 0.7422 - val_loss: 1.3006 - val_accuracy: 0.7131
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.72280
# 500/500 - 11s - loss: 1.2089 - accuracy: 0.7449 - val_loss: 1.2998 - val_accuracy: 0.7181
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.72280
# 500/500 - 11s - loss: 1.1980 - accuracy: 0.7475 - val_loss: 1.2836 - val_accuracy: 0.7209
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.72280
# 500/500 - 11s - loss: 1.1960 - accuracy: 0.7472 - val_loss: 1.2882 - val_accuracy: 0.7155
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.72280
# 500/500 - 11s - loss: 1.1866 - accuracy: 0.7492 - val_loss: 1.2880 - val_accuracy: 0.7149
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.72280
# 500/500 - 11s - loss: 1.1748 - accuracy: 0.7524 - val_loss: 1.3038 - val_accuracy: 0.7169
# Epoch 66/200
#
# Epoch 00066: val_accuracy improved from 0.72280 to 0.72920, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.1685 - accuracy: 0.7538 - val_loss: 1.2561 - val_accuracy: 0.7292
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.72920
# 500/500 - 11s - loss: 1.1591 - accuracy: 0.7559 - val_loss: 1.2552 - val_accuracy: 0.7248
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.72920
# 500/500 - 11s - loss: 1.1478 - accuracy: 0.7577 - val_loss: 1.2763 - val_accuracy: 0.7192
# Epoch 69/200
#
# Epoch 00069: val_accuracy improved from 0.72920 to 0.73710, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.1451 - accuracy: 0.7569 - val_loss: 1.2315 - val_accuracy: 0.7371
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.73710
# 500/500 - 11s - loss: 1.1380 - accuracy: 0.7597 - val_loss: 1.2485 - val_accuracy: 0.7227
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.73710
# 500/500 - 11s - loss: 1.1299 - accuracy: 0.7635 - val_loss: 1.2330 - val_accuracy: 0.7292
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.73710
# 500/500 - 11s - loss: 1.1254 - accuracy: 0.7633 - val_loss: 1.2187 - val_accuracy: 0.7320
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.73710
# 500/500 - 11s - loss: 1.1146 - accuracy: 0.7648 - val_loss: 1.2165 - val_accuracy: 0.7360
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.73710
# 500/500 - 11s - loss: 1.1127 - accuracy: 0.7668 - val_loss: 1.2270 - val_accuracy: 0.7262
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.73710
# 500/500 - 11s - loss: 1.1049 - accuracy: 0.7662 - val_loss: 1.2251 - val_accuracy: 0.7251
# Epoch 76/200
#
# Epoch 00076: val_accuracy improved from 0.73710 to 0.74270, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.0929 - accuracy: 0.7718 - val_loss: 1.1918 - val_accuracy: 0.7427
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0856 - accuracy: 0.7732 - val_loss: 1.1865 - val_accuracy: 0.7364
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0804 - accuracy: 0.7724 - val_loss: 1.2074 - val_accuracy: 0.7315
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0707 - accuracy: 0.7751 - val_loss: 1.1908 - val_accuracy: 0.7367
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0678 - accuracy: 0.7747 - val_loss: 1.1720 - val_accuracy: 0.7387
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0604 - accuracy: 0.7774 - val_loss: 1.2290 - val_accuracy: 0.7243
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0531 - accuracy: 0.7803 - val_loss: 1.1738 - val_accuracy: 0.7419
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0473 - accuracy: 0.7821 - val_loss: 1.1982 - val_accuracy: 0.7375
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0454 - accuracy: 0.7814 - val_loss: 1.1947 - val_accuracy: 0.7358
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.74270
# 500/500 - 11s - loss: 1.0395 - accuracy: 0.7822 - val_loss: 1.1593 - val_accuracy: 0.7385
# Epoch 86/200
#
# Epoch 00086: val_accuracy improved from 0.74270 to 0.74810, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.0280 - accuracy: 0.7857 - val_loss: 1.1459 - val_accuracy: 0.7481
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.74810
# 500/500 - 11s - loss: 1.0239 - accuracy: 0.7865 - val_loss: 1.1450 - val_accuracy: 0.7454
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.74810
# 500/500 - 11s - loss: 1.0184 - accuracy: 0.7880 - val_loss: 1.1480 - val_accuracy: 0.7481
# Epoch 89/200
#
# Epoch 00089: val_accuracy improved from 0.74810 to 0.75480, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.0144 - accuracy: 0.7879 - val_loss: 1.1291 - val_accuracy: 0.7548
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.75480
# 500/500 - 11s - loss: 1.0065 - accuracy: 0.7907 - val_loss: 1.1262 - val_accuracy: 0.7522
# Epoch 91/200
#
# Epoch 00091: val_accuracy improved from 0.75480 to 0.75520, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 1.0065 - accuracy: 0.7880 - val_loss: 1.1149 - val_accuracy: 0.7552
# Epoch 92/200
#
# Epoch 00092: val_accuracy improved from 0.75520 to 0.75630, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.9921 - accuracy: 0.7920 - val_loss: 1.1078 - val_accuracy: 0.7563
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.75630
# 500/500 - 11s - loss: 0.9880 - accuracy: 0.7942 - val_loss: 1.1368 - val_accuracy: 0.7481
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.75630
# 500/500 - 11s - loss: 0.9842 - accuracy: 0.7954 - val_loss: 1.1895 - val_accuracy: 0.7211
# Epoch 95/200
#
# Epoch 00095: val_accuracy improved from 0.75630 to 0.75650, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.9778 - accuracy: 0.7972 - val_loss: 1.1174 - val_accuracy: 0.7565
# Epoch 96/200
#
# Epoch 00096: val_accuracy did not improve from 0.75650
# 500/500 - 11s - loss: 0.9727 - accuracy: 0.7968 - val_loss: 1.1480 - val_accuracy: 0.7433
# Epoch 97/200
#
# Epoch 00097: val_accuracy improved from 0.75650 to 0.75800, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.9656 - accuracy: 0.8003 - val_loss: 1.1092 - val_accuracy: 0.7580
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.75800
# 500/500 - 11s - loss: 0.9628 - accuracy: 0.8003 - val_loss: 1.1184 - val_accuracy: 0.7515
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.75800
# 500/500 - 11s - loss: 0.9634 - accuracy: 0.7990 - val_loss: 1.1000 - val_accuracy: 0.7560
# Epoch 100/200
#
# Epoch 00100: val_accuracy did not improve from 0.75800
# 500/500 - 11s - loss: 0.9487 - accuracy: 0.8048 - val_loss: 1.1037 - val_accuracy: 0.7549
# Epoch 101/200
#
# Epoch 00101: val_accuracy improved from 0.75800 to 0.75830, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.9444 - accuracy: 0.8068 - val_loss: 1.0938 - val_accuracy: 0.7583
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.75830
# 500/500 - 11s - loss: 0.9428 - accuracy: 0.8047 - val_loss: 1.0991 - val_accuracy: 0.7560
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.75830
# 500/500 - 11s - loss: 0.9357 - accuracy: 0.8087 - val_loss: 1.1101 - val_accuracy: 0.7477
# Epoch 104/200
#
# Epoch 00104: val_accuracy improved from 0.75830 to 0.75860, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.9280 - accuracy: 0.8098 - val_loss: 1.0910 - val_accuracy: 0.7586
# Epoch 105/200
#
# Epoch 00105: val_accuracy improved from 0.75860 to 0.76420, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.9290 - accuracy: 0.8089 - val_loss: 1.0694 - val_accuracy: 0.7642
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.9228 - accuracy: 0.8097 - val_loss: 1.0911 - val_accuracy: 0.7613
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.9194 - accuracy: 0.8129 - val_loss: 1.1282 - val_accuracy: 0.7472
# Epoch 108/200
#
# Epoch 00108: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.9095 - accuracy: 0.8152 - val_loss: 1.0655 - val_accuracy: 0.7621
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.9050 - accuracy: 0.8159 - val_loss: 1.0865 - val_accuracy: 0.7563
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.9029 - accuracy: 0.8177 - val_loss: 1.0723 - val_accuracy: 0.7621
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.8951 - accuracy: 0.8179 - val_loss: 1.0904 - val_accuracy: 0.7566
# Epoch 112/200
#
# Epoch 00112: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.8923 - accuracy: 0.8200 - val_loss: 1.0643 - val_accuracy: 0.7629
# Epoch 113/200
#
# Epoch 00113: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.8877 - accuracy: 0.8211 - val_loss: 1.0936 - val_accuracy: 0.7543
# Epoch 114/200
#
# Epoch 00114: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.8841 - accuracy: 0.8229 - val_loss: 1.0625 - val_accuracy: 0.7622
# Epoch 115/200
#
# Epoch 00115: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.8803 - accuracy: 0.8229 - val_loss: 1.0693 - val_accuracy: 0.7604
# Epoch 116/200
#
# Epoch 00116: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.8755 - accuracy: 0.8241 - val_loss: 1.0591 - val_accuracy: 0.7634
# Epoch 117/200
#
# Epoch 00117: val_accuracy did not improve from 0.76420
# 500/500 - 11s - loss: 0.8711 - accuracy: 0.8229 - val_loss: 1.0618 - val_accuracy: 0.7581
# Epoch 118/200
#
# Epoch 00118: val_accuracy improved from 0.76420 to 0.76840, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.8683 - accuracy: 0.8253 - val_loss: 1.0396 - val_accuracy: 0.7684
# Epoch 119/200
#
# Epoch 00119: val_accuracy did not improve from 0.76840
# 500/500 - 11s - loss: 0.8627 - accuracy: 0.8269 - val_loss: 1.0533 - val_accuracy: 0.7651
# Epoch 120/200
#
# Epoch 00120: val_accuracy did not improve from 0.76840
# 500/500 - 11s - loss: 0.8586 - accuracy: 0.8286 - val_loss: 1.0422 - val_accuracy: 0.7659
# Epoch 121/200
#
# Epoch 00121: val_accuracy did not improve from 0.76840
# 500/500 - 11s - loss: 0.8546 - accuracy: 0.8281 - val_loss: 1.0555 - val_accuracy: 0.7611
# Epoch 122/200
#
# Epoch 00122: val_accuracy did not improve from 0.76840
# 500/500 - 11s - loss: 0.8433 - accuracy: 0.8344 - val_loss: 1.0339 - val_accuracy: 0.7673
# Epoch 123/200
#
# Epoch 00123: val_accuracy did not improve from 0.76840
# 500/500 - 11s - loss: 0.8448 - accuracy: 0.8331 - val_loss: 1.0678 - val_accuracy: 0.7586
# Epoch 124/200
#
# Epoch 00124: val_accuracy improved from 0.76840 to 0.77570, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.8442 - accuracy: 0.8309 - val_loss: 1.0171 - val_accuracy: 0.7757
# Epoch 125/200
#
# Epoch 00125: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8328 - accuracy: 0.8363 - val_loss: 1.0395 - val_accuracy: 0.7678
# Epoch 126/200
#
# Epoch 00126: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8284 - accuracy: 0.8375 - val_loss: 1.0274 - val_accuracy: 0.7726
# Epoch 127/200
#
# Epoch 00127: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8286 - accuracy: 0.8359 - val_loss: 1.0309 - val_accuracy: 0.7700
# Epoch 128/200
#
# Epoch 00128: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8175 - accuracy: 0.8388 - val_loss: 1.0289 - val_accuracy: 0.7707
# Epoch 129/200
#
# Epoch 00129: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8157 - accuracy: 0.8406 - val_loss: 1.0243 - val_accuracy: 0.7707
# Epoch 130/200
#
# Epoch 00130: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8173 - accuracy: 0.8397 - val_loss: 1.0426 - val_accuracy: 0.7711
# Epoch 131/200
#
# Epoch 00131: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8152 - accuracy: 0.8398 - val_loss: 1.0285 - val_accuracy: 0.7687
# Epoch 132/200
#
# Epoch 00132: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8068 - accuracy: 0.8425 - val_loss: 1.0688 - val_accuracy: 0.7584
# Epoch 133/200
#
# Epoch 00133: val_accuracy did not improve from 0.77570
# 500/500 - 11s - loss: 0.8029 - accuracy: 0.8438 - val_loss: 1.0633 - val_accuracy: 0.7649
# Epoch 134/200
#
# Epoch 00134: val_accuracy improved from 0.77570 to 0.78110, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.8012 - accuracy: 0.8425 - val_loss: 0.9981 - val_accuracy: 0.7811
# Epoch 135/200
#
# Epoch 00135: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7974 - accuracy: 0.8444 - val_loss: 1.0176 - val_accuracy: 0.7765
# Epoch 136/200
#
# Epoch 00136: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7912 - accuracy: 0.8464 - val_loss: 1.0115 - val_accuracy: 0.7792
# Epoch 137/200
#
# Epoch 00137: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7902 - accuracy: 0.8470 - val_loss: 1.0121 - val_accuracy: 0.7800
# Epoch 138/200
#
# Epoch 00138: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7867 - accuracy: 0.8470 - val_loss: 1.0292 - val_accuracy: 0.7674
# Epoch 139/200
#
# Epoch 00139: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7792 - accuracy: 0.8501 - val_loss: 1.0415 - val_accuracy: 0.7616
# Epoch 140/200
#
# Epoch 00140: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7800 - accuracy: 0.8497 - val_loss: 1.0293 - val_accuracy: 0.7699
# Epoch 141/200
#
# Epoch 00141: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7729 - accuracy: 0.8523 - val_loss: 1.0162 - val_accuracy: 0.7756
# Epoch 142/200
#
# Epoch 00142: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7707 - accuracy: 0.8523 - val_loss: 1.0158 - val_accuracy: 0.7764
# Epoch 143/200
#
# Epoch 00143: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7662 - accuracy: 0.8543 - val_loss: 0.9890 - val_accuracy: 0.7811
# Epoch 144/200
#
# Epoch 00144: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7602 - accuracy: 0.8551 - val_loss: 1.0162 - val_accuracy: 0.7724
# Epoch 145/200
#
# Epoch 00145: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7594 - accuracy: 0.8555 - val_loss: 1.0143 - val_accuracy: 0.7741
# Epoch 146/200
#
# Epoch 00146: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7586 - accuracy: 0.8571 - val_loss: 1.0244 - val_accuracy: 0.7702
# Epoch 147/200
#
# Epoch 00147: val_accuracy did not improve from 0.78110
# 500/500 - 11s - loss: 0.7509 - accuracy: 0.8573 - val_loss: 0.9995 - val_accuracy: 0.7788
# Epoch 148/200
#
# Epoch 00148: val_accuracy improved from 0.78110 to 0.78180, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.7514 - accuracy: 0.8577 - val_loss: 0.9851 - val_accuracy: 0.7818
# Epoch 149/200
#
# Epoch 00149: val_accuracy did not improve from 0.78180
# 500/500 - 11s - loss: 0.7439 - accuracy: 0.8612 - val_loss: 1.0016 - val_accuracy: 0.7760
# Epoch 150/200
#
# Epoch 00150: val_accuracy did not improve from 0.78180
# 500/500 - 11s - loss: 0.7450 - accuracy: 0.8608 - val_loss: 1.0451 - val_accuracy: 0.7664
# Epoch 151/200
#
# Epoch 00151: val_accuracy did not improve from 0.78180
# 500/500 - 11s - loss: 0.7374 - accuracy: 0.8619 - val_loss: 1.0185 - val_accuracy: 0.7711
# Epoch 152/200
#
# Epoch 00152: val_accuracy improved from 0.78180 to 0.78290, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.7338 - accuracy: 0.8640 - val_loss: 0.9823 - val_accuracy: 0.7829
# Epoch 153/200
#
# Epoch 00153: val_accuracy did not improve from 0.78290
# 500/500 - 11s - loss: 0.7304 - accuracy: 0.8651 - val_loss: 1.0174 - val_accuracy: 0.7746
# Epoch 154/200
#
# Epoch 00154: val_accuracy did not improve from 0.78290
# 500/500 - 11s - loss: 0.7255 - accuracy: 0.8676 - val_loss: 1.0046 - val_accuracy: 0.7740
# Epoch 155/200
#
# Epoch 00155: val_accuracy did not improve from 0.78290
# 500/500 - 11s - loss: 0.7208 - accuracy: 0.8672 - val_loss: 0.9965 - val_accuracy: 0.7775
# Epoch 156/200
#
# Epoch 00156: val_accuracy did not improve from 0.78290
# 500/500 - 11s - loss: 0.7191 - accuracy: 0.8682 - val_loss: 1.0086 - val_accuracy: 0.7766
# Epoch 157/200
#
# Epoch 00157: val_accuracy did not improve from 0.78290
# 500/500 - 11s - loss: 0.7180 - accuracy: 0.8681 - val_loss: 1.0266 - val_accuracy: 0.7734
# Epoch 158/200
#
# Epoch 00158: val_accuracy improved from 0.78290 to 0.78360, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.7090 - accuracy: 0.8721 - val_loss: 0.9809 - val_accuracy: 0.7836
# Epoch 159/200
#
# Epoch 00159: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.7127 - accuracy: 0.8700 - val_loss: 1.0229 - val_accuracy: 0.7741
# Epoch 160/200
#
# Epoch 00160: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.7077 - accuracy: 0.8714 - val_loss: 1.0300 - val_accuracy: 0.7690
# Epoch 161/200
#
# Epoch 00161: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.7016 - accuracy: 0.8744 - val_loss: 0.9949 - val_accuracy: 0.7794
# Epoch 162/200
#
# Epoch 00162: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.7007 - accuracy: 0.8725 - val_loss: 0.9821 - val_accuracy: 0.7809
# Epoch 163/200
#
# Epoch 00163: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.6965 - accuracy: 0.8767 - val_loss: 1.0105 - val_accuracy: 0.7726
# Epoch 164/200
#
# Epoch 00164: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.6923 - accuracy: 0.8760 - val_loss: 0.9911 - val_accuracy: 0.7783
# Epoch 165/200
#
# Epoch 00165: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.6910 - accuracy: 0.8766 - val_loss: 1.0043 - val_accuracy: 0.7812
# Epoch 166/200
#
# Epoch 00166: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.6911 - accuracy: 0.8765 - val_loss: 1.0494 - val_accuracy: 0.7638
# Epoch 167/200
#
# Epoch 00167: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.6863 - accuracy: 0.8768 - val_loss: 1.0180 - val_accuracy: 0.7740
# Epoch 168/200
#
# Epoch 00168: val_accuracy did not improve from 0.78360
# 500/500 - 11s - loss: 0.6802 - accuracy: 0.8787 - val_loss: 1.1381 - val_accuracy: 0.7402
# Epoch 169/200
#
# Epoch 00169: val_accuracy improved from 0.78360 to 0.78700, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.6818 - accuracy: 0.8798 - val_loss: 0.9729 - val_accuracy: 0.7870
# Epoch 170/200
#
# Epoch 00170: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6764 - accuracy: 0.8799 - val_loss: 0.9831 - val_accuracy: 0.7862
# Epoch 171/200
#
# Epoch 00171: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6718 - accuracy: 0.8829 - val_loss: 0.9967 - val_accuracy: 0.7787
# Epoch 172/200
#
# Epoch 00172: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6678 - accuracy: 0.8853 - val_loss: 0.9861 - val_accuracy: 0.7823
# Epoch 173/200
#
# Epoch 00173: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6655 - accuracy: 0.8843 - val_loss: 0.9856 - val_accuracy: 0.7805
# Epoch 174/200
#
# Epoch 00174: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6606 - accuracy: 0.8852 - val_loss: 1.0073 - val_accuracy: 0.7755
# Epoch 175/200
#
# Epoch 00175: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6575 - accuracy: 0.8867 - val_loss: 0.9910 - val_accuracy: 0.7824
# Epoch 176/200
#
# Epoch 00176: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6564 - accuracy: 0.8869 - val_loss: 0.9672 - val_accuracy: 0.7863
# Epoch 177/200
#
# Epoch 00177: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6509 - accuracy: 0.8893 - val_loss: 1.0115 - val_accuracy: 0.7801
# Epoch 178/200
#
# Epoch 00178: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6497 - accuracy: 0.8899 - val_loss: 0.9922 - val_accuracy: 0.7802
# Epoch 179/200
#
# Epoch 00179: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6468 - accuracy: 0.8882 - val_loss: 1.0022 - val_accuracy: 0.7769
# Epoch 180/200
#
# Epoch 00180: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6435 - accuracy: 0.8916 - val_loss: 0.9870 - val_accuracy: 0.7826
# Epoch 181/200
#
# Epoch 00181: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6408 - accuracy: 0.8928 - val_loss: 0.9913 - val_accuracy: 0.7855
# Epoch 182/200
#
# Epoch 00182: val_accuracy did not improve from 0.78700
# 500/500 - 11s - loss: 0.6386 - accuracy: 0.8939 - val_loss: 1.0010 - val_accuracy: 0.7804
# Epoch 183/200
#
# Epoch 00183: val_accuracy improved from 0.78700 to 0.78840, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.6358 - accuracy: 0.8946 - val_loss: 0.9675 - val_accuracy: 0.7884
# Epoch 184/200
#
# Epoch 00184: val_accuracy did not improve from 0.78840
# 500/500 - 11s - loss: 0.6322 - accuracy: 0.8945 - val_loss: 0.9943 - val_accuracy: 0.7833
# Epoch 185/200
#
# Epoch 00185: val_accuracy did not improve from 0.78840
# 500/500 - 11s - loss: 0.6244 - accuracy: 0.8979 - val_loss: 0.9986 - val_accuracy: 0.7818
# Epoch 186/200
#
# Epoch 00186: val_accuracy did not improve from 0.78840
# 500/500 - 11s - loss: 0.6223 - accuracy: 0.8988 - val_loss: 0.9825 - val_accuracy: 0.7879
# Epoch 187/200
#
# Epoch 00187: val_accuracy did not improve from 0.78840
# 500/500 - 11s - loss: 0.6228 - accuracy: 0.8974 - val_loss: 1.0121 - val_accuracy: 0.7830
# Epoch 188/200
#
# Epoch 00188: val_accuracy did not improve from 0.78840
# 500/500 - 11s - loss: 0.6177 - accuracy: 0.9007 - val_loss: 0.9920 - val_accuracy: 0.7862
# Epoch 189/200
#
# Epoch 00189: val_accuracy did not improve from 0.78840
# 500/500 - 11s - loss: 0.6146 - accuracy: 0.9009 - val_loss: 0.9871 - val_accuracy: 0.7884
# Epoch 190/200
#
# Epoch 00190: val_accuracy did not improve from 0.78840
# 500/500 - 11s - loss: 0.6148 - accuracy: 0.9005 - val_loss: 1.0497 - val_accuracy: 0.7734
# Epoch 191/200
#
# Epoch 00191: val_accuracy did not improve from 0.78840
# 500/500 - 11s - loss: 0.6121 - accuracy: 0.8998 - val_loss: 0.9863 - val_accuracy: 0.7843
# Epoch 192/200
#
# Epoch 00192: val_accuracy improved from 0.78840 to 0.78940, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.6044 - accuracy: 0.9033 - val_loss: 0.9803 - val_accuracy: 0.7894
# Epoch 193/200
#
# Epoch 00193: val_accuracy did not improve from 0.78940
# 500/500 - 11s - loss: 0.5999 - accuracy: 0.9062 - val_loss: 1.0439 - val_accuracy: 0.7757
# Epoch 194/200
#
# Epoch 00194: val_accuracy did not improve from 0.78940
# 500/500 - 11s - loss: 0.6016 - accuracy: 0.9054 - val_loss: 0.9721 - val_accuracy: 0.7884
# Epoch 195/200
#
# Epoch 00195: val_accuracy improved from 0.78940 to 0.79230, saving model to gdrive/My Drive/Colab Notebooks/L1L2_1.h5
# 500/500 - 11s - loss: 0.5994 - accuracy: 0.9045 - val_loss: 0.9767 - val_accuracy: 0.7923
# Epoch 196/200
#
# Epoch 00196: val_accuracy did not improve from 0.79230
# 500/500 - 11s - loss: 0.5895 - accuracy: 0.9108 - val_loss: 1.0059 - val_accuracy: 0.7820
# Epoch 197/200
#
# Epoch 00197: val_accuracy did not improve from 0.79230
# 500/500 - 11s - loss: 0.5904 - accuracy: 0.9088 - val_loss: 0.9884 - val_accuracy: 0.7875
# Epoch 198/200
#
# Epoch 00198: val_accuracy did not improve from 0.79230
# 500/500 - 11s - loss: 0.5848 - accuracy: 0.9108 - val_loss: 0.9836 - val_accuracy: 0.7884
# Epoch 199/200
#
# Epoch 00199: val_accuracy did not improve from 0.79230
# 500/500 - 11s - loss: 0.5884 - accuracy: 0.9092 - val_loss: 1.0062 - val_accuracy: 0.7786
# Epoch 200/200
#
# Epoch 00200: val_accuracy did not improve from 0.79230
# 500/500 - 11s - loss: 0.5876 - accuracy: 0.9110 - val_loss: 1.0417 - val_accuracy: 0.7749

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.7927295193299415
# Recall:  0.7923
# Accuracy:  0.7923
