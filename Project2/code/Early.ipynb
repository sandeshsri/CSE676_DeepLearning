# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adamax
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 10
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/Early_1.h5"
path_train = "gdrive/My Drive/Colab Notebooks/Early_1.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar10.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     zca_epsilon=1e-06,
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     vertical_flip=False)

# datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu')(l_3)
    # l_3 = BatchNormalization()(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu')(l_5)
    # l_5 = BatchNormalization()(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    # l_p = BatchNormalization()(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu')(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    # l = BatchNormalization()(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    # l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 64)   9472        input_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 64)   4160        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 192)  110784      conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 192)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 7, 7, 96)     18528       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 7, 7, 16)     3088        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 192)    0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 7, 7, 64)     12352       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 7, 7, 128)    110720      conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 7, 7, 32)     12832       conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 7, 7, 32)     6176        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 7, 7, 256)    0           conv2d_24[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 7, 7, 128)    32896       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 7, 7, 32)     8224        concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 256)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 7, 7, 128)    32896       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 7, 7, 480)    0           conv2d_30[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 4, 4, 480)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 4, 4, 480)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 4, 4, 512)    0           conv2d_36[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 1,058,154
# Trainable params: 1,058,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adamax(learning_rate=0.0001, decay=1e-06), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=30, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# model.load_weights(path_best)
history = model.fit(x_train_norm, y_train_norm,
                        batch_size=batch_size,
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint,early],verbose=2)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0058s vs `on_train_batch_end` time: 0.0254s). Check your callbacks.
#
# Epoch 00001: val_accuracy improved from -inf to 0.37780, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 1.9041 - accuracy: 0.3016 - val_loss: 1.6808 - val_accuracy: 0.3778
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.37780 to 0.43650, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 1.6074 - accuracy: 0.4135 - val_loss: 1.5574 - val_accuracy: 0.4365
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.43650 to 0.47620, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 1.4942 - accuracy: 0.4577 - val_loss: 1.4458 - val_accuracy: 0.4762
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.47620 to 0.50740, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 1.4049 - accuracy: 0.4923 - val_loss: 1.3618 - val_accuracy: 0.5074
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.50740 to 0.53620, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 1.3371 - accuracy: 0.5211 - val_loss: 1.2953 - val_accuracy: 0.5362
# Epoch 6/200
#
# Epoch 00006: val_accuracy did not improve from 0.53620
# 500/500 - 10s - loss: 1.2834 - accuracy: 0.5392 - val_loss: 1.2807 - val_accuracy: 0.5339
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.53620 to 0.55740, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 1.2418 - accuracy: 0.5582 - val_loss: 1.2354 - val_accuracy: 0.5574
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.55740 to 0.56730, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 1.2057 - accuracy: 0.5719 - val_loss: 1.2092 - val_accuracy: 0.5673
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.56730 to 0.58860, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 1.1742 - accuracy: 0.5841 - val_loss: 1.1723 - val_accuracy: 0.5886
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.58860 to 0.58970, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 1.1452 - accuracy: 0.5951 - val_loss: 1.1524 - val_accuracy: 0.5897
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.58970 to 0.60390, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 1.1174 - accuracy: 0.6056 - val_loss: 1.1245 - val_accuracy: 0.6039
# Epoch 12/200
#
# Epoch 00012: val_accuracy did not improve from 0.60390
# 500/500 - 10s - loss: 1.0893 - accuracy: 0.6156 - val_loss: 1.1128 - val_accuracy: 0.6002
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.60390 to 0.61920, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 1.0623 - accuracy: 0.6257 - val_loss: 1.0829 - val_accuracy: 0.6192
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.61920 to 0.63240, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 1.0401 - accuracy: 0.6329 - val_loss: 1.0456 - val_accuracy: 0.6324
# Epoch 15/200
#
# Epoch 00015: val_accuracy did not improve from 0.63240
# 500/500 - 10s - loss: 1.0196 - accuracy: 0.6408 - val_loss: 1.0648 - val_accuracy: 0.6243
# Epoch 16/200
#
# Epoch 00016: val_accuracy improved from 0.63240 to 0.63720, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.9991 - accuracy: 0.6487 - val_loss: 1.0244 - val_accuracy: 0.6372
# Epoch 17/200
#
# Epoch 00017: val_accuracy did not improve from 0.63720
# 500/500 - 10s - loss: 0.9770 - accuracy: 0.6573 - val_loss: 1.0418 - val_accuracy: 0.6319
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.63720 to 0.65340, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.9597 - accuracy: 0.6647 - val_loss: 0.9883 - val_accuracy: 0.6534
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.65340 to 0.66590, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.9425 - accuracy: 0.6682 - val_loss: 0.9723 - val_accuracy: 0.6659
# Epoch 20/200
#
# Epoch 00020: val_accuracy did not improve from 0.66590
# 500/500 - 10s - loss: 0.9264 - accuracy: 0.6746 - val_loss: 0.9618 - val_accuracy: 0.6632
# Epoch 21/200
#
# Epoch 00021: val_accuracy improved from 0.66590 to 0.66660, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.9121 - accuracy: 0.6790 - val_loss: 0.9444 - val_accuracy: 0.6666
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.66660 to 0.66930, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.8945 - accuracy: 0.6856 - val_loss: 0.9525 - val_accuracy: 0.6693
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.66930 to 0.67160, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.8738 - accuracy: 0.6933 - val_loss: 0.9302 - val_accuracy: 0.6716
# Epoch 24/200
#
# Epoch 00024: val_accuracy improved from 0.67160 to 0.67960, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.8658 - accuracy: 0.6958 - val_loss: 0.9231 - val_accuracy: 0.6796
# Epoch 25/200
#
# Epoch 00025: val_accuracy did not improve from 0.67960
# 500/500 - 10s - loss: 0.8474 - accuracy: 0.7028 - val_loss: 0.9287 - val_accuracy: 0.6735
# Epoch 26/200
#
# Epoch 00026: val_accuracy did not improve from 0.67960
# 500/500 - 10s - loss: 0.8351 - accuracy: 0.7082 - val_loss: 0.9169 - val_accuracy: 0.6765
# Epoch 27/200
#
# Epoch 00027: val_accuracy improved from 0.67960 to 0.68250, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.8272 - accuracy: 0.7096 - val_loss: 0.9151 - val_accuracy: 0.6825
# Epoch 28/200
#
# Epoch 00028: val_accuracy improved from 0.68250 to 0.69470, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.8128 - accuracy: 0.7162 - val_loss: 0.8873 - val_accuracy: 0.6947
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.69470
# 500/500 - 10s - loss: 0.8013 - accuracy: 0.7199 - val_loss: 0.8664 - val_accuracy: 0.6946
# Epoch 30/200
#
# Epoch 00030: val_accuracy improved from 0.69470 to 0.70220, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.7876 - accuracy: 0.7259 - val_loss: 0.8642 - val_accuracy: 0.7022
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.70220
# 500/500 - 10s - loss: 0.7776 - accuracy: 0.7300 - val_loss: 0.8823 - val_accuracy: 0.6942
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.70220 to 0.70420, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.7642 - accuracy: 0.7342 - val_loss: 0.8572 - val_accuracy: 0.7042
# Epoch 33/200
#
# Epoch 00033: val_accuracy improved from 0.70420 to 0.70660, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.7531 - accuracy: 0.7374 - val_loss: 0.8453 - val_accuracy: 0.7066
# Epoch 34/200
#
# Epoch 00034: val_accuracy improved from 0.70660 to 0.71890, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.7407 - accuracy: 0.7425 - val_loss: 0.8242 - val_accuracy: 0.7189
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.71890
# 500/500 - 10s - loss: 0.7306 - accuracy: 0.7454 - val_loss: 0.8205 - val_accuracy: 0.7139
# Epoch 36/200
#
# Epoch 00036: val_accuracy improved from 0.71890 to 0.71970, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.7239 - accuracy: 0.7483 - val_loss: 0.8149 - val_accuracy: 0.7197
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.71970
# 500/500 - 10s - loss: 0.7098 - accuracy: 0.7538 - val_loss: 0.8616 - val_accuracy: 0.7096
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.71970
# 500/500 - 10s - loss: 0.7044 - accuracy: 0.7540 - val_loss: 0.8472 - val_accuracy: 0.7124
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.71970 to 0.72670, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.6917 - accuracy: 0.7599 - val_loss: 0.7929 - val_accuracy: 0.7267
# Epoch 40/200
#
# Epoch 00040: val_accuracy improved from 0.72670 to 0.72790, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.6896 - accuracy: 0.7610 - val_loss: 0.7897 - val_accuracy: 0.7279
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.72790
# 500/500 - 10s - loss: 0.6749 - accuracy: 0.7646 - val_loss: 0.8013 - val_accuracy: 0.7243
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.72790
# 500/500 - 10s - loss: 0.6610 - accuracy: 0.7703 - val_loss: 0.7954 - val_accuracy: 0.7237
# Epoch 43/200
#
# Epoch 00043: val_accuracy improved from 0.72790 to 0.72860, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.6516 - accuracy: 0.7733 - val_loss: 0.7898 - val_accuracy: 0.7286
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.72860
# 500/500 - 10s - loss: 0.6422 - accuracy: 0.7769 - val_loss: 0.8213 - val_accuracy: 0.7167
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.72860
# 500/500 - 10s - loss: 0.6379 - accuracy: 0.7762 - val_loss: 0.8020 - val_accuracy: 0.7255
# Epoch 46/200
#
# Epoch 00046: val_accuracy improved from 0.72860 to 0.74090, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.6270 - accuracy: 0.7830 - val_loss: 0.7655 - val_accuracy: 0.7409
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.74090
# 500/500 - 10s - loss: 0.6180 - accuracy: 0.7875 - val_loss: 0.7689 - val_accuracy: 0.7372
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.74090
# 500/500 - 10s - loss: 0.6102 - accuracy: 0.7891 - val_loss: 0.7659 - val_accuracy: 0.7386
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.74090
# 500/500 - 10s - loss: 0.5978 - accuracy: 0.7924 - val_loss: 0.7750 - val_accuracy: 0.7400
# Epoch 50/200
#
# Epoch 00050: val_accuracy improved from 0.74090 to 0.74130, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.5896 - accuracy: 0.7955 - val_loss: 0.7655 - val_accuracy: 0.7413
# Epoch 51/200
#
# Epoch 00051: val_accuracy improved from 0.74130 to 0.74640, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.5852 - accuracy: 0.7973 - val_loss: 0.7541 - val_accuracy: 0.7464
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.74640
# 500/500 - 10s - loss: 0.5747 - accuracy: 0.8008 - val_loss: 0.7804 - val_accuracy: 0.7395
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.74640
# 500/500 - 10s - loss: 0.5675 - accuracy: 0.8040 - val_loss: 0.7639 - val_accuracy: 0.7437
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.74640
# 500/500 - 10s - loss: 0.5590 - accuracy: 0.8046 - val_loss: 0.7764 - val_accuracy: 0.7327
# Epoch 55/200
#
# Epoch 00055: val_accuracy improved from 0.74640 to 0.75190, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.5508 - accuracy: 0.8091 - val_loss: 0.7476 - val_accuracy: 0.7519
# Epoch 56/200
#
# Epoch 00056: val_accuracy improved from 0.75190 to 0.75250, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.5400 - accuracy: 0.8127 - val_loss: 0.7344 - val_accuracy: 0.7525
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.75250
# 500/500 - 10s - loss: 0.5350 - accuracy: 0.8152 - val_loss: 0.7303 - val_accuracy: 0.7481
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.75250
# 500/500 - 10s - loss: 0.5259 - accuracy: 0.8199 - val_loss: 0.7546 - val_accuracy: 0.7469
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.75250
# 500/500 - 10s - loss: 0.5152 - accuracy: 0.8224 - val_loss: 0.7465 - val_accuracy: 0.7466
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.75250
# 500/500 - 10s - loss: 0.5093 - accuracy: 0.8259 - val_loss: 0.7633 - val_accuracy: 0.7449
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.75250
# 500/500 - 10s - loss: 0.5011 - accuracy: 0.8272 - val_loss: 0.7382 - val_accuracy: 0.7486
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.75250
# 500/500 - 10s - loss: 0.4988 - accuracy: 0.8292 - val_loss: 0.7658 - val_accuracy: 0.7398
# Epoch 63/200
#
# Epoch 00063: val_accuracy improved from 0.75250 to 0.76180, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.4885 - accuracy: 0.8311 - val_loss: 0.7156 - val_accuracy: 0.7618
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.76180
# 500/500 - 10s - loss: 0.4830 - accuracy: 0.8328 - val_loss: 0.7350 - val_accuracy: 0.7554
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.76180
# 500/500 - 10s - loss: 0.4752 - accuracy: 0.8367 - val_loss: 0.8109 - val_accuracy: 0.7254
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.76180
# 500/500 - 10s - loss: 0.4670 - accuracy: 0.8387 - val_loss: 0.7771 - val_accuracy: 0.7464
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.76180
# 500/500 - 10s - loss: 0.4606 - accuracy: 0.8409 - val_loss: 0.7532 - val_accuracy: 0.7486
# Epoch 68/200
#
# Epoch 00068: val_accuracy improved from 0.76180 to 0.76290, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.4567 - accuracy: 0.8427 - val_loss: 0.7150 - val_accuracy: 0.7629
# Epoch 69/200
#
# Epoch 00069: val_accuracy improved from 0.76290 to 0.76620, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.4476 - accuracy: 0.8452 - val_loss: 0.7048 - val_accuracy: 0.7662
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.4383 - accuracy: 0.8494 - val_loss: 0.7325 - val_accuracy: 0.7595
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.4300 - accuracy: 0.8515 - val_loss: 0.7126 - val_accuracy: 0.7640
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.4275 - accuracy: 0.8532 - val_loss: 0.7183 - val_accuracy: 0.7632
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.4164 - accuracy: 0.8584 - val_loss: 0.7533 - val_accuracy: 0.7561
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.4091 - accuracy: 0.8593 - val_loss: 0.7479 - val_accuracy: 0.7583
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.4044 - accuracy: 0.8604 - val_loss: 0.7651 - val_accuracy: 0.7521
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.3982 - accuracy: 0.8626 - val_loss: 0.7308 - val_accuracy: 0.7660
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.3877 - accuracy: 0.8681 - val_loss: 0.7483 - val_accuracy: 0.7614
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.3785 - accuracy: 0.8702 - val_loss: 0.7547 - val_accuracy: 0.7590
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.76620
# 500/500 - 10s - loss: 0.3793 - accuracy: 0.8682 - val_loss: 0.7299 - val_accuracy: 0.7650
# Epoch 80/200
#
# Epoch 00080: val_accuracy improved from 0.76620 to 0.76910, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.3692 - accuracy: 0.8736 - val_loss: 0.7183 - val_accuracy: 0.7691
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.76910
# 500/500 - 10s - loss: 0.3649 - accuracy: 0.8744 - val_loss: 0.7336 - val_accuracy: 0.7661
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.76910
# 500/500 - 10s - loss: 0.3543 - accuracy: 0.8797 - val_loss: 0.7691 - val_accuracy: 0.7566
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.76910
# 500/500 - 10s - loss: 0.3488 - accuracy: 0.8819 - val_loss: 0.8081 - val_accuracy: 0.7475
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.76910
# 500/500 - 10s - loss: 0.3438 - accuracy: 0.8819 - val_loss: 0.7470 - val_accuracy: 0.7634
# Epoch 85/200
#
# Epoch 00085: val_accuracy improved from 0.76910 to 0.77060, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.3412 - accuracy: 0.8842 - val_loss: 0.7231 - val_accuracy: 0.7706
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.77060
# 500/500 - 10s - loss: 0.3324 - accuracy: 0.8864 - val_loss: 0.7691 - val_accuracy: 0.7615
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.77060
# 500/500 - 10s - loss: 0.3283 - accuracy: 0.8877 - val_loss: 0.7510 - val_accuracy: 0.7642
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.77060
# 500/500 - 10s - loss: 0.3206 - accuracy: 0.8905 - val_loss: 0.7341 - val_accuracy: 0.7695
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.77060
# 500/500 - 10s - loss: 0.3162 - accuracy: 0.8923 - val_loss: 0.7284 - val_accuracy: 0.7701
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.77060
# 500/500 - 10s - loss: 0.3032 - accuracy: 0.8977 - val_loss: 0.8104 - val_accuracy: 0.7557
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.77060
# 500/500 - 10s - loss: 0.2981 - accuracy: 0.8987 - val_loss: 0.7749 - val_accuracy: 0.7684
# Epoch 92/200
#
# Epoch 00092: val_accuracy improved from 0.77060 to 0.77330, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.2984 - accuracy: 0.8991 - val_loss: 0.7475 - val_accuracy: 0.7733
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.77330
# 500/500 - 10s - loss: 0.2889 - accuracy: 0.9032 - val_loss: 0.7592 - val_accuracy: 0.7709
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.77330
# 500/500 - 10s - loss: 0.2793 - accuracy: 0.9060 - val_loss: 0.7787 - val_accuracy: 0.7651
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.77330
# 500/500 - 10s - loss: 0.2744 - accuracy: 0.9082 - val_loss: 0.7846 - val_accuracy: 0.7693
# Epoch 96/200
#
# Epoch 00096: val_accuracy improved from 0.77330 to 0.77360, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.2702 - accuracy: 0.9093 - val_loss: 0.7682 - val_accuracy: 0.7736
# Epoch 97/200
#
# Epoch 00097: val_accuracy improved from 0.77360 to 0.77400, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 10s - loss: 0.2663 - accuracy: 0.9101 - val_loss: 0.7606 - val_accuracy: 0.7740
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.77400
# 500/500 - 10s - loss: 0.2574 - accuracy: 0.9133 - val_loss: 0.8166 - val_accuracy: 0.7620
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.77400
# 500/500 - 10s - loss: 0.2529 - accuracy: 0.9158 - val_loss: 0.7851 - val_accuracy: 0.7701
# Epoch 100/200
#
# Epoch 00100: val_accuracy did not improve from 0.77400
# 500/500 - 10s - loss: 0.2491 - accuracy: 0.9174 - val_loss: 0.7899 - val_accuracy: 0.7686
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.77400
# 500/500 - 10s - loss: 0.2393 - accuracy: 0.9218 - val_loss: 0.7930 - val_accuracy: 0.7732
# Epoch 102/200
#
# Epoch 00102: val_accuracy improved from 0.77400 to 0.77710, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.2365 - accuracy: 0.9206 - val_loss: 0.7718 - val_accuracy: 0.7771
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.2337 - accuracy: 0.9229 - val_loss: 0.7777 - val_accuracy: 0.7749
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.2269 - accuracy: 0.9245 - val_loss: 0.8024 - val_accuracy: 0.7756
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.2212 - accuracy: 0.9265 - val_loss: 0.7909 - val_accuracy: 0.7757
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.2175 - accuracy: 0.9283 - val_loss: 0.7851 - val_accuracy: 0.7755
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.2097 - accuracy: 0.9309 - val_loss: 0.8116 - val_accuracy: 0.7723
# Epoch 108/200
#
# Epoch 00108: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.2032 - accuracy: 0.9345 - val_loss: 0.8162 - val_accuracy: 0.7703
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.2011 - accuracy: 0.9342 - val_loss: 0.8097 - val_accuracy: 0.7744
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.1938 - accuracy: 0.9372 - val_loss: 0.8071 - val_accuracy: 0.7760
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.1918 - accuracy: 0.9375 - val_loss: 0.8300 - val_accuracy: 0.7711
# Epoch 112/200
#
# Epoch 00112: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.1816 - accuracy: 0.9410 - val_loss: 0.8267 - val_accuracy: 0.7734
# Epoch 113/200
#
# Epoch 00113: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.1821 - accuracy: 0.9407 - val_loss: 0.8541 - val_accuracy: 0.7732
# Epoch 114/200
#
# Epoch 00114: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.1786 - accuracy: 0.9415 - val_loss: 0.8579 - val_accuracy: 0.7741
# Epoch 115/200
#
# Epoch 00115: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.1662 - accuracy: 0.9479 - val_loss: 0.8346 - val_accuracy: 0.7742
# Epoch 116/200
#
# Epoch 00116: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.1641 - accuracy: 0.9476 - val_loss: 0.8747 - val_accuracy: 0.7722
# Epoch 117/200
#
# Epoch 00117: val_accuracy did not improve from 0.77710
# 500/500 - 10s - loss: 0.1586 - accuracy: 0.9501 - val_loss: 0.8952 - val_accuracy: 0.7678
# Epoch 118/200
#
# Epoch 00118: val_accuracy improved from 0.77710 to 0.77740, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.1575 - accuracy: 0.9496 - val_loss: 0.8657 - val_accuracy: 0.7774
# Epoch 119/200
#
# Epoch 00119: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1534 - accuracy: 0.9518 - val_loss: 0.9338 - val_accuracy: 0.7678
# Epoch 120/200
#
# Epoch 00120: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1444 - accuracy: 0.9559 - val_loss: 0.8837 - val_accuracy: 0.7720
# Epoch 121/200
#
# Epoch 00121: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1396 - accuracy: 0.9561 - val_loss: 0.9101 - val_accuracy: 0.7657
# Epoch 122/200
#
# Epoch 00122: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1360 - accuracy: 0.9570 - val_loss: 0.9187 - val_accuracy: 0.7699
# Epoch 123/200
#
# Epoch 00123: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1319 - accuracy: 0.9605 - val_loss: 0.9067 - val_accuracy: 0.7723
# Epoch 124/200
#
# Epoch 00124: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1330 - accuracy: 0.9586 - val_loss: 0.9310 - val_accuracy: 0.7707
# Epoch 125/200
#
# Epoch 00125: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1259 - accuracy: 0.9614 - val_loss: 0.9370 - val_accuracy: 0.7702
# Epoch 126/200
#
# Epoch 00126: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1261 - accuracy: 0.9606 - val_loss: 0.9612 - val_accuracy: 0.7641
# Epoch 127/200
#
# Epoch 00127: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1154 - accuracy: 0.9667 - val_loss: 0.9725 - val_accuracy: 0.7706
# Epoch 128/200
#
# Epoch 00128: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1171 - accuracy: 0.9646 - val_loss: 0.9571 - val_accuracy: 0.7727
# Epoch 129/200
#
# Epoch 00129: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1049 - accuracy: 0.9699 - val_loss: 0.9730 - val_accuracy: 0.7713
# Epoch 130/200
#
# Epoch 00130: val_accuracy did not improve from 0.77740
# 500/500 - 10s - loss: 0.1067 - accuracy: 0.9691 - val_loss: 0.9579 - val_accuracy: 0.7729
# Epoch 131/200
#
# Epoch 00131: val_accuracy improved from 0.77740 to 0.77840, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.1041 - accuracy: 0.9697 - val_loss: 0.9407 - val_accuracy: 0.7784
# Epoch 132/200
#
# Epoch 00132: val_accuracy did not improve from 0.77840
# 500/500 - 10s - loss: 0.0976 - accuracy: 0.9722 - val_loss: 1.0317 - val_accuracy: 0.7674
# Epoch 133/200
#
# Epoch 00133: val_accuracy did not improve from 0.77840
# 500/500 - 10s - loss: 0.0985 - accuracy: 0.9714 - val_loss: 0.9773 - val_accuracy: 0.7728
# Epoch 134/200
#
# Epoch 00134: val_accuracy did not improve from 0.77840
# 500/500 - 10s - loss: 0.0913 - accuracy: 0.9746 - val_loss: 0.9868 - val_accuracy: 0.7755
# Epoch 135/200
#
# Epoch 00135: val_accuracy did not improve from 0.77840
# 500/500 - 10s - loss: 0.0852 - accuracy: 0.9771 - val_loss: 1.0007 - val_accuracy: 0.7741
# Epoch 136/200
#
# Epoch 00136: val_accuracy did not improve from 0.77840
# 500/500 - 10s - loss: 0.0841 - accuracy: 0.9777 - val_loss: 1.0085 - val_accuracy: 0.7719
# Epoch 137/200
#
# Epoch 00137: val_accuracy did not improve from 0.77840
# 500/500 - 10s - loss: 0.0832 - accuracy: 0.9768 - val_loss: 1.0207 - val_accuracy: 0.7730
# Epoch 138/200
#
# Epoch 00138: val_accuracy improved from 0.77840 to 0.77890, saving model to gdrive/My Drive/Colab Notebooks/Early_1.h5
# 500/500 - 11s - loss: 0.0747 - accuracy: 0.9811 - val_loss: 1.0159 - val_accuracy: 0.7789
# Epoch 139/200
#
# Epoch 00139: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0753 - accuracy: 0.9802 - val_loss: 1.0682 - val_accuracy: 0.7719
# Epoch 140/200
#
# Epoch 00140: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0736 - accuracy: 0.9812 - val_loss: 1.0681 - val_accuracy: 0.7698
# Epoch 141/200
#
# Epoch 00141: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0697 - accuracy: 0.9822 - val_loss: 1.0936 - val_accuracy: 0.7720
# Epoch 142/200
#
# Epoch 00142: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0636 - accuracy: 0.9849 - val_loss: 1.0706 - val_accuracy: 0.7750
# Epoch 143/200
#
# Epoch 00143: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0714 - accuracy: 0.9804 - val_loss: 1.1308 - val_accuracy: 0.7678
# Epoch 144/200
#
# Epoch 00144: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0588 - accuracy: 0.9867 - val_loss: 1.1478 - val_accuracy: 0.7624
# Epoch 145/200
#
# Epoch 00145: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0585 - accuracy: 0.9860 - val_loss: 1.0842 - val_accuracy: 0.7734
# Epoch 146/200
#
# Epoch 00146: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0561 - accuracy: 0.9869 - val_loss: 1.1186 - val_accuracy: 0.7751
# Epoch 147/200
#
# Epoch 00147: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0563 - accuracy: 0.9868 - val_loss: 1.1290 - val_accuracy: 0.7697
# Epoch 148/200
#
# Epoch 00148: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0502 - accuracy: 0.9890 - val_loss: 1.1045 - val_accuracy: 0.7741
# Epoch 149/200
#
# Epoch 00149: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0499 - accuracy: 0.9894 - val_loss: 1.1933 - val_accuracy: 0.7687
# Epoch 150/200
#
# Epoch 00150: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0512 - accuracy: 0.9877 - val_loss: 1.1762 - val_accuracy: 0.7679
# Epoch 151/200
#
# Epoch 00151: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0446 - accuracy: 0.9911 - val_loss: 1.1805 - val_accuracy: 0.7661
# Epoch 152/200
#
# Epoch 00152: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0449 - accuracy: 0.9904 - val_loss: 1.1398 - val_accuracy: 0.7732
# Epoch 153/200
#
# Epoch 00153: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0399 - accuracy: 0.9923 - val_loss: 1.1828 - val_accuracy: 0.7754
# Epoch 154/200
#
# Epoch 00154: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0427 - accuracy: 0.9909 - val_loss: 1.1504 - val_accuracy: 0.7772
# Epoch 155/200
#
# Epoch 00155: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0366 - accuracy: 0.9933 - val_loss: 1.1837 - val_accuracy: 0.7739
# Epoch 156/200
#
# Epoch 00156: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0341 - accuracy: 0.9945 - val_loss: 1.2319 - val_accuracy: 0.7735
# Epoch 157/200
#
# Epoch 00157: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0358 - accuracy: 0.9934 - val_loss: 1.2228 - val_accuracy: 0.7771
# Epoch 158/200
#
# Epoch 00158: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0321 - accuracy: 0.9943 - val_loss: 1.2195 - val_accuracy: 0.7735
# Epoch 159/200
#
# Epoch 00159: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0307 - accuracy: 0.9945 - val_loss: 1.2405 - val_accuracy: 0.7709
# Epoch 160/200
#
# Epoch 00160: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0265 - accuracy: 0.9962 - val_loss: 1.2442 - val_accuracy: 0.7731
# Epoch 161/200
#
# Epoch 00161: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0298 - accuracy: 0.9950 - val_loss: 1.2607 - val_accuracy: 0.7748
# Epoch 162/200
#
# Epoch 00162: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0264 - accuracy: 0.9953 - val_loss: 1.2790 - val_accuracy: 0.7755
# Epoch 163/200
#
# Epoch 00163: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0268 - accuracy: 0.9950 - val_loss: 1.3079 - val_accuracy: 0.7693
# Epoch 164/200
#
# Epoch 00164: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0222 - accuracy: 0.9967 - val_loss: 1.4433 - val_accuracy: 0.7590
# Epoch 165/200
#
# Epoch 00165: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0218 - accuracy: 0.9972 - val_loss: 1.3183 - val_accuracy: 0.7721
# Epoch 166/200
#
# Epoch 00166: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0270 - accuracy: 0.9949 - val_loss: 1.3113 - val_accuracy: 0.7758
# Epoch 167/200
#
# Epoch 00167: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0173 - accuracy: 0.9981 - val_loss: 1.3228 - val_accuracy: 0.7718
# Epoch 168/200
#
# Epoch 00168: val_accuracy did not improve from 0.77890
# 500/500 - 10s - loss: 0.0153 - accuracy: 0.9989 - val_loss: 1.3603 - val_accuracy: 0.7715
# Epoch 00168: early stopping

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.7778942021506283
# Recall:  0.7789
# Accuracy:  0.7789
