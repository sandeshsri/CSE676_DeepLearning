# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adamax
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 10
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/Augmentation_2.h5"
path_train = "gdrive/My Drive/Colab Notebooks/Augmentation_2.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar10.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu')(l_3)
    # l_3 = BatchNormalization()(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu')(l_5)
    # l_5 = BatchNormalization()(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    # l_p = BatchNormalization()(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu')(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    # l = BatchNormalization()(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    # l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 192)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 96)     18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 16)     3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 192)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 64)     12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 128)    110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 32)     12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 256)    0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 480)    0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4, 4, 512)    0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,058,154
# Trainable params: 1,058,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adamax(learning_rate=0.0001, decay=1e-06), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# model.load_weights(path_best)
history = model.fit(datagen.flow(x_train_norm, y_train_norm,
                                        batch_size=batch_size),
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.36460, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.9206 - accuracy: 0.2920 - val_loss: 1.7022 - val_accuracy: 0.3646
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.36460 to 0.42270, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 1.6521 - accuracy: 0.3942 - val_loss: 1.5754 - val_accuracy: 0.4227
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.42270 to 0.45910, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.5403 - accuracy: 0.4408 - val_loss: 1.4878 - val_accuracy: 0.4591
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.45910 to 0.48600, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.4654 - accuracy: 0.4656 - val_loss: 1.4241 - val_accuracy: 0.4860
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.48600 to 0.50050, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 1.4165 - accuracy: 0.4879 - val_loss: 1.3772 - val_accuracy: 0.5005
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.50050 to 0.52940, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 1.3708 - accuracy: 0.5057 - val_loss: 1.3027 - val_accuracy: 0.5294
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.52940 to 0.53110, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.3274 - accuracy: 0.5237 - val_loss: 1.3060 - val_accuracy: 0.5311
# Epoch 8/200
#
# Epoch 00008: val_accuracy did not improve from 0.53110
# 500/500 - 24s - loss: 1.3005 - accuracy: 0.5360 - val_loss: 1.3462 - val_accuracy: 0.5276
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.53110 to 0.53640, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.2634 - accuracy: 0.5514 - val_loss: 1.3137 - val_accuracy: 0.5364
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.53640 to 0.56180, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 1.2364 - accuracy: 0.5583 - val_loss: 1.2355 - val_accuracy: 0.5618
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.56180 to 0.58800, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.2151 - accuracy: 0.5677 - val_loss: 1.1719 - val_accuracy: 0.5880
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.58800 to 0.59290, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.1893 - accuracy: 0.5756 - val_loss: 1.1485 - val_accuracy: 0.5929
# Epoch 13/200
#
# Epoch 00013: val_accuracy did not improve from 0.59290
# 500/500 - 24s - loss: 1.1663 - accuracy: 0.5848 - val_loss: 1.2062 - val_accuracy: 0.5744
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.59290 to 0.61490, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 1.1466 - accuracy: 0.5918 - val_loss: 1.0907 - val_accuracy: 0.6149
# Epoch 15/200
#
# Epoch 00015: val_accuracy did not improve from 0.61490
# 500/500 - 24s - loss: 1.1318 - accuracy: 0.5987 - val_loss: 1.1614 - val_accuracy: 0.5948
# Epoch 16/200
#
# Epoch 00016: val_accuracy did not improve from 0.61490
# 500/500 - 24s - loss: 1.1103 - accuracy: 0.6066 - val_loss: 1.1223 - val_accuracy: 0.6080
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.61490 to 0.61620, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 1.0892 - accuracy: 0.6149 - val_loss: 1.1059 - val_accuracy: 0.6162
# Epoch 18/200
#
# Epoch 00018: val_accuracy did not improve from 0.61620
# 500/500 - 24s - loss: 1.0703 - accuracy: 0.6220 - val_loss: 1.1341 - val_accuracy: 0.6143
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.61620 to 0.63220, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.0550 - accuracy: 0.6273 - val_loss: 1.0482 - val_accuracy: 0.6322
# Epoch 20/200
#
# Epoch 00020: val_accuracy did not improve from 0.63220
# 500/500 - 24s - loss: 1.0424 - accuracy: 0.6330 - val_loss: 1.0890 - val_accuracy: 0.6224
# Epoch 21/200
#
# Epoch 00021: val_accuracy improved from 0.63220 to 0.64470, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.0316 - accuracy: 0.6397 - val_loss: 1.0050 - val_accuracy: 0.6447
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.64470 to 0.64930, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 1.0096 - accuracy: 0.6455 - val_loss: 1.0084 - val_accuracy: 0.6493
# Epoch 23/200
#
# Epoch 00023: val_accuracy did not improve from 0.64930
# 500/500 - 24s - loss: 1.0013 - accuracy: 0.6481 - val_loss: 1.0421 - val_accuracy: 0.6447
# Epoch 24/200
#
# Epoch 00024: val_accuracy improved from 0.64930 to 0.65580, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.9844 - accuracy: 0.6530 - val_loss: 1.0065 - val_accuracy: 0.6558
# Epoch 25/200
#
# Epoch 00025: val_accuracy did not improve from 0.65580
# 500/500 - 24s - loss: 0.9720 - accuracy: 0.6590 - val_loss: 1.0698 - val_accuracy: 0.6382
# Epoch 26/200
#
# Epoch 00026: val_accuracy improved from 0.65580 to 0.66830, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.9603 - accuracy: 0.6626 - val_loss: 0.9645 - val_accuracy: 0.6683
# Epoch 27/200
#
# Epoch 00027: val_accuracy did not improve from 0.66830
# 500/500 - 24s - loss: 0.9488 - accuracy: 0.6669 - val_loss: 1.0492 - val_accuracy: 0.6484
# Epoch 28/200
#
# Epoch 00028: val_accuracy did not improve from 0.66830
# 500/500 - 24s - loss: 0.9405 - accuracy: 0.6684 - val_loss: 0.9754 - val_accuracy: 0.6623
# Epoch 29/200
#
# Epoch 00029: val_accuracy did not improve from 0.66830
# 500/500 - 24s - loss: 0.9256 - accuracy: 0.6765 - val_loss: 0.9618 - val_accuracy: 0.6676
# Epoch 30/200
#
# Epoch 00030: val_accuracy improved from 0.66830 to 0.68560, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.9132 - accuracy: 0.6773 - val_loss: 0.9085 - val_accuracy: 0.6856
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.68560
# 500/500 - 24s - loss: 0.9096 - accuracy: 0.6797 - val_loss: 0.9260 - val_accuracy: 0.6816
# Epoch 32/200
#
# Epoch 00032: val_accuracy did not improve from 0.68560
# 500/500 - 24s - loss: 0.8930 - accuracy: 0.6872 - val_loss: 0.9438 - val_accuracy: 0.6774
# Epoch 33/200
#
# Epoch 00033: val_accuracy did not improve from 0.68560
# 500/500 - 24s - loss: 0.8872 - accuracy: 0.6906 - val_loss: 0.9131 - val_accuracy: 0.6846
# Epoch 34/200
#
# Epoch 00034: val_accuracy improved from 0.68560 to 0.69200, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.8767 - accuracy: 0.6939 - val_loss: 0.8944 - val_accuracy: 0.6920
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.69200
# 500/500 - 25s - loss: 0.8630 - accuracy: 0.6979 - val_loss: 0.8979 - val_accuracy: 0.6872
# Epoch 36/200
#
# Epoch 00036: val_accuracy did not improve from 0.69200
# 500/500 - 24s - loss: 0.8556 - accuracy: 0.6996 - val_loss: 0.9172 - val_accuracy: 0.6858
# Epoch 37/200
#
# Epoch 00037: val_accuracy improved from 0.69200 to 0.69520, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.8524 - accuracy: 0.6998 - val_loss: 0.8806 - val_accuracy: 0.6952
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.69520
# 500/500 - 24s - loss: 0.8393 - accuracy: 0.7053 - val_loss: 0.9004 - val_accuracy: 0.6915
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.69520 to 0.70760, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.8331 - accuracy: 0.7086 - val_loss: 0.8468 - val_accuracy: 0.7076
# Epoch 40/200
#
# Epoch 00040: val_accuracy did not improve from 0.70760
# 500/500 - 25s - loss: 0.8219 - accuracy: 0.7119 - val_loss: 0.8583 - val_accuracy: 0.7058
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.70760
# 500/500 - 24s - loss: 0.8165 - accuracy: 0.7168 - val_loss: 0.8554 - val_accuracy: 0.7051
# Epoch 42/200
#
# Epoch 00042: val_accuracy improved from 0.70760 to 0.71660, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.8100 - accuracy: 0.7164 - val_loss: 0.8183 - val_accuracy: 0.7166
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.71660
# 500/500 - 24s - loss: 0.8013 - accuracy: 0.7167 - val_loss: 0.8553 - val_accuracy: 0.7129
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.71660
# 500/500 - 24s - loss: 0.7902 - accuracy: 0.7233 - val_loss: 0.8335 - val_accuracy: 0.7142
# Epoch 45/200
#
# Epoch 00045: val_accuracy improved from 0.71660 to 0.72540, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.7847 - accuracy: 0.7233 - val_loss: 0.8155 - val_accuracy: 0.7254
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.72540
# 500/500 - 24s - loss: 0.7769 - accuracy: 0.7274 - val_loss: 0.7972 - val_accuracy: 0.7250
# Epoch 47/200
#
# Epoch 00047: val_accuracy improved from 0.72540 to 0.73000, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.7658 - accuracy: 0.7320 - val_loss: 0.7906 - val_accuracy: 0.7300
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.73000
# 500/500 - 24s - loss: 0.7608 - accuracy: 0.7326 - val_loss: 0.8147 - val_accuracy: 0.7232
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.73000
# 500/500 - 24s - loss: 0.7546 - accuracy: 0.7334 - val_loss: 0.8439 - val_accuracy: 0.7159
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.73000
# 500/500 - 24s - loss: 0.7520 - accuracy: 0.7356 - val_loss: 0.8580 - val_accuracy: 0.7132
# Epoch 51/200
#
# Epoch 00051: val_accuracy improved from 0.73000 to 0.73080, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.7436 - accuracy: 0.7404 - val_loss: 0.7756 - val_accuracy: 0.7308
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.73080
# 500/500 - 23s - loss: 0.7364 - accuracy: 0.7434 - val_loss: 0.8177 - val_accuracy: 0.7260
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.73080
# 500/500 - 24s - loss: 0.7281 - accuracy: 0.7450 - val_loss: 0.8335 - val_accuracy: 0.7213
# Epoch 54/200
#
# Epoch 00054: val_accuracy improved from 0.73080 to 0.73270, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.7277 - accuracy: 0.7455 - val_loss: 0.7769 - val_accuracy: 0.7327
# Epoch 55/200
#
# Epoch 00055: val_accuracy improved from 0.73270 to 0.74190, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.7149 - accuracy: 0.7500 - val_loss: 0.7563 - val_accuracy: 0.7419
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.74190
# 500/500 - 24s - loss: 0.7080 - accuracy: 0.7515 - val_loss: 0.8004 - val_accuracy: 0.7311
# Epoch 57/200
#
# Epoch 00057: val_accuracy improved from 0.74190 to 0.75080, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.7076 - accuracy: 0.7513 - val_loss: 0.7204 - val_accuracy: 0.7508
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.75080
# 500/500 - 24s - loss: 0.7052 - accuracy: 0.7538 - val_loss: 0.7504 - val_accuracy: 0.7428
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.75080
# 500/500 - 24s - loss: 0.6952 - accuracy: 0.7570 - val_loss: 0.7692 - val_accuracy: 0.7396
# Epoch 60/200
#
# Epoch 00060: val_accuracy improved from 0.75080 to 0.75870, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.6870 - accuracy: 0.7614 - val_loss: 0.7119 - val_accuracy: 0.7587
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.75870
# 500/500 - 24s - loss: 0.6850 - accuracy: 0.7603 - val_loss: 0.7416 - val_accuracy: 0.7482
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.75870
# 500/500 - 24s - loss: 0.6730 - accuracy: 0.7648 - val_loss: 0.7115 - val_accuracy: 0.7546
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.75870
# 500/500 - 24s - loss: 0.6753 - accuracy: 0.7631 - val_loss: 0.7678 - val_accuracy: 0.7428
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.75870
# 500/500 - 24s - loss: 0.6700 - accuracy: 0.7656 - val_loss: 0.7343 - val_accuracy: 0.7506
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.75870
# 500/500 - 24s - loss: 0.6638 - accuracy: 0.7697 - val_loss: 0.7455 - val_accuracy: 0.7502
# Epoch 66/200
#
# Epoch 00066: val_accuracy improved from 0.75870 to 0.76220, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.6600 - accuracy: 0.7688 - val_loss: 0.6861 - val_accuracy: 0.7622
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.76220
# 500/500 - 24s - loss: 0.6527 - accuracy: 0.7720 - val_loss: 0.7348 - val_accuracy: 0.7482
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.76220
# 500/500 - 24s - loss: 0.6505 - accuracy: 0.7710 - val_loss: 0.7886 - val_accuracy: 0.7404
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.76220
# 500/500 - 24s - loss: 0.6419 - accuracy: 0.7758 - val_loss: 0.7075 - val_accuracy: 0.7593
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.76220
# 500/500 - 24s - loss: 0.6429 - accuracy: 0.7755 - val_loss: 0.7370 - val_accuracy: 0.7492
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.76220
# 500/500 - 24s - loss: 0.6391 - accuracy: 0.7762 - val_loss: 0.8063 - val_accuracy: 0.7354
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.76220
# 500/500 - 24s - loss: 0.6344 - accuracy: 0.7784 - val_loss: 0.7538 - val_accuracy: 0.7465
# Epoch 73/200
#
# Epoch 00073: val_accuracy improved from 0.76220 to 0.76420, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.6242 - accuracy: 0.7812 - val_loss: 0.6973 - val_accuracy: 0.7642
# Epoch 74/200
#
# Epoch 00074: val_accuracy improved from 0.76420 to 0.76620, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.6233 - accuracy: 0.7831 - val_loss: 0.6805 - val_accuracy: 0.7662
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.76620
# 500/500 - 24s - loss: 0.6150 - accuracy: 0.7848 - val_loss: 0.7242 - val_accuracy: 0.7560
# Epoch 76/200
#
# Epoch 00076: val_accuracy improved from 0.76620 to 0.76640, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.6125 - accuracy: 0.7862 - val_loss: 0.6922 - val_accuracy: 0.7664
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.76640
# 500/500 - 24s - loss: 0.6079 - accuracy: 0.7864 - val_loss: 0.7334 - val_accuracy: 0.7553
# Epoch 78/200
#
# Epoch 00078: val_accuracy improved from 0.76640 to 0.76670, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.6011 - accuracy: 0.7917 - val_loss: 0.6861 - val_accuracy: 0.7667
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.76670
# 500/500 - 24s - loss: 0.5956 - accuracy: 0.7915 - val_loss: 0.7128 - val_accuracy: 0.7626
# Epoch 80/200
#
# Epoch 00080: val_accuracy improved from 0.76670 to 0.77210, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.5954 - accuracy: 0.7916 - val_loss: 0.6809 - val_accuracy: 0.7721
# Epoch 81/200
#
# Epoch 00081: val_accuracy improved from 0.77210 to 0.77810, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.5850 - accuracy: 0.7962 - val_loss: 0.6560 - val_accuracy: 0.7781
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.77810
# 500/500 - 24s - loss: 0.5856 - accuracy: 0.7958 - val_loss: 0.6609 - val_accuracy: 0.7748
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.77810
# 500/500 - 24s - loss: 0.5824 - accuracy: 0.7970 - val_loss: 0.6760 - val_accuracy: 0.7721
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.77810
# 500/500 - 24s - loss: 0.5785 - accuracy: 0.7958 - val_loss: 0.6788 - val_accuracy: 0.7716
# Epoch 85/200
#
# Epoch 00085: val_accuracy improved from 0.77810 to 0.78350, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.5804 - accuracy: 0.7981 - val_loss: 0.6332 - val_accuracy: 0.7835
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.78350
# 500/500 - 24s - loss: 0.5709 - accuracy: 0.8008 - val_loss: 0.6629 - val_accuracy: 0.7757
# Epoch 87/200
#
# Epoch 00087: val_accuracy did not improve from 0.78350
# 500/500 - 24s - loss: 0.5674 - accuracy: 0.8007 - val_loss: 0.7051 - val_accuracy: 0.7651
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.78350
# 500/500 - 24s - loss: 0.5673 - accuracy: 0.8020 - val_loss: 0.6738 - val_accuracy: 0.7704
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.78350
# 500/500 - 24s - loss: 0.5578 - accuracy: 0.8047 - val_loss: 0.7146 - val_accuracy: 0.7604
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.78350
# 500/500 - 24s - loss: 0.5570 - accuracy: 0.8048 - val_loss: 0.7423 - val_accuracy: 0.7573
# Epoch 91/200
#
# Epoch 00091: val_accuracy improved from 0.78350 to 0.79520, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.5533 - accuracy: 0.8070 - val_loss: 0.6039 - val_accuracy: 0.7952
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.79520
# 500/500 - 24s - loss: 0.5469 - accuracy: 0.8076 - val_loss: 0.6459 - val_accuracy: 0.7807
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.79520
# 500/500 - 24s - loss: 0.5479 - accuracy: 0.8080 - val_loss: 0.7037 - val_accuracy: 0.7665
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.79520
# 500/500 - 24s - loss: 0.5421 - accuracy: 0.8100 - val_loss: 0.6579 - val_accuracy: 0.7818
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.79520
# 500/500 - 24s - loss: 0.5407 - accuracy: 0.8121 - val_loss: 0.7260 - val_accuracy: 0.7568
# Epoch 96/200
#
# Epoch 00096: val_accuracy improved from 0.79520 to 0.79580, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 24s - loss: 0.5325 - accuracy: 0.8132 - val_loss: 0.6159 - val_accuracy: 0.7958
# Epoch 97/200
#
# Epoch 00097: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5291 - accuracy: 0.8149 - val_loss: 0.6289 - val_accuracy: 0.7843
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5331 - accuracy: 0.8138 - val_loss: 0.6592 - val_accuracy: 0.7746
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5286 - accuracy: 0.8136 - val_loss: 0.6606 - val_accuracy: 0.7792
# Epoch 100/200
#
# Epoch 00100: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5265 - accuracy: 0.8152 - val_loss: 0.6771 - val_accuracy: 0.7746
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5210 - accuracy: 0.8178 - val_loss: 0.6098 - val_accuracy: 0.7943
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5170 - accuracy: 0.8200 - val_loss: 0.7018 - val_accuracy: 0.7709
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5132 - accuracy: 0.8224 - val_loss: 0.6112 - val_accuracy: 0.7941
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5084 - accuracy: 0.8218 - val_loss: 0.6262 - val_accuracy: 0.7921
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5014 - accuracy: 0.8248 - val_loss: 0.6514 - val_accuracy: 0.7835
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5047 - accuracy: 0.8227 - val_loss: 0.6155 - val_accuracy: 0.7930
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.79580
# 500/500 - 24s - loss: 0.5018 - accuracy: 0.8233 - val_loss: 0.6467 - val_accuracy: 0.7872
# Epoch 108/200
#
# Epoch 00108: val_accuracy improved from 0.79580 to 0.80450, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 26s - loss: 0.4992 - accuracy: 0.8259 - val_loss: 0.5888 - val_accuracy: 0.8045
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.80450
# 500/500 - 24s - loss: 0.4926 - accuracy: 0.8272 - val_loss: 0.6117 - val_accuracy: 0.7959
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.80450
# 500/500 - 24s - loss: 0.4916 - accuracy: 0.8272 - val_loss: 0.6419 - val_accuracy: 0.7879
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.80450
# 500/500 - 24s - loss: 0.4874 - accuracy: 0.8300 - val_loss: 0.6379 - val_accuracy: 0.7889
# Epoch 112/200
#
# Epoch 00112: val_accuracy did not improve from 0.80450
# 500/500 - 25s - loss: 0.4833 - accuracy: 0.8312 - val_loss: 0.6534 - val_accuracy: 0.7860
# Epoch 113/200
#
# Epoch 00113: val_accuracy did not improve from 0.80450
# 500/500 - 24s - loss: 0.4863 - accuracy: 0.8285 - val_loss: 0.6399 - val_accuracy: 0.7899
# Epoch 114/200
#
# Epoch 00114: val_accuracy did not improve from 0.80450
# 500/500 - 24s - loss: 0.4776 - accuracy: 0.8313 - val_loss: 0.6343 - val_accuracy: 0.7894
# Epoch 115/200
#
# Epoch 00115: val_accuracy did not improve from 0.80450
# 500/500 - 24s - loss: 0.4801 - accuracy: 0.8325 - val_loss: 0.6094 - val_accuracy: 0.7992
# Epoch 116/200
#
# Epoch 00116: val_accuracy improved from 0.80450 to 0.80500, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.4739 - accuracy: 0.8341 - val_loss: 0.5860 - val_accuracy: 0.8050
# Epoch 117/200
#
# Epoch 00117: val_accuracy did not improve from 0.80500
# 500/500 - 25s - loss: 0.4736 - accuracy: 0.8323 - val_loss: 0.6004 - val_accuracy: 0.7999
# Epoch 118/200
#
# Epoch 00118: val_accuracy did not improve from 0.80500
# 500/500 - 24s - loss: 0.4696 - accuracy: 0.8365 - val_loss: 0.6205 - val_accuracy: 0.7927
# Epoch 119/200
#
# Epoch 00119: val_accuracy did not improve from 0.80500
# 500/500 - 25s - loss: 0.4647 - accuracy: 0.8369 - val_loss: 0.5994 - val_accuracy: 0.8015
# Epoch 120/200
#
# Epoch 00120: val_accuracy did not improve from 0.80500
# 500/500 - 25s - loss: 0.4647 - accuracy: 0.8375 - val_loss: 0.5953 - val_accuracy: 0.8013
# Epoch 121/200
#
# Epoch 00121: val_accuracy improved from 0.80500 to 0.81040, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.4576 - accuracy: 0.8411 - val_loss: 0.5729 - val_accuracy: 0.8104
# Epoch 122/200
#
# Epoch 00122: val_accuracy did not improve from 0.81040
# 500/500 - 25s - loss: 0.4570 - accuracy: 0.8398 - val_loss: 0.6120 - val_accuracy: 0.8008
# Epoch 123/200
#
# Epoch 00123: val_accuracy did not improve from 0.81040
# 500/500 - 25s - loss: 0.4551 - accuracy: 0.8388 - val_loss: 0.6092 - val_accuracy: 0.7977
# Epoch 124/200
#
# Epoch 00124: val_accuracy improved from 0.81040 to 0.81150, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.4520 - accuracy: 0.8404 - val_loss: 0.5659 - val_accuracy: 0.8115
# Epoch 125/200
#
# Epoch 00125: val_accuracy did not improve from 0.81150
# 500/500 - 24s - loss: 0.4490 - accuracy: 0.8425 - val_loss: 0.6441 - val_accuracy: 0.7867
# Epoch 126/200
#
# Epoch 00126: val_accuracy did not improve from 0.81150
# 500/500 - 25s - loss: 0.4467 - accuracy: 0.8428 - val_loss: 0.6153 - val_accuracy: 0.7978
# Epoch 127/200
#
# Epoch 00127: val_accuracy did not improve from 0.81150
# 500/500 - 24s - loss: 0.4463 - accuracy: 0.8417 - val_loss: 0.6267 - val_accuracy: 0.7947
# Epoch 128/200
#
# Epoch 00128: val_accuracy did not improve from 0.81150
# 500/500 - 24s - loss: 0.4440 - accuracy: 0.8430 - val_loss: 0.5801 - val_accuracy: 0.8085
# Epoch 129/200
#
# Epoch 00129: val_accuracy did not improve from 0.81150
# 500/500 - 25s - loss: 0.4412 - accuracy: 0.8454 - val_loss: 0.5788 - val_accuracy: 0.8097
# Epoch 130/200
#
# Epoch 00130: val_accuracy did not improve from 0.81150
# 500/500 - 25s - loss: 0.4381 - accuracy: 0.8456 - val_loss: 0.5671 - val_accuracy: 0.8112
# Epoch 131/200
#
# Epoch 00131: val_accuracy did not improve from 0.81150
# 500/500 - 25s - loss: 0.4322 - accuracy: 0.8474 - val_loss: 0.5829 - val_accuracy: 0.8046
# Epoch 132/200
#
# Epoch 00132: val_accuracy did not improve from 0.81150
# 500/500 - 24s - loss: 0.4345 - accuracy: 0.8483 - val_loss: 0.5750 - val_accuracy: 0.8111
# Epoch 133/200
#
# Epoch 00133: val_accuracy did not improve from 0.81150
# 500/500 - 25s - loss: 0.4289 - accuracy: 0.8513 - val_loss: 0.5786 - val_accuracy: 0.8100
# Epoch 134/200
#
# Epoch 00134: val_accuracy did not improve from 0.81150
# 500/500 - 25s - loss: 0.4324 - accuracy: 0.8476 - val_loss: 0.5851 - val_accuracy: 0.8066
# Epoch 135/200
#
# Epoch 00135: val_accuracy improved from 0.81150 to 0.81630, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.4253 - accuracy: 0.8495 - val_loss: 0.5688 - val_accuracy: 0.8163
# Epoch 136/200
#
# Epoch 00136: val_accuracy did not improve from 0.81630
# 500/500 - 24s - loss: 0.4198 - accuracy: 0.8520 - val_loss: 0.6046 - val_accuracy: 0.8054
# Epoch 137/200
#
# Epoch 00137: val_accuracy did not improve from 0.81630
# 500/500 - 24s - loss: 0.4223 - accuracy: 0.8522 - val_loss: 0.6098 - val_accuracy: 0.8010
# Epoch 138/200
#
# Epoch 00138: val_accuracy did not improve from 0.81630
# 500/500 - 24s - loss: 0.4166 - accuracy: 0.8542 - val_loss: 0.5955 - val_accuracy: 0.8058
# Epoch 139/200
#
# Epoch 00139: val_accuracy did not improve from 0.81630
# 500/500 - 25s - loss: 0.4183 - accuracy: 0.8524 - val_loss: 0.5896 - val_accuracy: 0.8062
# Epoch 140/200
#
# Epoch 00140: val_accuracy did not improve from 0.81630
# 500/500 - 24s - loss: 0.4201 - accuracy: 0.8527 - val_loss: 0.5575 - val_accuracy: 0.8129
# Epoch 141/200
#
# Epoch 00141: val_accuracy did not improve from 0.81630
# 500/500 - 25s - loss: 0.4178 - accuracy: 0.8523 - val_loss: 0.6096 - val_accuracy: 0.8034
# Epoch 142/200
#
# Epoch 00142: val_accuracy did not improve from 0.81630
# 500/500 - 25s - loss: 0.4100 - accuracy: 0.8561 - val_loss: 0.5824 - val_accuracy: 0.8110
# Epoch 143/200
#
# Epoch 00143: val_accuracy did not improve from 0.81630
# 500/500 - 25s - loss: 0.4094 - accuracy: 0.8566 - val_loss: 0.6098 - val_accuracy: 0.8017
# Epoch 144/200
#
# Epoch 00144: val_accuracy did not improve from 0.81630
# 500/500 - 24s - loss: 0.4073 - accuracy: 0.8565 - val_loss: 0.6195 - val_accuracy: 0.8002
# Epoch 145/200
#
# Epoch 00145: val_accuracy improved from 0.81630 to 0.81780, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.4021 - accuracy: 0.8611 - val_loss: 0.5576 - val_accuracy: 0.8178
# Epoch 146/200
#
# Epoch 00146: val_accuracy did not improve from 0.81780
# 500/500 - 24s - loss: 0.4043 - accuracy: 0.8581 - val_loss: 0.5689 - val_accuracy: 0.8139
# Epoch 147/200
#
# Epoch 00147: val_accuracy did not improve from 0.81780
# 500/500 - 24s - loss: 0.3964 - accuracy: 0.8611 - val_loss: 0.5984 - val_accuracy: 0.8109
# Epoch 148/200
#
# Epoch 00148: val_accuracy improved from 0.81780 to 0.82050, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.3966 - accuracy: 0.8605 - val_loss: 0.5451 - val_accuracy: 0.8205
# Epoch 149/200
#
# Epoch 00149: val_accuracy did not improve from 0.82050
# 500/500 - 25s - loss: 0.3950 - accuracy: 0.8603 - val_loss: 0.5652 - val_accuracy: 0.8162
# Epoch 150/200
#
# Epoch 00150: val_accuracy did not improve from 0.82050
# 500/500 - 25s - loss: 0.3969 - accuracy: 0.8579 - val_loss: 0.5752 - val_accuracy: 0.8165
# Epoch 151/200
#
# Epoch 00151: val_accuracy did not improve from 0.82050
# 500/500 - 25s - loss: 0.3878 - accuracy: 0.8639 - val_loss: 0.6634 - val_accuracy: 0.7932
# Epoch 152/200
#
# Epoch 00152: val_accuracy did not improve from 0.82050
# 500/500 - 24s - loss: 0.3898 - accuracy: 0.8627 - val_loss: 0.5703 - val_accuracy: 0.8173
# Epoch 153/200
#
# Epoch 00153: val_accuracy did not improve from 0.82050
# 500/500 - 24s - loss: 0.3791 - accuracy: 0.8659 - val_loss: 0.6220 - val_accuracy: 0.7999
# Epoch 154/200
#
# Epoch 00154: val_accuracy did not improve from 0.82050
# 500/500 - 24s - loss: 0.3825 - accuracy: 0.8657 - val_loss: 0.5916 - val_accuracy: 0.8085
# Epoch 155/200
#
# Epoch 00155: val_accuracy did not improve from 0.82050
# 500/500 - 25s - loss: 0.3861 - accuracy: 0.8645 - val_loss: 0.5965 - val_accuracy: 0.8107
# Epoch 156/200
#
# Epoch 00156: val_accuracy improved from 0.82050 to 0.82090, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.3813 - accuracy: 0.8660 - val_loss: 0.5581 - val_accuracy: 0.8209
# Epoch 157/200
#
# Epoch 00157: val_accuracy did not improve from 0.82090
# 500/500 - 24s - loss: 0.3787 - accuracy: 0.8662 - val_loss: 0.5618 - val_accuracy: 0.8188
# Epoch 158/200
#
# Epoch 00158: val_accuracy did not improve from 0.82090
# 500/500 - 24s - loss: 0.3782 - accuracy: 0.8671 - val_loss: 0.5694 - val_accuracy: 0.8152
# Epoch 159/200
#
# Epoch 00159: val_accuracy improved from 0.82090 to 0.82130, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.3734 - accuracy: 0.8675 - val_loss: 0.5533 - val_accuracy: 0.8213
# Epoch 160/200
#
# Epoch 00160: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3723 - accuracy: 0.8678 - val_loss: 0.5560 - val_accuracy: 0.8205
# Epoch 161/200
#
# Epoch 00161: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3694 - accuracy: 0.8699 - val_loss: 0.5843 - val_accuracy: 0.8139
# Epoch 162/200
#
# Epoch 00162: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3683 - accuracy: 0.8685 - val_loss: 0.5776 - val_accuracy: 0.8146
# Epoch 163/200
#
# Epoch 00163: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3649 - accuracy: 0.8718 - val_loss: 0.5560 - val_accuracy: 0.8212
# Epoch 164/200
#
# Epoch 00164: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3575 - accuracy: 0.8750 - val_loss: 0.5636 - val_accuracy: 0.8194
# Epoch 165/200
#
# Epoch 00165: val_accuracy did not improve from 0.82130
# 500/500 - 25s - loss: 0.3656 - accuracy: 0.8713 - val_loss: 0.5761 - val_accuracy: 0.8167
# Epoch 166/200
#
# Epoch 00166: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3621 - accuracy: 0.8718 - val_loss: 0.5832 - val_accuracy: 0.8124
# Epoch 167/200
#
# Epoch 00167: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3592 - accuracy: 0.8725 - val_loss: 0.5883 - val_accuracy: 0.8139
# Epoch 168/200
#
# Epoch 00168: val_accuracy did not improve from 0.82130
# 500/500 - 25s - loss: 0.3546 - accuracy: 0.8747 - val_loss: 0.5598 - val_accuracy: 0.8195
# Epoch 169/200
#
# Epoch 00169: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3512 - accuracy: 0.8751 - val_loss: 0.5618 - val_accuracy: 0.8203
# Epoch 170/200
#
# Epoch 00170: val_accuracy did not improve from 0.82130
# 500/500 - 24s - loss: 0.3571 - accuracy: 0.8740 - val_loss: 0.5649 - val_accuracy: 0.8193
# Epoch 171/200
#
# Epoch 00171: val_accuracy improved from 0.82130 to 0.82410, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.3484 - accuracy: 0.8770 - val_loss: 0.5454 - val_accuracy: 0.8241
# Epoch 172/200
#
# Epoch 00172: val_accuracy did not improve from 0.82410
# 500/500 - 24s - loss: 0.3479 - accuracy: 0.8774 - val_loss: 0.5760 - val_accuracy: 0.8182
# Epoch 173/200
#
# Epoch 00173: val_accuracy did not improve from 0.82410
# 500/500 - 24s - loss: 0.3446 - accuracy: 0.8799 - val_loss: 0.5899 - val_accuracy: 0.8122
# Epoch 174/200
#
# Epoch 00174: val_accuracy did not improve from 0.82410
# 500/500 - 24s - loss: 0.3425 - accuracy: 0.8802 - val_loss: 0.5725 - val_accuracy: 0.8204
# Epoch 175/200
#
# Epoch 00175: val_accuracy did not improve from 0.82410
# 500/500 - 24s - loss: 0.3437 - accuracy: 0.8792 - val_loss: 0.5719 - val_accuracy: 0.8230
# Epoch 176/200
#
# Epoch 00176: val_accuracy did not improve from 0.82410
# 500/500 - 24s - loss: 0.3426 - accuracy: 0.8780 - val_loss: 0.5744 - val_accuracy: 0.8221
# Epoch 177/200
#
# Epoch 00177: val_accuracy improved from 0.82410 to 0.82960, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.3398 - accuracy: 0.8796 - val_loss: 0.5413 - val_accuracy: 0.8296
# Epoch 178/200
#
# Epoch 00178: val_accuracy did not improve from 0.82960
# 500/500 - 24s - loss: 0.3384 - accuracy: 0.8810 - val_loss: 0.5945 - val_accuracy: 0.8106
# Epoch 179/200
#
# Epoch 00179: val_accuracy did not improve from 0.82960
# 500/500 - 24s - loss: 0.3330 - accuracy: 0.8824 - val_loss: 0.5910 - val_accuracy: 0.8190
# Epoch 180/200
#
# Epoch 00180: val_accuracy did not improve from 0.82960
# 500/500 - 24s - loss: 0.3366 - accuracy: 0.8803 - val_loss: 0.5982 - val_accuracy: 0.8167
# Epoch 181/200
#
# Epoch 00181: val_accuracy did not improve from 0.82960
# 500/500 - 24s - loss: 0.3339 - accuracy: 0.8826 - val_loss: 0.6218 - val_accuracy: 0.8045
# Epoch 182/200
#
# Epoch 00182: val_accuracy improved from 0.82960 to 0.83010, saving model to gdrive/My Drive/Colab Notebooks/Augmentation_2.h5
# 500/500 - 25s - loss: 0.3308 - accuracy: 0.8846 - val_loss: 0.5456 - val_accuracy: 0.8301
# Epoch 183/200
#
# Epoch 00183: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3291 - accuracy: 0.8844 - val_loss: 0.5657 - val_accuracy: 0.8208
# Epoch 184/200
#
# Epoch 00184: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3283 - accuracy: 0.8841 - val_loss: 0.5592 - val_accuracy: 0.8252
# Epoch 185/200
#
# Epoch 00185: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3255 - accuracy: 0.8847 - val_loss: 0.5516 - val_accuracy: 0.8284
# Epoch 186/200
#
# Epoch 00186: val_accuracy did not improve from 0.83010
# 500/500 - 23s - loss: 0.3237 - accuracy: 0.8853 - val_loss: 0.5668 - val_accuracy: 0.8232
# Epoch 187/200
#
# Epoch 00187: val_accuracy did not improve from 0.83010
# 500/500 - 23s - loss: 0.3213 - accuracy: 0.8863 - val_loss: 0.5475 - val_accuracy: 0.8295
# Epoch 188/200
#
# Epoch 00188: val_accuracy did not improve from 0.83010
# 500/500 - 23s - loss: 0.3189 - accuracy: 0.8875 - val_loss: 0.5654 - val_accuracy: 0.8178
# Epoch 189/200
#
# Epoch 00189: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3246 - accuracy: 0.8861 - val_loss: 0.5424 - val_accuracy: 0.8299
# Epoch 190/200
#
# Epoch 00190: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3191 - accuracy: 0.8867 - val_loss: 0.5614 - val_accuracy: 0.8250
# Epoch 191/200
#
# Epoch 00191: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3192 - accuracy: 0.8873 - val_loss: 0.5790 - val_accuracy: 0.8206
# Epoch 192/200
#
# Epoch 00192: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3149 - accuracy: 0.8893 - val_loss: 0.5666 - val_accuracy: 0.8238
# Epoch 193/200
#
# Epoch 00193: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3138 - accuracy: 0.8889 - val_loss: 0.5579 - val_accuracy: 0.8217
# Epoch 194/200
#
# Epoch 00194: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3109 - accuracy: 0.8888 - val_loss: 0.6084 - val_accuracy: 0.8109
# Epoch 195/200
#
# Epoch 00195: val_accuracy did not improve from 0.83010
# 500/500 - 23s - loss: 0.3115 - accuracy: 0.8904 - val_loss: 0.5550 - val_accuracy: 0.8286
# Epoch 196/200
#
# Epoch 00196: val_accuracy did not improve from 0.83010
# 500/500 - 23s - loss: 0.3080 - accuracy: 0.8926 - val_loss: 0.5554 - val_accuracy: 0.8296
# Epoch 197/200
#
# Epoch 00197: val_accuracy did not improve from 0.83010
# 500/500 - 23s - loss: 0.3045 - accuracy: 0.8920 - val_loss: 0.5653 - val_accuracy: 0.8259
# Epoch 198/200
#
# Epoch 00198: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3035 - accuracy: 0.8930 - val_loss: 0.5770 - val_accuracy: 0.8208
# Epoch 199/200
#
# Epoch 00199: val_accuracy did not improve from 0.83010
# 500/500 - 24s - loss: 0.3036 - accuracy: 0.8924 - val_loss: 0.5614 - val_accuracy: 0.8275
# Epoch 200/200
#
# Epoch 00200: val_accuracy did not improve from 0.83010
# 500/500 - 23s - loss: 0.3012 - accuracy: 0.8920 - val_loss: 0.5708 - val_accuracy: 0.8266

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.8293347955472194
# Recall:  0.8301
# Accuracy:  0.8301
