# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, GaussianNoise
from keras.optimizers import Adamax
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 10
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5"
path_train = "gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar10.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     zca_epsilon=1e-06,
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     vertical_flip=False)

# datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu')(l_3)
    # l_3 = BatchNormalization()(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu')(l_5)
    # l_5 = BatchNormalization()(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    # l_p = BatchNormalization()(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    # input = GaussianNoise(0.01)(input)
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)

    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu')(l)

    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    # l = BatchNormalization()(l)


    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = GaussianNoise(0.005)(l)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    # l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 192)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 96)     18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 16)     3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 192)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 64)     12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 128)    110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 32)     12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 256)    0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# gaussian_noise (GaussianNoise)  (None, 7, 7, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    32896       gaussian_noise[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     8224        gaussian_noise[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)    0           gaussian_noise[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    32896       gaussian_noise[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 480)    0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4, 4, 512)    0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,058,154
# Trainable params: 1,058,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adamax(learning_rate=0.0001, decay=1e-06), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# model.load_weights(path_best)
history = model.fit(x_train_norm, y_train_norm,
                        batch_size=batch_size,
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.36870, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.9034 - accuracy: 0.3064 - val_loss: 1.6929 - val_accuracy: 0.3687
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.36870 to 0.43310, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 1.6070 - accuracy: 0.4125 - val_loss: 1.5302 - val_accuracy: 0.4331
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.43310 to 0.47120, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 1.4853 - accuracy: 0.4568 - val_loss: 1.4346 - val_accuracy: 0.4712
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.47120 to 0.50530, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.4030 - accuracy: 0.4905 - val_loss: 1.3652 - val_accuracy: 0.5053
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.50530 to 0.52820, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.3428 - accuracy: 0.5176 - val_loss: 1.3094 - val_accuracy: 0.5282
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.52820 to 0.54010, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.2916 - accuracy: 0.5363 - val_loss: 1.2728 - val_accuracy: 0.5401
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.54010 to 0.54470, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.2503 - accuracy: 0.5527 - val_loss: 1.2546 - val_accuracy: 0.5447
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.54470 to 0.56690, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.2122 - accuracy: 0.5679 - val_loss: 1.2319 - val_accuracy: 0.5669
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.56690 to 0.58170, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 1.1788 - accuracy: 0.5816 - val_loss: 1.1685 - val_accuracy: 0.5817
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.58170 to 0.58510, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 1.1415 - accuracy: 0.5945 - val_loss: 1.1630 - val_accuracy: 0.5851
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.58510 to 0.61000, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.1157 - accuracy: 0.6061 - val_loss: 1.1156 - val_accuracy: 0.6100
# Epoch 12/200
#
# Epoch 00012: val_accuracy did not improve from 0.61000
# 500/500 - 10s - loss: 1.0823 - accuracy: 0.6163 - val_loss: 1.1191 - val_accuracy: 0.5988
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.61000 to 0.62130, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.0628 - accuracy: 0.6270 - val_loss: 1.0706 - val_accuracy: 0.6213
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.62130 to 0.62190, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.0342 - accuracy: 0.6360 - val_loss: 1.0686 - val_accuracy: 0.6219
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.62190 to 0.63970, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 1.0177 - accuracy: 0.6431 - val_loss: 1.0236 - val_accuracy: 0.6397
# Epoch 16/200
#
# Epoch 00016: val_accuracy improved from 0.63970 to 0.64310, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.9930 - accuracy: 0.6505 - val_loss: 1.0258 - val_accuracy: 0.6431
# Epoch 17/200
#
# Epoch 00017: val_accuracy did not improve from 0.64310
# 500/500 - 10s - loss: 0.9742 - accuracy: 0.6595 - val_loss: 1.0090 - val_accuracy: 0.6425
# Epoch 18/200
#
# Epoch 00018: val_accuracy did not improve from 0.64310
# 500/500 - 10s - loss: 0.9594 - accuracy: 0.6631 - val_loss: 1.0274 - val_accuracy: 0.6403
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.64310 to 0.64520, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.9380 - accuracy: 0.6717 - val_loss: 1.0114 - val_accuracy: 0.6452
# Epoch 20/200
#
# Epoch 00020: val_accuracy improved from 0.64520 to 0.65500, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.9228 - accuracy: 0.6759 - val_loss: 0.9752 - val_accuracy: 0.6550
# Epoch 21/200
#
# Epoch 00021: val_accuracy improved from 0.65500 to 0.67590, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.9016 - accuracy: 0.6846 - val_loss: 0.9419 - val_accuracy: 0.6759
# Epoch 22/200
#
# Epoch 00022: val_accuracy did not improve from 0.67590
# 500/500 - 10s - loss: 0.8852 - accuracy: 0.6911 - val_loss: 0.9388 - val_accuracy: 0.6689
# Epoch 23/200
#
# Epoch 00023: val_accuracy did not improve from 0.67590
# 500/500 - 10s - loss: 0.8769 - accuracy: 0.6934 - val_loss: 0.9458 - val_accuracy: 0.6695
# Epoch 24/200
#
# Epoch 00024: val_accuracy improved from 0.67590 to 0.68210, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.8568 - accuracy: 0.7002 - val_loss: 0.9173 - val_accuracy: 0.6821
# Epoch 25/200
#
# Epoch 00025: val_accuracy did not improve from 0.68210
# 500/500 - 10s - loss: 0.8433 - accuracy: 0.7066 - val_loss: 0.9186 - val_accuracy: 0.6809
# Epoch 26/200
#
# Epoch 00026: val_accuracy did not improve from 0.68210
# 500/500 - 10s - loss: 0.8331 - accuracy: 0.7091 - val_loss: 0.9065 - val_accuracy: 0.6811
# Epoch 27/200
#
# Epoch 00027: val_accuracy improved from 0.68210 to 0.69290, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.8189 - accuracy: 0.7150 - val_loss: 0.8884 - val_accuracy: 0.6929
# Epoch 28/200
#
# Epoch 00028: val_accuracy improved from 0.69290 to 0.69700, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.8026 - accuracy: 0.7219 - val_loss: 0.8814 - val_accuracy: 0.6970
# Epoch 29/200
#
# Epoch 00029: val_accuracy improved from 0.69700 to 0.70660, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 0.7895 - accuracy: 0.7246 - val_loss: 0.8528 - val_accuracy: 0.7066
# Epoch 30/200
#
# Epoch 00030: val_accuracy did not improve from 0.70660
# 500/500 - 10s - loss: 0.7812 - accuracy: 0.7272 - val_loss: 0.8635 - val_accuracy: 0.7014
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.70660
# 500/500 - 10s - loss: 0.7667 - accuracy: 0.7338 - val_loss: 0.8441 - val_accuracy: 0.7066
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.70660 to 0.71010, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.7556 - accuracy: 0.7375 - val_loss: 0.8394 - val_accuracy: 0.7101
# Epoch 33/200
#
# Epoch 00033: val_accuracy improved from 0.71010 to 0.71310, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.7430 - accuracy: 0.7441 - val_loss: 0.8306 - val_accuracy: 0.7131
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.71310
# 500/500 - 10s - loss: 0.7328 - accuracy: 0.7452 - val_loss: 0.8548 - val_accuracy: 0.7002
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.71310
# 500/500 - 10s - loss: 0.7236 - accuracy: 0.7475 - val_loss: 0.8604 - val_accuracy: 0.7035
# Epoch 36/200
#
# Epoch 00036: val_accuracy improved from 0.71310 to 0.71400, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.7132 - accuracy: 0.7539 - val_loss: 0.8249 - val_accuracy: 0.7140
# Epoch 37/200
#
# Epoch 00037: val_accuracy improved from 0.71400 to 0.72110, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.6999 - accuracy: 0.7573 - val_loss: 0.8058 - val_accuracy: 0.7211
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.72110
# 500/500 - 10s - loss: 0.6922 - accuracy: 0.7589 - val_loss: 0.8188 - val_accuracy: 0.7190
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.72110 to 0.73060, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.6785 - accuracy: 0.7648 - val_loss: 0.7864 - val_accuracy: 0.7306
# Epoch 40/200
#
# Epoch 00040: val_accuracy improved from 0.73060 to 0.73320, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.6713 - accuracy: 0.7678 - val_loss: 0.7758 - val_accuracy: 0.7332
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.73320
# 500/500 - 10s - loss: 0.6554 - accuracy: 0.7710 - val_loss: 0.7741 - val_accuracy: 0.7322
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.73320
# 500/500 - 10s - loss: 0.6562 - accuracy: 0.7724 - val_loss: 0.7895 - val_accuracy: 0.7288
# Epoch 43/200
#
# Epoch 00043: val_accuracy improved from 0.73320 to 0.74150, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.6388 - accuracy: 0.7791 - val_loss: 0.7617 - val_accuracy: 0.7415
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.74150
# 500/500 - 10s - loss: 0.6358 - accuracy: 0.7788 - val_loss: 0.7921 - val_accuracy: 0.7278
# Epoch 45/200
#
# Epoch 00045: val_accuracy did not improve from 0.74150
# 500/500 - 10s - loss: 0.6235 - accuracy: 0.7830 - val_loss: 0.7577 - val_accuracy: 0.7387
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.74150
# 500/500 - 10s - loss: 0.6114 - accuracy: 0.7864 - val_loss: 0.8146 - val_accuracy: 0.7228
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.74150
# 500/500 - 10s - loss: 0.6035 - accuracy: 0.7914 - val_loss: 0.7605 - val_accuracy: 0.7376
# Epoch 48/200
#
# Epoch 00048: val_accuracy improved from 0.74150 to 0.74810, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.5962 - accuracy: 0.7926 - val_loss: 0.7429 - val_accuracy: 0.7481
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.74810
# 500/500 - 10s - loss: 0.5870 - accuracy: 0.7969 - val_loss: 0.7904 - val_accuracy: 0.7295
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.74810
# 500/500 - 10s - loss: 0.5803 - accuracy: 0.7983 - val_loss: 0.7993 - val_accuracy: 0.7309
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.74810
# 500/500 - 10s - loss: 0.5696 - accuracy: 0.8024 - val_loss: 0.7630 - val_accuracy: 0.7412
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.74810
# 500/500 - 10s - loss: 0.5577 - accuracy: 0.8077 - val_loss: 0.7515 - val_accuracy: 0.7418
# Epoch 53/200
#
# Epoch 00053: val_accuracy improved from 0.74810 to 0.75390, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.5495 - accuracy: 0.8088 - val_loss: 0.7393 - val_accuracy: 0.7539
# Epoch 54/200
#
# Epoch 00054: val_accuracy improved from 0.75390 to 0.75550, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.5440 - accuracy: 0.8104 - val_loss: 0.7282 - val_accuracy: 0.7555
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.75550
# 500/500 - 10s - loss: 0.5327 - accuracy: 0.8156 - val_loss: 0.7634 - val_accuracy: 0.7439
# Epoch 56/200
#
# Epoch 00056: val_accuracy improved from 0.75550 to 0.75640, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.5290 - accuracy: 0.8184 - val_loss: 0.7247 - val_accuracy: 0.7564
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.75640
# 500/500 - 10s - loss: 0.5138 - accuracy: 0.8228 - val_loss: 0.7559 - val_accuracy: 0.7450
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.75640
# 500/500 - 10s - loss: 0.5109 - accuracy: 0.8239 - val_loss: 0.7346 - val_accuracy: 0.7538
# Epoch 59/200
#
# Epoch 00059: val_accuracy did not improve from 0.75640
# 500/500 - 10s - loss: 0.5063 - accuracy: 0.8238 - val_loss: 0.7376 - val_accuracy: 0.7524
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.75640
# 500/500 - 10s - loss: 0.4953 - accuracy: 0.8280 - val_loss: 0.7554 - val_accuracy: 0.7457
# Epoch 61/200
#
# Epoch 00061: val_accuracy improved from 0.75640 to 0.75850, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.4832 - accuracy: 0.8325 - val_loss: 0.7334 - val_accuracy: 0.7585
# Epoch 62/200
#
# Epoch 00062: val_accuracy improved from 0.75850 to 0.76530, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 0.4810 - accuracy: 0.8334 - val_loss: 0.7024 - val_accuracy: 0.7653
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.76530
# 500/500 - 10s - loss: 0.4768 - accuracy: 0.8357 - val_loss: 0.7110 - val_accuracy: 0.7633
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.76530
# 500/500 - 10s - loss: 0.4741 - accuracy: 0.8345 - val_loss: 0.7303 - val_accuracy: 0.7583
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.76530
# 500/500 - 10s - loss: 0.4615 - accuracy: 0.8404 - val_loss: 0.7952 - val_accuracy: 0.7385
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.76530
# 500/500 - 10s - loss: 0.4508 - accuracy: 0.8444 - val_loss: 0.7216 - val_accuracy: 0.7642
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.76530
# 500/500 - 10s - loss: 0.4475 - accuracy: 0.8460 - val_loss: 0.7111 - val_accuracy: 0.7645
# Epoch 68/200
#
# Epoch 00068: val_accuracy did not improve from 0.76530
# 500/500 - 10s - loss: 0.4358 - accuracy: 0.8508 - val_loss: 0.7572 - val_accuracy: 0.7542
# Epoch 69/200
#
# Epoch 00069: val_accuracy did not improve from 0.76530
# 500/500 - 10s - loss: 0.4307 - accuracy: 0.8519 - val_loss: 0.7256 - val_accuracy: 0.7628
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.76530
# 500/500 - 10s - loss: 0.4262 - accuracy: 0.8536 - val_loss: 0.7243 - val_accuracy: 0.7647
# Epoch 71/200
#
# Epoch 00071: val_accuracy improved from 0.76530 to 0.76750, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.4138 - accuracy: 0.8576 - val_loss: 0.7141 - val_accuracy: 0.7675
# Epoch 72/200
#
# Epoch 00072: val_accuracy improved from 0.76750 to 0.77190, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.4095 - accuracy: 0.8584 - val_loss: 0.7068 - val_accuracy: 0.7719
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.4045 - accuracy: 0.8610 - val_loss: 0.7428 - val_accuracy: 0.7588
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.3951 - accuracy: 0.8650 - val_loss: 0.7296 - val_accuracy: 0.7608
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.3891 - accuracy: 0.8661 - val_loss: 0.7276 - val_accuracy: 0.7667
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.3807 - accuracy: 0.8691 - val_loss: 0.7379 - val_accuracy: 0.7671
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.3774 - accuracy: 0.8709 - val_loss: 0.7729 - val_accuracy: 0.7525
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.3690 - accuracy: 0.8742 - val_loss: 0.7617 - val_accuracy: 0.7617
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.3624 - accuracy: 0.8768 - val_loss: 0.7413 - val_accuracy: 0.7620
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.3564 - accuracy: 0.8779 - val_loss: 0.7299 - val_accuracy: 0.7668
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.77190
# 500/500 - 10s - loss: 0.3464 - accuracy: 0.8824 - val_loss: 0.7267 - val_accuracy: 0.7700
# Epoch 82/200
#
# Epoch 00082: val_accuracy improved from 0.77190 to 0.77260, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.3444 - accuracy: 0.8832 - val_loss: 0.7137 - val_accuracy: 0.7726
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.77260
# 500/500 - 10s - loss: 0.3351 - accuracy: 0.8863 - val_loss: 0.7396 - val_accuracy: 0.7690
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.77260
# 500/500 - 10s - loss: 0.3320 - accuracy: 0.8871 - val_loss: 0.7303 - val_accuracy: 0.7718
# Epoch 85/200
#
# Epoch 00085: val_accuracy did not improve from 0.77260
# 500/500 - 10s - loss: 0.3217 - accuracy: 0.8919 - val_loss: 0.7315 - val_accuracy: 0.7724
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.77260
# 500/500 - 10s - loss: 0.3171 - accuracy: 0.8934 - val_loss: 0.7872 - val_accuracy: 0.7585
# Epoch 87/200
#
# Epoch 00087: val_accuracy improved from 0.77260 to 0.77600, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.3112 - accuracy: 0.8938 - val_loss: 0.7311 - val_accuracy: 0.7760
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.3114 - accuracy: 0.8952 - val_loss: 0.7652 - val_accuracy: 0.7637
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.2981 - accuracy: 0.8982 - val_loss: 0.7644 - val_accuracy: 0.7710
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.2960 - accuracy: 0.9006 - val_loss: 0.7677 - val_accuracy: 0.7684
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.2910 - accuracy: 0.9024 - val_loss: 0.7484 - val_accuracy: 0.7746
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.2800 - accuracy: 0.9051 - val_loss: 0.7402 - val_accuracy: 0.7738
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.2736 - accuracy: 0.9081 - val_loss: 0.8230 - val_accuracy: 0.7552
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.2705 - accuracy: 0.9086 - val_loss: 0.7790 - val_accuracy: 0.7662
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.2664 - accuracy: 0.9102 - val_loss: 0.8062 - val_accuracy: 0.7628
# Epoch 96/200
#
# Epoch 00096: val_accuracy did not improve from 0.77600
# 500/500 - 10s - loss: 0.2557 - accuracy: 0.9149 - val_loss: 0.7848 - val_accuracy: 0.7690
# Epoch 97/200
#
# Epoch 00097: val_accuracy improved from 0.77600 to 0.77680, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 11s - loss: 0.2516 - accuracy: 0.9164 - val_loss: 0.7527 - val_accuracy: 0.7768
# Epoch 98/200
#
# Epoch 00098: val_accuracy improved from 0.77680 to 0.77720, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 0.2454 - accuracy: 0.9183 - val_loss: 0.7469 - val_accuracy: 0.7772
# Epoch 99/200
#
# Epoch 00099: val_accuracy improved from 0.77720 to 0.77790, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 0.2395 - accuracy: 0.9212 - val_loss: 0.7654 - val_accuracy: 0.7779
# Epoch 100/200
#
# Epoch 00100: val_accuracy improved from 0.77790 to 0.78030, saving model to gdrive/My Drive/Colab Notebooks/NoiseHidden_4.h5
# 500/500 - 10s - loss: 0.2328 - accuracy: 0.9242 - val_loss: 0.7680 - val_accuracy: 0.7803
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.2266 - accuracy: 0.9255 - val_loss: 0.7883 - val_accuracy: 0.7709
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.2237 - accuracy: 0.9267 - val_loss: 0.8688 - val_accuracy: 0.7565
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.2196 - accuracy: 0.9270 - val_loss: 0.8348 - val_accuracy: 0.7666
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.2156 - accuracy: 0.9291 - val_loss: 0.7837 - val_accuracy: 0.7777
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.2056 - accuracy: 0.9313 - val_loss: 0.8284 - val_accuracy: 0.7712
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1969 - accuracy: 0.9360 - val_loss: 0.8439 - val_accuracy: 0.7647
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1982 - accuracy: 0.9364 - val_loss: 0.7946 - val_accuracy: 0.7803
# Epoch 108/200
#
# Epoch 00108: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1893 - accuracy: 0.9396 - val_loss: 0.9001 - val_accuracy: 0.7622
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1829 - accuracy: 0.9421 - val_loss: 0.8406 - val_accuracy: 0.7726
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1792 - accuracy: 0.9415 - val_loss: 0.8451 - val_accuracy: 0.7723
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1716 - accuracy: 0.9463 - val_loss: 0.8478 - val_accuracy: 0.7734
# Epoch 112/200
#
# Epoch 00112: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1723 - accuracy: 0.9445 - val_loss: 0.8524 - val_accuracy: 0.7724
# Epoch 113/200
#
# Epoch 00113: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1624 - accuracy: 0.9491 - val_loss: 0.8560 - val_accuracy: 0.7757
# Epoch 114/200
#
# Epoch 00114: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1592 - accuracy: 0.9492 - val_loss: 0.8584 - val_accuracy: 0.7715
# Epoch 115/200
#
# Epoch 00115: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1588 - accuracy: 0.9491 - val_loss: 0.8656 - val_accuracy: 0.7745
# Epoch 116/200
#
# Epoch 00116: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1480 - accuracy: 0.9554 - val_loss: 0.8614 - val_accuracy: 0.7754
# Epoch 117/200
#
# Epoch 00117: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1434 - accuracy: 0.9567 - val_loss: 0.9412 - val_accuracy: 0.7665
# Epoch 118/200
#
# Epoch 00118: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1441 - accuracy: 0.9550 - val_loss: 0.8987 - val_accuracy: 0.7754
# Epoch 119/200
#
# Epoch 00119: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1462 - accuracy: 0.9537 - val_loss: 0.9222 - val_accuracy: 0.7698
# Epoch 120/200
#
# Epoch 00120: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1312 - accuracy: 0.9602 - val_loss: 0.9341 - val_accuracy: 0.7684
# Epoch 121/200
#
# Epoch 00121: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1292 - accuracy: 0.9603 - val_loss: 0.9131 - val_accuracy: 0.7734
# Epoch 122/200
#
# Epoch 00122: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1203 - accuracy: 0.9643 - val_loss: 0.9539 - val_accuracy: 0.7672
# Epoch 123/200
#
# Epoch 00123: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1216 - accuracy: 0.9634 - val_loss: 0.9641 - val_accuracy: 0.7656
# Epoch 124/200
#
# Epoch 00124: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1155 - accuracy: 0.9658 - val_loss: 0.9059 - val_accuracy: 0.7752
# Epoch 125/200
#
# Epoch 00125: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1112 - accuracy: 0.9678 - val_loss: 0.9608 - val_accuracy: 0.7687
# Epoch 126/200
#
# Epoch 00126: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1066 - accuracy: 0.9690 - val_loss: 1.0019 - val_accuracy: 0.7656
# Epoch 127/200
#
# Epoch 00127: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1046 - accuracy: 0.9691 - val_loss: 0.9695 - val_accuracy: 0.7720
# Epoch 128/200
#
# Epoch 00128: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.1038 - accuracy: 0.9695 - val_loss: 1.0064 - val_accuracy: 0.7698
# Epoch 129/200
#
# Epoch 00129: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0992 - accuracy: 0.9717 - val_loss: 1.0100 - val_accuracy: 0.7683
# Epoch 130/200
#
# Epoch 00130: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0902 - accuracy: 0.9755 - val_loss: 1.0021 - val_accuracy: 0.7685
# Epoch 131/200
#
# Epoch 00131: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0849 - accuracy: 0.9771 - val_loss: 1.0048 - val_accuracy: 0.7688
# Epoch 132/200
#
# Epoch 00132: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0900 - accuracy: 0.9747 - val_loss: 1.0147 - val_accuracy: 0.7711
# Epoch 133/200
#
# Epoch 00133: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0815 - accuracy: 0.9789 - val_loss: 1.0412 - val_accuracy: 0.7670
# Epoch 134/200
#
# Epoch 00134: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0785 - accuracy: 0.9784 - val_loss: 1.0950 - val_accuracy: 0.7641
# Epoch 135/200
#
# Epoch 00135: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0755 - accuracy: 0.9804 - val_loss: 1.0479 - val_accuracy: 0.7708
# Epoch 136/200
#
# Epoch 00136: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0742 - accuracy: 0.9806 - val_loss: 1.0820 - val_accuracy: 0.7676
# Epoch 137/200
#
# Epoch 00137: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0707 - accuracy: 0.9816 - val_loss: 1.0384 - val_accuracy: 0.7742
# Epoch 138/200
#
# Epoch 00138: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0651 - accuracy: 0.9837 - val_loss: 1.0696 - val_accuracy: 0.7715
# Epoch 139/200
#
# Epoch 00139: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0624 - accuracy: 0.9851 - val_loss: 1.1237 - val_accuracy: 0.7659
# Epoch 140/200
#
# Epoch 00140: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0608 - accuracy: 0.9851 - val_loss: 1.0946 - val_accuracy: 0.7715
# Epoch 141/200
#
# Epoch 00141: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0569 - accuracy: 0.9865 - val_loss: 1.1068 - val_accuracy: 0.7678
# Epoch 142/200
#
# Epoch 00142: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0547 - accuracy: 0.9879 - val_loss: 1.1558 - val_accuracy: 0.7665
# Epoch 143/200
#
# Epoch 00143: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0545 - accuracy: 0.9870 - val_loss: 1.1510 - val_accuracy: 0.7709
# Epoch 144/200
#
# Epoch 00144: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0516 - accuracy: 0.9882 - val_loss: 1.1077 - val_accuracy: 0.7740
# Epoch 145/200
#
# Epoch 00145: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0512 - accuracy: 0.9879 - val_loss: 1.1208 - val_accuracy: 0.7730
# Epoch 146/200
#
# Epoch 00146: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0433 - accuracy: 0.9919 - val_loss: 1.2210 - val_accuracy: 0.7608
# Epoch 147/200
#
# Epoch 00147: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0521 - accuracy: 0.9865 - val_loss: 1.1372 - val_accuracy: 0.7717
# Epoch 148/200
#
# Epoch 00148: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0412 - accuracy: 0.9918 - val_loss: 1.1764 - val_accuracy: 0.7699
# Epoch 149/200
#
# Epoch 00149: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0439 - accuracy: 0.9902 - val_loss: 1.1922 - val_accuracy: 0.7696
# Epoch 150/200
#
# Epoch 00150: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0377 - accuracy: 0.9933 - val_loss: 1.1823 - val_accuracy: 0.7701
# Epoch 151/200
#
# Epoch 00151: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0383 - accuracy: 0.9920 - val_loss: 1.1958 - val_accuracy: 0.7722
# Epoch 152/200
#
# Epoch 00152: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0326 - accuracy: 0.9947 - val_loss: 1.2864 - val_accuracy: 0.7637
# Epoch 153/200
#
# Epoch 00153: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0382 - accuracy: 0.9921 - val_loss: 1.2367 - val_accuracy: 0.7748
# Epoch 154/200
#
# Epoch 00154: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0329 - accuracy: 0.9934 - val_loss: 1.2522 - val_accuracy: 0.7662
# Epoch 155/200
#
# Epoch 00155: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0300 - accuracy: 0.9947 - val_loss: 1.2341 - val_accuracy: 0.7730
# Epoch 156/200
#
# Epoch 00156: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0261 - accuracy: 0.9967 - val_loss: 1.3406 - val_accuracy: 0.7615
# Epoch 157/200
#
# Epoch 00157: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0287 - accuracy: 0.9954 - val_loss: 1.3045 - val_accuracy: 0.7681
# Epoch 158/200
#
# Epoch 00158: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0221 - accuracy: 0.9975 - val_loss: 1.3006 - val_accuracy: 0.7698
# Epoch 159/200
#
# Epoch 00159: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0253 - accuracy: 0.9959 - val_loss: 1.2961 - val_accuracy: 0.7684
# Epoch 160/200
#
# Epoch 00160: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0267 - accuracy: 0.9955 - val_loss: 1.2801 - val_accuracy: 0.7727
# Epoch 161/200
#
# Epoch 00161: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0214 - accuracy: 0.9969 - val_loss: 1.3019 - val_accuracy: 0.7736
# Epoch 162/200
#
# Epoch 00162: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0199 - accuracy: 0.9971 - val_loss: 1.3365 - val_accuracy: 0.7709
# Epoch 163/200
#
# Epoch 00163: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0262 - accuracy: 0.9945 - val_loss: 1.3354 - val_accuracy: 0.7707
# Epoch 164/200
#
# Epoch 00164: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0110 - accuracy: 0.9998 - val_loss: 1.3269 - val_accuracy: 0.7736
# Epoch 165/200
#
# Epoch 00165: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0136 - accuracy: 0.9990 - val_loss: 1.3665 - val_accuracy: 0.7693
# Epoch 166/200
#
# Epoch 00166: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0151 - accuracy: 0.9987 - val_loss: 1.3622 - val_accuracy: 0.7744
# Epoch 167/200
#
# Epoch 00167: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0158 - accuracy: 0.9983 - val_loss: 1.3694 - val_accuracy: 0.7731
# Epoch 168/200
#
# Epoch 00168: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0152 - accuracy: 0.9981 - val_loss: 1.3893 - val_accuracy: 0.7744
# Epoch 169/200
#
# Epoch 00169: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0153 - accuracy: 0.9981 - val_loss: 1.4165 - val_accuracy: 0.7670
# Epoch 170/200
#
# Epoch 00170: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0179 - accuracy: 0.9970 - val_loss: 1.3741 - val_accuracy: 0.7752
# Epoch 171/200
#
# Epoch 00171: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0130 - accuracy: 0.9982 - val_loss: 1.4027 - val_accuracy: 0.7736
# Epoch 172/200
#
# Epoch 00172: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.4125 - val_accuracy: 0.7747
# Epoch 173/200
#
# Epoch 00173: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0139 - accuracy: 0.9980 - val_loss: 1.4101 - val_accuracy: 0.7748
# Epoch 174/200
#
# Epoch 00174: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0103 - accuracy: 0.9990 - val_loss: 1.4694 - val_accuracy: 0.7713
# Epoch 175/200
#
# Epoch 00175: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0139 - accuracy: 0.9974 - val_loss: 1.4337 - val_accuracy: 0.7763
# Epoch 176/200
#
# Epoch 00176: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.4399 - val_accuracy: 0.7763
# Epoch 177/200
#
# Epoch 00177: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0080 - accuracy: 0.9995 - val_loss: 1.4662 - val_accuracy: 0.7770
# Epoch 178/200
#
# Epoch 00178: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0100 - accuracy: 0.9988 - val_loss: 1.4593 - val_accuracy: 0.7726
# Epoch 179/200
#
# Epoch 00179: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0085 - accuracy: 0.9992 - val_loss: 1.5328 - val_accuracy: 0.7643
# Epoch 180/200
#
# Epoch 00180: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0113 - accuracy: 0.9981 - val_loss: 1.4754 - val_accuracy: 0.7755
# Epoch 181/200
#
# Epoch 00181: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.4930 - val_accuracy: 0.7739
# Epoch 182/200
#
# Epoch 00182: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0052 - accuracy: 0.9999 - val_loss: 1.4950 - val_accuracy: 0.7751
# Epoch 183/200
#
# Epoch 00183: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0103 - accuracy: 0.9986 - val_loss: 1.5037 - val_accuracy: 0.7730
# Epoch 184/200
#
# Epoch 00184: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0077 - accuracy: 0.9991 - val_loss: 1.5984 - val_accuracy: 0.7644
# Epoch 185/200
#
# Epoch 00185: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0062 - accuracy: 0.9995 - val_loss: 1.5272 - val_accuracy: 0.7727
# Epoch 186/200
#
# Epoch 00186: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0085 - accuracy: 0.9987 - val_loss: 1.5251 - val_accuracy: 0.7732
# Epoch 187/200
#
# Epoch 00187: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.5326 - val_accuracy: 0.7722
# Epoch 188/200
#
# Epoch 00188: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.5704 - val_accuracy: 0.7738
# Epoch 189/200
#
# Epoch 00189: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0127 - accuracy: 0.9969 - val_loss: 1.5359 - val_accuracy: 0.7737
# Epoch 190/200
#
# Epoch 00190: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.5553 - val_accuracy: 0.7742
# Epoch 191/200
#
# Epoch 00191: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0043 - accuracy: 0.9998 - val_loss: 1.5916 - val_accuracy: 0.7710
# Epoch 192/200
#
# Epoch 00192: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0059 - accuracy: 0.9994 - val_loss: 1.5683 - val_accuracy: 0.7763
# Epoch 193/200
#
# Epoch 00193: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.5885 - val_accuracy: 0.7735
# Epoch 194/200
#
# Epoch 00194: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0114 - accuracy: 0.9973 - val_loss: 1.5794 - val_accuracy: 0.7775
# Epoch 195/200
#
# Epoch 00195: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.5948 - val_accuracy: 0.7768
# Epoch 196/200
#
# Epoch 00196: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0069 - accuracy: 0.9985 - val_loss: 1.6871 - val_accuracy: 0.7641
# Epoch 197/200
#
# Epoch 00197: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0039 - accuracy: 0.9997 - val_loss: 1.6021 - val_accuracy: 0.7749
# Epoch 198/200
#
# Epoch 00198: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6137 - val_accuracy: 0.7754
# Epoch 199/200
#
# Epoch 00199: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0031 - accuracy: 0.9999 - val_loss: 1.7061 - val_accuracy: 0.7671
# Epoch 200/200
#
# Epoch 00200: val_accuracy did not improve from 0.78030
# 500/500 - 10s - loss: 0.0059 - accuracy: 0.9990 - val_loss: 1.6234 - val_accuracy: 0.7757

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.7840985414977588
# Recall:  0.7803
# Accuracy:  0.7803
