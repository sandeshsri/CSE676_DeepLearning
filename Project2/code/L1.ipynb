# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adamax
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l1
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 10
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/L1_3.h5"
path_train = "gdrive/My Drive/Colab Notebooks/L1_3.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar10.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     zca_epsilon=1e-06,
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     vertical_flip=False)

# datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu')(l_3)
    # l_3 = BatchNormalization()(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=l1(l1=0.01), bias_regularizer=l1(1e-4), activity_regularizer=l1(1e-5))(l_5)
    # l_5 = BatchNormalization()(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    # l_p = BatchNormalization()(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu')(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    # l = BatchNormalization()(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    # l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 192)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 96)     18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 16)     3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 192)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 64)     12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 128)    110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 32)     12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 256)    0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 480)    0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4, 4, 512)    0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,058,154
# Trainable params: 1,058,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adamax(learning_rate=0.0001, decay=1e-06), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# model.load_weights(path_best)
history = model.fit(x_train_norm, y_train_norm,
                        batch_size=batch_size,
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.37680, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 11.7158 - accuracy: 0.2935 - val_loss: 2.7851 - val_accuracy: 0.3768
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.37680 to 0.42800, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.9308 - accuracy: 0.4036 - val_loss: 1.6357 - val_accuracy: 0.4280
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.42800 to 0.46530, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.5372 - accuracy: 0.4527 - val_loss: 1.4747 - val_accuracy: 0.4653
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.46530 to 0.49300, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.4385 - accuracy: 0.4832 - val_loss: 1.4087 - val_accuracy: 0.4930
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.49300 to 0.51750, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.3786 - accuracy: 0.5046 - val_loss: 1.3491 - val_accuracy: 0.5175
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.51750 to 0.52480, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.3364 - accuracy: 0.5207 - val_loss: 1.3267 - val_accuracy: 0.5248
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.52480 to 0.53970, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.2999 - accuracy: 0.5386 - val_loss: 1.2824 - val_accuracy: 0.5397
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.53970 to 0.55840, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.2657 - accuracy: 0.5509 - val_loss: 1.2471 - val_accuracy: 0.5584
# Epoch 9/200
#
# Epoch 00009: val_accuracy did not improve from 0.55840
# 500/500 - 8s - loss: 1.2355 - accuracy: 0.5636 - val_loss: 1.2437 - val_accuracy: 0.5575
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.55840 to 0.57170, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.2042 - accuracy: 0.5775 - val_loss: 1.1989 - val_accuracy: 0.5717
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.57170 to 0.58470, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.1758 - accuracy: 0.5871 - val_loss: 1.1742 - val_accuracy: 0.5847
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.58470 to 0.59440, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.1506 - accuracy: 0.5976 - val_loss: 1.1505 - val_accuracy: 0.5944
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.59440 to 0.60410, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.1269 - accuracy: 0.6078 - val_loss: 1.1343 - val_accuracy: 0.6041
# Epoch 14/200
#
# Epoch 00014: val_accuracy did not improve from 0.60410
# 500/500 - 8s - loss: 1.1009 - accuracy: 0.6165 - val_loss: 1.1402 - val_accuracy: 0.6005
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.60410 to 0.60800, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.0799 - accuracy: 0.6237 - val_loss: 1.1071 - val_accuracy: 0.6080
# Epoch 16/200
#
# Epoch 00016: val_accuracy improved from 0.60800 to 0.61010, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.0589 - accuracy: 0.6319 - val_loss: 1.0947 - val_accuracy: 0.6101
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.61010 to 0.63640, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.0399 - accuracy: 0.6379 - val_loss: 1.0429 - val_accuracy: 0.6364
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.63640 to 0.64000, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.0219 - accuracy: 0.6444 - val_loss: 1.0427 - val_accuracy: 0.6400
# Epoch 19/200
#
# Epoch 00019: val_accuracy improved from 0.64000 to 0.64300, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 1.0018 - accuracy: 0.6524 - val_loss: 1.0187 - val_accuracy: 0.6430
# Epoch 20/200
#
# Epoch 00020: val_accuracy did not improve from 0.64300
# 500/500 - 8s - loss: 0.9860 - accuracy: 0.6581 - val_loss: 1.0276 - val_accuracy: 0.6426
# Epoch 21/200
#
# Epoch 00021: val_accuracy improved from 0.64300 to 0.64930, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.9693 - accuracy: 0.6638 - val_loss: 0.9997 - val_accuracy: 0.6493
# Epoch 22/200
#
# Epoch 00022: val_accuracy improved from 0.64930 to 0.66020, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.9525 - accuracy: 0.6713 - val_loss: 0.9705 - val_accuracy: 0.6602
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.66020 to 0.66050, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.9367 - accuracy: 0.6762 - val_loss: 0.9668 - val_accuracy: 0.6605
# Epoch 24/200
#
# Epoch 00024: val_accuracy did not improve from 0.66050
# 500/500 - 8s - loss: 0.9282 - accuracy: 0.6793 - val_loss: 0.9872 - val_accuracy: 0.6554
# Epoch 25/200
#
# Epoch 00025: val_accuracy improved from 0.66050 to 0.66960, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.9125 - accuracy: 0.6857 - val_loss: 0.9478 - val_accuracy: 0.6696
# Epoch 26/200
#
# Epoch 00026: val_accuracy improved from 0.66960 to 0.67510, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.8961 - accuracy: 0.6914 - val_loss: 0.9305 - val_accuracy: 0.6751
# Epoch 27/200
#
# Epoch 00027: val_accuracy did not improve from 0.67510
# 500/500 - 8s - loss: 0.8838 - accuracy: 0.6961 - val_loss: 0.9596 - val_accuracy: 0.6642
# Epoch 28/200
#
# Epoch 00028: val_accuracy improved from 0.67510 to 0.67750, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.8701 - accuracy: 0.7018 - val_loss: 0.9338 - val_accuracy: 0.6775
# Epoch 29/200
#
# Epoch 00029: val_accuracy improved from 0.67750 to 0.67940, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.8577 - accuracy: 0.7057 - val_loss: 0.9352 - val_accuracy: 0.6794
# Epoch 30/200
#
# Epoch 00030: val_accuracy improved from 0.67940 to 0.68910, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.8491 - accuracy: 0.7084 - val_loss: 0.8871 - val_accuracy: 0.6891
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.68910
# 500/500 - 8s - loss: 0.8376 - accuracy: 0.7123 - val_loss: 0.9138 - val_accuracy: 0.6839
# Epoch 32/200
#
# Epoch 00032: val_accuracy did not improve from 0.68910
# 500/500 - 8s - loss: 0.8242 - accuracy: 0.7168 - val_loss: 0.9228 - val_accuracy: 0.6820
# Epoch 33/200
#
# Epoch 00033: val_accuracy improved from 0.68910 to 0.69970, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.8124 - accuracy: 0.7219 - val_loss: 0.8707 - val_accuracy: 0.6997
# Epoch 34/200
#
# Epoch 00034: val_accuracy improved from 0.69970 to 0.70610, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.8047 - accuracy: 0.7245 - val_loss: 0.8599 - val_accuracy: 0.7061
# Epoch 35/200
#
# Epoch 00035: val_accuracy did not improve from 0.70610
# 500/500 - 8s - loss: 0.7912 - accuracy: 0.7295 - val_loss: 0.8838 - val_accuracy: 0.7043
# Epoch 36/200
#
# Epoch 00036: val_accuracy improved from 0.70610 to 0.71430, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.7794 - accuracy: 0.7329 - val_loss: 0.8378 - val_accuracy: 0.7143
# Epoch 37/200
#
# Epoch 00037: val_accuracy improved from 0.71430 to 0.71500, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.7698 - accuracy: 0.7358 - val_loss: 0.8346 - val_accuracy: 0.7150
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.71500
# 500/500 - 8s - loss: 0.7600 - accuracy: 0.7399 - val_loss: 0.8617 - val_accuracy: 0.7073
# Epoch 39/200
#
# Epoch 00039: val_accuracy did not improve from 0.71500
# 500/500 - 8s - loss: 0.7482 - accuracy: 0.7433 - val_loss: 0.8288 - val_accuracy: 0.7145
# Epoch 40/200
#
# Epoch 00040: val_accuracy improved from 0.71500 to 0.72070, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.7417 - accuracy: 0.7457 - val_loss: 0.8293 - val_accuracy: 0.7207
# Epoch 41/200
#
# Epoch 00041: val_accuracy improved from 0.72070 to 0.72110, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.7304 - accuracy: 0.7499 - val_loss: 0.8303 - val_accuracy: 0.7211
# Epoch 42/200
#
# Epoch 00042: val_accuracy improved from 0.72110 to 0.72830, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.7181 - accuracy: 0.7555 - val_loss: 0.8099 - val_accuracy: 0.7283
# Epoch 43/200
#
# Epoch 00043: val_accuracy did not improve from 0.72830
# 500/500 - 8s - loss: 0.7120 - accuracy: 0.7563 - val_loss: 0.8044 - val_accuracy: 0.7256
# Epoch 44/200
#
# Epoch 00044: val_accuracy did not improve from 0.72830
# 500/500 - 8s - loss: 0.7026 - accuracy: 0.7610 - val_loss: 0.8117 - val_accuracy: 0.7239
# Epoch 45/200
#
# Epoch 00045: val_accuracy improved from 0.72830 to 0.73530, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.6920 - accuracy: 0.7636 - val_loss: 0.7912 - val_accuracy: 0.7353
# Epoch 46/200
#
# Epoch 00046: val_accuracy did not improve from 0.73530
# 500/500 - 8s - loss: 0.6852 - accuracy: 0.7651 - val_loss: 0.8131 - val_accuracy: 0.7267
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.73530
# 500/500 - 8s - loss: 0.6752 - accuracy: 0.7686 - val_loss: 0.8113 - val_accuracy: 0.7214
# Epoch 48/200
#
# Epoch 00048: val_accuracy improved from 0.73530 to 0.73790, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.6677 - accuracy: 0.7712 - val_loss: 0.7733 - val_accuracy: 0.7379
# Epoch 49/200
#
# Epoch 00049: val_accuracy improved from 0.73790 to 0.74180, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.6610 - accuracy: 0.7737 - val_loss: 0.7744 - val_accuracy: 0.7418
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.74180
# 500/500 - 8s - loss: 0.6531 - accuracy: 0.7770 - val_loss: 0.7672 - val_accuracy: 0.7348
# Epoch 51/200
#
# Epoch 00051: val_accuracy did not improve from 0.74180
# 500/500 - 8s - loss: 0.6453 - accuracy: 0.7784 - val_loss: 0.7809 - val_accuracy: 0.7381
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.74180
# 500/500 - 8s - loss: 0.6349 - accuracy: 0.7830 - val_loss: 0.7544 - val_accuracy: 0.7417
# Epoch 53/200
#
# Epoch 00053: val_accuracy did not improve from 0.74180
# 500/500 - 8s - loss: 0.6275 - accuracy: 0.7865 - val_loss: 0.8021 - val_accuracy: 0.7315
# Epoch 54/200
#
# Epoch 00054: val_accuracy improved from 0.74180 to 0.74920, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.6219 - accuracy: 0.7867 - val_loss: 0.7561 - val_accuracy: 0.7492
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.74920
# 500/500 - 8s - loss: 0.6112 - accuracy: 0.7922 - val_loss: 0.7533 - val_accuracy: 0.7490
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.74920
# 500/500 - 8s - loss: 0.6091 - accuracy: 0.7927 - val_loss: 0.7429 - val_accuracy: 0.7486
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.74920
# 500/500 - 8s - loss: 0.5989 - accuracy: 0.7960 - val_loss: 0.7472 - val_accuracy: 0.7491
# Epoch 58/200
#
# Epoch 00058: val_accuracy improved from 0.74920 to 0.75020, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.5905 - accuracy: 0.7981 - val_loss: 0.7482 - val_accuracy: 0.7502
# Epoch 59/200
#
# Epoch 00059: val_accuracy improved from 0.75020 to 0.75300, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.5866 - accuracy: 0.8001 - val_loss: 0.7471 - val_accuracy: 0.7530
# Epoch 60/200
#
# Epoch 00060: val_accuracy improved from 0.75300 to 0.75780, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.5823 - accuracy: 0.8017 - val_loss: 0.7278 - val_accuracy: 0.7578
# Epoch 61/200
#
# Epoch 00061: val_accuracy did not improve from 0.75780
# 500/500 - 8s - loss: 0.5715 - accuracy: 0.8043 - val_loss: 0.7287 - val_accuracy: 0.7552
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.75780
# 500/500 - 8s - loss: 0.5637 - accuracy: 0.8069 - val_loss: 0.7561 - val_accuracy: 0.7487
# Epoch 63/200
#
# Epoch 00063: val_accuracy did not improve from 0.75780
# 500/500 - 8s - loss: 0.5537 - accuracy: 0.8118 - val_loss: 0.7689 - val_accuracy: 0.7367
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.75780
# 500/500 - 8s - loss: 0.5500 - accuracy: 0.8121 - val_loss: 0.7414 - val_accuracy: 0.7547
# Epoch 65/200
#
# Epoch 00065: val_accuracy did not improve from 0.75780
# 500/500 - 8s - loss: 0.5417 - accuracy: 0.8148 - val_loss: 0.7457 - val_accuracy: 0.7535
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.75780
# 500/500 - 8s - loss: 0.5377 - accuracy: 0.8175 - val_loss: 0.7351 - val_accuracy: 0.7569
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.75780
# 500/500 - 8s - loss: 0.5292 - accuracy: 0.8217 - val_loss: 0.7282 - val_accuracy: 0.7578
# Epoch 68/200
#
# Epoch 00068: val_accuracy improved from 0.75780 to 0.75820, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.5228 - accuracy: 0.8227 - val_loss: 0.7375 - val_accuracy: 0.7582
# Epoch 69/200
#
# Epoch 00069: val_accuracy improved from 0.75820 to 0.76750, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.5170 - accuracy: 0.8242 - val_loss: 0.7026 - val_accuracy: 0.7675
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.5110 - accuracy: 0.8277 - val_loss: 0.7091 - val_accuracy: 0.7633
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.5110 - accuracy: 0.8254 - val_loss: 0.7284 - val_accuracy: 0.7599
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.4937 - accuracy: 0.8338 - val_loss: 0.7389 - val_accuracy: 0.7583
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.4889 - accuracy: 0.8352 - val_loss: 0.7086 - val_accuracy: 0.7660
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.4835 - accuracy: 0.8352 - val_loss: 0.7228 - val_accuracy: 0.7633
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.4806 - accuracy: 0.8375 - val_loss: 0.7252 - val_accuracy: 0.7583
# Epoch 76/200
#
# Epoch 00076: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.4708 - accuracy: 0.8417 - val_loss: 0.7217 - val_accuracy: 0.7604
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.4686 - accuracy: 0.8422 - val_loss: 0.7035 - val_accuracy: 0.7644
# Epoch 78/200
#
# Epoch 00078: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.4611 - accuracy: 0.8449 - val_loss: 0.7552 - val_accuracy: 0.7531
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.76750
# 500/500 - 8s - loss: 0.4570 - accuracy: 0.8435 - val_loss: 0.7171 - val_accuracy: 0.7614
# Epoch 80/200
#
# Epoch 00080: val_accuracy improved from 0.76750 to 0.76930, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.4504 - accuracy: 0.8486 - val_loss: 0.6896 - val_accuracy: 0.7693
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.76930
# 500/500 - 8s - loss: 0.4464 - accuracy: 0.8498 - val_loss: 0.7431 - val_accuracy: 0.7628
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.76930
# 500/500 - 8s - loss: 0.4435 - accuracy: 0.8513 - val_loss: 0.7245 - val_accuracy: 0.7690
# Epoch 83/200
#
# Epoch 00083: val_accuracy improved from 0.76930 to 0.76940, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.4332 - accuracy: 0.8539 - val_loss: 0.7150 - val_accuracy: 0.7694
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.76940
# 500/500 - 8s - loss: 0.4269 - accuracy: 0.8574 - val_loss: 0.7265 - val_accuracy: 0.7658
# Epoch 85/200
#
# Epoch 00085: val_accuracy improved from 0.76940 to 0.77500, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.4233 - accuracy: 0.8586 - val_loss: 0.6966 - val_accuracy: 0.7750
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.77500
# 500/500 - 8s - loss: 0.4154 - accuracy: 0.8620 - val_loss: 0.7290 - val_accuracy: 0.7676
# Epoch 87/200
#
# Epoch 00087: val_accuracy improved from 0.77500 to 0.77620, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.4145 - accuracy: 0.8600 - val_loss: 0.7000 - val_accuracy: 0.7762
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.77620
# 500/500 - 8s - loss: 0.4077 - accuracy: 0.8638 - val_loss: 0.6947 - val_accuracy: 0.7745
# Epoch 89/200
#
# Epoch 00089: val_accuracy improved from 0.77620 to 0.77630, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.3957 - accuracy: 0.8682 - val_loss: 0.7049 - val_accuracy: 0.7763
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.77630
# 500/500 - 8s - loss: 0.3936 - accuracy: 0.8680 - val_loss: 0.7002 - val_accuracy: 0.7753
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.77630
# 500/500 - 8s - loss: 0.3903 - accuracy: 0.8690 - val_loss: 0.7300 - val_accuracy: 0.7698
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.77630
# 500/500 - 8s - loss: 0.3852 - accuracy: 0.8713 - val_loss: 0.7187 - val_accuracy: 0.7734
# Epoch 93/200
#
# Epoch 00093: val_accuracy did not improve from 0.77630
# 500/500 - 8s - loss: 0.3781 - accuracy: 0.8746 - val_loss: 0.7417 - val_accuracy: 0.7703
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.77630
# 500/500 - 8s - loss: 0.3697 - accuracy: 0.8777 - val_loss: 0.7198 - val_accuracy: 0.7747
# Epoch 95/200
#
# Epoch 00095: val_accuracy improved from 0.77630 to 0.77990, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.3651 - accuracy: 0.8787 - val_loss: 0.7104 - val_accuracy: 0.7799
# Epoch 96/200
#
# Epoch 00096: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3593 - accuracy: 0.8807 - val_loss: 0.7245 - val_accuracy: 0.7679
# Epoch 97/200
#
# Epoch 00097: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3572 - accuracy: 0.8825 - val_loss: 0.7025 - val_accuracy: 0.7773
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3583 - accuracy: 0.8793 - val_loss: 0.7110 - val_accuracy: 0.7765
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3479 - accuracy: 0.8833 - val_loss: 0.7357 - val_accuracy: 0.7699
# Epoch 100/200
#
# Epoch 00100: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3446 - accuracy: 0.8858 - val_loss: 0.7075 - val_accuracy: 0.7787
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3412 - accuracy: 0.8874 - val_loss: 0.7661 - val_accuracy: 0.7652
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3340 - accuracy: 0.8895 - val_loss: 0.7152 - val_accuracy: 0.7784
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3291 - accuracy: 0.8911 - val_loss: 0.7108 - val_accuracy: 0.7750
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3211 - accuracy: 0.8954 - val_loss: 0.7010 - val_accuracy: 0.7799
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3155 - accuracy: 0.8953 - val_loss: 0.7181 - val_accuracy: 0.7783
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.77990
# 500/500 - 8s - loss: 0.3164 - accuracy: 0.8960 - val_loss: 0.7296 - val_accuracy: 0.7764
# Epoch 107/200
#
# Epoch 00107: val_accuracy improved from 0.77990 to 0.78390, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.3068 - accuracy: 0.8993 - val_loss: 0.7047 - val_accuracy: 0.7839
# Epoch 108/200
#
# Epoch 00108: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.3012 - accuracy: 0.8999 - val_loss: 0.7915 - val_accuracy: 0.7658
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.3021 - accuracy: 0.9007 - val_loss: 0.7511 - val_accuracy: 0.7725
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2990 - accuracy: 0.9020 - val_loss: 0.7344 - val_accuracy: 0.7738
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2882 - accuracy: 0.9071 - val_loss: 0.7299 - val_accuracy: 0.7798
# Epoch 112/200
#
# Epoch 00112: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2845 - accuracy: 0.9076 - val_loss: 0.7790 - val_accuracy: 0.7637
# Epoch 113/200
#
# Epoch 00113: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2766 - accuracy: 0.9096 - val_loss: 0.7618 - val_accuracy: 0.7766
# Epoch 114/200
#
# Epoch 00114: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2801 - accuracy: 0.9084 - val_loss: 0.7404 - val_accuracy: 0.7801
# Epoch 115/200
#
# Epoch 00115: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2701 - accuracy: 0.9117 - val_loss: 0.7369 - val_accuracy: 0.7795
# Epoch 116/200
#
# Epoch 00116: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2669 - accuracy: 0.9139 - val_loss: 0.7454 - val_accuracy: 0.7787
# Epoch 117/200
#
# Epoch 00117: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2638 - accuracy: 0.9141 - val_loss: 0.7467 - val_accuracy: 0.7805
# Epoch 118/200
#
# Epoch 00118: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2602 - accuracy: 0.9154 - val_loss: 0.7341 - val_accuracy: 0.7829
# Epoch 119/200
#
# Epoch 00119: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2504 - accuracy: 0.9195 - val_loss: 0.7356 - val_accuracy: 0.7834
# Epoch 120/200
#
# Epoch 00120: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2560 - accuracy: 0.9164 - val_loss: 0.7743 - val_accuracy: 0.7778
# Epoch 121/200
#
# Epoch 00121: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2426 - accuracy: 0.9216 - val_loss: 0.7542 - val_accuracy: 0.7828
# Epoch 122/200
#
# Epoch 00122: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2371 - accuracy: 0.9250 - val_loss: 0.7659 - val_accuracy: 0.7814
# Epoch 123/200
#
# Epoch 00123: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2358 - accuracy: 0.9241 - val_loss: 0.7996 - val_accuracy: 0.7758
# Epoch 124/200
#
# Epoch 00124: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2304 - accuracy: 0.9261 - val_loss: 0.8227 - val_accuracy: 0.7700
# Epoch 125/200
#
# Epoch 00125: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2314 - accuracy: 0.9248 - val_loss: 0.7679 - val_accuracy: 0.7794
# Epoch 126/200
#
# Epoch 00126: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2235 - accuracy: 0.9276 - val_loss: 0.8104 - val_accuracy: 0.7769
# Epoch 127/200
#
# Epoch 00127: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2249 - accuracy: 0.9269 - val_loss: 0.7962 - val_accuracy: 0.7810
# Epoch 128/200
#
# Epoch 00128: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2126 - accuracy: 0.9332 - val_loss: 0.8113 - val_accuracy: 0.7768
# Epoch 129/200
#
# Epoch 00129: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2107 - accuracy: 0.9333 - val_loss: 0.7944 - val_accuracy: 0.7801
# Epoch 130/200
#
# Epoch 00130: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2042 - accuracy: 0.9363 - val_loss: 0.7972 - val_accuracy: 0.7758
# Epoch 131/200
#
# Epoch 00131: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.2047 - accuracy: 0.9370 - val_loss: 0.8018 - val_accuracy: 0.7825
# Epoch 132/200
#
# Epoch 00132: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1955 - accuracy: 0.9389 - val_loss: 0.8099 - val_accuracy: 0.7793
# Epoch 133/200
#
# Epoch 00133: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1936 - accuracy: 0.9404 - val_loss: 0.8277 - val_accuracy: 0.7772
# Epoch 134/200
#
# Epoch 00134: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1902 - accuracy: 0.9412 - val_loss: 0.8622 - val_accuracy: 0.7667
# Epoch 135/200
#
# Epoch 00135: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1864 - accuracy: 0.9423 - val_loss: 0.8694 - val_accuracy: 0.7690
# Epoch 136/200
#
# Epoch 00136: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1828 - accuracy: 0.9440 - val_loss: 0.8188 - val_accuracy: 0.7794
# Epoch 137/200
#
# Epoch 00137: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1775 - accuracy: 0.9448 - val_loss: 0.8467 - val_accuracy: 0.7766
# Epoch 138/200
#
# Epoch 00138: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1765 - accuracy: 0.9453 - val_loss: 0.8347 - val_accuracy: 0.7783
# Epoch 139/200
#
# Epoch 00139: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1700 - accuracy: 0.9479 - val_loss: 0.8363 - val_accuracy: 0.7786
# Epoch 140/200
#
# Epoch 00140: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1692 - accuracy: 0.9489 - val_loss: 0.8482 - val_accuracy: 0.7735
# Epoch 141/200
#
# Epoch 00141: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1633 - accuracy: 0.9506 - val_loss: 0.8313 - val_accuracy: 0.7823
# Epoch 142/200
#
# Epoch 00142: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1574 - accuracy: 0.9544 - val_loss: 0.8884 - val_accuracy: 0.7752
# Epoch 143/200
#
# Epoch 00143: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1528 - accuracy: 0.9549 - val_loss: 0.8622 - val_accuracy: 0.7786
# Epoch 144/200
#
# Epoch 00144: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1478 - accuracy: 0.9571 - val_loss: 0.8589 - val_accuracy: 0.7832
# Epoch 145/200
#
# Epoch 00145: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1458 - accuracy: 0.9576 - val_loss: 0.8444 - val_accuracy: 0.7833
# Epoch 146/200
#
# Epoch 00146: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1485 - accuracy: 0.9561 - val_loss: 0.8735 - val_accuracy: 0.7824
# Epoch 147/200
#
# Epoch 00147: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1447 - accuracy: 0.9576 - val_loss: 0.8934 - val_accuracy: 0.7796
# Epoch 148/200
#
# Epoch 00148: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1384 - accuracy: 0.9596 - val_loss: 0.9262 - val_accuracy: 0.7768
# Epoch 149/200
#
# Epoch 00149: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1330 - accuracy: 0.9618 - val_loss: 0.9247 - val_accuracy: 0.7741
# Epoch 150/200
#
# Epoch 00150: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1288 - accuracy: 0.9644 - val_loss: 0.8985 - val_accuracy: 0.7771
# Epoch 151/200
#
# Epoch 00151: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1257 - accuracy: 0.9653 - val_loss: 0.9095 - val_accuracy: 0.7793
# Epoch 152/200
#
# Epoch 00152: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1251 - accuracy: 0.9645 - val_loss: 0.9616 - val_accuracy: 0.7714
# Epoch 153/200
#
# Epoch 00153: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1173 - accuracy: 0.9682 - val_loss: 0.9006 - val_accuracy: 0.7827
# Epoch 154/200
#
# Epoch 00154: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1209 - accuracy: 0.9656 - val_loss: 0.9724 - val_accuracy: 0.7759
# Epoch 155/200
#
# Epoch 00155: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1135 - accuracy: 0.9692 - val_loss: 0.9179 - val_accuracy: 0.7821
# Epoch 156/200
#
# Epoch 00156: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1123 - accuracy: 0.9698 - val_loss: 0.9824 - val_accuracy: 0.7731
# Epoch 157/200
#
# Epoch 00157: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1101 - accuracy: 0.9707 - val_loss: 0.9597 - val_accuracy: 0.7780
# Epoch 158/200
#
# Epoch 00158: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1058 - accuracy: 0.9718 - val_loss: 0.9630 - val_accuracy: 0.7829
# Epoch 159/200
#
# Epoch 00159: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.1019 - accuracy: 0.9739 - val_loss: 0.9868 - val_accuracy: 0.7777
# Epoch 160/200
#
# Epoch 00160: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.0999 - accuracy: 0.9743 - val_loss: 0.9665 - val_accuracy: 0.7812
# Epoch 161/200
#
# Epoch 00161: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.0991 - accuracy: 0.9750 - val_loss: 0.9771 - val_accuracy: 0.7822
# Epoch 162/200
#
# Epoch 00162: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.0956 - accuracy: 0.9755 - val_loss: 0.9997 - val_accuracy: 0.7801
# Epoch 163/200
#
# Epoch 00163: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.0968 - accuracy: 0.9752 - val_loss: 0.9911 - val_accuracy: 0.7793
# Epoch 164/200
#
# Epoch 00164: val_accuracy did not improve from 0.78390
# 500/500 - 8s - loss: 0.0913 - accuracy: 0.9777 - val_loss: 0.9972 - val_accuracy: 0.7809
# Epoch 165/200
#
# Epoch 00165: val_accuracy improved from 0.78390 to 0.78410, saving model to gdrive/My Drive/Colab Notebooks/L1_3.h5
# 500/500 - 9s - loss: 0.0900 - accuracy: 0.9780 - val_loss: 0.9821 - val_accuracy: 0.7841
# Epoch 166/200
#
# Epoch 00166: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0856 - accuracy: 0.9792 - val_loss: 1.0168 - val_accuracy: 0.7813
# Epoch 167/200
#
# Epoch 00167: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0834 - accuracy: 0.9797 - val_loss: 1.0289 - val_accuracy: 0.7796
# Epoch 168/200
#
# Epoch 00168: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0799 - accuracy: 0.9809 - val_loss: 1.0576 - val_accuracy: 0.7762
# Epoch 169/200
#
# Epoch 00169: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0790 - accuracy: 0.9811 - val_loss: 1.0343 - val_accuracy: 0.7806
# Epoch 170/200
#
# Epoch 00170: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0771 - accuracy: 0.9822 - val_loss: 1.0649 - val_accuracy: 0.7788
# Epoch 171/200
#
# Epoch 00171: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0712 - accuracy: 0.9848 - val_loss: 1.0650 - val_accuracy: 0.7775
# Epoch 172/200
#
# Epoch 00172: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0726 - accuracy: 0.9842 - val_loss: 1.0610 - val_accuracy: 0.7776
# Epoch 173/200
#
# Epoch 00173: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0680 - accuracy: 0.9857 - val_loss: 1.1219 - val_accuracy: 0.7747
# Epoch 174/200
#
# Epoch 00174: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0684 - accuracy: 0.9848 - val_loss: 1.0841 - val_accuracy: 0.7823
# Epoch 175/200
#
# Epoch 00175: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0655 - accuracy: 0.9869 - val_loss: 1.1109 - val_accuracy: 0.7800
# Epoch 176/200
#
# Epoch 00176: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0574 - accuracy: 0.9895 - val_loss: 1.0905 - val_accuracy: 0.7826
# Epoch 177/200
#
# Epoch 00177: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0614 - accuracy: 0.9876 - val_loss: 1.1161 - val_accuracy: 0.7770
# Epoch 178/200
#
# Epoch 00178: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0593 - accuracy: 0.9886 - val_loss: 1.1364 - val_accuracy: 0.7749
# Epoch 179/200
#
# Epoch 00179: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0605 - accuracy: 0.9869 - val_loss: 1.1136 - val_accuracy: 0.7811
# Epoch 180/200
#
# Epoch 00180: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0543 - accuracy: 0.9897 - val_loss: 1.0993 - val_accuracy: 0.7835
# Epoch 181/200
#
# Epoch 00181: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0546 - accuracy: 0.9901 - val_loss: 1.1603 - val_accuracy: 0.7740
# Epoch 182/200
#
# Epoch 00182: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0561 - accuracy: 0.9888 - val_loss: 1.1115 - val_accuracy: 0.7825
# Epoch 183/200
#
# Epoch 00183: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0427 - accuracy: 0.9945 - val_loss: 1.1524 - val_accuracy: 0.7814
# Epoch 184/200
#
# Epoch 00184: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0489 - accuracy: 0.9912 - val_loss: 1.1803 - val_accuracy: 0.7721
# Epoch 185/200
#
# Epoch 00185: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0488 - accuracy: 0.9916 - val_loss: 1.1614 - val_accuracy: 0.7807
# Epoch 186/200
#
# Epoch 00186: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0484 - accuracy: 0.9915 - val_loss: 1.1796 - val_accuracy: 0.7796
# Epoch 187/200
#
# Epoch 00187: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0407 - accuracy: 0.9944 - val_loss: 1.1883 - val_accuracy: 0.7785
# Epoch 188/200
#
# Epoch 00188: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0440 - accuracy: 0.9931 - val_loss: 1.3086 - val_accuracy: 0.7651
# Epoch 189/200
#
# Epoch 00189: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0403 - accuracy: 0.9940 - val_loss: 1.2092 - val_accuracy: 0.7797
# Epoch 190/200
#
# Epoch 00190: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0387 - accuracy: 0.9951 - val_loss: 1.2258 - val_accuracy: 0.7789
# Epoch 191/200
#
# Epoch 00191: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0417 - accuracy: 0.9930 - val_loss: 1.2236 - val_accuracy: 0.7798
# Epoch 192/200
#
# Epoch 00192: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0343 - accuracy: 0.9965 - val_loss: 1.2382 - val_accuracy: 0.7799
# Epoch 193/200
#
# Epoch 00193: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0390 - accuracy: 0.9942 - val_loss: 1.2356 - val_accuracy: 0.7810
# Epoch 194/200
#
# Epoch 00194: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0320 - accuracy: 0.9965 - val_loss: 1.2411 - val_accuracy: 0.7795
# Epoch 195/200
#
# Epoch 00195: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0347 - accuracy: 0.9958 - val_loss: 1.2527 - val_accuracy: 0.7814
# Epoch 196/200
#
# Epoch 00196: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0317 - accuracy: 0.9969 - val_loss: 1.2862 - val_accuracy: 0.7780
# Epoch 197/200
#
# Epoch 00197: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0288 - accuracy: 0.9974 - val_loss: 1.2704 - val_accuracy: 0.7764
# Epoch 198/200
#
# Epoch 00198: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0353 - accuracy: 0.9950 - val_loss: 1.2593 - val_accuracy: 0.7815
# Epoch 199/200
#
# Epoch 00199: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0233 - accuracy: 0.9988 - val_loss: 1.2984 - val_accuracy: 0.7816
# Epoch 200/200
#
# Epoch 00200: val_accuracy did not improve from 0.78410
# 500/500 - 8s - loss: 0.0350 - accuracy: 0.9947 - val_loss: 1.2753 - val_accuracy: 0.7836

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.7839905704731115
# Recall:  0.7841
# Accuracy:  0.7841
