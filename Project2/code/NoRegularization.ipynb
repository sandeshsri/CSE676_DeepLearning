# %%
import numpy as np
from keras.models import Sequential
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Input, concatenate, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adamax
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
NUMBER_OF_CLASSES = 10
epochs = 200
batch_size = 100
path_best = "gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5"
path_train = "gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5"

# %%
(x_train,y_train), (x_test, y_test) = cifar10.load_data()

y_train_norm = to_categorical(y_train, NUMBER_OF_CLASSES)
y_test_norm = to_categorical(y_test, NUMBER_OF_CLASSES)

y_test = y_test.flatten()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))

x_train_norm = (x_train-mean)/(std+1e-7)
x_test_norm = (x_test-mean)/(std+1e-7)

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     zca_epsilon=1e-06,
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     vertical_flip=False)

# datagen.fit(x_train_norm)

# %%
def inceptionBuilder(l, f_1x1, f_3x3_r, f_3x3, f_5x5_r, f_5x5, f_p):
    l_1 = Conv2D(filters=f_1x1, kernel_size=(1,1), padding='same', activation='relu')(l)

    l_3 = Conv2D(filters=f_3x3_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_3 = Conv2D(filters=f_3x3, kernel_size=(3,3), padding='same', activation='relu')(l_3)
    # l_3 = BatchNormalization()(l_3)

    l_5 = Conv2D(filters=f_5x5_r, kernel_size=(1,1), padding='same', activation='relu')(l)
    l_5 = Conv2D(filters=f_5x5, kernel_size=(5,5), padding='same', activation='relu')(l_5)
    # l_5 = BatchNormalization()(l_5)

    l_p = MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(l)
    l_p = Conv2D(filters=f_p, kernel_size=(1,1), padding='same', activation='relu')(l_p)
    # l_p = BatchNormalization()(l_p)

    ret = concatenate([l_1, l_3, l_5, l_p], axis=3)

    return ret

# %%
def create_InceptionV2Model():
    input = Input(shape=(32,32,3))
    l = Conv2D(filters=64, kernel_size=(7,7), padding="same")(input)
    l = Activation('relu')(l)
    
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Conv2D(filters=192, kernel_size=(3,3), activation='relu')(l)
    l = MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(l)
    # l = BatchNormalization()(l)

    l = inceptionBuilder(l, 64, 96, 128, 16, 32, 32)
    l = inceptionBuilder(l, 128, 128, 192, 32, 96, 64)

    l = MaxPool2D(pool_size=(3,3,), strides=(2,2), padding='same')(l)

    l = inceptionBuilder(l, 192, 96, 208, 16, 48, 64)
    # l = BatchNormalization()(l)

    l = GlobalAveragePooling2D()(l)
    l = Dense(NUMBER_OF_CLASSES, activation='softmax')(l)

    model = Model(inputs = input, outputs = l)
    return model

# %%
model = create_InceptionV2Model()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 192)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 96)     18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 16)     3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 192)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 64)     12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 128)    110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 32)     12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 256)    0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 192)    221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 96)     76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 480)    0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4, 4, 512)    0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,058,154
# Trainable params: 1,058,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Code to visualize model
#
# from keras.utils.vis_utils import plot_model
# plot_model(model, to_file="gdrive/My Drive/Colab Notebooks/model.png", show_shapes=True)

# %%
model.compile(optimizer=Adamax(learning_rate=0.0001, decay=1e-06), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %% [markdown]
# **Training**

# %%
checkpoint = ModelCheckpoint(path_train, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=100, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# model.load_weights(path_best)
history = model.fit(x_train_norm, y_train_norm,
                        batch_size=batch_size,
                        steps_per_epoch=x_train_norm.shape[0]// batch_size,
                        epochs=epochs,
                        validation_data=(x_test_norm,y_test_norm),
                        callbacks=[checkpoint],verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 00001: val_accuracy improved from -inf to 0.38270, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 12s - loss: 1.9049 - accuracy: 0.3076 - val_loss: 1.6841 - val_accuracy: 0.3827
# Epoch 2/200
#
# Epoch 00002: val_accuracy improved from 0.38270 to 0.43420, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 10s - loss: 1.5957 - accuracy: 0.4189 - val_loss: 1.5274 - val_accuracy: 0.4342
# Epoch 3/200
#
# Epoch 00003: val_accuracy improved from 0.43420 to 0.46990, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.4823 - accuracy: 0.4591 - val_loss: 1.4355 - val_accuracy: 0.4699
# Epoch 4/200
#
# Epoch 00004: val_accuracy improved from 0.46990 to 0.49740, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.4064 - accuracy: 0.4901 - val_loss: 1.3920 - val_accuracy: 0.4974
# Epoch 5/200
#
# Epoch 00005: val_accuracy improved from 0.49740 to 0.50850, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.3456 - accuracy: 0.5169 - val_loss: 1.3341 - val_accuracy: 0.5085
# Epoch 6/200
#
# Epoch 00006: val_accuracy improved from 0.50850 to 0.53420, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.3011 - accuracy: 0.5348 - val_loss: 1.2814 - val_accuracy: 0.5342
# Epoch 7/200
#
# Epoch 00007: val_accuracy improved from 0.53420 to 0.54310, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.2595 - accuracy: 0.5510 - val_loss: 1.2540 - val_accuracy: 0.5431
# Epoch 8/200
#
# Epoch 00008: val_accuracy improved from 0.54310 to 0.56020, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.2264 - accuracy: 0.5650 - val_loss: 1.2113 - val_accuracy: 0.5602
# Epoch 9/200
#
# Epoch 00009: val_accuracy improved from 0.56020 to 0.57880, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.1940 - accuracy: 0.5746 - val_loss: 1.1744 - val_accuracy: 0.5788
# Epoch 10/200
#
# Epoch 00010: val_accuracy improved from 0.57880 to 0.58080, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.1669 - accuracy: 0.5843 - val_loss: 1.1788 - val_accuracy: 0.5808
# Epoch 11/200
#
# Epoch 00011: val_accuracy improved from 0.58080 to 0.59120, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.1330 - accuracy: 0.5978 - val_loss: 1.1427 - val_accuracy: 0.5912
# Epoch 12/200
#
# Epoch 00012: val_accuracy improved from 0.59120 to 0.59730, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.1106 - accuracy: 0.6071 - val_loss: 1.1233 - val_accuracy: 0.5973
# Epoch 13/200
#
# Epoch 00013: val_accuracy improved from 0.59730 to 0.60430, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.0893 - accuracy: 0.6145 - val_loss: 1.1199 - val_accuracy: 0.6043
# Epoch 14/200
#
# Epoch 00014: val_accuracy improved from 0.60430 to 0.62010, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 12s - loss: 1.0636 - accuracy: 0.6241 - val_loss: 1.0826 - val_accuracy: 0.6201
# Epoch 15/200
#
# Epoch 00015: val_accuracy improved from 0.62010 to 0.62550, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.0424 - accuracy: 0.6335 - val_loss: 1.0579 - val_accuracy: 0.6255
# Epoch 16/200
#
# Epoch 00016: val_accuracy did not improve from 0.62550
# 500/500 - 11s - loss: 1.0180 - accuracy: 0.6420 - val_loss: 1.1059 - val_accuracy: 0.6101
# Epoch 17/200
#
# Epoch 00017: val_accuracy improved from 0.62550 to 0.62750, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 1.0000 - accuracy: 0.6490 - val_loss: 1.0570 - val_accuracy: 0.6275
# Epoch 18/200
#
# Epoch 00018: val_accuracy improved from 0.62750 to 0.64840, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.9786 - accuracy: 0.6568 - val_loss: 1.0093 - val_accuracy: 0.6484
# Epoch 19/200
#
# Epoch 00019: val_accuracy did not improve from 0.64840
# 500/500 - 11s - loss: 0.9591 - accuracy: 0.6630 - val_loss: 1.0247 - val_accuracy: 0.6404
# Epoch 20/200
#
# Epoch 00020: val_accuracy improved from 0.64840 to 0.65150, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.9443 - accuracy: 0.6674 - val_loss: 0.9925 - val_accuracy: 0.6515
# Epoch 21/200
#
# Epoch 00021: val_accuracy did not improve from 0.65150
# 500/500 - 11s - loss: 0.9236 - accuracy: 0.6764 - val_loss: 1.0008 - val_accuracy: 0.6449
# Epoch 22/200
#
# Epoch 00022: val_accuracy did not improve from 0.65150
# 500/500 - 11s - loss: 0.9107 - accuracy: 0.6820 - val_loss: 1.0170 - val_accuracy: 0.6415
# Epoch 23/200
#
# Epoch 00023: val_accuracy improved from 0.65150 to 0.65700, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.8939 - accuracy: 0.6861 - val_loss: 0.9678 - val_accuracy: 0.6570
# Epoch 24/200
#
# Epoch 00024: val_accuracy improved from 0.65700 to 0.67710, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.8791 - accuracy: 0.6924 - val_loss: 0.9276 - val_accuracy: 0.6771
# Epoch 25/200
#
# Epoch 00025: val_accuracy improved from 0.67710 to 0.67750, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.8625 - accuracy: 0.6966 - val_loss: 0.9207 - val_accuracy: 0.6775
# Epoch 26/200
#
# Epoch 00026: val_accuracy improved from 0.67750 to 0.68390, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.8471 - accuracy: 0.7048 - val_loss: 0.9097 - val_accuracy: 0.6839
# Epoch 27/200
#
# Epoch 00027: val_accuracy improved from 0.68390 to 0.68920, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.8343 - accuracy: 0.7078 - val_loss: 0.8932 - val_accuracy: 0.6892
# Epoch 28/200
#
# Epoch 00028: val_accuracy did not improve from 0.68920
# 500/500 - 11s - loss: 0.8218 - accuracy: 0.7122 - val_loss: 0.9068 - val_accuracy: 0.6826
# Epoch 29/200
#
# Epoch 00029: val_accuracy improved from 0.68920 to 0.69230, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.8064 - accuracy: 0.7180 - val_loss: 0.8870 - val_accuracy: 0.6923
# Epoch 30/200
#
# Epoch 00030: val_accuracy did not improve from 0.69230
# 500/500 - 11s - loss: 0.7947 - accuracy: 0.7223 - val_loss: 0.8847 - val_accuracy: 0.6896
# Epoch 31/200
#
# Epoch 00031: val_accuracy did not improve from 0.69230
# 500/500 - 11s - loss: 0.7851 - accuracy: 0.7264 - val_loss: 0.9130 - val_accuracy: 0.6828
# Epoch 32/200
#
# Epoch 00032: val_accuracy improved from 0.69230 to 0.70180, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.7714 - accuracy: 0.7315 - val_loss: 0.8651 - val_accuracy: 0.7018
# Epoch 33/200
#
# Epoch 00033: val_accuracy improved from 0.70180 to 0.70400, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.7611 - accuracy: 0.7365 - val_loss: 0.8483 - val_accuracy: 0.7040
# Epoch 34/200
#
# Epoch 00034: val_accuracy did not improve from 0.70400
# 500/500 - 11s - loss: 0.7483 - accuracy: 0.7398 - val_loss: 0.8859 - val_accuracy: 0.6949
# Epoch 35/200
#
# Epoch 00035: val_accuracy improved from 0.70400 to 0.71910, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.7357 - accuracy: 0.7438 - val_loss: 0.8100 - val_accuracy: 0.7191
# Epoch 36/200
#
# Epoch 00036: val_accuracy did not improve from 0.71910
# 500/500 - 11s - loss: 0.7253 - accuracy: 0.7473 - val_loss: 0.8430 - val_accuracy: 0.7045
# Epoch 37/200
#
# Epoch 00037: val_accuracy did not improve from 0.71910
# 500/500 - 11s - loss: 0.7167 - accuracy: 0.7503 - val_loss: 0.8469 - val_accuracy: 0.7045
# Epoch 38/200
#
# Epoch 00038: val_accuracy did not improve from 0.71910
# 500/500 - 11s - loss: 0.7033 - accuracy: 0.7552 - val_loss: 0.8197 - val_accuracy: 0.7146
# Epoch 39/200
#
# Epoch 00039: val_accuracy improved from 0.71910 to 0.71920, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.6936 - accuracy: 0.7587 - val_loss: 0.8129 - val_accuracy: 0.7192
# Epoch 40/200
#
# Epoch 00040: val_accuracy improved from 0.71920 to 0.72560, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.6856 - accuracy: 0.7614 - val_loss: 0.8028 - val_accuracy: 0.7256
# Epoch 41/200
#
# Epoch 00041: val_accuracy did not improve from 0.72560
# 500/500 - 11s - loss: 0.6765 - accuracy: 0.7662 - val_loss: 0.8118 - val_accuracy: 0.7188
# Epoch 42/200
#
# Epoch 00042: val_accuracy did not improve from 0.72560
# 500/500 - 11s - loss: 0.6625 - accuracy: 0.7697 - val_loss: 0.8277 - val_accuracy: 0.7203
# Epoch 43/200
#
# Epoch 00043: val_accuracy improved from 0.72560 to 0.72780, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.6518 - accuracy: 0.7733 - val_loss: 0.7896 - val_accuracy: 0.7278
# Epoch 44/200
#
# Epoch 00044: val_accuracy improved from 0.72780 to 0.73180, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.6454 - accuracy: 0.7760 - val_loss: 0.7784 - val_accuracy: 0.7318
# Epoch 45/200
#
# Epoch 00045: val_accuracy improved from 0.73180 to 0.73570, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.6356 - accuracy: 0.7770 - val_loss: 0.7696 - val_accuracy: 0.7357
# Epoch 46/200
#
# Epoch 00046: val_accuracy improved from 0.73570 to 0.73970, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.6270 - accuracy: 0.7823 - val_loss: 0.7630 - val_accuracy: 0.7397
# Epoch 47/200
#
# Epoch 00047: val_accuracy did not improve from 0.73970
# 500/500 - 11s - loss: 0.6170 - accuracy: 0.7854 - val_loss: 0.7873 - val_accuracy: 0.7315
# Epoch 48/200
#
# Epoch 00048: val_accuracy did not improve from 0.73970
# 500/500 - 11s - loss: 0.6078 - accuracy: 0.7904 - val_loss: 0.7792 - val_accuracy: 0.7331
# Epoch 49/200
#
# Epoch 00049: val_accuracy did not improve from 0.73970
# 500/500 - 11s - loss: 0.6036 - accuracy: 0.7899 - val_loss: 0.7806 - val_accuracy: 0.7328
# Epoch 50/200
#
# Epoch 00050: val_accuracy did not improve from 0.73970
# 500/500 - 11s - loss: 0.5925 - accuracy: 0.7926 - val_loss: 0.7683 - val_accuracy: 0.7325
# Epoch 51/200
#
# Epoch 00051: val_accuracy improved from 0.73970 to 0.74330, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.5798 - accuracy: 0.7990 - val_loss: 0.7499 - val_accuracy: 0.7433
# Epoch 52/200
#
# Epoch 00052: val_accuracy did not improve from 0.74330
# 500/500 - 11s - loss: 0.5752 - accuracy: 0.8001 - val_loss: 0.7741 - val_accuracy: 0.7363
# Epoch 53/200
#
# Epoch 00053: val_accuracy improved from 0.74330 to 0.74940, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.5664 - accuracy: 0.8033 - val_loss: 0.7342 - val_accuracy: 0.7494
# Epoch 54/200
#
# Epoch 00054: val_accuracy did not improve from 0.74940
# 500/500 - 11s - loss: 0.5528 - accuracy: 0.8097 - val_loss: 0.7285 - val_accuracy: 0.7480
# Epoch 55/200
#
# Epoch 00055: val_accuracy did not improve from 0.74940
# 500/500 - 11s - loss: 0.5468 - accuracy: 0.8086 - val_loss: 0.7574 - val_accuracy: 0.7405
# Epoch 56/200
#
# Epoch 00056: val_accuracy did not improve from 0.74940
# 500/500 - 11s - loss: 0.5379 - accuracy: 0.8147 - val_loss: 0.7621 - val_accuracy: 0.7397
# Epoch 57/200
#
# Epoch 00057: val_accuracy did not improve from 0.74940
# 500/500 - 11s - loss: 0.5278 - accuracy: 0.8175 - val_loss: 0.7586 - val_accuracy: 0.7402
# Epoch 58/200
#
# Epoch 00058: val_accuracy did not improve from 0.74940
# 500/500 - 11s - loss: 0.5246 - accuracy: 0.8191 - val_loss: 0.7418 - val_accuracy: 0.7459
# Epoch 59/200
#
# Epoch 00059: val_accuracy improved from 0.74940 to 0.75190, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.5148 - accuracy: 0.8222 - val_loss: 0.7293 - val_accuracy: 0.7519
# Epoch 60/200
#
# Epoch 00060: val_accuracy did not improve from 0.75190
# 500/500 - 11s - loss: 0.5091 - accuracy: 0.8234 - val_loss: 0.7678 - val_accuracy: 0.7424
# Epoch 61/200
#
# Epoch 00061: val_accuracy improved from 0.75190 to 0.75470, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.4984 - accuracy: 0.8287 - val_loss: 0.7304 - val_accuracy: 0.7547
# Epoch 62/200
#
# Epoch 00062: val_accuracy did not improve from 0.75470
# 500/500 - 11s - loss: 0.4878 - accuracy: 0.8319 - val_loss: 0.7445 - val_accuracy: 0.7521
# Epoch 63/200
#
# Epoch 00063: val_accuracy improved from 0.75470 to 0.75520, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.4852 - accuracy: 0.8329 - val_loss: 0.7334 - val_accuracy: 0.7552
# Epoch 64/200
#
# Epoch 00064: val_accuracy did not improve from 0.75520
# 500/500 - 11s - loss: 0.4767 - accuracy: 0.8349 - val_loss: 0.7549 - val_accuracy: 0.7497
# Epoch 65/200
#
# Epoch 00065: val_accuracy improved from 0.75520 to 0.75770, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.4674 - accuracy: 0.8382 - val_loss: 0.7212 - val_accuracy: 0.7577
# Epoch 66/200
#
# Epoch 00066: val_accuracy did not improve from 0.75770
# 500/500 - 11s - loss: 0.4617 - accuracy: 0.8413 - val_loss: 0.7225 - val_accuracy: 0.7569
# Epoch 67/200
#
# Epoch 00067: val_accuracy did not improve from 0.75770
# 500/500 - 11s - loss: 0.4512 - accuracy: 0.8439 - val_loss: 0.7394 - val_accuracy: 0.7525
# Epoch 68/200
#
# Epoch 00068: val_accuracy improved from 0.75770 to 0.75850, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.4465 - accuracy: 0.8463 - val_loss: 0.7286 - val_accuracy: 0.7585
# Epoch 69/200
#
# Epoch 00069: val_accuracy improved from 0.75850 to 0.76060, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.4403 - accuracy: 0.8480 - val_loss: 0.7321 - val_accuracy: 0.7606
# Epoch 70/200
#
# Epoch 00070: val_accuracy did not improve from 0.76060
# 500/500 - 11s - loss: 0.4300 - accuracy: 0.8524 - val_loss: 0.7375 - val_accuracy: 0.7558
# Epoch 71/200
#
# Epoch 00071: val_accuracy did not improve from 0.76060
# 500/500 - 11s - loss: 0.4215 - accuracy: 0.8557 - val_loss: 0.7250 - val_accuracy: 0.7599
# Epoch 72/200
#
# Epoch 00072: val_accuracy did not improve from 0.76060
# 500/500 - 11s - loss: 0.4173 - accuracy: 0.8566 - val_loss: 0.7190 - val_accuracy: 0.7573
# Epoch 73/200
#
# Epoch 00073: val_accuracy did not improve from 0.76060
# 500/500 - 11s - loss: 0.4072 - accuracy: 0.8610 - val_loss: 0.7269 - val_accuracy: 0.7579
# Epoch 74/200
#
# Epoch 00074: val_accuracy did not improve from 0.76060
# 500/500 - 11s - loss: 0.3999 - accuracy: 0.8628 - val_loss: 0.7462 - val_accuracy: 0.7551
# Epoch 75/200
#
# Epoch 00075: val_accuracy did not improve from 0.76060
# 500/500 - 11s - loss: 0.3934 - accuracy: 0.8650 - val_loss: 0.7567 - val_accuracy: 0.7554
# Epoch 76/200
#
# Epoch 00076: val_accuracy improved from 0.76060 to 0.76520, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.3834 - accuracy: 0.8681 - val_loss: 0.7157 - val_accuracy: 0.7652
# Epoch 77/200
#
# Epoch 00077: val_accuracy did not improve from 0.76520
# 500/500 - 11s - loss: 0.3799 - accuracy: 0.8710 - val_loss: 0.7841 - val_accuracy: 0.7458
# Epoch 78/200
#
# Epoch 00078: val_accuracy improved from 0.76520 to 0.76970, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.3784 - accuracy: 0.8709 - val_loss: 0.7094 - val_accuracy: 0.7697
# Epoch 79/200
#
# Epoch 00079: val_accuracy did not improve from 0.76970
# 500/500 - 11s - loss: 0.3713 - accuracy: 0.8742 - val_loss: 0.7527 - val_accuracy: 0.7602
# Epoch 80/200
#
# Epoch 00080: val_accuracy did not improve from 0.76970
# 500/500 - 11s - loss: 0.3623 - accuracy: 0.8775 - val_loss: 0.7172 - val_accuracy: 0.7683
# Epoch 81/200
#
# Epoch 00081: val_accuracy did not improve from 0.76970
# 500/500 - 11s - loss: 0.3580 - accuracy: 0.8780 - val_loss: 0.7492 - val_accuracy: 0.7612
# Epoch 82/200
#
# Epoch 00082: val_accuracy did not improve from 0.76970
# 500/500 - 11s - loss: 0.3465 - accuracy: 0.8829 - val_loss: 0.7640 - val_accuracy: 0.7584
# Epoch 83/200
#
# Epoch 00083: val_accuracy did not improve from 0.76970
# 500/500 - 11s - loss: 0.3398 - accuracy: 0.8851 - val_loss: 0.7360 - val_accuracy: 0.7678
# Epoch 84/200
#
# Epoch 00084: val_accuracy did not improve from 0.76970
# 500/500 - 11s - loss: 0.3353 - accuracy: 0.8869 - val_loss: 0.7621 - val_accuracy: 0.7617
# Epoch 85/200
#
# Epoch 00085: val_accuracy improved from 0.76970 to 0.77020, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.3301 - accuracy: 0.8866 - val_loss: 0.7256 - val_accuracy: 0.7702
# Epoch 86/200
#
# Epoch 00086: val_accuracy did not improve from 0.77020
# 500/500 - 11s - loss: 0.3170 - accuracy: 0.8924 - val_loss: 0.7761 - val_accuracy: 0.7599
# Epoch 87/200
#
# Epoch 00087: val_accuracy improved from 0.77020 to 0.77390, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.3174 - accuracy: 0.8922 - val_loss: 0.7284 - val_accuracy: 0.7739
# Epoch 88/200
#
# Epoch 00088: val_accuracy did not improve from 0.77390
# 500/500 - 11s - loss: 0.3128 - accuracy: 0.8942 - val_loss: 0.7566 - val_accuracy: 0.7654
# Epoch 89/200
#
# Epoch 00089: val_accuracy did not improve from 0.77390
# 500/500 - 11s - loss: 0.3015 - accuracy: 0.8990 - val_loss: 0.7660 - val_accuracy: 0.7642
# Epoch 90/200
#
# Epoch 00090: val_accuracy did not improve from 0.77390
# 500/500 - 11s - loss: 0.2953 - accuracy: 0.9006 - val_loss: 0.7658 - val_accuracy: 0.7654
# Epoch 91/200
#
# Epoch 00091: val_accuracy did not improve from 0.77390
# 500/500 - 11s - loss: 0.2891 - accuracy: 0.9024 - val_loss: 0.7607 - val_accuracy: 0.7667
# Epoch 92/200
#
# Epoch 00092: val_accuracy did not improve from 0.77390
# 500/500 - 11s - loss: 0.2794 - accuracy: 0.9060 - val_loss: 0.7605 - val_accuracy: 0.7683
# Epoch 93/200
#
# Epoch 00093: val_accuracy improved from 0.77390 to 0.77550, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.2816 - accuracy: 0.9046 - val_loss: 0.7443 - val_accuracy: 0.7755
# Epoch 94/200
#
# Epoch 00094: val_accuracy did not improve from 0.77550
# 500/500 - 11s - loss: 0.2688 - accuracy: 0.9103 - val_loss: 0.7646 - val_accuracy: 0.7709
# Epoch 95/200
#
# Epoch 00095: val_accuracy did not improve from 0.77550
# 500/500 - 11s - loss: 0.2633 - accuracy: 0.9113 - val_loss: 0.8568 - val_accuracy: 0.7505
# Epoch 96/200
#
# Epoch 00096: val_accuracy did not improve from 0.77550
# 500/500 - 11s - loss: 0.2617 - accuracy: 0.9126 - val_loss: 0.7916 - val_accuracy: 0.7688
# Epoch 97/200
#
# Epoch 00097: val_accuracy did not improve from 0.77550
# 500/500 - 11s - loss: 0.2500 - accuracy: 0.9158 - val_loss: 0.7940 - val_accuracy: 0.7713
# Epoch 98/200
#
# Epoch 00098: val_accuracy did not improve from 0.77550
# 500/500 - 11s - loss: 0.2448 - accuracy: 0.9177 - val_loss: 0.7716 - val_accuracy: 0.7738
# Epoch 99/200
#
# Epoch 00099: val_accuracy did not improve from 0.77550
# 500/500 - 11s - loss: 0.2434 - accuracy: 0.9185 - val_loss: 0.8113 - val_accuracy: 0.7645
# Epoch 100/200
#
# Epoch 00100: val_accuracy improved from 0.77550 to 0.77800, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.2380 - accuracy: 0.9205 - val_loss: 0.7751 - val_accuracy: 0.7780
# Epoch 101/200
#
# Epoch 00101: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.2302 - accuracy: 0.9238 - val_loss: 0.7921 - val_accuracy: 0.7769
# Epoch 102/200
#
# Epoch 00102: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.2199 - accuracy: 0.9275 - val_loss: 0.7796 - val_accuracy: 0.7757
# Epoch 103/200
#
# Epoch 00103: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.2188 - accuracy: 0.9273 - val_loss: 0.8424 - val_accuracy: 0.7624
# Epoch 104/200
#
# Epoch 00104: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.2134 - accuracy: 0.9298 - val_loss: 0.8101 - val_accuracy: 0.7760
# Epoch 105/200
#
# Epoch 00105: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.2067 - accuracy: 0.9325 - val_loss: 0.8081 - val_accuracy: 0.7729
# Epoch 106/200
#
# Epoch 00106: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.2038 - accuracy: 0.9339 - val_loss: 0.8397 - val_accuracy: 0.7708
# Epoch 107/200
#
# Epoch 00107: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1991 - accuracy: 0.9335 - val_loss: 0.9193 - val_accuracy: 0.7551
# Epoch 108/200
#
# Epoch 00108: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1936 - accuracy: 0.9365 - val_loss: 0.8441 - val_accuracy: 0.7673
# Epoch 109/200
#
# Epoch 00109: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1879 - accuracy: 0.9388 - val_loss: 0.8233 - val_accuracy: 0.7772
# Epoch 110/200
#
# Epoch 00110: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1814 - accuracy: 0.9410 - val_loss: 0.8374 - val_accuracy: 0.7710
# Epoch 111/200
#
# Epoch 00111: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1772 - accuracy: 0.9428 - val_loss: 0.8725 - val_accuracy: 0.7675
# Epoch 112/200
#
# Epoch 00112: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1713 - accuracy: 0.9447 - val_loss: 0.8581 - val_accuracy: 0.7708
# Epoch 113/200
#
# Epoch 00113: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1634 - accuracy: 0.9477 - val_loss: 0.8494 - val_accuracy: 0.7746
# Epoch 114/200
#
# Epoch 00114: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1625 - accuracy: 0.9483 - val_loss: 0.8577 - val_accuracy: 0.7756
# Epoch 115/200
#
# Epoch 00115: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1624 - accuracy: 0.9472 - val_loss: 0.9052 - val_accuracy: 0.7689
# Epoch 116/200
#
# Epoch 00116: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1527 - accuracy: 0.9525 - val_loss: 0.9495 - val_accuracy: 0.7608
# Epoch 117/200
#
# Epoch 00117: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1468 - accuracy: 0.9546 - val_loss: 0.8614 - val_accuracy: 0.7779
# Epoch 118/200
#
# Epoch 00118: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1439 - accuracy: 0.9557 - val_loss: 0.8774 - val_accuracy: 0.7769
# Epoch 119/200
#
# Epoch 00119: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1383 - accuracy: 0.9578 - val_loss: 0.9065 - val_accuracy: 0.7711
# Epoch 120/200
#
# Epoch 00120: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1325 - accuracy: 0.9598 - val_loss: 0.9264 - val_accuracy: 0.7691
# Epoch 121/200
#
# Epoch 00121: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1305 - accuracy: 0.9593 - val_loss: 0.9210 - val_accuracy: 0.7697
# Epoch 122/200
#
# Epoch 00122: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1214 - accuracy: 0.9640 - val_loss: 0.9422 - val_accuracy: 0.7737
# Epoch 123/200
#
# Epoch 00123: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1202 - accuracy: 0.9646 - val_loss: 0.9373 - val_accuracy: 0.7743
# Epoch 124/200
#
# Epoch 00124: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1196 - accuracy: 0.9632 - val_loss: 0.9291 - val_accuracy: 0.7761
# Epoch 125/200
#
# Epoch 00125: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1082 - accuracy: 0.9695 - val_loss: 0.9382 - val_accuracy: 0.7777
# Epoch 126/200
#
# Epoch 00126: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1060 - accuracy: 0.9686 - val_loss: 0.9486 - val_accuracy: 0.7740
# Epoch 127/200
#
# Epoch 00127: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.1005 - accuracy: 0.9712 - val_loss: 0.9998 - val_accuracy: 0.7722
# Epoch 128/200
#
# Epoch 00128: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0992 - accuracy: 0.9716 - val_loss: 0.9873 - val_accuracy: 0.7733
# Epoch 129/200
#
# Epoch 00129: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0958 - accuracy: 0.9728 - val_loss: 0.9801 - val_accuracy: 0.7752
# Epoch 130/200
#
# Epoch 00130: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0960 - accuracy: 0.9728 - val_loss: 1.0255 - val_accuracy: 0.7681
# Epoch 131/200
#
# Epoch 00131: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0920 - accuracy: 0.9741 - val_loss: 1.0476 - val_accuracy: 0.7678
# Epoch 132/200
#
# Epoch 00132: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0872 - accuracy: 0.9755 - val_loss: 1.0070 - val_accuracy: 0.7759
# Epoch 133/200
#
# Epoch 00133: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0808 - accuracy: 0.9788 - val_loss: 1.0511 - val_accuracy: 0.7702
# Epoch 134/200
#
# Epoch 00134: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0812 - accuracy: 0.9769 - val_loss: 1.0460 - val_accuracy: 0.7694
# Epoch 135/200
#
# Epoch 00135: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0774 - accuracy: 0.9793 - val_loss: 1.0736 - val_accuracy: 0.7706
# Epoch 136/200
#
# Epoch 00136: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0741 - accuracy: 0.9807 - val_loss: 1.0658 - val_accuracy: 0.7691
# Epoch 137/200
#
# Epoch 00137: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0666 - accuracy: 0.9834 - val_loss: 1.0807 - val_accuracy: 0.7696
# Epoch 138/200
#
# Epoch 00138: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0662 - accuracy: 0.9837 - val_loss: 1.0831 - val_accuracy: 0.7688
# Epoch 139/200
#
# Epoch 00139: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0617 - accuracy: 0.9855 - val_loss: 1.0797 - val_accuracy: 0.7733
# Epoch 140/200
#
# Epoch 00140: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0625 - accuracy: 0.9844 - val_loss: 1.1033 - val_accuracy: 0.7736
# Epoch 141/200
#
# Epoch 00141: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0581 - accuracy: 0.9863 - val_loss: 1.0823 - val_accuracy: 0.7767
# Epoch 142/200
#
# Epoch 00142: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0550 - accuracy: 0.9868 - val_loss: 1.1550 - val_accuracy: 0.7674
# Epoch 143/200
#
# Epoch 00143: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0521 - accuracy: 0.9882 - val_loss: 1.1540 - val_accuracy: 0.7697
# Epoch 144/200
#
# Epoch 00144: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0533 - accuracy: 0.9876 - val_loss: 1.1498 - val_accuracy: 0.7687
# Epoch 145/200
#
# Epoch 00145: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0494 - accuracy: 0.9890 - val_loss: 1.1733 - val_accuracy: 0.7701
# Epoch 146/200
#
# Epoch 00146: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0475 - accuracy: 0.9895 - val_loss: 1.2160 - val_accuracy: 0.7660
# Epoch 147/200
#
# Epoch 00147: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0443 - accuracy: 0.9909 - val_loss: 1.2023 - val_accuracy: 0.7680
# Epoch 148/200
#
# Epoch 00148: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0446 - accuracy: 0.9905 - val_loss: 1.1885 - val_accuracy: 0.7767
# Epoch 149/200
#
# Epoch 00149: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0384 - accuracy: 0.9927 - val_loss: 1.1763 - val_accuracy: 0.7766
# Epoch 150/200
#
# Epoch 00150: val_accuracy did not improve from 0.77800
# 500/500 - 11s - loss: 0.0404 - accuracy: 0.9913 - val_loss: 1.2341 - val_accuracy: 0.7707
# Epoch 151/200
#
# Epoch 00151: val_accuracy improved from 0.77800 to 0.77850, saving model to gdrive/My Drive/Colab Notebooks/NoRegularization_1.h5
# 500/500 - 11s - loss: 0.0359 - accuracy: 0.9933 - val_loss: 1.1820 - val_accuracy: 0.7785
# Epoch 152/200
#
# Epoch 00152: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0317 - accuracy: 0.9951 - val_loss: 1.2206 - val_accuracy: 0.7770
# Epoch 153/200
#
# Epoch 00153: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0346 - accuracy: 0.9933 - val_loss: 1.2482 - val_accuracy: 0.7718
# Epoch 154/200
#
# Epoch 00154: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0347 - accuracy: 0.9929 - val_loss: 1.2265 - val_accuracy: 0.7737
# Epoch 155/200
#
# Epoch 00155: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0206 - accuracy: 0.9985 - val_loss: 1.2567 - val_accuracy: 0.7783
# Epoch 156/200
#
# Epoch 00156: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0318 - accuracy: 0.9938 - val_loss: 1.2437 - val_accuracy: 0.7770
# Epoch 157/200
#
# Epoch 00157: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0288 - accuracy: 0.9948 - val_loss: 1.2669 - val_accuracy: 0.7750
# Epoch 158/200
#
# Epoch 00158: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0287 - accuracy: 0.9947 - val_loss: 1.2618 - val_accuracy: 0.7767
# Epoch 159/200
#
# Epoch 00159: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0224 - accuracy: 0.9970 - val_loss: 1.2799 - val_accuracy: 0.7772
# Epoch 160/200
#
# Epoch 00160: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0268 - accuracy: 0.9953 - val_loss: 1.4029 - val_accuracy: 0.7630
# Epoch 161/200
#
# Epoch 00161: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0235 - accuracy: 0.9961 - val_loss: 1.3135 - val_accuracy: 0.7713
# Epoch 162/200
#
# Epoch 00162: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0230 - accuracy: 0.9967 - val_loss: 1.3085 - val_accuracy: 0.7771
# Epoch 163/200
#
# Epoch 00163: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0159 - accuracy: 0.9990 - val_loss: 1.3772 - val_accuracy: 0.7696
# Epoch 164/200
#
# Epoch 00164: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0213 - accuracy: 0.9965 - val_loss: 1.3629 - val_accuracy: 0.7692
# Epoch 165/200
#
# Epoch 00165: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0214 - accuracy: 0.9967 - val_loss: 1.3680 - val_accuracy: 0.7711
# Epoch 166/200
#
# Epoch 00166: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0206 - accuracy: 0.9964 - val_loss: 1.4145 - val_accuracy: 0.7676
# Epoch 167/200
#
# Epoch 00167: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0201 - accuracy: 0.9965 - val_loss: 1.4119 - val_accuracy: 0.7678
# Epoch 168/200
#
# Epoch 00168: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0103 - accuracy: 0.9998 - val_loss: 1.3678 - val_accuracy: 0.7778
# Epoch 169/200
#
# Epoch 00169: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0170 - accuracy: 0.9977 - val_loss: 1.3764 - val_accuracy: 0.7777
# Epoch 170/200
#
# Epoch 00170: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0107 - accuracy: 0.9992 - val_loss: 1.4061 - val_accuracy: 0.7762
# Epoch 171/200
#
# Epoch 00171: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0152 - accuracy: 0.9979 - val_loss: 1.4278 - val_accuracy: 0.7725
# Epoch 172/200
#
# Epoch 00172: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0082 - accuracy: 0.9999 - val_loss: 1.4191 - val_accuracy: 0.7768
# Epoch 173/200
#
# Epoch 00173: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0128 - accuracy: 0.9981 - val_loss: 1.4202 - val_accuracy: 0.7777
# Epoch 174/200
#
# Epoch 00174: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0071 - accuracy: 0.9999 - val_loss: 1.4387 - val_accuracy: 0.7746
# Epoch 175/200
#
# Epoch 00175: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0107 - accuracy: 0.9991 - val_loss: 1.4657 - val_accuracy: 0.7718
# Epoch 176/200
#
# Epoch 00176: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0106 - accuracy: 0.9989 - val_loss: 1.4784 - val_accuracy: 0.7712
# Epoch 177/200
#
# Epoch 00177: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0094 - accuracy: 0.9988 - val_loss: 1.4652 - val_accuracy: 0.7764
# Epoch 178/200
#
# Epoch 00178: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.4817 - val_accuracy: 0.7759
# Epoch 179/200
#
# Epoch 00179: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0120 - accuracy: 0.9979 - val_loss: 1.4776 - val_accuracy: 0.7752
# Epoch 180/200
#
# Epoch 00180: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.4907 - val_accuracy: 0.7750
# Epoch 181/200
#
# Epoch 00181: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0099 - accuracy: 0.9986 - val_loss: 1.4875 - val_accuracy: 0.7778
# Epoch 182/200
#
# Epoch 00182: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.5339 - val_accuracy: 0.7746
# Epoch 183/200
#
# Epoch 00183: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0084 - accuracy: 0.9989 - val_loss: 1.5419 - val_accuracy: 0.7736
# Epoch 184/200
#
# Epoch 00184: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.5472 - val_accuracy: 0.7756
# Epoch 185/200
#
# Epoch 00185: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0109 - accuracy: 0.9978 - val_loss: 1.5278 - val_accuracy: 0.7777
# Epoch 186/200
#
# Epoch 00186: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.5430 - val_accuracy: 0.7768
# Epoch 187/200
#
# Epoch 00187: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.5577 - val_accuracy: 0.7756
# Epoch 188/200
#
# Epoch 00188: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0075 - accuracy: 0.9988 - val_loss: 1.6325 - val_accuracy: 0.7675
# Epoch 189/200
#
# Epoch 00189: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0054 - accuracy: 0.9996 - val_loss: 1.5713 - val_accuracy: 0.7769
# Epoch 190/200
#
# Epoch 00190: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0091 - accuracy: 0.9981 - val_loss: 1.5741 - val_accuracy: 0.7757
# Epoch 191/200
#
# Epoch 00191: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.5719 - val_accuracy: 0.7765
# Epoch 192/200
#
# Epoch 00192: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.5901 - val_accuracy: 0.7769
# Epoch 193/200
#
# Epoch 00193: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0094 - accuracy: 0.9979 - val_loss: 1.6496 - val_accuracy: 0.7698
# Epoch 194/200
#
# Epoch 00194: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.5914 - val_accuracy: 0.7773
# Epoch 195/200
#
# Epoch 00195: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.6206 - val_accuracy: 0.7754
# Epoch 196/200
#
# Epoch 00196: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0140 - accuracy: 0.9962 - val_loss: 1.6074 - val_accuracy: 0.7767
# Epoch 197/200
#
# Epoch 00197: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.5997 - val_accuracy: 0.7775
# Epoch 198/200
#
# Epoch 00198: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.6156 - val_accuracy: 0.7769
# Epoch 199/200
#
# Epoch 00199: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0052 - accuracy: 0.9991 - val_loss: 1.8246 - val_accuracy: 0.7603
# Epoch 200/200
#
# Epoch 00200: val_accuracy did not improve from 0.77850
# 500/500 - 11s - loss: 0.0040 - accuracy: 0.9997 - val_loss: 1.6257 - val_accuracy: 0.7754

# %% [markdown]
# *Plotting training accuracy and loss*

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model Accuracy')
axs[0].set(ylabel ='accuracy')
axs[0].set(xlabel ='epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model Loss')
axs[1].set(ylabel='loss')
axs[1].set(xlabel='epoch')
axs[1].legend(['train', 'test'], loc='upper left')

# %% [markdown]
# **Prediction**

# %%
model.load_weights(path_best)
y_pred = np.argmax(model.predict(x_test_norm), axis=-1)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision: ", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall: ", recall)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Precision:  0.7789613716331782
# Recall:  0.7785
# Accuracy:  0.7785
